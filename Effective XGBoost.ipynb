# %% [markdown]
# # Datasets
#
# ### Cleaup & Loading

# %%
# Data Manipulation
import pandas as pd

# URL Library
import urllib.request
import zipfile

# %%
# Retrieving & storage
url = 'https://github.com/mattharrison/datasets/raw/master/data/'\
'kaggle-survey-2018.zip'
fname = 'kaggle-survey-2018.zip'
member_name = 'multipleChoiceResponses.csv'

# %%
# Function Extration
def extract_zip(src, dst, member_name):
    """Extract a member file from a zip file & read it into pandas
    DataFrame.
    
    Parameters:
        src '(str:)' URL of the zip file to be downloaded and extrated.
        dst 'str': Local file path where the zip file will be written.
        member_name: Name of the member file inside the zip file to be
            read into a DataFrame.
            
    Returns:
        pandas.DataFrame containing the contents of member file.
    """
    url = src
    fname = dst
    fin = urllib.request.urlopen(url)
    data = fin.read()
    with open(dst, mode='wb') as fout:
        fout.write(data)
    with zipfile.ZipFile(dst) as z:
        kag = pd.read_csv(z.open(member_name))
        kag_questions = kag.iloc[0]
        raw = kag.iloc[1:]
        return raw

# %%
raw = extract_zip(url, fname, member_name)
# Out:
# /var/folders/wh/l_q69dcj75z0c82jy8ry71f40000gn/T/ipykernel_18050/3680407660.py:22: DtypeWarning: Columns (0,2,8,10,21,23,24,25,26,27,28,44,56,64,83,85,87,107,109,123,125,150,157,172,174,194,210,218,219,223,246,249,262,264,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,304,306,325,326,329,341,368,371,384,385,389,390,391,393,394) have mixed types. Specify dtype option on import or set low_memory=False.
#   kag = pd.read_csv(z.open(member_name))

# %% [markdown]
# ## CleanUp Pipeline

# %%
def tweak_kag(df_: pd.DataFrame) -> pd.DataFrame:
    """
    Tweak the Kaggle survey data and return a new DataFrame.

    This function takes a Pandas DataFrame containing Kaggle 
    survey data as input and returns a new DataFrame. The 
    modifications include extracting and transforming certain 
    columns, renaming columns, and selecting a subset of columns.

    Parameters
    ----------
    df_ : pd.DataFrame
        The input DataFrame containing Kaggle survey data.

    Returns
    -------
    pd.DataFrame
        The new DataFrame with the modified and selected columns.
    """    
    return (df_
            .assign(age=df_.Q2.str.slice(0,2).astype(int),
                    education=df_.Q4.replace({'Master’s degree': 18,
                         'Bachelor’s degree': 16,
                         'Doctoral degree': 20,
'Some college/university study without earning a bachelor’s degree': 13,
                         'Professional degree': 19,
                         'I prefer not to answer': None,
                         'No formal education past high school': 12}),
                    major=(df_.Q5
                              .pipe(topn, n=3)
                              .replace({
                        'Computer science (software engineering, etc.)': 'cs',
                        'Engineering (non-computer focused)': 'eng',
                        'Mathematics or statistics': 'stat'})
                         ),
                    years_exp=(df_.Q8.str.replace('+','', regex=False)
                           .str.split('-', expand=True)
                           .iloc[:,0]
                           .astype(float)),
                    compensation=(df_.Q9.str.replace('+','', regex=False)
                           .str.replace(',','', regex=False)
                           .str.replace('500000', '500', regex=False)
  .str.replace('I do not wish to disclose my approximate yearly compensation',
             '0', regex=False)
                           .str.split('-', expand=True)
                           .iloc[:,0]
                           .fillna(0)
                           .astype(int)
                           .mul(1_000)
                                    ),
                    python=df_.Q16_Part_1.fillna(0).replace('Python', 1),
                    r=df_.Q16_Part_2.fillna(0).replace('R', 1),
                    sql=df_.Q16_Part_3.fillna(0).replace('SQL', 1)
               )#assign
        .rename(columns=lambda col:col.replace(' ', '_'))
        .loc[:, 'Q1,Q3,age,education,major,years_exp,compensation,'
                'python,r,sql'.split(',')]   
       )

# %%
def topn(ser, n=5, default='other'):
    counts = ser.value_counts()
    return ser.where(ser.isin(counts.index[:n]), default)

# %%
from feature_engine import encoding, imputation
from sklearn import base, pipeline
# Out:
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
class TweakKagTransformer(base.BaseEstimator, base.TransformerMixin):
    
    def __init__(self, ycol=None):
        self.ycol = ycol
        
    def transform(self, X):
        return tweak_kag(X)
    
    def fit(self, X, y=None):
        return self

# %%
def get_rawX_y(df, y_col):
    raw = (df
           .query('Q3.isin(["United States of America", "China", "India"]) '
              'and Q6.isin(["Data Scientist", "Software Engineer"])')
    )
    return raw.drop(columns=[y_col]), raw[y_col]

# %%
# Create Pipeline
kag_pl = pipeline.Pipeline(
    [('tweak', TweakKagTransformer()),
     ('cat', encoding.OneHotEncoder(top_categories=5, drop_last=True, variables=['Q1', 'Q3', 'major'])),
     ('num_impute', imputation.MeanMedianImputer(imputation_method='median', variables=['education', 'years_exp']))]
)

# %%
from sklearn import model_selection

# %%
kag_X, kag_y = get_rawX_y(raw, 'Q6')

kag_X_train, kag_X_test, kag_y_train, kag_y_test = \
model_selection.train_test_split(
    kag_X, kag_y, test_size=.3, random_state=42, stratify=kag_y)

# %%
X_train = kag_pl.fit_transform(kag_X_train, kag_y_train)

X_test = kag_pl.transform(kag_X_test)

# %%
print(X_train)
# Out:
#        age  education  years_exp  compensation  python  r  sql  Q1_Male  \
# 587     25       18.0        4.0             0       1  0    1        1
# 3065    22       16.0        1.0         10000       1  0    0        1
# 8435    22       18.0        1.0             0       1  0    0        1
# 3110    40       20.0        3.0        125000       1  0    1        0
# 16372   45       12.0        5.0        100000       1  0    1        1
# ...    ...        ...        ...           ...     ... ..  ...      ...
# 16608   25       16.0        2.0         10000       0  0    1        1
# 7325    18       16.0        1.0         30000       1  0    1        1
# 21810   18       16.0        2.0             0       0  0    0        1
# 4917    25       18.0        1.0        100000       1  0    1        1
# 639     25       18.0        1.0         10000       1  0    0        0
#
#        Q1_Female  Q1_Prefer not to say  Q1_Prefer to self-describe  \
# 587            0                     0                           0
# 3065           0                     0                           0
# 8435           0                     0                           0
# 3110           1                     0                           0
# 16372          0                     0                           0
# ...          ...                   ...                         ...
# 16608          0                     0                           0
# 7325           0                     0                           0
# 21810          0                     0                           0
# 4917           0                     0                           0
# 639            1                     0                           0
#
#        Q3_United States of America  Q3_India  Q3_China  major_cs  major_other  \
# 587                              0         1         0         0            1
# 3065                             0         1         0         1            0
# 8435                             0         1         0         0            1
# 3110                             1         0         0         0            1
# 16372                            1         0         0         0            1
# ...                            ...       ...       ...       ...          ...
# 16608                            0         1         0         1            0
# 7325                             1         0         0         1            0
# 21810                            0         1         0         1            0
# 4917                             1         0         0         0            0
# 639                              0         1         0         1            0
#
#        major_eng  major_stat
# 587            0           0
# 3065           0           0
# 8435           0           0
# 3110           0           0
# 16372          0           0
# ...          ...         ...
# 16608          0           0
# 7325           0           0
# 21810          0           0
# 4917           0           1
# 639            0           0
#
# [2110 rows x 18 columns]

# %%
kag_y_train
# Out:
# 587      Software Engineer
# 3065        Data Scientist
# 8435        Data Scientist
# 3110        Data Scientist
# 16372    Software Engineer
#                ...
# 16608    Software Engineer
# 7325     Software Engineer
# 21810       Data Scientist
# 4917        Data Scientist
# 639         Data Scientist
# Name: Q6, Length: 2110, dtype: object

# %% [markdown]
# ## Exploratory Data Analysis

# %%
(X_train
 .assign(data_scientist = kag_y_train == 'Data Scientist')
 .corr(method='spearman')
 .style
 .background_gradient(cmap='RdBu', vmax=1, vmin=-1)
 .set_sticky(axis='index')
)
# Out:
# <style type="text/css">
# #T_efbfb thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_efbfb tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# #T_efbfb_row0_col0, #T_efbfb_row1_col1, #T_efbfb_row2_col2, #T_efbfb_row3_col3, #T_efbfb_row4_col4, #T_efbfb_row5_col5, #T_efbfb_row6_col6, #T_efbfb_row7_col7, #T_efbfb_row8_col8, #T_efbfb_row9_col9, #T_efbfb_row10_col10, #T_efbfb_row11_col11, #T_efbfb_row12_col12, #T_efbfb_row13_col13, #T_efbfb_row14_col14, #T_efbfb_row15_col15, #T_efbfb_row16_col16, #T_efbfb_row17_col17, #T_efbfb_row18_col18 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_efbfb_row0_col1, #T_efbfb_row1_col0 {
#   background-color: #a2cde3;
#   color: #000000;
# }
# #T_efbfb_row0_col2, #T_efbfb_row2_col0 {
#   background-color: #3b88be;
#   color: #f1f1f1;
# }
# #T_efbfb_row0_col3, #T_efbfb_row3_col0 {
#   background-color: #7eb8d7;
#   color: #000000;
# }
# #T_efbfb_row0_col4, #T_efbfb_row0_col10, #T_efbfb_row2_col17, #T_efbfb_row4_col0, #T_efbfb_row4_col7, #T_efbfb_row7_col4, #T_efbfb_row9_col11, #T_efbfb_row10_col0, #T_efbfb_row10_col11, #T_efbfb_row11_col9, #T_efbfb_row11_col10, #T_efbfb_row17_col2 {
#   background-color: #eff3f5;
#   color: #000000;
# }
# #T_efbfb_row0_col5, #T_efbfb_row5_col0, #T_efbfb_row8_col11, #T_efbfb_row11_col8 {
#   background-color: #deebf2;
#   color: #000000;
# }
# #T_efbfb_row0_col6, #T_efbfb_row5_col15, #T_efbfb_row6_col0, #T_efbfb_row15_col5 {
#   background-color: #ddebf2;
#   color: #000000;
# }
# #T_efbfb_row0_col7, #T_efbfb_row2_col5, #T_efbfb_row4_col16, #T_efbfb_row4_col17, #T_efbfb_row5_col2, #T_efbfb_row7_col0, #T_efbfb_row9_col15, #T_efbfb_row15_col9, #T_efbfb_row16_col4, #T_efbfb_row17_col4 {
#   background-color: #f5f6f7;
#   color: #000000;
# }
# #T_efbfb_row0_col8, #T_efbfb_row3_col9, #T_efbfb_row8_col0, #T_efbfb_row8_col16, #T_efbfb_row9_col3, #T_efbfb_row9_col12, #T_efbfb_row10_col12, #T_efbfb_row12_col9, #T_efbfb_row12_col10, #T_efbfb_row13_col17, #T_efbfb_row16_col8, #T_efbfb_row17_col13 {
#   background-color: #f8f2ef;
#   color: #000000;
# }
# #T_efbfb_row0_col9, #T_efbfb_row2_col6, #T_efbfb_row3_col10, #T_efbfb_row4_col11, #T_efbfb_row6_col2, #T_efbfb_row7_col13, #T_efbfb_row9_col0, #T_efbfb_row10_col3, #T_efbfb_row10_col15, #T_efbfb_row11_col4, #T_efbfb_row13_col7, #T_efbfb_row15_col10 {
#   background-color: #edf2f5;
#   color: #000000;
# }
# #T_efbfb_row0_col11, #T_efbfb_row11_col0 {
#   background-color: #9bc9e0;
#   color: #000000;
# }
# #T_efbfb_row0_col12, #T_efbfb_row12_col0 {
#   background-color: #f6af8e;
#   color: #000000;
# }
# #T_efbfb_row0_col13, #T_efbfb_row4_col13, #T_efbfb_row5_col16, #T_efbfb_row6_col10, #T_efbfb_row8_col10, #T_efbfb_row10_col6, #T_efbfb_row10_col8, #T_efbfb_row10_col14, #T_efbfb_row10_col16, #T_efbfb_row10_col17, #T_efbfb_row13_col0, #T_efbfb_row13_col4, #T_efbfb_row14_col10, #T_efbfb_row16_col5, #T_efbfb_row16_col10, #T_efbfb_row17_col10 {
#   background-color: #f8f4f2;
#   color: #000000;
# }
# #T_efbfb_row0_col14, #T_efbfb_row3_col14, #T_efbfb_row7_col9, #T_efbfb_row9_col7, #T_efbfb_row14_col0, #T_efbfb_row14_col3 {
#   background-color: #fcd5bf;
#   color: #000000;
# }
# #T_efbfb_row0_col15, #T_efbfb_row3_col6, #T_efbfb_row6_col3, #T_efbfb_row15_col0, #T_efbfb_row15_col18, #T_efbfb_row18_col15 {
#   background-color: #d1e5f0;
#   color: #000000;
# }
# #T_efbfb_row0_col16, #T_efbfb_row1_col10, #T_efbfb_row2_col16, #T_efbfb_row3_col7, #T_efbfb_row3_col8, #T_efbfb_row5_col9, #T_efbfb_row7_col3, #T_efbfb_row8_col3, #T_efbfb_row9_col5, #T_efbfb_row10_col1, #T_efbfb_row16_col0, #T_efbfb_row16_col2 {
#   background-color: #f6f7f7;
#   color: #000000;
# }
# #T_efbfb_row0_col17, #T_efbfb_row0_col18, #T_efbfb_row6_col17, #T_efbfb_row17_col0, #T_efbfb_row17_col6, #T_efbfb_row18_col0 {
#   background-color: #e9f0f4;
#   color: #000000;
# }
# #T_efbfb_row1_col2, #T_efbfb_row2_col1, #T_efbfb_row4_col15, #T_efbfb_row15_col4 {
#   background-color: #e4eef4;
#   color: #000000;
# }
# #T_efbfb_row1_col3, #T_efbfb_row3_col1, #T_efbfb_row3_col15, #T_efbfb_row12_col14, #T_efbfb_row14_col12, #T_efbfb_row15_col3 {
#   background-color: #c5dfec;
#   color: #000000;
# }
# #T_efbfb_row1_col4, #T_efbfb_row1_col9, #T_efbfb_row4_col1, #T_efbfb_row9_col1 {
#   background-color: #ecf2f5;
#   color: #000000;
# }
# #T_efbfb_row1_col5, #T_efbfb_row5_col1, #T_efbfb_row11_col17, #T_efbfb_row17_col11 {
#   background-color: #dae9f2;
#   color: #000000;
# }
# #T_efbfb_row1_col6, #T_efbfb_row1_col8, #T_efbfb_row5_col8, #T_efbfb_row6_col1, #T_efbfb_row7_col14, #T_efbfb_row8_col1, #T_efbfb_row8_col5, #T_efbfb_row8_col15, #T_efbfb_row13_col14, #T_efbfb_row14_col7, #T_efbfb_row14_col13, #T_efbfb_row15_col8 {
#   background-color: #eaf1f5;
#   color: #000000;
# }
# #T_efbfb_row1_col7, #T_efbfb_row7_col1 {
#   background-color: #f9ebe3;
#   color: #000000;
# }
# #T_efbfb_row1_col11, #T_efbfb_row1_col18, #T_efbfb_row11_col1, #T_efbfb_row11_col15, #T_efbfb_row15_col11, #T_efbfb_row18_col1 {
#   background-color: #bbdaea;
#   color: #000000;
# }
# #T_efbfb_row1_col12, #T_efbfb_row11_col14, #T_efbfb_row12_col1, #T_efbfb_row14_col11 {
#   background-color: #fac8af;
#   color: #000000;
# }
# #T_efbfb_row1_col13, #T_efbfb_row1_col16, #T_efbfb_row4_col9, #T_efbfb_row4_col10, #T_efbfb_row5_col10, #T_efbfb_row9_col4, #T_efbfb_row9_col10, #T_efbfb_row10_col4, #T_efbfb_row10_col5, #T_efbfb_row10_col9, #T_efbfb_row13_col1, #T_efbfb_row16_col1 {
#   background-color: #f7f6f6;
#   color: #000000;
# }
# #T_efbfb_row1_col14, #T_efbfb_row14_col1 {
#   background-color: #fcd7c2;
#   color: #000000;
# }
# #T_efbfb_row1_col15, #T_efbfb_row3_col4, #T_efbfb_row3_col5, #T_efbfb_row4_col3, #T_efbfb_row5_col3, #T_efbfb_row6_col11, #T_efbfb_row11_col6, #T_efbfb_row15_col1 {
#   background-color: #d7e8f1;
#   color: #000000;
# }
# #T_efbfb_row1_col17, #T_efbfb_row2_col11, #T_efbfb_row4_col18, #T_efbfb_row6_col18, #T_efbfb_row11_col2, #T_efbfb_row17_col1, #T_efbfb_row18_col4, #T_efbfb_row18_col6 {
#   background-color: #e0ecf3;
#   color: #000000;
# }
# #T_efbfb_row2_col3, #T_efbfb_row3_col2 {
#   background-color: #c0dceb;
#   color: #000000;
# }
# #T_efbfb_row2_col4, #T_efbfb_row3_col16, #T_efbfb_row4_col2, #T_efbfb_row16_col3 {
#   background-color: #f9efe9;
#   color: #000000;
# }
# #T_efbfb_row2_col7, #T_efbfb_row7_col2, #T_efbfb_row12_col16, #T_efbfb_row16_col12 {
#   background-color: #e7f0f4;
#   color: #000000;
# }
# #T_efbfb_row2_col8, #T_efbfb_row4_col14, #T_efbfb_row7_col10, #T_efbfb_row8_col2, #T_efbfb_row10_col7, #T_efbfb_row14_col4 {
#   background-color: #fae9df;
#   color: #000000;
# }
# #T_efbfb_row2_col9, #T_efbfb_row6_col8, #T_efbfb_row8_col6, #T_efbfb_row8_col17, #T_efbfb_row9_col2, #T_efbfb_row17_col8 {
#   background-color: #f0f4f6;
#   color: #000000;
# }
# #T_efbfb_row2_col10, #T_efbfb_row2_col15, #T_efbfb_row9_col17, #T_efbfb_row9_col18, #T_efbfb_row10_col2, #T_efbfb_row10_col18, #T_efbfb_row15_col2, #T_efbfb_row16_col18, #T_efbfb_row17_col9, #T_efbfb_row18_col9, #T_efbfb_row18_col10, #T_efbfb_row18_col16 {
#   background-color: #f3f5f6;
#   color: #000000;
# }
# #T_efbfb_row2_col12, #T_efbfb_row5_col13, #T_efbfb_row12_col2, #T_efbfb_row12_col17, #T_efbfb_row13_col5, #T_efbfb_row17_col12 {
#   background-color: #fbe4d6;
#   color: #000000;
# }
# #T_efbfb_row2_col13, #T_efbfb_row7_col16, #T_efbfb_row9_col16, #T_efbfb_row13_col2, #T_efbfb_row16_col7, #T_efbfb_row16_col9 {
#   background-color: #f2f5f6;
#   color: #000000;
# }
# #T_efbfb_row2_col14, #T_efbfb_row4_col8, #T_efbfb_row4_col12, #T_efbfb_row7_col17, #T_efbfb_row8_col4, #T_efbfb_row8_col9, #T_efbfb_row9_col8, #T_efbfb_row9_col14, #T_efbfb_row12_col4, #T_efbfb_row14_col2, #T_efbfb_row14_col9, #T_efbfb_row17_col7 {
#   background-color: #f8f1ed;
#   color: #000000;
# }
# #T_efbfb_row2_col18, #T_efbfb_row7_col11, #T_efbfb_row11_col7, #T_efbfb_row18_col2 {
#   background-color: #fbe3d4;
#   color: #000000;
# }
# #T_efbfb_row3_col11, #T_efbfb_row11_col3 {
#   background-color: #408fc1;
#   color: #f1f1f1;
# }
# #T_efbfb_row3_col12, #T_efbfb_row12_col3 {
#   background-color: #dc6e57;
#   color: #f1f1f1;
# }
# #T_efbfb_row3_col13, #T_efbfb_row13_col3 {
#   background-color: #fbe6da;
#   color: #000000;
# }
# #T_efbfb_row3_col17, #T_efbfb_r

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 4))
(X_train
 .assign(data_scientist = kag_y_train)
 .groupby('r')
 .data_scientist
 .value_counts()
 .unstack()
 .plot.bar(ax=ax)
)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 4))
(pd.crosstab(index=X_train['major_cs'],
             columns=kag_y)
 .plot.bar(ax=ax)
)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 4))
(X_train
 .plot.scatter(x='years_exp', y='compensation', alpha=.3, ax=ax, c='purple')
)

plt.show()

# %% [markdown]
# #### adding Jitter

# %%
import seaborn.objects as so

# %%
fig = plt.figure(figsize=(8, 4))
(so
 .Plot(X_train.assign(title=kag_y_train), x='years_exp', y='compensation', color='title')
 .add(so.Dots(alpha=.3, pointsize=2), so.Jitter(x=.5, y=10_000))
 .add(so.Line(), so.PolyFit())
 .on(fig)
 .plot()
)

# %% [markdown]
# #### Adjusted Visualization

# %%
fig = plt.figure(figsize=(8, 4))
(so
 .Plot(X_train
       # .query('compensation < 200_000 and years_exp < 16')
       .assign(
           title=kag_y_train,
           country=(X_train
                    .loc[:, 'Q3_United States of America': 'Q3_China']
                    .idxmax(axis='columns')
                   )
       ), x='years_exp', y='compensation', color='title')
 .facet('country')
 .add(so.Dots(alpha=.01, pointsize=2, color='grey'), so.Jitter(x=.5, y=10_000), col=None)
 .add(so.Dots(alpha=.5, pointsize=1.5), so.Jitter(x=.5, y=10_000))
 .add(so.Line(pointsize=1), so.PolyFit(order=2))
 .scale(x=so.Continuous().tick(at=[0, 1, 2, 3, 4, 5]))
 .limit(y=(-10_000, 200_000), x=(-1, 6))
 .on(fig)
 .plot()
 )

# %% [markdown]
# ## Tree Creation

# %%
# Numerical Manipualtion
import numpy as np
import numpy.random as rn

# %%
pos_center = 12
pos_count = 100
neg_center = 7
neg_count = 1000

rs = rn.RandomState(rn.MT19937(rn.SeedSequence(42)))
gini = pd.DataFrame({'value':
                      np.append((pos_center) + rs.randn(pos_count),
                               (neg_center) + rs.randn(neg_count)),
                      'label':
                      ['pos']* pos_count + ['neg'] * neg_count})

# %%
fig, ax = plt.subplots(figsize=(8, 4))
_ = (gini
     .groupby('label')
     [['value']]
     .plot.hist(bins=30, alpha=.5, ax=ax, edgecolor='black')
    )
ax.legend(['Negative', 'Positive'])

plt.show()

# %%
def calc_gini(df, val_col, label_col, pos_val, split_point,
             debug=False):
    """
    This function calculates the Gini impurity of a dataset. Gini Impurity
    is a measure of the probability of a random sample being classified
    incorectly when a feature is sued to split the data. The lower the 
    impurity, the better the split.
    
    Parameters:
    df(pd.DataFrame): The dataframe containing the data
    val_col (str): the column name of the feature used to split the data
    label_col (str): The column name of the target variable
    pos_val (str or int): The value of the target variable that represents
        the positive class
    split_point (float): The threshold used to split the data.
    debug (bool): optional, when set to True, prints the calculated Gini
        impurities and the final weighted aveerage
        
    Returns:
    float: The weighted average of Gini impurity for the positive and
        negative subsets.
    """
    ge_split = df[val_col] >= split_point
    eq_pos = df[label_col] == pos_val
    tp = df[ge_split & eq_pos].shape[0]
    fp = df[ge_split & ~eq_pos].shape[0]
    tn = df[~ge_split & ~eq_pos].shape[0]
    fn = df[~ge_split & eq_pos].shape[0]
    pos_size = tp+fp
    neg_size = tn+fn
    total_size = len(df)
    if pos_size == 0:
        gini_pos = 0
    else:
        gini_pos = 1 - (tp/pos_size)**2 - (fp/pos_size)**2
    if neg_size == 0:
        gini_neg = 0
    else:
        gini_neg = 1 - (tn/neg_size)**2 - (fn/neg_size)**2
    weighted_avg = gini_pos * (pos_size/total_size) * \
    gini_neg * (neg_size/total_size)
    if debug:
        print(f'{gini_pos=:3} {gini_neg=:.3} {weighted_avg=:3}')
    return weighted_avg

# %%
calc_gini(gini, val_col='value', label_col='label', pos_val='pos', split_point=9.24, debug=True)
# Out:
# gini_pos=0.21708826063121614 gini_neg=0.00202 weighted_avg=4.050598243782082e-05
# 4.050598243782082e-05

# %%
values = np.arange(5, 15, .1)
ginis = []
for v in values:
    ginis.append(calc_gini(gini, val_col='value', label_col='label',
                          pos_val='pos', split_point=v))

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(values, ginis)
ax.set_title('Gini Coefficient')
ax.set_ylabel('Gini Coefficient')
ax.set_xlabel('Split Point')

plt.show()

# %%
pd.Series(ginis, index=values).loc[9.5:10.5]
# Out:
# 9.6     0.000022
# 9.7     0.000016
# 9.8     0.000013
# 9.9     0.000007
# 10.0    0.000010
# 10.1    0.000000
# 10.2    0.000000
# 10.3    0.000000
# 10.4    0.000000
# 10.5    0.000000
# dtype: float64

# %%
print(pd.DataFrame({'gini':ginis, 'split':values})
      .query('gini <= gini.min()'))
# Out:
#     gini  split
# 0    0.0    5.0
# 1    0.0    5.1
# 2    0.0    5.2
# 3    0.0    5.3
# 4    0.0    5.4
# ..   ...    ...
# 95   0.0   14.5
# 96   0.0   14.6
# 97   0.0   14.7
# 98   0.0   14.8
# 99   0.0   14.9
#
# [90 rows x 2 columns]

# %% [markdown]
# #### Coeffiecients in Trees

# %%
from sklearn import tree
stump = tree.DecisionTreeClassifier(max_depth=1)
stump.fit(gini[['value']], gini.label)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
fig, ax = plt.subplots(figsize=(8, 4))
tree.plot_tree(stump, feature_names=['value'],
               filled=True, 
               class_names=stump.classes_,
               ax=ax)
# Out:
# [Text(0.5, 0.75, 'value <= 9.708\ngini = 0.165\nsamples = 1100\nvalue = [1000, 100]\nclass = neg'),
#  Text(0.25, 0.25, 'gini = 0.002\nsamples = 999\nvalue = [998, 1]\nclass = neg'),
#  Text(0.75, 0.25, 'gini = 0.039\nsamples = 101\nvalue = [2, 99]\nclass = pos')]

# %%
gini_pos = 0.039
gini_neg = 0.002
pos_size = 101
neg_size = 999
total_size = pos_size + neg_size
weighted_avg = gini_pos * (pos_size/total_size) + \
gini_neg * (neg_size/total_size)

# %%
print(weighted_avg)
# Out:
# 0.005397272727272727

# %%
import xgboost as xgb

# %%
# from graphviz import Digraph

# dot = Digraph(comment='The Round Table')
# dot.node('A', 'King Arthur')
# dot.node('B', 'Sir Bedevere the Wise')
# dot.node('L', 'Sir Lancelot the Brave')

# dot.edges(['AB', 'AL'])
# dot.edge('B', 'L', constraint='false')
# print(dot.source)

# %%
xg_stump = xgb.XGBClassifier(n_estimators=1, max_depth=1)
xg_stump.fit(gini[['value']], (gini.label== 'pos'))
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=1, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=1, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
import os
os.environ["PATH"] += os.pathsep + '/Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/bin'


xgb.plot_tree(xg_stump, num_trees=0)

plt.show()

# %%
import subprocess

def my_dot_export(xg, num_trees, filename, title='', direction='TB'):
    """Exports a specified number of trees from an XGBoost model as a graph 
    visualization in dot and png formats.

    Args:
        xg: An XGBoost model.
        num_trees: The number of tree to export.
        filename: The name of the file to save the exported visualization.
        title: The title to display on the graph visualization (optional).
        direction: The direction to lay out the graph, either 'TB' (top to 
            bottom) or 'LR' (left to right) (optional).
    """
    res = xgb.to_graphviz(xg, num_trees=num_trees)
    content = f'''    node [fontname = "Helvetica"];
    edge [fontname = "Helvetica Thin"];
    label = "{title}"
    fontname = "Helvetica"
    '''
    out = res.source.replace('graph [ rankdir=TB ]', 
                             f'graph [ rankdir={direction} ];\n {content}')
    # dot -Gdpi=300 -Tpng -ocourseflow.png courseflow.dot 
    dot_filename = filename
    with open(dot_filename, 'w') as fout:
        fout.write(out)
    png_filename = dot_filename.replace('.dot', '.png')
    subprocess.run(f'dot -Gdpi=300 -Tpng -o{png_filename} {dot_filename}'.split())

# %%
my_dot_export(xg_stump, num_trees=0, filename='/Users/isisromero/Desktop/img_XGB/stump_xg.dot', title='A demo stump')

# %% [markdown]
# #### Another Visualization Tool

# %%
import dtreeviz
viz = dtreeviz.model(xg_stump, X_train=gini[['value']], 
                     y_train=gini.label=='pos',
    target_name='positive',
    feature_names=['value'], class_names=['negative', 'positive'],
    tree_index=0)
viz.view()

# %% [markdown]
# ## Stumps on Real Data

# %%
stump_dt = tree.DecisionTreeClassifier(max_depth=1)
X_train = kag_pl.fit_transform(kag_X_train)
stump_dt.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
fig, ax = plt.subplots(figsize=(8, 4))
features = list(c for c in X_train.columns)
tree.plot_tree(stump_dt, feature_names=features,
               filled=True,
               class_names=stump_dt.classes_,
               ax=ax)
# Out:
# [Text(0.5, 0.75, 'r <= 0.5\ngini = 0.496\nsamples = 2110\nvalue = [1153, 957]\nclass = Data Scientist'),
#  Text(0.25, 0.25, 'gini = 0.493\nsamples = 1484\nvalue = [653, 831]\nclass = Software Engineer'),
#  Text(0.75, 0.25, 'gini = 0.322\nsamples = 626\nvalue = [500, 126]\nclass = Data Scientist')]

# %%
X_test = kag_pl.transform(kag_X_test)

# %%
stump_dt.score(X_test, kag_y_test)
# Out:
# 0.6243093922651933

# %% [markdown]
# #### The Dummy Classifier

# %%
from sklearn import dummy

# %%
dummy_model = dummy.DummyClassifier()

# %%
dummy_model.fit(X_train, kag_y_train)
# Out:
# DummyClassifier()

# %%
dummy_model.score(X_test, kag_y_test)
# Out:
# 0.5458563535911602

# %%
import xgboost as xgb

# %%
kag_stump = xgb.XGBClassifier(n_estimators=1, max_depth=1)
kag_stump.fit(X_train, kag_y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 2
#       1 kag_stump = xgb.XGBClassifier(n_estimators=1, max_depth=1)
# ----> 2 kag_stump.fit(X_train, kag_y_train)
#
# File ~/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/xgboost/sklearn.py:1440, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1435     expected_classes = np.arange(self.n_classes_)
#    1436 if (
#    1437     self.classes_.shape != expected_classes.shape
#    1438     or not (self.classes_ == expected_classes).all()
#    1439 ):
# -> 1440     raise ValueError(
#    1441         f"Invalid classes inferred from unique values of `y`.  "
#    1442         f"Expected: {expected_classes}, got {self.classes_}"
#    1443     )
#    1445 params = self.get_xgb_params()
#    1447 if callable(self.objective):
#
# ValueError: Invalid classes inferred from unique values of `y`.  Expected: [0 1], got ['Data Scientist' 'Software Engineer']

# %%
print(kag_y_train)
# Out:
# 587      Software Engineer
# 3065        Data Scientist
# 8435        Data Scientist
# 3110        Data Scientist
# 16372    Software Engineer
#                ...
# 16608    Software Engineer
# 7325     Software Engineer
# 21810       Data Scientist
# 4917        Data Scientist
# 639         Data Scientist
# Name: Q6, Length: 2110, dtype: object

# %%
print(kag_y_train == 'Software Engineer')
# Out:
# 587       True
# 3065     False
# 8435     False
# 3110     False
# 16372     True
#          ...
# 16608     True
# 7325      True
# 21810    False
# 4917     False
# 639      False
# Name: Q6, Length: 2110, dtype: bool

# %% [markdown]
# #### Using Label Encoder

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
y_train = label_encoder.fit_transform(kag_y_train)
y_test = label_encoder.transform(kag_y_test)

# %%
y_test[:5]
# Out:
# array([1, 0, 0, 1, 1])

# %%
label_encoder.classes_
# Out:
# array(['Data Scientist', 'Software Engineer'], dtype=object)

# %%
# Inverse Tranformation Procedure
label_encoder.inverse_transform([0, 1])
# Out:
# array(['Data Scientist', 'Software Engineer'], dtype=object)

# %%
kag_stump = xgb.XGBClassifier(n_estimators=1, max_depth=1)
kag_stump.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=1, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=1, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
kag_stump.score(X_test, y_test)
# Out:
# 0.6243093922651933

# %%
my_dot_export(kag_stump, num_trees=0, filename='/Users/isisromero/Desktop/img_XGB/stump_xg.dot',
             title='XGBoost Stump')

# %%
kag_stump.classes_
# Out:
# array([0, 1])

# %%
def inv_logit(p: float) -> float:
    """
    Compute the inverse logit function of a given value.

    The inverse logit function is defined as:
        f(p) = exp(p) / (1 + exp(p))

    Parameters
    ----------
    p : float
        The input value to the inverse logit function.

    Returns
    -------
    float
        The output of the inverse logit function.
    """
    return np.exp(p) / (1 + np.exp(p))

# %%
inv_logit(.07117741922)
# Out:
# 0.5177868460919524

# %%
inv_logit(-.3592)
# Out:
# 0.41115323716754393

# %%
fig, ax = plt.subplots(figsize=(8, 4))
vals = np.linspace(-7, 7)
ax.plot(vals, inv_logit(vals))
ax.annotate('Crossover point', (0,.5), (-5,.8), arrowprops={'color':'k'})
ax.annotate('Predict Positive', (5,.6), (1,.6), va='center', arrowprops={'color':'k'})
ax.annotate('Predict Negative', (-5,.4), (-3,.4), va='center', arrowprops={'color':'k'})
# Out:
# Text(-3, 0.4, 'Predict Negative')

# %% [markdown]
# ## Model Complexity & Hyperparameters
#
# #### Underfit Model

# %%
underfit = tree.DecisionTreeClassifier(max_depth=1)
X_train = kag_pl.fit_transform(kag_X_train)

# %%
underfit.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
underfit.score(X_test, kag_y_test)
# Out:
# 0.6243093922651933

# %% [markdown]
# #### Overfitting with Decision Trees

# %%
hi_variance = tree.DecisionTreeClassifier(max_depth=None)
X_train = kag_pl.fit_transform(kag_X_train)

# %%
hi_variance.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier()

# %%
hi_variance.score(X_test, kag_y_test)
# Out:
# 0.6674033149171271

# %%
fig, ax = plt.subplots(figsize=(8, 4))
features = list(c for c in X_train.columns)
tree.plot_tree(hi_variance, feature_names=features, filled=True)
# Out:
# [Text(0.6590059822396963, 0.9761904761904762, 'r <= 0.5\ngini = 0.496\nsamples = 2110\nvalue = [1153, 957]'),
#  Text(0.39967546773318874, 0.9285714285714286, 'major_cs <= 0.5\ngini = 0.493\nsamples = 1484\nvalue = [653, 831]'),
#  Text(0.19505151843817786, 0.8809523809523809, 'Q3_United States of America <= 0.5\ngini = 0.49\nsamples = 718\nvalue = [410, 308]'),
#  Text(0.08274132321041215, 0.8333333333333334, 'years_exp <= 0.5\ngini = 0.491\nsamples = 322\nvalue = [140, 182]'),
#  Text(0.026464208242950107, 0.7857142857142857, 'education <= 17.0\ngini = 0.463\nsamples = 74\nvalue = [47, 27]'),
#  Text(0.019956616052060738, 0.7380952380952381, 'age <= 27.5\ngini = 0.499\nsamples = 40\nvalue = [21, 19]'),
#  Text(0.01822125813449024, 0.6904761904761905, 'major_stat <= 0.5\ngini = 0.5\nsamples = 38\nvalue = [19, 19]'),
#  Text(0.01648590021691974, 0.6428571428571429, 'compensation <= 55000.0\ngini = 0.498\nsamples = 36\nvalue = [17, 19]'),
#  Text(0.01475054229934924, 0.5952380952380952, 'compensation <= 15000.0\ngini = 0.5\nsamples = 35\nvalue = [17, 18]'),
#  Text(0.013015184381778741, 0.5476190476190477, 'python <= 0.5\ngini = 0.496\nsamples = 33\nvalue = [15, 18]'),
#  Text(0.008676789587852495, 0.5, 'age <= 23.5\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.005206073752711497, 0.4523809523809524, 'Q1_Female <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.0034707158351409977, 0.40476190476190477, 'age <= 20.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.0017353579175704988, 0.35714285714285715, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.005206073752711497, 0.35714285714285715, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.006941431670281995, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.012147505422993492, 0.4523809523809524, 'Q3_India <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.010412147505422993, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01388286334056399, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.01735357917570499, 0.5, 'Q1_Male <= 0.5\ngini = 0.5\nsamples = 22\nvalue = [11, 11]'),
#  Text(0.015618221258134491, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.01908893709327549, 0.4523809523809524, 'Q3_China <= 0.5\ngini = 0.495\nsamples = 20\nvalue = [9, 11]'),
#  Text(0.01735357917570499, 0.40476190476190477, 'compensation <= 5000.0\ngini = 0.488\nsamples = 19\nvalue = [8, 11]'),
#  Text(0.013015184381778741, 0.35714285714285715, 'age <= 20.0\ngini = 0.469\nsamples = 16\nvalue = [6, 10]'),
#  Text(0.009544468546637744, 0.30952380952380953, 'education <= 14.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.0078091106290672455, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.011279826464208243, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.01648590021691974, 0.30952380952380953, 'age <= 23.5\ngini = 0.426\nsamples = 13\nvalue = [4, 9]'),
#  Text(0.01475054229934924, 0.2619047619047619, 'sql <= 0.5\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.011279826464208243, 0.21428571428571427, 'major_other <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.009544468546637744, 0.16666666666666666, 'gini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.013015184381778741, 0.16666666666666666, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.01822125813449024, 0.21428571428571427, 'major_eng <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.01648590021691974, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.019956616052060738, 0.16666666666666666, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.01822125813449024, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.021691973969631236, 0.35714285714285715, 'age <= 20.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.019956616052060738, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.023427331887201735, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.020824295010845987, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.01648590021691974, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.01822125813449024, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.019956616052060738, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.021691973969631236, 0.6904761904761905, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.03297180043383948, 0.7380952380952381, 'sql <= 0.5\ngini = 0.36\nsamples = 34\nvalue = [26, 8]'),
#  Text(0.026898047722342732, 0.6904761904761905, 'compensation <= 5000.0\ngini = 0.269\nsamples = 25\nvalue = [21, 4]'),
#  Text(0.023427331887201735, 0.6428571428571429, 'Q3_India <= 0.5\ngini = 0.095\nsamples = 20\nvalue = [19, 1]'),
#  Text(0.021691973969631236, 0.5952380952380952, 'major_other <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.019956616052060738, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.023427331887201735, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.025162689804772233, 0.5952380952380952, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.03036876355748373, 0.6428571428571429, 'age <= 23.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.02863340563991323, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.03210412147505423, 0.5952380952380952, 'compensation <= 15000.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.03036876355748373, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03383947939262473, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.039045553145336226, 0.6904761904761905, 'compensation <= 5000.0\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.03731019522776573, 0.6428571428571429, 'age <= 20.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.03557483731019523, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.039045553145336226, 0.5952380952380952, 'age <= 23.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.03731019522776573, 0.5476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.040780911062906725, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.040780911062906725, 0.6428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.13901843817787418, 0.7857142857142857, 'major_stat <= 0.5\ngini = 0.469\nsamples = 248\nvalue = [93, 155]'),
#  Text(0.10797180043383948, 0.7380952380952381, 'education <= 17.0\ngini = 0.446\nsamples = 220\nvalue = [74, 146]'),
#  Text(0.06643167028199566, 0.6904761904761905, 'years_exp <= 1.5\ngini = 0.38\nsamples = 110\nvalue = [28, 82]'),
#  Text(0.052060737527114966, 0.6428571428571429, 'compensation <= 15000.0\ngini = 0.49\nsamples = 28\nvalue = [12, 16]'),
#  Text(0.05032537960954447, 0.5952380952380952, 'age <= 23.5\ngini = 0.444\nsamples = 24\nvalue = [8, 16]'),
#  Text(0.04425162689804772, 0.5476190476190477, 'python <= 0.5\ngini = 0.36\nsamples = 17\nvalue = [4, 13]'),
#  Text(0.040780911062906725, 0.5, 'age <= 20.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.039045553145336226, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.04251626898047722, 0.4523809523809524, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.04772234273318872, 0.5, 'Q1_Prefer not to say <= 0.5\ngini = 0.245\nsamples = 14\nvalue = [2, 12]'),
#  Text(0.04598698481561822, 0.4523809523809524, 'sql <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.04425162689804772, 0.40476190476190477, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.04772234273318872, 0.40476190476190477, 'major_other <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.04598698481561822, 0.35714285714285715, 'compensation <= 5000.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.04425162689804772, 0.30952380952380953, 'gini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.04772234273318872, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04945770065075922, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.04945770065075922, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.05639913232104121, 0.5476190476190477, 'compensation <= 5000.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.054663774403470713, 0.5, 'major_other <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.052928416485900215, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.05639913232104121, 0.4523809523809524, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.054663774403470713, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.05813449023861171, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05813449023861171, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.053796095444685464, 0.5952380952380952, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.08080260303687635, 0.6428571428571429, 'age <= 20.0\ngini = 0.314\nsamples = 82\nvalue = [16, 66]'),
#  Text(0.07906724511930585, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08253796095444685, 0.5952380952380952, 'age <= 45.0\ngini = 0.302\nsamples = 81\nvalue = [15, 66]'),
#  Text(0.08080260303687635, 0.5476190476190477, 'years_exp <= 4.5\ngini = 0.289\nsamples = 80\nvalue = [14, 66]'),
#  Text(0.07136659436008677, 0.5, 'age <= 23.5\ngini = 0.357\nsamples = 56\nvalue = [13, 43]'),
#  Text(0.0633405639913232, 0.4523809523809524, 'compensation <= 5000.0\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.061605206073752715, 0.40476190476190477, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.0650759219088937, 0.40476190476190477, 'years_exp <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.0633405639913232, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0668112798264642, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.07939262472885032, 0.4523809523809524, 'compensation <= 45000.0\ngini = 0.402\nsamples = 43\nvalue = [12, 31]'),
#  Text(0.07765726681127982, 0.40476190476190477, 'sql <= 0.5\ngini = 0.387\nsamples = 42\nvalue = [11, 31]'),
#  Text(0.0702819956616052, 0.35714285714285715, 'age <= 32.5\ngini = 0.32\nsamples = 25\nvalue = [5, 20]'),
#  Text(0.0685466377440347, 0.30952380952380953, 'education <= 14.0\ngini = 0.351\nsamples = 22\nvalue = [5, 17]'),
#  Text(0.0650759219088937, 0.2619047619047619, 'Q1_Female <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0633405639913232, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0668112798264642, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0720173535791757, 0.2619047619047619, 'years_exp <= 2.5\ngini = 0.32\nsamples = 20\nvalue = [4, 16]'),
#  Text(0.0702819956616052, 0.21428571428571427, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.0737527114967462, 0.21428571428571427, 'Q3_China <= 0.5\ngini = 0.408\nsamples = 14\nvalue = [4, 10]'),
#  Text(0.0720173535791757, 0.16666666666666666, 'compensation <= 5000.0\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.06767895878524946, 0.11904761904761904, 'age <= 27.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.06420824295010846, 0.07142857142857142, 'years_exp <= 3.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.062472885032537964, 0.023809523809523808, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.06594360086767896, 0.023809523809523808, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.07114967462039046, 0.07142857142857142, 'years_exp <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06941431670281996, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07288503253796096, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07635574837310195, 0.11904761904761904, 'major_eng <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.07462039045553145, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07809110629067245, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.0754880694143167, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.0720173535791757, 0.30952380952380953, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.08503253796095445, 0.35714285714285715, 'python <= 0.5\ngini = 0.457\nsamples = 17\nvalue = [6, 11]'),
#  Text(0.08329718004338395, 0.30952380952380953, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.08676789587852494, 0.30952380952380953, 'compensation <= 15000.0\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.08503253796095445, 0.2619047619047619, 'compensation <= 5000.0\ngini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(0.08329718004338395, 0.21428571428571427, 'Q1_Male <= 0.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.08156182212581345, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08503253796095445, 0.16666666666666666, 'years_exp <= 3.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.08329718004338395, 0.11904761904761904, 'years_exp <= 2.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.08156182212581345, 0.07142857142857142, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.08503253796095445, 0.07142857142857142, 'major_eng <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.08329718004338395, 0.023809523809523808, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08676789587852494, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08676789587852494, 0.11904761904761904, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.08676789587852494, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.08850325379609544, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08112798264642082, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09023861171366594, 0.5, 'compensation <= 25000.0\ngini = 0.08\nsamples = 24\nvalue = [1, 23]'),
#  Text(0.08850325379609544, 0.4523809523809524, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.09197396963123644, 0.4523809523809524, 'Q3_China <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.09023861171366594, 0.40476190476190477, 'age <= 27.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08850325379609544, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09197396963123644, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09370932754880694, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.08427331887201735, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1495119305856833, 0.6904761904761905, 'education <= 19.5\ngini = 0.487\nsamples = 110\nvalue = [46, 64]'),
#  Text(0.1411062906724512, 0.6428571428571429, 'education <= 18.5\ngini = 0.477\nsamples = 102\nvalue = [40, 62]'),
#  Text(0.1329718004338395, 0.5952380952380952, 'sql <= 0.5\ngini = 0.487\nsamples = 93\nvalue = [39, 54]'),
#  Text(0.12190889370932755, 0.5476190476190477, 'compensation <= 15000.0\ngini = 0.461\nsamples = 61\nvalue = [22, 39]'),
#  Text(0.1175704989154013, 0.5, 'years_exp <= 7.5\ngini = 0.495\nsamples = 40\nvalue = [18, 22]'),
#  Text(0.11583514099783081, 0.4523809523809524, 'age <= 32.5\ngini = 0.497\nsamples = 39\nvalue = [18, 21]'),
#  Text(0.11409978308026031, 0.40476190476190477, 'years_exp <= 3.5\ngini = 0.491\nsamples = 37\nvalue = [16, 21]'),
#  Text(0.10845986984815618, 0.35714285714285715, 'age <= 27.5\ngini = 0.477\nsamples = 28\nvalue = [11, 17]'),
#  Text(0.10672451193058569, 0.30952380952380953, 'age <= 23.5\ngini = 0.453\nsamples = 26\nvalue = [9, 17]'),
#  Text(0.09718004338394794, 0.2619047619047619, 'years_exp <= 2.5\ngini = 0.496\nsamples = 11\nvalue = [5, 6]'),
#  Text(0.09544468546637744, 0.21428571428571427, 'major_eng <= 0.5\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.09197396963123644, 0.16666666666666666, 'Q1_Female <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.09023861171366594, 0.11904761904761904, 'years_exp <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08850325379609544, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09197396963123644, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09370932754880694, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09891540130151844, 0.16666666666666666, 'python <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.09718004338394794, 0.11904761904761904, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.10065075921908893, 0.11904761904761904, 'compensation <= 5000.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.09891540130151844, 0.07142857142857142, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.10238611713665943, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09891540130151844, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11626898047722342, 0.2619047619047619, 'Q1_Female <= 0.5\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.11279826464208242, 0.21428571428571427, 'python <= 0.5\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.11106290672451193, 0.16666666666666666, 'years_exp <= 2.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.10932754880694143, 0.11904761904761904, 'Q3_China <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.10585683297180043, 0.07142857142857142, 'years_exp <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.10412147505422993, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10759219088937093, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11279826464208242, 0.07142857142857142, 'major_eng <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.11106290672451193, 0.023809523809523808, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11453362255965292, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11279826464208242, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11453362255965292, 0.16666666666666666, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.11973969631236442, 0.21428571428571427, 'Q3_India <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.11800433839479392, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12147505422993492, 0.16666666666666666, 'python <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.11973969631236442, 0.11904761904761904, 'major_other <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11800433839479392, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12147505422993492, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12321041214750543, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11019522776572668, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.11973969631236442, 0.35714285714285715, 'age <= 27.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.11800433839479392, 0.30952380952380953, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.12147505422993492, 0.30952380952380953, 'major_eng <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.11973969631236442, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.12321041214750543, 0.2619047619047619, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1175704989154013, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1193058568329718, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12624728850325379, 0.5, 'years_exp <= 7.5\ngini = 0.308\nsamples = 21\nvalue = [4, 17]'),
#  Text(0.1227765726681128, 0.4523809523809524, 'compensation <= 75000.0\ngini = 0.124\nsamples = 15\nvalue = [1, 14]'),
#  Text(0.1210412147505423, 0.40476190476190477, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.1245119305856833, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12971800433839478, 0.4523809523809524, 'years_exp <= 12.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.1279826464208243, 0.40476190476190477, 'age <= 32.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.12624728850325379, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12971800433839478, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.1314533622559653, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1440347071583514, 0.5476190476190477, 'years_exp <= 3.5\ngini = 0.498\nsamples = 32\nvalue = [17, 15]'),
#  Text(0.1383947939262473, 0.5, 'compensation <= 107500.0\ngini = 0.415\nsamples = 17\nvalue = [12, 5]'),
#  Text(0.13665943600867678, 0.4523809523809524, 'compensation <= 5000.0\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.1349240780911063, 0.40476190476190477, 'age <= 27.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.13318872017353578, 0.35714285714285715, 'major_other <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.1314533622559653, 0.30952380952380953, 'age <= 23.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.12971800433839478, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.13318872017353578, 0.2619047619047619, 'years_exp <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1314533622559653, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1349240780911063, 0.21428571428571427, 'Q3_China <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.13318872017353578, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13665943600867678, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1349240780911063, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.13665943600867678, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1383947939262473, 0.40476190476190477, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.14013015184381777, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14967462039045554, 0.5, 'compensation <= 35000.0\ngini = 0.444\nsamples = 15\nvalue = [5, 10]'),
#  Text(0.14533622559652928, 0.4523809523809524, 'years_exp <= 7.5\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.1418655097613883, 0.40476190476190477, 'major_eng <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.14013015184381777, 0.35714285714285715, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.1436008676789588, 0.35714285714285715, 'Q1_Male <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.1418655097613883, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14533622559652928, 0.30952380952380953, 'Q3_China <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.1436008676789588, 0.2619047619047619, 'years_exp <= 4.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1418655097613883, 0.21428571428571427, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.14533622559652928, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1470715835140998, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14880694143167028, 0.40476190476190477, 'compensation <= 25000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1470715835140998, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1505422993492408, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1540130151843818, 0.4523809523809524, 'compensation <= 90000.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.15227765726681128, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.15574837310195228, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1492407809110629, 0.5952380952380952, 'age <= 32.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.1475054229934924, 0.5476190476190477, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.1509761388286334, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1579175704989154, 0.6428571428571429, 'python <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.1561822125813449, 0.5952380952380952, 'Q3_India <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1544468546637744, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1579175704989154, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1596529284164859, 0.5952380952380952, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.1700650759219089, 0.7380952380952381, 'sql <= 0.5\ngini = 0.436\nsamples = 28\nvalue = [19, 9]'),
#  Text(0.1665943600867679, 0.6904761904761905, 'years_exp <= 7.5\ngini = 0.32\nsamples = 20\nvalue = [16, 4]'),
#  Text(0.1648590021691974, 0.6428571428571429, 'python <= 0.5\ngini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.1631236442516269, 0.5952380952380952, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.1665943600867679, 0.5952380952380952, 'compensation <= 15000.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.1648590021691974, 0.5476190476190477, 'Q3_China <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.1631236442516269, 0.5, 'education <= 17.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.16138828633405639, 0.4523809523809524, 'age <= 20.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1596529284164859, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1631236442516269, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1648590021691974, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1665943600867679, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1683297180043384, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1683297180043384, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1735357917570499, 0.6904761904761905, 'Q1_Male <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.1718004338394794, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1752711496746204, 0.6428571428571429, 'compensation <= 15000.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.1735357917570499, 0.5952380952380952, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.1770065075921909, 0.5952380952380952, 'age <= 27.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1752711496746204, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1787418655097614, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3073617136659436, 0.8333333333333334, 'years_exp <= 4.5\ngini = 0.434\nsamples = 396\nvalue = [270, 126]'),
#  Text(0.2645065075921909, 0.7857142857142857, 'major_eng <= 0.5\ngini = 0.363\nsamples = 294\nvalue = [224, 70]'),
#  Text(0.2282537960954447, 0.7380952380952381, 'education <= 19.5\ngini = 0.303\nsamples = 204\nvalue = [166, 38]'),
#  Text(0.20401301518438178, 0.6904761904761905, 'years_exp <= 1.5\ngini = 0.348\nsamples = 147\nvalue = [114, 33]'),
#  Text(0.18741865509761388, 0.6428571428571429, 'education <= 18.5\ngini = 0.263\nsamples = 77\nvalue = [65, 12]'),
#  Text(0.1856832971800434, 0.5952380952380952, 'Q1_Prefer to self-describe <= 0.5\ngini = 0.248\nsamples = 76\nvalue = [65, 11]'),
#  Text(0.18394793926247288, 0.5476190476190477, 'age <= 37.5\ngini = 0.231\nsamples = 75\nvalue = [65, 10]'),
#  Text(0.1770065075921909, 0.5, 'education <= 17.0\ngini = 0.205\nsamples = 69\nvalue = [61, 8]'),
#  Text(0.1700650759219089, 0.4523809523809524, 'major_stat <= 0.5\ngini = 0.278\nsamples = 30\nvalue = [25, 5]'),
#  Text(0.1665943600867679, 0.40476190476190477, 'compensation <= 75000.0\ngini = 0.36\nsamples = 17\nvalue = [13, 4]'),
#  Text(0.1648590021691974, 0.35714285714285715, 'age <= 23.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.16138828633405639, 0.30952380952380953, 'compensation <= 60000.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.1596529284164859, 0.2619047619047619, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.1631236442516269, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1683297180043384, 0.30952380952380953, 'compensation <= 65000.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.1665943600867679, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.1700650759219089, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1683297180043384, 0.35714285714285715, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.1735357917570499, 0.40476190476190477, 'compensation <= 90000.0\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.1718004338394794, 0.35714285714285715, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.1752711496746204, 0.35714285714285715, 'Q1_Female <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1735357917570499, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1770065075921909, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18394793926247288, 0.4523809523809524, 'major_other <= 0.5\ngini = 0.142\nsamples = 39\nvalue = [36, 3]'),
#  Text(0.18047722342733188, 0.40476190476190477, 'sql <= 0.5\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.1787418655097614, 0.35714285714285715, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.1822125813449024, 0.35714285714285715, 'Q1_Female <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.18047722342733188, 0.30952380952380953, 'compensation <= 112500.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.1787418655097614, 0.2619047619047619, 'compensation <= 35000.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.1770065075921909, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.18047722342733188, 0.21428571428571427, 'years_exp <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1787418655097614, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1822125813449024, 0.16666666666666666, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1822125813449024, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.18394793926247288, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.18741865509761388, 0.40476190476190477, 'compensation <= 112500.0\ngini = 0.074\nsamples = 26\nvalue = [25, 1]'),
#  Text(0.1856832971800434, 0.35714285714285715, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.1891540130151844, 0.35714285714285715, 'sql <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.18741865509761388, 0.30952380952380953, 'python <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1856832971800434, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1891540130151844, 0.2619047619047619, 'age <= 23.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.18741865509761388, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.19088937093275488, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19088937093275488, 0.30952380952380953, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.19088937093275488, 0.5, 'compensation <= 30000.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.1891540130151844, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.1926247288503254, 0.4523809523809524, 'age <= 45.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.19088937093275488, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.19436008676789587, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.18741865509761388, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1891540130151844, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.22060737527114968, 0.6428571428571429, 'compensation <= 75000.0\ngini = 0.42\nsamples = 70\nvalue = [49, 21]'),
#  Text(0.20911062906724512, 0.5952380952380952, 'compensation <= 10000.0\ngini = 0.499\nsamples = 25\nvalue = [13, 12]'),
#  Text(0.20477223427331886, 0.5476190476190477, 'age <= 27.5\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.20130151843817787, 0.5, 'education <= 17.0\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.19956616052060738, 0.4523809523809524, 'Q1_Female <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.19783080260303687, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.20130151843817787, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.20303687635574838, 0.4523809523809524, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.20824295010845986, 0.5, 'Q1_Female <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.20650759219088938, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.20997830802603037, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.21344902386117137, 0.5476190476190477, 'years_exp <= 3.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.21171366594360086, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.21518438177874186, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.23210412147505424, 0.5952380952380952, 'sql <= 0.5\ngini = 0.32\nsamples = 45\nvalue = [36, 9]'),
#  Text(0.2264642082429501, 0.5476190476190477, 'compensation <= 112500.0\ngini = 0.413\nsamples = 24\nvalue = [17, 7]'),
#  Text(0.22039045553145337, 0.5, 'education <= 17.0\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.21344902386117137, 0.4523809523809524, 'education <= 12.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.21171366594360086, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.21518438177874186, 0.40476190476190477, 'years_exp <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.21344902386117137, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.21691973969631237, 0.35714285714285715, 'years_exp <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.21518438177874186, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.21865509761388285, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.22733188720173536, 0.4523809523809524, 'years_exp <= 3.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.22559652928416485, 0.40476190476190477, 'Q1_Female <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.22386117136659436, 0.35714285714285715, 'age <= 27.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.22212581344902385, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.22559652928416485, 0.30952380952380953, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.22733188720173536, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.22906724511930585, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.23253796095444684, 0.5, 'Q1_Prefer not to say <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.23080260303687636, 0.4523809523809524, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.23427331887201736, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23774403470715835, 0.5476190476190477, 'compensation <= 137500.0\ngini = 0.172\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.23600867678958784, 0.5, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.23947939262472884, 0.5, 'major_other <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.23774403470715835, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.24121475054229935, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.25249457700650757, 0.6904761904761905, 'compensation <= 137500.0\ngini = 0.16\nsamples = 57\nvalue = [52, 5]'),
#  Text(0.24642082429501086, 0.6428571428571429, 'age <= 27.5\ngini = 0.083\nsamples = 46\nvalue = [44, 2]'),
#  Text(0.24295010845986983, 0.5952380952380952, 'compensation <= 90000.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.24121475054229935, 0.5476190476190477, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.24468546637744035, 0.5476190476190477, 'Q1_Female <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.24295010845986983, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.24642082429501086, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.24989154013015186, 0.5952380952380952, 'sql <= 0.5\ngini = 0.05\nsamples = 39\nvalue = [38, 1]'),
#  Text(0.24815618221258134, 0.5476190476190477, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.25162689804772237, 0.5476190476190477, 'age <= 32.5\ngini = 0.095\nsamples = 20\nvalue = [19, 1]'),
#  Text(0.24989154013015186, 0.5, 'years_exp <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.24815618221258134, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.25162689804772237, 0.4523809523809524, 'years_exp <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.24989154013015186, 0.40476190476190477, 'compensation <= 112500.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.24815618221258134, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.25162689804772237, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2533622559652928, 0.40476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2533622559652928, 0.5, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.25856832971800436, 0.6428571428571429, 'Q1_Male <= 0.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.25683297180043385, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2603036876355748, 0.5952380952380952, 'sql <= 0.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.25856832971800436, 0.5476190476190477, 'compensation <= 275000.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.25683297180043385, 0.5, 'years_exp <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.25509761388286334, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.25856832971800436, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2603036876355748, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.26203904555314533, 0.5476190476190477, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.3007592190889371, 0.7380952380952381, 'compensation <= 112500.0\ngini = 0.458\nsamples = 90\nvalue = [58, 32]'),
#  Text(0.29262472885032537, 0.6904761904761905, 'years_exp <= 3.5\ngini = 0.489\nsamples = 66\nvalue = [38, 28]'),
#  Text(0.29088937093275485, 0.6428571428571429, 'age <= 37.5\ngini = 0.475\nsamples = 62\nvalue = [38, 24]'),
#  Text(0.28156182212581343, 0.5952380952380952, 'years_exp <= 0.5\ngini = 0.456\nsamples = 57\nvalue = [37, 20]'),
#  Text(0.26811279826464207, 0.5476190476190477, 'age <= 32.5\ngini = 0.491\nsamples = 23\nvalue = [13, 10]'),
#  Text(0.26637744034707156, 0.5, 'Q1_Male <= 0.5\ngini = 0.483\nsamples = 22\nvalue = [13, 9]'),
#  Text(0.26203904555314533, 0.4523809523809524, 'sql <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.2603036876355748, 0.40476190476190477, 'compensation <= 45000.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.25856832971800436, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.26203904555314533, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.26377440347071585, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.27071583514099784, 0.4523809523809524, 'age <= 23.5\ngini = 0.457\nsamples = 17\nvalue = [11, 6]'),
#  Text(0.2672451193058568, 0.40476190476190477, 'sql <= 0.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.26550976138828636, 0.35714285714285715, 'compensation <= 75000.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.26377440347071585, 0.30952380952380953, 'education <= 19.0\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.26203904555314533, 0.2619047619047619, 'education <= 17.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.2603036876355748, 0.21428571428571427, 'python <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.25856832971800436, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.26203904555314533, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.26377440347071585, 0.21428571428571427, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.26550976138828636, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2672451193058568, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.26898047722342733, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2741865509761388, 0.40476190476190477, 'compensation <= 60000.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.27245119305856835, 0.35714285714285715, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.2759219088937093, 0.35714285714285715, 'sql <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2741865509761388, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.27765726681127983, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2698481561822126, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2950108459869848, 0.5476190476190477, 'age <= 32.5\ngini = 0.415\nsamples = 34\nvalue = [24, 10]'),
#  Text(0.29327548806941434, 0.5, 'compensation <= 95000.0\ngini = 0.444\nsamples = 30\nvalue = [20, 10]'),
#  Text(0.2898047722342733, 0.4523809523809524, 'Q1_Prefer not to say <= 0.5\ngini = 0.469\nsamples = 24\nvalue = [15, 9]'),
#  Text(0.2880694143167028, 0.40476190476190477, 'sql <= 0.5\ngini = 0.476\nsamples = 23\nvalue = [14, 9]'),
#  Text(0.2828633405639913, 0.35714285714285715, 'age <= 27.5\ngini = 0.444\nsamples = 15\nvalue = [10, 5]'),
#  Text(0.2811279826464208, 0.30952380952380953, 'years_exp <= 2.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.27765726681127983, 0.2619047619047619, 'compensation <= 75000.0\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.2759219088937093, 0.21428571428571427, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.27939262472885035, 0.21428571428571427, 'compensation <= 85000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.27765726681127983, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2811279826464208, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.28459869848156183, 0.2619047619047619, 'compensation <= 75000.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2828633405639913, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.28633405639913234, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.28459869848156183, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.29327548806941434, 0.35714285714285715, 'age <= 27.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.2898047722342733, 0.30952380952380953, 'compensation <= 35000.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.2880694143167028, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2915401301518438, 0.2619047619047619, 'Q1_Male <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2898047722342733, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.29327548806941434, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2967462039045553, 0.30952380952380953, 'education <= 19.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.2950108459869848, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.2984815618221258, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2915401301518438, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2967462039045553, 0.4523809523809524, 'years_exp <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.2950108459869848, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.2984815618221258, 0.40476190476190477, 'years_exp <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.2967462039045553, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.30021691973969633, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2967462039045553, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.30021691973969633, 0.5952380952380952, 'years_exp <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.2984815618221258, 0.5476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3019522776572668, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2943600867678959, 0.6428571428571429, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3088937093275488, 0.6904761904761905, 'education <= 17.0\ngini = 0.278\nsamples = 24\nvalue = [20, 4]'),
#  Text(0.3054229934924078, 0.6428571428571429, 'age <= 23.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3036876355748373, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3071583514099783, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3123644251626898, 0.6428571428571429, 'age <= 27.5\ngini = 0.172\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.3106290672451193, 0.5952380952380952, 'years_exp <= 3.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.3088937093275488, 0.5476190476190477, 'compensation <= 137500.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.3071583514099783, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3106290672451193, 0.5, 'sql <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.3088937093275488, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3123644251626898, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3123644251626898, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3140997830802603, 0.5952380952380952, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.3502169197396963, 0.7857142857142857, 'education <= 18.5\ngini = 0.495\nsamples = 102\nvalue = [46, 56]'),
#  Text(0.33080260303687636, 0.7380952380952381, 'education <= 17.0\ngini = 0.438\nsamples = 74\nvalue = [24, 50]'),
#  Text(0.3210412147505423, 0.6904761904761905, 'major_other <= 0.5\ngini = 0.165\nsamples = 22\nvalue = [2, 20]'),
#  Text(0.3193058568329718, 0.6428571428571429, 'age <= 40.0\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.3175704989154013, 0.5952380952380952, 'compensation <= 65000.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.3158351409978308, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3193058568329718, 0.5476190476190477, 'compensation <= 137500.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.3175704989154013, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3210412147505423, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3210412147505423, 0.5952380952380952, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.32277657266811277, 0.6428571428571429, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.3405639913232104, 0.6904761904761905, 'compensation <= 112500.0\ngini = 0.488\nsamples = 52\nvalue = [22, 30]'),
#  Text(0.33058568329718, 0.6428571428571429, 'age <= 32.5\ngini = 0.415\nsamples = 34\nvalue = [10, 24]'),
#  Text(0.3245119305856833, 0.5952380952380952, 'Q1_Male <= 0.5\ngini = 0.486\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.32277657266811277, 0.5476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
# ...
#  Text(0.6095444685466378, 0.40476190476190477, 'age <= 27.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.6060737527114968, 0.35714285714285715, 'compensation <= 35000.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6043383947939263, 0.30952380952380953, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6078091106290673, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6130151843817787, 0.35714285714285715, 'compensation <= 80000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6112798264642082, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6147505422993492, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6130151843817787, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6251626898047722, 0.4523809523809524, 'years_exp <= 1.5\ngini = 0.415\nsamples = 17\nvalue = [12, 5]'),
#  Text(0.6234273318872018, 0.40476190476190477, 'compensation <= 112500.0\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.6199566160520608, 0.35714285714285715, 'age <= 27.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.6182212581344902, 0.30952380952380953, 'compensation <= 75000.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.6164859002169197, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6199566160520608, 0.2619047619047619, 'years_exp <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.6182212581344902, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6216919739696313, 0.21428571428571427, 'sql <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.6199566160520608, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6234273318872018, 0.16666666666666666, 'compensation <= 90000.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.6216919739696313, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6251626898047722, 0.11904761904761904, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6216919739696313, 0.30952380952380953, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6268980477223427, 0.35714285714285715, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6251626898047722, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6286334056399132, 0.30952380952380953, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6268980477223427, 0.40476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6303687635574837, 0.5, 'Q3_China <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6286334056399132, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6321041214750542, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.627765726681128, 0.5476190476190477, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6295010845986985, 0.5952380952380952, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.7091885845986985, 0.8333333333333334, 'education <= 17.0\ngini = 0.334\nsamples = 293\nvalue = [62, 231]'),
#  Text(0.6671637744034707, 0.7857142857142857, 'Q3_China <= 0.5\ngini = 0.233\nsamples = 134\nvalue = [18, 116]'),
#  Text(0.6599240780911063, 0.7380952380952381, 'years_exp <= 12.5\ngini = 0.203\nsamples = 122\nvalue = [14, 108]'),
#  Text(0.6581887201735358, 0.6904761904761905, 'age <= 42.5\ngini = 0.226\nsamples = 108\nvalue = [14, 94]'),
#  Text(0.650650759219089, 0.6428571428571429, 'years_exp <= 3.5\ngini = 0.215\nsamples = 106\nvalue = [13, 93]'),
#  Text(0.6407809110629067, 0.5952380952380952, 'compensation <= 90000.0\ngini = 0.32\nsamples = 20\nvalue = [4, 16]'),
#  Text(0.6390455531453362, 0.5476190476190477, 'age <= 32.5\ngini = 0.198\nsamples = 18\nvalue = [2, 16]'),
#  Text(0.6373101952277658, 0.5, 'python <= 0.5\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(0.6355748373101953, 0.4523809523809524, 'compensation <= 5000.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6338394793926247, 0.40476190476190477, 'age <= 21.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6321041214750542, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6355748373101953, 0.35714285714285715, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6373101952277658, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6390455531453362, 0.4523809523809524, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.6407809110629067, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6425162689804772, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6605206073752712, 0.5952380952380952, 'Q3_United States of America <= 0.5\ngini = 0.187\nsamples = 86\nvalue = [9, 77]'),
#  Text(0.6587852494577007, 0.5476190476190477, 'compensation <= 85000.0\ngini = 0.27\nsamples = 56\nvalue = [9, 47]'),
#  Text(0.6516268980477223, 0.5, 'compensation <= 5000.0\ngini = 0.252\nsamples = 54\nvalue = [8, 46]'),
#  Text(0.6425162689804772, 0.4523809523809524, 'age <= 32.5\ngini = 0.33\nsamples = 24\nvalue = [5, 19]'),
#  Text(0.6407809110629067, 0.40476190476190477, 'Q1_Male <= 0.5\ngini = 0.363\nsamples = 21\nvalue = [5, 16]'),
#  Text(0.6390455531453362, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6425162689804772, 0.35714285714285715, 'python <= 0.5\ngini = 0.401\nsamples = 18\nvalue = [5, 13]'),
#  Text(0.6364425162689805, 0.30952380952380953, 'years_exp <= 4.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.63470715835141, 0.2619047619047619, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.638177874186551, 0.2619047619047619, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6364425162689805, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6399132321041214, 0.21428571428571427, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.648590021691974, 0.30952380952380953, 'years_exp <= 7.5\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.645119305856833, 0.2619047619047619, 'sql <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.6433839479392625, 0.21428571428571427, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.6468546637744035, 0.21428571428571427, 'years_exp <= 4.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.645119305856833, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.648590021691974, 0.16666666666666666, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6468546637744035, 0.11904761904761904, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6503253796095445, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.652060737527115, 0.2619047619047619, 'age <= 24.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6503253796095445, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6537960954446854, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6442516268980477, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6607375271149675, 0.4523809523809524, 'python <= 0.5\ngini = 0.18\nsamples = 30\nvalue = [3, 27]'),
#  Text(0.659002169197397, 0.40476190476190477, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.662472885032538, 0.40476190476190477, 'compensation <= 15000.0\ngini = 0.255\nsamples = 20\nvalue = [3, 17]'),
#  Text(0.6607375271149675, 0.35714285714285715, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.6642082429501085, 0.35714285714285715, 'years_exp <= 7.5\ngini = 0.32\nsamples = 15\nvalue = [3, 12]'),
#  Text(0.662472885032538, 0.30952380952380953, 'compensation <= 35000.0\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(0.6607375271149675, 0.2619047619047619, 'age <= 32.5\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.659002169197397, 0.21428571428571427, 'sql <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.6555314533622559, 0.16666666666666666, 'years_exp <= 4.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.6537960954446854, 0.11904761904761904, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6572668112798264, 0.11904761904761904, 'Q1_Female <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.6555314533622559, 0.07142857142857142, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6537960954446854, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6572668112798264, 0.023809523809523808, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.659002169197397, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.662472885032538, 0.16666666666666666, 'years_exp <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6607375271149675, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6642082429501085, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.662472885032538, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6642082429501085, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.665943600867679, 0.30952380952380953, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.665943600867679, 0.5, 'compensation <= 300000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6642082429501085, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6676789587852494, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6622559652928417, 0.5476190476190477, 'gini = 0.0\nsamples = 30\nvalue = [0, 30]'),
#  Text(0.6657266811279826, 0.6428571428571429, 'compensation <= 225000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6639913232104121, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6674620390455531, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6616594360086768, 0.6904761904761905, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.6744034707158352, 0.7380952380952381, 'sql <= 0.5\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.6709327548806941, 0.6904761904761905, 'age <= 32.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.6691973969631236, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6726681127982647, 0.6428571428571429, 'years_exp <= 4.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6709327548806941, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6744034707158352, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6778741865509761, 0.6904761904761905, 'compensation <= 55000.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.6761388286334057, 0.6428571428571429, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.6796095444685466, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7512133947939262, 0.7857142857142857, 'age <= 20.0\ngini = 0.4\nsamples = 159\nvalue = [44, 115]'),
#  Text(0.7494780368763557, 0.7380952380952381, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7529487527114967, 0.7380952380952381, 'age <= 47.5\ngini = 0.392\nsamples = 157\nvalue = [42, 115]'),
#  Text(0.7419061822125813, 0.6904761904761905, 'years_exp <= 7.5\ngini = 0.375\nsamples = 148\nvalue = [37, 111]'),
#  Text(0.7302331887201735, 0.6428571428571429, 'education <= 19.5\ngini = 0.422\nsamples = 109\nvalue = [33, 76]'),
#  Text(0.7172993492407809, 0.5952380952380952, 'age <= 37.5\ngini = 0.397\nsamples = 99\nvalue = [27, 72]'),
#  Text(0.7035791757049892, 0.5476190476190477, 'age <= 27.5\ngini = 0.372\nsamples = 93\nvalue = [23, 70]'),
#  Text(0.6880694143167028, 0.5, 'education <= 18.5\ngini = 0.427\nsamples = 42\nvalue = [13, 29]'),
#  Text(0.6863340563991324, 0.4523809523809524, 'compensation <= 5000.0\ngini = 0.414\nsamples = 41\nvalue = [12, 29]'),
#  Text(0.6754880694143167, 0.40476190476190477, 'years_exp <= 4.5\ngini = 0.298\nsamples = 22\nvalue = [4, 18]'),
#  Text(0.6737527114967462, 0.35714285714285715, 'python <= 0.5\ngini = 0.332\nsamples = 19\nvalue = [4, 15]'),
#  Text(0.6694143167028199, 0.30952380952380953, 'years_exp <= 3.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.6676789587852494, 0.2619047619047619, 'age <= 23.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.665943600867679, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6694143167028199, 0.21428571428571427, 'Q3_China <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6676789587852494, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6711496746203904, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6711496746203904, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6780911062906725, 0.30952380952380953, 'years_exp <= 3.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.6746203904555315, 0.2619047619047619, 'Q3_United States of America <= 0.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.672885032537961, 0.21428571428571427, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.676355748373102, 0.21428571428571427, 'sql <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6746203904555315, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6780911062906725, 0.16666666666666666, 'Q1_Male <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.676355748373102, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.679826464208243, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6815618221258134, 0.2619047619047619, 'Q1_Female <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.679826464208243, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6832971800433839, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6772234273318872, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6971800433839479, 0.40476190476190477, 'compensation <= 125000.0\ngini = 0.488\nsamples = 19\nvalue = [8, 11]'),
#  Text(0.6954446854663774, 0.35714285714285715, 'years_exp <= 4.5\ngini = 0.5\nsamples = 16\nvalue = [8, 8]'),
#  Text(0.693709327548807, 0.30952380952380953, 'python <= 0.5\ngini = 0.498\nsamples = 15\nvalue = [7, 8]'),
#  Text(0.6885032537960954, 0.2619047619047619, 'compensation <= 60000.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6867678958785249, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.690238611713666, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6989154013015184, 0.2619047619047619, 'compensation <= 45000.0\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.693709327548807, 0.21428571428571427, 'sql <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.6919739696312365, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6954446854663774, 0.16666666666666666, 'years_exp <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.693709327548807, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6971800433839479, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.70412147505423, 0.21428571428571427, 'Q3_United States of America <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.7023861171366594, 0.16666666666666666, 'compensation <= 55000.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.7006507592190889, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.70412147505423, 0.11904761904761904, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7058568329718005, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6971800433839479, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6989154013015184, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6898047722342733, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7190889370932755, 0.5, 'compensation <= 112500.0\ngini = 0.315\nsamples = 51\nvalue = [10, 41]'),
#  ...]

# %%
fig, ax = plt.subplots(figsize=(8, 4))
features = list(c for c in X_train.columns)
tree.plot_tree(hi_variance, feature_names=features, filled=True, class_names=hi_variance.classes_,
              max_depth=2, fontsize=6)
# Out:
# [Text(0.5, 0.875, 'r <= 0.5\ngini = 0.496\nsamples = 2110\nvalue = [1153, 957]\nclass = Data Scientist'),
#  Text(0.25, 0.625, 'major_cs <= 0.5\ngini = 0.493\nsamples = 1484\nvalue = [653, 831]\nclass = Software Engineer'),
#  Text(0.125, 0.375, 'Q3_United States of America <= 0.5\ngini = 0.49\nsamples = 718\nvalue = [410, 308]\nclass = Data Scientist'),
#  Text(0.0625, 0.125, '\n  (...)  \n'),
#  Text(0.1875, 0.125, '\n  (...)  \n'),
#  Text(0.375, 0.375, 'years_exp <= 2.5\ngini = 0.433\nsamples = 766\nvalue = [243, 523]\nclass = Software Engineer'),
#  Text(0.3125, 0.125, '\n  (...)  \n'),
#  Text(0.4375, 0.125, '\n  (...)  \n'),
#  Text(0.75, 0.625, 'major_cs <= 0.5\ngini = 0.322\nsamples = 626\nvalue = [500, 126]\nclass = Data Scientist'),
#  Text(0.625, 0.375, 'years_exp <= 22.5\ngini = 0.211\nsamples = 443\nvalue = [390, 53]\nclass = Data Scientist'),
#  Text(0.5625, 0.125, '\n  (...)  \n'),
#  Text(0.6875, 0.125, '\n  (...)  \n'),
#  Text(0.875, 0.375, 'years_exp <= 7.5\ngini = 0.48\nsamples = 183\nvalue = [110, 73]\nclass = Data Scientist'),
#  Text(0.8125, 0.125, '\n  (...)  \n'),
#  Text(0.9375, 0.125, '\n  (...)  \n')]

# %% [markdown]
# ## Tree Hyperparameters

# %%
stump.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 1,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %% [markdown]
# #### Tracking changes with Validation Curves

# %%
accuracies = []
for depth in range(1, 15):
    between = tree.DecisionTreeClassifier(max_depth=depth)
    between.fit(X_train, kag_y_train)
    accuracies.append(between.score(X_test, kag_y_test))

# %%
fig, ax = plt.subplots(figsize=(10, 4))
(pd.Series(accuracies, name='Accuracy', index=range(1, len(accuracies)+1))
 .plot(ax=ax, title='Accuracy at a given Tree Depth'))
ax.set_ylabel('Accuracy')
ax.set_xlabel('max_depth')

plt.grid(True)
plt.show()

# %%
between = tree.DecisionTreeClassifier(max_depth=7)
between.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier(max_depth=7)

# %%
between.score(X_test, kag_y_test)
# Out:
# 0.7348066298342542

# %% [markdown]
# #### Leveraging Yellowbrick

# %%
from yellowbrick.model_selection import validation_curve

# %%
fig, ax = plt.subplots(figsize=(10, 4))
viz = validation_curve(tree.DecisionTreeClassifier(),
                       X=pd.concat([X_train, X_test]),
                       y=pd.concat([kag_y_train, kag_y_test]),
                       param_name='max_depth', param_range=range(1, 14),
                       scoring='accuracy', cv=5, ax=ax, n_jobs=6)

plt.show()
# Out:
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# #### Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'max_depth': [3, 5, 7, 8],
    'min_samples_leaf': [1, 3, 4, 5, 6],
    'min_samples_split': [2, 3, 4, 5, 6],
}

# %%
grid_search = GridSearchCV(estimator=tree.DecisionTreeClassifier(),
                           param_grid=params, cv=4, n_jobs=-1,
                           verbose=1, scoring="accuracy")

# %%
grid_search.fit(pd.concat([X_train, X_test]),
                pd.concat([kag_y_train, kag_y_test]))
# Out:
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [3, 5, 7, 8],
#                          'min_samples_leaf': [1, 3, 4, 5, 6],
#                          'min_samples_split': [2, 3, 4, 5, 6]},
#              scoring='accuracy', verbose=1)

# %%
grid_search.best_params_
# Out:
# {'max_depth': 7, 'min_samples_leaf': 5, 'min_samples_split': 3}

# %%
between2 = tree.DecisionTreeClassifier(**grid_search.best_params_)

# %%
between2.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier(max_depth=7, min_samples_leaf=5, min_samples_split=3)

# %%
between2.score(X_test, kag_y_test)
# Out:
# 0.7259668508287292

# %%
(pd.DataFrame(grid_search.cv_results_)
 .sort_values(by='rank_test_score')
 .style
 .background_gradient(axis='rows')
)
# Out:
# <style type="text/css">
# #T_85902_row0_col0, #T_85902_row18_col3, #T_85902_row66_col12, #T_85902_row67_col12, #T_85902_row72_col3 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_85902_row0_col1, #T_85902_row22_col1, #T_85902_row27_col3, #T_85902_row37_col1, #T_85902_row44_col1, #T_85902_row46_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_85902_row0_col2, #T_85902_row47_col2, #T_85902_row69_col3, #T_85902_row76_col3 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_85902_row0_col3, #T_85902_row5_col3, #T_85902_row30_col1, #T_85902_row68_col1 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_85902_row0_col8, #T_85902_row0_col10, #T_85902_row1_col10, #T_85902_row3_col10, #T_85902_row4_col8, #T_85902_row5_col10, #T_85902_row7_col10, #T_85902_row11_col10, #T_85902_row15_col10, #T_85902_row98_col2 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_85902_row0_col9, #T_85902_row2_col9, #T_85902_row3_col9, #T_85902_row5_col9, #T_85902_row16_col9, #T_85902_row33_col9 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_85902_row0_col11, #T_85902_row19_col11, #T_85902_row20_col11, #T_85902_row21_col11, #T_85902_row29_col11, #T_85902_row30_col11, #T_85902_row31_col11, #T_85902_row32_col11, #T_85902_row36_col11, #T_85902_row37_col11, #T_85902_row38_col11 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_85902_row0_col12, #T_85902_row1_col9, #T_85902_row2_col10, #T_85902_row9_col2, #T_85902_row9_col3, #T_85902_row18_col11, #T_85902_row19_col8, #T_85902_row20_col8, #T_85902_row21_col8, #T_85902_row26_col11, #T_85902_row51_col13, #T_85902_row53_col0, #T_85902_row81_col1, #T_85902_row90_col14, #T_85902_row91_col14, #T_85902_row92_col14, #T_85902_row93_col14, #T_85902_row94_col14, #T_85902_row95_col14, #T_85902_row96_col14, #T_85902_row97_col14, #T_85902_row98_col14, #T_85902_row99_col14 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_85902_row0_col13, #T_85902_row7_col1, #T_85902_row12_col0, #T_85902_row28_col10, #T_85902_row29_col10, #T_85902_row30_col10, #T_85902_row31_col10, #T_85902_row38_col10, #T_85902_row38_col14, #T_85902_row47_col10, #T_85902_row48_col10 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_85902_row0_col14, #T_85902_row6_col1, #T_85902_row25_col3, #T_85902_row28_col1, #T_85902_row41_col3, #T_85902_row47_col1, #T_85902_row49_col1, #T_85902_row53_col8, #T_85902_row63_col3, #T_85902_row67_col10, #T_85902_row71_col3, #T_85902_row75_col9, #T_85902_row75_col11, #T_85902_row76_col9, #T_85902_row76_col11, #T_85902_row77_col9, #T_85902_row77_col11, #T_85902_row78_col9, #T_85902_row78_col11, #T_85902_row79_col9, #T_85902_row79_col11, #T_85902_row80_col9, #T_85902_row80_col11, #T_85902_row81_col9, #T_85902_row81_col11, #T_85902_row82_col9, #T_85902_row82_col11, #T_85902_row83_col9, #T_85902_row83_col11, #T_85902_row84_col9, #T_85902_row84_col11, #T_85902_row85_col9, #T_85902_row85_col11, #T_85902_row86_col9, #T_85902_row86_col11, #T_85902_row87_col9, #T_85902_row87_col11, #T_85902_row88_col9, #T_85902_row88_col11, #T_85902_row89_col9, #T_85902_row89_col11, #T_85902_row90_col9, #T_85902_row90_col11, #T_85902_row90_col12, #T_85902_row90_col13, #T_85902_row91_col9, #T_85902_row91_col11, #T_85902_row91_col12, #T_85902_row91_col13, #T_85902_row92_col9, #T_85902_row92_col11, #T_85902_row92_col12, #T_85902_row92_col13, #T_85902_row93_col9, #T_85902_row93_col11, #T_85902_row93_col12, #T_85902_row93_col13, #T_85902_row94_col9, #T_85902_row94_col11, #T_85902_row94_col12, #T_85902_row94_col13, #T_85902_row95_col9, #T_85902_row95_col11, #T_85902_row95_col12, #T_85902_row95_col13, #T_85902_row96_col9, #T_85902_row96_col11, #T_85902_row96_col12, #T_85902_row96_col13, #T_85902_row97_col9, #T_85902_row97_col11, #T_85902_row97_col12, #T_85902_row97_col13, #T_85902_row98_col9, #T_85902_row98_col11, #T_85902_row98_col12, #T_85902_row98_col13, #T_85902_row99_col0, #T_85902_row99_col2, #T_85902_row99_col9, #T_85902_row99_col11, #T_85902_row99_col12, #T_85902_row99_col13 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_85902_row1_col0, #T_85902_row51_col0, #T_85902_row94_col0 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_85902_row1_col1, #T_85902_row33_col14, #T_85902_row51_col3 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_85902_row1_col2, #T_85902_row18_col0, #T_85902_row20_col0, #T_85902_row65_col2, #T_85902_row69_col9, #T_85902_row71_col9 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_85902_row1_col3, #T_85902_row3_col14, #T_85902_row19_col1, #T_85902_row43_col3, #T_85902_row87_col3 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_85902_row1_col8, #T_85902_row2_col8, #T_85902_row3_col8, #T_85902_row6_col8, #T_85902_row7_col8, #T_85902_row12_col10, #T_85902_row14_col10, #T_85902_row22_col10, #T_85902_row27_col10, #T_85902_row66_col8, #T_85902_row67_col8, #T_85902_row69_col8 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_85902_row1_col11, #T_85902_row2_col11, #T_85902_row3_col11, #T_85902_row4_col11, #T_85902_row5_col11, #T_85902_row8_col11, #T_85902_row9_col11, #T_85902_row15_col9, #T_85902_row22_col9, #T_85902_row26_col9, #T_85902_row34_col9, #T_85902_row39_col9, #T_85902_row40_col9, #T_85902_row41_col9, #T_85902_row41_col11, #T_85902_row42_col9, #T_85902_row42_col11, #T_85902_row47_col9, #T_85902_row47_col11, #T_85902_row48_col9, #T_85902_row48_col11, #T_85902_row49_col11, #T_85902_row54_col9 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_85902_row1_col12, #T_85902_row2_col12, #T_85902_row95_col2 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_85902_row1_col13 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_85902_row1_col14, #T_85902_row2_col14, #T_85902_row17_col3, #T_85902_row33_col3, #T_85902_row77_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_85902_row2_col0 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_85902_row2_col1, #T_85902_row54_col0, #T_85902_row67_col13 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_85902_row2_col2, #T_85902_row25_col13, #T_85902_row74_col0, #T_85902_row76_col2 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_85902_row2_col3, #T_85902_row4_col3, #T_85902_row8_col1, #T_85902_row44_col0, #T_85902_row45_col0, #T_85902_row59_col2, #T_85902_row72_col12, #T_85902_row73_col12 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_85902_row2_col13, #T_85902_row63_col13 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_85902_row3_col0, #T_85902_row98_col1 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_85902_row3_col1, #T_85902_row54_col12 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_85902_row3_col2, #T_85902_row50_col14, #T_85902_row58_col2, #T_85902_row67_col0 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_85902_row3_col3, #T_85902_row36_col0, #T_85902_row66_col1 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_85902_row3_col12 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_85902_row3_col13, #T_85902_row4_col0, #T_85902_row56_col9, #T_85902_row56_col12, #T_85902_row57_col12, #T_85902_row58_col9, #T_85902_row58_col12, #T_85902_row59_col9, #T_85902_row59_col12, #T_85902_row89_col0 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_85902_row4_col1, #T_85902_row41_col0, #T_85902_row65_col12, #T_85902_row85_col0 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_85902_row4_col2, #T_85902_row44_col9, #T_85902_row45_col9, #T_85902_row46_col9, #T_85902_row49_col9, #T_85902_row62_col14, #T_85902_row63_col14, #T_85902_row64_col14 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_85902_row4_col9, #T_85902_row6_col9, #T_85902_row8_col9, #T_85902_row9_col9, #T_85902_row10_col9, #T_85902_row12_col9, #T_85902_row13_col9, #T_85902_row17_col9 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_85902_row4_col10, #T_85902_row6_col10, #T_85902_row8_col10, #T_85902_row9_col10, #T_85902_row10_col10, #T_85902_row13_col10, #T_85902_row15_col12 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_85902_row4_col12, #T_85902_row5_col12 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_859

# %%
results = model_selection.cross_val_score(
    tree.DecisionTreeClassifier(max_depth=7),
    X=pd.concat([X_train, X_test], axis='index'),
    y=pd.concat([kag_y_train, kag_y_test], axis='index'),
    cv=4
)

# %%
results
# Out:
# array([0.69628647, 0.73740053, 0.70424403, 0.71447543])

# %%
results.mean()
# Out:
# 0.7131016165224162

# %%
results = model_selection.cross_val_score(
    tree.DecisionTreeClassifier(max_depth=7, min_samples_leaf=5,
                               min_samples_split=2),
    X=pd.concat([X_train, X_test], axis='index'),
    y=pd.concat([kag_y_train, kag_y_test], axis='index'),
    cv=4
)

# %%
results
# Out:
# array([0.70822281, 0.74005305, 0.71220159, 0.71580345])

# %%
results.mean()
# Out:
# 0.719070226609037

# %% [markdown]
# ## Random Forest
#
# #### Scikit-Learn Random Forest

# %%
from sklearn import ensemble

# %%
rf = ensemble.RandomForestClassifier(random_state=42)

# %%
rf.fit(X_train, kag_y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rf.score(X_test, kag_y_test)
# Out:
# 0.7237569060773481

# %%
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %%
len(rf.estimators_)
# Out:
# 100

# %%
print(rf.estimators_[0])
# Out:
# DecisionTreeClassifier(max_features='sqrt', random_state=1608637542)

# %%
fig, ax = plt.subplots(figsize=(8, 4))
features = list(c for c in X_train.columns)
tree.plot_tree(rf.estimators_[0], feature_names=features,
               filled=True, class_names=rf.classes_, ax=ax,
               max_depth=2, fontsize=6)
# Out:
# [Text(0.5, 0.875, 'Q3_United States of America <= 0.5\ngini = 0.496\nsamples = 1354\nvalue = [1146, 964]\nclass = Data Scientist'),
#  Text(0.25, 0.625, 'r <= 0.5\ngini = 0.496\nsamples = 681\nvalue = [496, 588]\nclass = Software Engineer'),
#  Text(0.125, 0.375, 'education <= 17.0\ngini = 0.469\nsamples = 530\nvalue = [317, 528]\nclass = Software Engineer'),
#  Text(0.0625, 0.125, '\n  (...)  \n'),
#  Text(0.1875, 0.125, '\n  (...)  \n'),
#  Text(0.375, 0.375, 'education <= 17.0\ngini = 0.376\nsamples = 151\nvalue = [179, 60]\nclass = Data Scientist'),
#  Text(0.3125, 0.125, '\n  (...)  \n'),
#  Text(0.4375, 0.125, '\n  (...)  \n'),
#  Text(0.75, 0.625, 'education <= 17.0\ngini = 0.464\nsamples = 673\nvalue = [650, 376]\nclass = Data Scientist'),
#  Text(0.625, 0.375, 'major_cs <= 0.5\ngini = 0.485\nsamples = 176\nvalue = [109, 154]\nclass = Software Engineer'),
#  Text(0.5625, 0.125, '\n  (...)  \n'),
#  Text(0.6875, 0.125, '\n  (...)  \n'),
#  Text(0.875, 0.375, 'major_cs <= 0.5\ngini = 0.413\nsamples = 497\nvalue = [541, 222]\nclass = Data Scientist'),
#  Text(0.8125, 0.125, '\n  (...)  \n'),
#  Text(0.9375, 0.125, '\n  (...)  \n')]

# %% [markdown]
# #### XGBoost Random Forest

# %%
import xgboost as xgb

# %%
rf_xg = xgb.XGBRFClassifier(random_state=42)

# %%
rf_xg.fit(X_train, y_train)
# Out:
# XGBRFClassifier(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bytree=None,
#                 early_stopping_rounds=None, enable_categorical=False,
#                 eval_metric=None, feature_types=None, gamma=None, gpu_id=None,
#                 grow_policy=None, importance_type=None,
#                 interaction_constraints=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                 objective='binary:logistic', predictor=None, random_state=42,
#                 reg_alpha=None, ...)

# %%
rf_xg.score(X_test, y_test)
# Out:
# 0.7447513812154696

# %%
rf_xg.get_params()
# Out:
# {'colsample_bynode': 0.8,
#  'learning_rate': 1.0,
#  'reg_lambda': 1e-05,
#  'subsample': 0.8,
#  'objective': 'binary:logistic',
#  'use_label_encoder': None,
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bytree': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'gpu_id': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'predictor': None,
#  'random_state': 42,
#  'reg_alpha': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None}

# %%
fig, ax = plt.subplots(figsize=(6, 12), dpi=600)
xgb.plot_tree(rf_xg, num_trees=0, ax=ax, size='1, 1')
# Out:
# <Axes: >

# %%
my_dot_export(rf_xg, num_trees=0, filename='/Users/isisromero/Desktop/img_XGB/stump_xg.dot',
              title='First Random Forest Tree')
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.960825 to fit

# %%
viz = dtreeviz.model(rf_xg, X_train=X_train,
                     y_train=y_train,
                     target_name='Job', feature_names=list(X_train.columns),
                     class_names=['DS', 'SE'], tree_index=0)

# %%
viz.view(depth_range_to_display=[0, 2])

# %% [markdown]
# #### Training the Number of Trees in the Forest

# %%
from yellowbrick.model_selection import validation_curve

# %%
fig, ax = plt.subplots(figsize=(10, 4))
viz = validation_curve(xgb.XGBClassifier(random_state=42),
                       X=pd.concat([X_train, X_test], axis='index'),
                       y=np.concatenate([y_train, y_test]),
                       param_name='n_estimators', param_range=range(1, 100, 2),
                       scoring='accuracy', cv=3,
                       ax=ax)

# %%
rf_xg29 = xgb.XGBClassifier(random_state=42, n_estimators=29)

# %%
rf_xg29.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=29, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=42, ...)

# %%
rf_xg29.score(X_test, y_test)
# Out:
# 0.7591160220994475

# %% [markdown]
# ## XGBoost
#
# #### Creating an XGBoost Model

# %%
# %matplotlib inline

# Visualization 
import dtreeviz
import matplotlib.pyplot as plt
# Feature Engineering
from feature_engine import encoding, imputation
# Numerical Manipulation
import numpy as np
# Data Manipulation
import pandas as pd

# %%
# Machine Learning Libraries

from sklearn import base, compose, datasets, ensemble, \
metrics, model_selection, pipeline, preprocessing, tree

# %%
# Scikit Plotting
import scikitplot
# Extreme Gradient Boosting
import xgboost as xgb
# Sensical Visualizer & Classifier
import yellowbrick.model_selection as ms
from yellowbrick import classifier

# %%
# Retrieving Data

import urllib
import zipfile

# %%
url = 'https://github.com/mattharrison/datasets/raw/master/data/'\
'kaggle-survey-2018.zip'
fname = 'kaggle-survey-2018.zip'
member_name = 'multipleChoiceResponses.csv'

# %%
# Function Extration
def extract_zip(src, dst, member_name):
    """Extract a member file from a zip file & read it into pandas
    DataFrame.
    
    Parameters:
        src '(str:)' URL of the zip file to be downloaded and extrated.
        dst 'str': Local file path where the zip file will be written.
        member_name: Name of the member file inside the zip file to be
            read into a DataFrame.
            
    Returns:
        pandas.DataFrame containing the contents of member file.
    """
    url = src
    fname = dst
    fin = urllib.request.urlopen(url)
    data = fin.read()
    with open(dst, mode='wb') as fout:
        fout.write(data)
    with zipfile.ZipFile(dst) as z:
        kag = pd.read_csv(z.open(member_name))
        kag_questions = kag.iloc[0]
        raw = kag.iloc[1:]
        return raw

# %%
raw = extract_zip(url, fname, member_name)
# Out:
# /var/folders/wh/l_q69dcj75z0c82jy8ry71f40000gn/T/ipykernel_18050/3680407660.py:22: DtypeWarning: Columns (0,2,8,10,21,23,24,25,26,27,28,44,56,64,83,85,87,107,109,123,125,150,157,172,174,194,210,218,219,223,246,249,262,264,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,304,306,325,326,329,341,368,371,384,385,389,390,391,393,394) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
## Create raw X and raw y
kag_X, kag_y = get_rawX_y(raw, 'Q6')

# %%
## Split data    
kag_X_train, kag_X_test, kag_y_train, kag_y_test = \
    model_selection.train_test_split(
        kag_X, kag_y, test_size=.3, random_state=42, stratify=kag_y)

# %%
## Transform X with pipeline
X_train = kag_pl.fit_transform(kag_X_train)
X_test = kag_pl.transform(kag_X_test)

# %%
## Transform y with label encoder
label_encoder = preprocessing.LabelEncoder()
label_encoder.fit(kag_y_train)
y_train = label_encoder.transform(kag_y_train)
y_test = label_encoder.transform(kag_y_test)

# %%
# Combined Data for cross validation/etc
X = pd.concat([X_train, X_test], axis='index')
y = pd.Series([*y_train, *y_test], index=X.index)

# %% [markdown]
# #### A Boosted Model

# %%
xg_oob = xgb.XGBClassifier()

# %%
xg_oob.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
xg_oob.score(X_test, y_test)
# Out:
# 0.7458563535911602
