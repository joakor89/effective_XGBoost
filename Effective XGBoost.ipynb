# %% [markdown]
# # Datasets
#
# ### Cleaup & Loading

# %%
# Data Manipulation
import pandas as pd

# URL Library
import urllib.request
import zipfile

# %%
# Retrieving & storage
url = 'https://github.com/mattharrison/datasets/raw/master/data/'\
'kaggle-survey-2018.zip'
fname = 'kaggle-survey-2018.zip'
member_name = 'multipleChoiceResponses.csv'

# %%
# Function Extration
def extract_zip(src, dst, member_name):
    """Extract a member file from a zip file & read it into pandas
    DataFrame.
    
    Parameters:
        src '(str:)' URL of the zip file to be downloaded and extrated.
        dst 'str': Local file path where the zip file will be written.
        member_name: Name of the member file inside the zip file to be
            read into a DataFrame.
            
    Returns:
        pandas.DataFrame containing the contents of member file.
    """
    url = src
    fname = dst
    fin = urllib.request.urlopen(url)
    data = fin.read()
    with open(dst, mode='wb') as fout:
        fout.write(data)
    with zipfile.ZipFile(dst) as z:
        kag = pd.read_csv(z.open(member_name))
        kag_questions = kag.iloc[0]
        raw = kag.iloc[1:]
        return raw

# %%
raw = extract_zip(url, fname, member_name)
# Out:
# /var/folders/wh/l_q69dcj75z0c82jy8ry71f40000gn/T/ipykernel_5219/3680407660.py:22: DtypeWarning: Columns (0,2,8,10,21,23,24,25,26,27,28,44,56,64,83,85,87,107,109,123,125,150,157,172,174,194,210,218,219,223,246,249,262,264,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,304,306,325,326,329,341,368,371,384,385,389,390,391,393,394) have mixed types. Specify dtype option on import or set low_memory=False.
#   kag = pd.read_csv(z.open(member_name))

# %% [markdown]
# ## CleanUp Pipeline

# %%
def tweak_kag(df_: pd.DataFrame) -> pd.DataFrame:
    """
    Tweak the Kaggle survey data and return a new DataFrame.

    This function takes a Pandas DataFrame containing Kaggle 
    survey data as input and returns a new DataFrame. The 
    modifications include extracting and transforming certain 
    columns, renaming columns, and selecting a subset of columns.

    Parameters
    ----------
    df_ : pd.DataFrame
        The input DataFrame containing Kaggle survey data.

    Returns
    -------
    pd.DataFrame
        The new DataFrame with the modified and selected columns.
    """    
    return (df_
            .assign(age=df_.Q2.str.slice(0,2).astype(int),
                    education=df_.Q4.replace({'Master’s degree': 18,
                         'Bachelor’s degree': 16,
                         'Doctoral degree': 20,
'Some college/university study without earning a bachelor’s degree': 13,
                         'Professional degree': 19,
                         'I prefer not to answer': None,
                         'No formal education past high school': 12}),
                    major=(df_.Q5
                              .pipe(topn, n=3)
                              .replace({
                        'Computer science (software engineering, etc.)': 'cs',
                        'Engineering (non-computer focused)': 'eng',
                        'Mathematics or statistics': 'stat'})
                         ),
                    years_exp=(df_.Q8.str.replace('+','', regex=False)
                           .str.split('-', expand=True)
                           .iloc[:,0]
                           .astype(float)),
                    compensation=(df_.Q9.str.replace('+','', regex=False)
                           .str.replace(',','', regex=False)
                           .str.replace('500000', '500', regex=False)
  .str.replace('I do not wish to disclose my approximate yearly compensation',
             '0', regex=False)
                           .str.split('-', expand=True)
                           .iloc[:,0]
                           .fillna(0)
                           .astype(int)
                           .mul(1_000)
                                    ),
                    python=df_.Q16_Part_1.fillna(0).replace('Python', 1),
                    r=df_.Q16_Part_2.fillna(0).replace('R', 1),
                    sql=df_.Q16_Part_3.fillna(0).replace('SQL', 1)
               )#assign
        .rename(columns=lambda col:col.replace(' ', '_'))
        .loc[:, 'Q1,Q3,age,education,major,years_exp,compensation,'
                'python,r,sql'.split(',')]   
       )

# %%
def topn(ser, n=5, default='other'):
    counts = ser.value_counts()
    return ser.where(ser.isin(counts.index[:n]), default)

# %%
from feature_engine import encoding, imputation
from sklearn import base, pipeline
# Out:
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
class TweakKagTransformer(base.BaseEstimator, base.TransformerMixin):
    
    def __init__(self, ycol=None):
        self.ycol = ycol
        
    def transform(self, X):
        return tweak_kag(X)
    
    def fit(self, X, y=None):
        return self

# %%
def get_rawX_y(df, y_col):
    raw = (df
           .query('Q3.isin(["United States of America", "China", "India"]) '
              'and Q6.isin(["Data Scientist", "Software Engineer"])')
    )
    return raw.drop(columns=[y_col]), raw[y_col]

# %%
# Create Pipeline
kag_pl = pipeline.Pipeline(
    [('tweak', TweakKagTransformer()),
     ('cat', encoding.OneHotEncoder(top_categories=5, drop_last=True, variables=['Q1', 'Q3', 'major'])),
     ('num_impute', imputation.MeanMedianImputer(imputation_method='median', variables=['education', 'years_exp']))]
)

# %%
from sklearn import model_selection

# %%
kag_X, kag_y = get_rawX_y(raw, 'Q6')

kag_X_train, kag_X_test, kag_y_train, kag_y_test = \
model_selection.train_test_split(
    kag_X, kag_y, test_size=.3, random_state=42, stratify=kag_y)

# %%
X_train = kag_pl.fit_transform(kag_X_train, kag_y_train)

X_test = kag_pl.transform(kag_X_test)

# %%
print(X_train)
# Out:
#        age  education  years_exp  compensation  python  r  sql  Q1_Male  \
# 587     25       18.0        4.0             0       1  0    1        1
# 3065    22       16.0        1.0         10000       1  0    0        1
# 8435    22       18.0        1.0             0       1  0    0        1
# 3110    40       20.0        3.0        125000       1  0    1        0
# 16372   45       12.0        5.0        100000       1  0    1        1
# ...    ...        ...        ...           ...     ... ..  ...      ...
# 16608   25       16.0        2.0         10000       0  0    1        1
# 7325    18       16.0        1.0         30000       1  0    1        1
# 21810   18       16.0        2.0             0       0  0    0        1
# 4917    25       18.0        1.0        100000       1  0    1        1
# 639     25       18.0        1.0         10000       1  0    0        0
#
#        Q1_Female  Q1_Prefer not to say  Q1_Prefer to self-describe  \
# 587            0                     0                           0
# 3065           0                     0                           0
# 8435           0                     0                           0
# 3110           1                     0                           0
# 16372          0                     0                           0
# ...          ...                   ...                         ...
# 16608          0                     0                           0
# 7325           0                     0                           0
# 21810          0                     0                           0
# 4917           0                     0                           0
# 639            1                     0                           0
#
#        Q3_United States of America  Q3_India  Q3_China  major_cs  major_other  \
# 587                              0         1         0         0            1
# 3065                             0         1         0         1            0
# 8435                             0         1         0         0            1
# 3110                             1         0         0         0            1
# 16372                            1         0         0         0            1
# ...                            ...       ...       ...       ...          ...
# 16608                            0         1         0         1            0
# 7325                             1         0         0         1            0
# 21810                            0         1         0         1            0
# 4917                             1         0         0         0            0
# 639                              0         1         0         1            0
#
#        major_eng  major_stat
# 587            0           0
# 3065           0           0
# 8435           0           0
# 3110           0           0
# 16372          0           0
# ...          ...         ...
# 16608          0           0
# 7325           0           0
# 21810          0           0
# 4917           0           1
# 639            0           0
#
# [2110 rows x 18 columns]

# %%
kag_y_train
# Out:
# 587      Software Engineer
# 3065        Data Scientist
# 8435        Data Scientist
# 3110        Data Scientist
# 16372    Software Engineer
#                ...
# 16608    Software Engineer
# 7325     Software Engineer
# 21810       Data Scientist
# 4917        Data Scientist
# 639         Data Scientist
# Name: Q6, Length: 2110, dtype: object

# %% [markdown]
# ## Exploratory Data Analysis

# %%
(X_train
 .assign(data_scientist = kag_y_train == 'Data Scientist')
 .corr(method='spearman')
 .style
 .background_gradient(cmap='RdBu', vmax=1, vmin=-1)
 .set_sticky(axis='index')
)
# Out:
# <style type="text/css">
# #T_b77cf thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_b77cf tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# #T_b77cf_row0_col0, #T_b77cf_row1_col1, #T_b77cf_row2_col2, #T_b77cf_row3_col3, #T_b77cf_row4_col4, #T_b77cf_row5_col5, #T_b77cf_row6_col6, #T_b77cf_row7_col7, #T_b77cf_row8_col8, #T_b77cf_row9_col9, #T_b77cf_row10_col10, #T_b77cf_row11_col11, #T_b77cf_row12_col12, #T_b77cf_row13_col13, #T_b77cf_row14_col14, #T_b77cf_row15_col15, #T_b77cf_row16_col16, #T_b77cf_row17_col17, #T_b77cf_row18_col18 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_b77cf_row0_col1, #T_b77cf_row1_col0 {
#   background-color: #a2cde3;
#   color: #000000;
# }
# #T_b77cf_row0_col2, #T_b77cf_row2_col0 {
#   background-color: #3b88be;
#   color: #f1f1f1;
# }
# #T_b77cf_row0_col3, #T_b77cf_row3_col0 {
#   background-color: #7eb8d7;
#   color: #000000;
# }
# #T_b77cf_row0_col4, #T_b77cf_row0_col10, #T_b77cf_row2_col17, #T_b77cf_row4_col0, #T_b77cf_row4_col7, #T_b77cf_row7_col4, #T_b77cf_row9_col11, #T_b77cf_row10_col0, #T_b77cf_row10_col11, #T_b77cf_row11_col9, #T_b77cf_row11_col10, #T_b77cf_row17_col2 {
#   background-color: #eff3f5;
#   color: #000000;
# }
# #T_b77cf_row0_col5, #T_b77cf_row5_col0, #T_b77cf_row8_col11, #T_b77cf_row11_col8 {
#   background-color: #deebf2;
#   color: #000000;
# }
# #T_b77cf_row0_col6, #T_b77cf_row5_col15, #T_b77cf_row6_col0, #T_b77cf_row15_col5 {
#   background-color: #ddebf2;
#   color: #000000;
# }
# #T_b77cf_row0_col7, #T_b77cf_row2_col5, #T_b77cf_row4_col16, #T_b77cf_row4_col17, #T_b77cf_row5_col2, #T_b77cf_row7_col0, #T_b77cf_row9_col15, #T_b77cf_row15_col9, #T_b77cf_row16_col4, #T_b77cf_row17_col4 {
#   background-color: #f5f6f7;
#   color: #000000;
# }
# #T_b77cf_row0_col8, #T_b77cf_row3_col9, #T_b77cf_row8_col0, #T_b77cf_row8_col16, #T_b77cf_row9_col3, #T_b77cf_row9_col12, #T_b77cf_row10_col12, #T_b77cf_row12_col9, #T_b77cf_row12_col10, #T_b77cf_row13_col17, #T_b77cf_row16_col8, #T_b77cf_row17_col13 {
#   background-color: #f8f2ef;
#   color: #000000;
# }
# #T_b77cf_row0_col9, #T_b77cf_row2_col6, #T_b77cf_row3_col10, #T_b77cf_row4_col11, #T_b77cf_row6_col2, #T_b77cf_row7_col13, #T_b77cf_row9_col0, #T_b77cf_row10_col3, #T_b77cf_row10_col15, #T_b77cf_row11_col4, #T_b77cf_row13_col7, #T_b77cf_row15_col10 {
#   background-color: #edf2f5;
#   color: #000000;
# }
# #T_b77cf_row0_col11, #T_b77cf_row11_col0 {
#   background-color: #9bc9e0;
#   color: #000000;
# }
# #T_b77cf_row0_col12, #T_b77cf_row12_col0 {
#   background-color: #f6af8e;
#   color: #000000;
# }
# #T_b77cf_row0_col13, #T_b77cf_row4_col13, #T_b77cf_row5_col16, #T_b77cf_row6_col10, #T_b77cf_row8_col10, #T_b77cf_row10_col6, #T_b77cf_row10_col8, #T_b77cf_row10_col14, #T_b77cf_row10_col16, #T_b77cf_row10_col17, #T_b77cf_row13_col0, #T_b77cf_row13_col4, #T_b77cf_row14_col10, #T_b77cf_row16_col5, #T_b77cf_row16_col10, #T_b77cf_row17_col10 {
#   background-color: #f8f4f2;
#   color: #000000;
# }
# #T_b77cf_row0_col14, #T_b77cf_row3_col14, #T_b77cf_row7_col9, #T_b77cf_row9_col7, #T_b77cf_row14_col0, #T_b77cf_row14_col3 {
#   background-color: #fcd5bf;
#   color: #000000;
# }
# #T_b77cf_row0_col15, #T_b77cf_row3_col6, #T_b77cf_row6_col3, #T_b77cf_row15_col0, #T_b77cf_row15_col18, #T_b77cf_row18_col15 {
#   background-color: #d1e5f0;
#   color: #000000;
# }
# #T_b77cf_row0_col16, #T_b77cf_row1_col10, #T_b77cf_row2_col16, #T_b77cf_row3_col7, #T_b77cf_row3_col8, #T_b77cf_row5_col9, #T_b77cf_row7_col3, #T_b77cf_row8_col3, #T_b77cf_row9_col5, #T_b77cf_row10_col1, #T_b77cf_row16_col0, #T_b77cf_row16_col2 {
#   background-color: #f6f7f7;
#   color: #000000;
# }
# #T_b77cf_row0_col17, #T_b77cf_row0_col18, #T_b77cf_row6_col17, #T_b77cf_row17_col0, #T_b77cf_row17_col6, #T_b77cf_row18_col0 {
#   background-color: #e9f0f4;
#   color: #000000;
# }
# #T_b77cf_row1_col2, #T_b77cf_row2_col1, #T_b77cf_row4_col15, #T_b77cf_row15_col4 {
#   background-color: #e4eef4;
#   color: #000000;
# }
# #T_b77cf_row1_col3, #T_b77cf_row3_col1, #T_b77cf_row3_col15, #T_b77cf_row12_col14, #T_b77cf_row14_col12, #T_b77cf_row15_col3 {
#   background-color: #c5dfec;
#   color: #000000;
# }
# #T_b77cf_row1_col4, #T_b77cf_row1_col9, #T_b77cf_row4_col1, #T_b77cf_row9_col1 {
#   background-color: #ecf2f5;
#   color: #000000;
# }
# #T_b77cf_row1_col5, #T_b77cf_row5_col1, #T_b77cf_row11_col17, #T_b77cf_row17_col11 {
#   background-color: #dae9f2;
#   color: #000000;
# }
# #T_b77cf_row1_col6, #T_b77cf_row1_col8, #T_b77cf_row5_col8, #T_b77cf_row6_col1, #T_b77cf_row7_col14, #T_b77cf_row8_col1, #T_b77cf_row8_col5, #T_b77cf_row8_col15, #T_b77cf_row13_col14, #T_b77cf_row14_col7, #T_b77cf_row14_col13, #T_b77cf_row15_col8 {
#   background-color: #eaf1f5;
#   color: #000000;
# }
# #T_b77cf_row1_col7, #T_b77cf_row7_col1 {
#   background-color: #f9ebe3;
#   color: #000000;
# }
# #T_b77cf_row1_col11, #T_b77cf_row1_col18, #T_b77cf_row11_col1, #T_b77cf_row11_col15, #T_b77cf_row15_col11, #T_b77cf_row18_col1 {
#   background-color: #bbdaea;
#   color: #000000;
# }
# #T_b77cf_row1_col12, #T_b77cf_row11_col14, #T_b77cf_row12_col1, #T_b77cf_row14_col11 {
#   background-color: #fac8af;
#   color: #000000;
# }
# #T_b77cf_row1_col13, #T_b77cf_row1_col16, #T_b77cf_row4_col9, #T_b77cf_row4_col10, #T_b77cf_row5_col10, #T_b77cf_row9_col4, #T_b77cf_row9_col10, #T_b77cf_row10_col4, #T_b77cf_row10_col5, #T_b77cf_row10_col9, #T_b77cf_row13_col1, #T_b77cf_row16_col1 {
#   background-color: #f7f6f6;
#   color: #000000;
# }
# #T_b77cf_row1_col14, #T_b77cf_row14_col1 {
#   background-color: #fcd7c2;
#   color: #000000;
# }
# #T_b77cf_row1_col15, #T_b77cf_row3_col4, #T_b77cf_row3_col5, #T_b77cf_row4_col3, #T_b77cf_row5_col3, #T_b77cf_row6_col11, #T_b77cf_row11_col6, #T_b77cf_row15_col1 {
#   background-color: #d7e8f1;
#   color: #000000;
# }
# #T_b77cf_row1_col17, #T_b77cf_row2_col11, #T_b77cf_row4_col18, #T_b77cf_row6_col18, #T_b77cf_row11_col2, #T_b77cf_row17_col1, #T_b77cf_row18_col4, #T_b77cf_row18_col6 {
#   background-color: #e0ecf3;
#   color: #000000;
# }
# #T_b77cf_row2_col3, #T_b77cf_row3_col2 {
#   background-color: #c0dceb;
#   color: #000000;
# }
# #T_b77cf_row2_col4, #T_b77cf_row3_col16, #T_b77cf_row4_col2, #T_b77cf_row16_col3 {
#   background-color: #f9efe9;
#   color: #000000;
# }
# #T_b77cf_row2_col7, #T_b77cf_row7_col2, #T_b77cf_row12_col16, #T_b77cf_row16_col12 {
#   background-color: #e7f0f4;
#   color: #000000;
# }
# #T_b77cf_row2_col8, #T_b77cf_row4_col14, #T_b77cf_row7_col10, #T_b77cf_row8_col2, #T_b77cf_row10_col7, #T_b77cf_row14_col4 {
#   background-color: #fae9df;
#   color: #000000;
# }
# #T_b77cf_row2_col9, #T_b77cf_row6_col8, #T_b77cf_row8_col6, #T_b77cf_row8_col17, #T_b77cf_row9_col2, #T_b77cf_row17_col8 {
#   background-color: #f0f4f6;
#   color: #000000;
# }
# #T_b77cf_row2_col10, #T_b77cf_row2_col15, #T_b77cf_row9_col17, #T_b77cf_row9_col18, #T_b77cf_row10_col2, #T_b77cf_row10_col18, #T_b77cf_row15_col2, #T_b77cf_row16_col18, #T_b77cf_row17_col9, #T_b77cf_row18_col9, #T_b77cf_row18_col10, #T_b77cf_row18_col16 {
#   background-color: #f3f5f6;
#   color: #000000;
# }
# #T_b77cf_row2_col12, #T_b77cf_row5_col13, #T_b77cf_row12_col2, #T_b77cf_row12_col17, #T_b77cf_row13_col5, #T_b77cf_row17_col12 {
#   background-color: #fbe4d6;
#   color: #000000;
# }
# #T_b77cf_row2_col13, #T_b77cf_row7_col16, #T_b77cf_row9_col16, #T_b77cf_row13_col2, #T_b77cf_row16_col7, #T_b77cf_row16_col9 {
#   background-color: #f2f5f6;
#   color: #000000;
# }
# #T_b77cf_row2_col14, #T_b77cf_row4_col8, #T_b77cf_row4_col12, #T_b77cf_row7_col17, #T_b77cf_row8_col4, #T_b77cf_row8_col9, #T_b77cf_row9_col8, #T_b77cf_row9_col14, #T_b77cf_row12_col4, #T_b77cf_row14_col2, #T_b77cf_row14_col9, #T_b77cf_row17_col7 {
#   background-color: #f8f1ed;
#   color: #000000;
# }
# #T_b77cf_row2_col18, #T_b77cf_row7_col11, #T_b77cf_row11_col7, #T_b77cf_row18_col2 {
#   background-color: #fbe3d4;
#   color: #000000;
# }
# #T_b77cf_row3_col11, #T_b77cf_row11_col3 {
#   background-color: #408fc1;
#   color: #f1f1f1;
# }
# #T_b77cf_row3_col12, #T_b77cf_row12_col3 {
#   background-color: #dc6e57;
#   color: #f1f1f1;
# }
# #T_b77cf_row3_col13, #T_b77cf_row13_col3 {
#   background-color: #fbe6da;
#   color: #000000;
# }
# #T_b77cf_row3_col17, #T_b77cf_r

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 4))
(X_train
 .assign(data_scientist = kag_y_train)
 .groupby('r')
 .data_scientist
 .value_counts()
 .unstack()
 .plot.bar(ax=ax)
)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 4))
(pd.crosstab(index=X_train['major_cs'],
             columns=kag_y)
 .plot.bar(ax=ax)
)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 4))
(X_train
 .plot.scatter(x='years_exp', y='compensation', alpha=.3, ax=ax, c='purple')
)

plt.show()

# %% [markdown]
# #### adding Jitter

# %%
import seaborn.objects as so

# %%
fig = plt.figure(figsize=(8, 4))
(so
 .Plot(X_train.assign(title=kag_y_train), x='years_exp', y='compensation', color='title')
 .add(so.Dots(alpha=.3, pointsize=2), so.Jitter(x=.5, y=10_000))
 .add(so.Line(), so.PolyFit())
 .on(fig)
 .plot()
)

# %% [markdown]
# #### Adjusted Visualization

# %%
fig = plt.figure(figsize=(8, 4))
(so
 .Plot(X_train
       # .query('compensation < 200_000 and years_exp < 16')
       .assign(
           title=kag_y_train,
           country=(X_train
                    .loc[:, 'Q3_United States of America': 'Q3_China']
                    .idxmax(axis='columns')
                   )
       ), x='years_exp', y='compensation', color='title')
 .facet('country')
 .add(so.Dots(alpha=.01, pointsize=2, color='grey'), so.Jitter(x=.5, y=10_000), col=None)
 .add(so.Dots(alpha=.5, pointsize=1.5), so.Jitter(x=.5, y=10_000))
 .add(so.Line(pointsize=1), so.PolyFit(order=2))
 .scale(x=so.Continuous().tick(at=[0, 1, 2, 3, 4, 5]))
 .limit(y=(-10_000, 200_000), x=(-1, 6))
 .on(fig)
 .plot()
 )

# %% [markdown]
# ## Tree Creation

# %%
# Numerical Manipualtion
import numpy as np
import numpy.random as rn

# %%
pos_center = 12
pos_count = 100
neg_center = 7
neg_count = 1000

rs = rn.RandomState(rn.MT19937(rn.SeedSequence(42)))
gini = pd.DataFrame({'value':
                      np.append((pos_center) + rs.randn(pos_count),
                               (neg_center) + rs.randn(neg_count)),
                      'label':
                      ['pos']* pos_count + ['neg'] * neg_count})

# %%
fig, ax = plt.subplots(figsize=(8, 4))
_ = (gini
     .groupby('label')
     [['value']]
     .plot.hist(bins=30, alpha=.5, ax=ax, edgecolor='black')
    )
ax.legend(['Negative', 'Positive'])

plt.show()

# %%
def calc_gini(df, val_col, label_col, pos_val, split_point,
             debug=False):
    """
    This function calculates the Gini impurity of a dataset. Gini Impurity
    is a measure of the probability of a random sample being classified
    incorectly when a feature is sued to split the data. The lower the 
    impurity, the better the split.
    
    Parameters:
    df(pd.DataFrame): The dataframe containing the data
    val_col (str): the column name of the feature used to split the data
    label_col (str): The column name of the target variable
    pos_val (str or int): The value of the target variable that represents
        the positive class
    split_point (float): The threshold used to split the data.
    debug (bool): optional, when set to True, prints the calculated Gini
        impurities and the final weighted aveerage
        
    Returns:
    float: The weighted average of Gini impurity for the positive and
        negative subsets.
    """
    ge_split = df[val_col] >= split_point
    eq_pos = df[label_col] == pos_val
    tp = df[ge_split & eq_pos].shape[0]
    fp = df[ge_split & ~eq_pos].shape[0]
    tn = df[~ge_split & ~eq_pos].shape[0]
    fn = df[~ge_split & eq_pos].shape[0]
    pos_size = tp+fp
    neg_size = tn+fn
    total_size = len(df)
    if pos_size == 0:
        gini_pos = 0
    else:
        gini_pos = 1 - (tp/pos_size)**2 - (fp/pos_size)**2
    if neg_size == 0:
        gini_neg = 0
    else:
        gini_neg = 1 - (tn/neg_size)**2 - (fn/neg_size)**2
    weighted_avg = gini_pos * (pos_size/total_size) * \
    gini_neg * (neg_size/total_size)
    if debug:
        print(f'{gini_pos=:3} {gini_neg=:.3} {weighted_avg=:3}')
    return weighted_avg

# %%
calc_gini(gini, val_col='value', label_col='label', pos_val='pos', split_point=9.24, debug=True)
# Out:
# gini_pos=0.21708826063121614 gini_neg=0.00202 weighted_avg=4.050598243782082e-05
# 4.050598243782082e-05

# %%
values = np.arange(5, 15, .1)
ginis = []
for v in values:
    ginis.append(calc_gini(gini, val_col='value', label_col='label',
                          pos_val='pos', split_point=v))

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(values, ginis)
ax.set_title('Gini Coefficient')
ax.set_ylabel('Gini Coefficient')
ax.set_xlabel('Split Point')

plt.show()

# %%
pd.Series(ginis, index=values).loc[9.5:10.5]
# Out:
# 9.6     0.000022
# 9.7     0.000016
# 9.8     0.000013
# 9.9     0.000007
# 10.0    0.000010
# 10.1    0.000000
# 10.2    0.000000
# 10.3    0.000000
# 10.4    0.000000
# 10.5    0.000000
# dtype: float64

# %%
print(pd.DataFrame({'gini':ginis, 'split':values})
      .query('gini <= gini.min()'))
# Out:
#     gini  split
# 0    0.0    5.0
# 1    0.0    5.1
# 2    0.0    5.2
# 3    0.0    5.3
# 4    0.0    5.4
# ..   ...    ...
# 95   0.0   14.5
# 96   0.0   14.6
# 97   0.0   14.7
# 98   0.0   14.8
# 99   0.0   14.9
#
# [90 rows x 2 columns]

# %% [markdown]
# #### Coeffiecients in Trees

# %%
from sklearn import tree
stump = tree.DecisionTreeClassifier(max_depth=1)
stump.fit(gini[['value']], gini.label)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
fig, ax = plt.subplots(figsize=(8, 4))
tree.plot_tree(stump, feature_names=['value'],
               filled=True, 
               class_names=stump.classes_,
               ax=ax)
# Out:
# [Text(0.5, 0.75, 'value <= 9.708\ngini = 0.165\nsamples = 1100\nvalue = [1000, 100]\nclass = neg'),
#  Text(0.25, 0.25, 'gini = 0.002\nsamples = 999\nvalue = [998, 1]\nclass = neg'),
#  Text(0.75, 0.25, 'gini = 0.039\nsamples = 101\nvalue = [2, 99]\nclass = pos')]

# %%
gini_pos = 0.039
gini_neg = 0.002
pos_size = 101
neg_size = 999
total_size = pos_size + neg_size
weighted_avg = gini_pos * (pos_size/total_size) + \
gini_neg * (neg_size/total_size)

# %%
print(weighted_avg)
# Out:
# 0.005397272727272727

# %%
import xgboost as xgb

# %%
# from graphviz import Digraph

# dot = Digraph(comment='The Round Table')
# dot.node('A', 'King Arthur')
# dot.node('B', 'Sir Bedevere the Wise')
# dot.node('L', 'Sir Lancelot the Brave')

# dot.edges(['AB', 'AL'])
# dot.edge('B', 'L', constraint='false')
# print(dot.source)

# %%
xg_stump = xgb.XGBClassifier(n_estimators=1, max_depth=1)
xg_stump.fit(gini[['value']], (gini.label== 'pos'))
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=1, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=1, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
import os
os.environ["PATH"] += os.pathsep + '/Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/bin'


xgb.plot_tree(xg_stump, num_trees=0)

plt.show()

# %%
import subprocess

def my_dot_export(xg, num_trees, filename, title='', direction='TB'):
    """Exports a specified number of trees from an XGBoost model as a graph 
    visualization in dot and png formats.

    Args:
        xg: An XGBoost model.
        num_trees: The number of tree to export.
        filename: The name of the file to save the exported visualization.
        title: The title to display on the graph visualization (optional).
        direction: The direction to lay out the graph, either 'TB' (top to 
            bottom) or 'LR' (left to right) (optional).
    """
    res = xgb.to_graphviz(xg, num_trees=num_trees)
    content = f'''    node [fontname = "Helvetica"];
    edge [fontname = "Helvetica Thin"];
    label = "{title}"
    fontname = "Helvetica"
    '''
    out = res.source.replace('graph [ rankdir=TB ]', 
                             f'graph [ rankdir={direction} ];\n {content}')
    # dot -Gdpi=300 -Tpng -ocourseflow.png courseflow.dot 
    dot_filename = filename
    with open(dot_filename, 'w') as fout:
        fout.write(out)
    png_filename = dot_filename.replace('.dot', '.png')
    subprocess.run(f'dot -Gdpi=300 -Tpng -o{png_filename} {dot_filename}'.split())

# %%
my_dot_export(xg_stump, num_trees=0, filename='/Users/isisromero/Desktop/img_XGB/stump_xg.dot', title='A demo stump')

# %% [markdown]
# #### Another Visualization Tool

# %%
import dtreeviz
viz = dtreeviz.model(xg_stump, X_train=gini[['value']], 
                     y_train=gini.label=='pos',
    target_name='positive',
    feature_names=['value'], class_names=['negative', 'positive'],
    tree_index=0)
viz.view()

# %% [markdown]
# ## Stumps on Real Data

# %%
stump_dt = tree.DecisionTreeClassifier(max_depth=1)
X_train = kag_pl.fit_transform(kag_X_train)
stump_dt.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
fig, ax = plt.subplots(figsize=(8, 4))
features = list(c for c in X_train.columns)
tree.plot_tree(stump_dt, feature_names=features,
               filled=True,
               class_names=stump_dt.classes_,
               ax=ax)
# Out:
# [Text(0.5, 0.75, 'r <= 0.5\ngini = 0.496\nsamples = 2110\nvalue = [1153, 957]\nclass = Data Scientist'),
#  Text(0.25, 0.25, 'gini = 0.493\nsamples = 1484\nvalue = [653, 831]\nclass = Software Engineer'),
#  Text(0.75, 0.25, 'gini = 0.322\nsamples = 626\nvalue = [500, 126]\nclass = Data Scientist')]

# %%
X_test = kag_pl.transform(kag_X_test)

# %%
stump_dt.score(X_test, kag_y_test)
# Out:
# 0.6243093922651933

# %% [markdown]
# #### The Dummy Classifier

# %%
from sklearn import dummy

# %%
dummy_model = dummy.DummyClassifier()

# %%
dummy_model.fit(X_train, kag_y_train)
# Out:
# DummyClassifier()

# %%
dummy_model.score(X_test, kag_y_test)
# Out:
# 0.5458563535911602

# %%
import xgboost as xgb

# %%
kag_stump = xgb.XGBClassifier(n_estimators=1, max_depth=1)
kag_stump.fit(X_train, kag_y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 2
#       1 kag_stump = xgb.XGBClassifier(n_estimators=1, max_depth=1)
# ----> 2 kag_stump.fit(X_train, kag_y_train)
#
# File ~/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/xgboost/sklearn.py:1440, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1435     expected_classes = np.arange(self.n_classes_)
#    1436 if (
#    1437     self.classes_.shape != expected_classes.shape
#    1438     or not (self.classes_ == expected_classes).all()
#    1439 ):
# -> 1440     raise ValueError(
#    1441         f"Invalid classes inferred from unique values of `y`.  "
#    1442         f"Expected: {expected_classes}, got {self.classes_}"
#    1443     )
#    1445 params = self.get_xgb_params()
#    1447 if callable(self.objective):
#
# ValueError: Invalid classes inferred from unique values of `y`.  Expected: [0 1], got ['Data Scientist' 'Software Engineer']

# %%
print(kag_y_train)
# Out:
# 587      Software Engineer
# 3065        Data Scientist
# 8435        Data Scientist
# 3110        Data Scientist
# 16372    Software Engineer
#                ...
# 16608    Software Engineer
# 7325     Software Engineer
# 21810       Data Scientist
# 4917        Data Scientist
# 639         Data Scientist
# Name: Q6, Length: 2110, dtype: object

# %%
print(kag_y_train == 'Software Engineer')
# Out:
# 587       True
# 3065     False
# 8435     False
# 3110     False
# 16372     True
#          ...
# 16608     True
# 7325      True
# 21810    False
# 4917     False
# 639      False
# Name: Q6, Length: 2110, dtype: bool

# %% [markdown]
# #### Using Label Encoder

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
y_train = label_encoder.fit_transform(kag_y_train)
y_test = label_encoder.transform(kag_y_test)

# %%
y_test[:5]
# Out:
# array([1, 0, 0, 1, 1])

# %%
label_encoder.classes_
# Out:
# array(['Data Scientist', 'Software Engineer'], dtype=object)

# %%
# Inverse Tranformation Procedure
label_encoder.inverse_transform([0, 1])
# Out:
# array(['Data Scientist', 'Software Engineer'], dtype=object)

# %%
kag_stump = xgb.XGBClassifier(n_estimators=1, max_depth=1)
kag_stump.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=1, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=1, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
kag_stump.score(X_test, y_test)
# Out:
# 0.6243093922651933

# %%
my_dot_export(kag_stump, num_trees=0, filename='/Users/isisromero/Desktop/img_XGB/stump_xg.dot',
             title='XGBoost Stump')

# %%
kag_stump.classes_
# Out:
# array([0, 1])

# %%
def inv_logit(p: float) -> float:
    """
    Compute the inverse logit function of a given value.

    The inverse logit function is defined as:
        f(p) = exp(p) / (1 + exp(p))

    Parameters
    ----------
    p : float
        The input value to the inverse logit function.

    Returns
    -------
    float
        The output of the inverse logit function.
    """
    return np.exp(p) / (1 + np.exp(p))

# %%
inv_logit(.07117741922)
# Out:
# 0.5177868460919524

# %%
inv_logit(-.3592)
# Out:
# 0.41115323716754393

# %%
fig, ax = plt.subplots(figsize=(8, 4))
vals = np.linspace(-7, 7)
ax.plot(vals, inv_logit(vals))
ax.annotate('Crossover point', (0,.5), (-5,.8), arrowprops={'color':'k'})
ax.annotate('Predict Positive', (5,.6), (1,.6), va='center', arrowprops={'color':'k'})
ax.annotate('Predict Negative', (-5,.4), (-3,.4), va='center', arrowprops={'color':'k'})
# Out:
# Text(-3, 0.4, 'Predict Negative')

# %% [markdown]
# ## Model Complexity & Hyperparameters
#
# #### Underfit Model

# %%
underfit = tree.DecisionTreeClassifier(max_depth=1)
X_train = kag_pl.fit_transform(kag_X_train)

# %%
underfit.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
underfit.score(X_test, kag_y_test)
# Out:
# 0.6243093922651933

# %% [markdown]
# #### Overfitting with Decision Trees

# %%
hi_variance = tree.DecisionTreeClassifier(max_depth=None)
X_train = kag_pl.fit_transform(kag_X_train)

# %%
hi_variance.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier()

# %%
hi_variance.score(X_test, kag_y_test)
# Out:
# 0.6596685082872928

# %%
fig, ax = plt.subplots(figsize=(8, 4))
features = list(c for c in X_train.columns)
tree.plot_tree(hi_variance, feature_names=features, filled=True)
# Out:
# [Text(0.6582503916378565, 0.9772727272727273, 'r <= 0.5\ngini = 0.496\nsamples = 2110\nvalue = [1153, 957]'),
#  Text(0.3974685339239412, 0.9318181818181818, 'major_cs <= 0.5\ngini = 0.493\nsamples = 1484\nvalue = [653, 831]'),
#  Text(0.1936531033923941, 0.8863636363636364, 'Q3_United States of America <= 0.5\ngini = 0.49\nsamples = 718\nvalue = [410, 308]'),
#  Text(0.07922226123595505, 0.8409090909090909, 'years_exp <= 0.5\ngini = 0.491\nsamples = 322\nvalue = [140, 182]'),
#  Text(0.026361279170267933, 0.7954545454545454, 'education <= 17.0\ngini = 0.463\nsamples = 74\nvalue = [47, 27]'),
#  Text(0.019878997407087293, 0.75, 'age <= 27.5\ngini = 0.499\nsamples = 40\nvalue = [21, 19]'),
#  Text(0.018150388936905792, 0.7045454545454546, 'major_stat <= 0.5\ngini = 0.5\nsamples = 38\nvalue = [19, 19]'),
#  Text(0.016421780466724288, 0.6590909090909091, 'compensation <= 55000.0\ngini = 0.498\nsamples = 36\nvalue = [17, 19]'),
#  Text(0.014693171996542784, 0.6136363636363636, 'compensation <= 15000.0\ngini = 0.5\nsamples = 35\nvalue = [17, 18]'),
#  Text(0.01296456352636128, 0.5681818181818182, 'python <= 0.5\ngini = 0.496\nsamples = 33\nvalue = [15, 18]'),
#  Text(0.006914433880726016, 0.5227272727272727, 'age <= 23.5\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.003457216940363008, 0.4772727272727273, 'Q1_Male <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.001728608470181504, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.005185825410544511, 0.4318181818181818, 'age <= 20.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.003457216940363008, 0.38636363636363635, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.006914433880726016, 0.38636363636363635, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.010371650821089023, 0.4772727272727273, 'Q3_India <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.00864304235090752, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.012100259291270527, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.01901469317199654, 0.5227272727272727, 'Q1_Female <= 0.5\ngini = 0.5\nsamples = 22\nvalue = [11, 11]'),
#  Text(0.01728608470181504, 0.4772727272727273, 'Q3_India <= 0.5\ngini = 0.495\nsamples = 20\nvalue = [9, 11]'),
#  Text(0.015557476231633534, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.01901469317199654, 0.4318181818181818, 'compensation <= 5000.0\ngini = 0.488\nsamples = 19\nvalue = [8, 11]'),
#  Text(0.014693171996542784, 0.38636363636363635, 'age <= 20.0\ngini = 0.469\nsamples = 16\nvalue = [6, 10]'),
#  Text(0.011235955056179775, 0.3409090909090909, 'education <= 14.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.00950734658599827, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01296456352636128, 0.29545454545454547, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.018150388936905792, 0.3409090909090909, 'age <= 23.5\ngini = 0.426\nsamples = 13\nvalue = [4, 9]'),
#  Text(0.016421780466724288, 0.29545454545454547, 'sql <= 0.5\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.01296456352636128, 0.25, 'major_other <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.011235955056179775, 0.20454545454545456, 'gini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.014693171996542784, 0.20454545454545456, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.019878997407087293, 0.25, 'major_other <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.018150388936905792, 0.20454545454545456, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.021607605877268798, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.019878997407087293, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.023336214347450302, 0.38636363636363635, 'age <= 20.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.021607605877268798, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.025064822817631807, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.020743301642178046, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.016421780466724288, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.018150388936905792, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.019878997407087293, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.021607605877268798, 0.7045454545454546, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.032843560933448576, 0.75, 'sql <= 0.5\ngini = 0.36\nsamples = 34\nvalue = [26, 8]'),
#  Text(0.02679343128781331, 0.7045454545454546, 'compensation <= 5000.0\ngini = 0.269\nsamples = 25\nvalue = [21, 4]'),
#  Text(0.023336214347450302, 0.6590909090909091, 'Q3_India <= 0.5\ngini = 0.095\nsamples = 20\nvalue = [19, 1]'),
#  Text(0.021607605877268798, 0.6136363636363636, 'major_other <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.019878997407087293, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.023336214347450302, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.025064822817631807, 0.6136363636363636, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.03025064822817632, 0.6590909090909091, 'Q3_China <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.028522039757994815, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.03197925669835782, 0.6136363636363636, 'Q1_Female <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.03025064822817632, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.033707865168539325, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03889369057908384, 0.7045454545454546, 'compensation <= 5000.0\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.037165082108902334, 0.6590909090909091, 'age <= 20.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.03543647363872083, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03889369057908384, 0.6136363636363636, 'age <= 23.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.037165082108902334, 0.5681818181818182, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.04062229904926534, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.04062229904926534, 0.6590909090909091, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.13208324330164217, 0.7954545454545454, 'major_stat <= 0.5\ngini = 0.469\nsamples = 248\nvalue = [93, 155]'),
#  Text(0.10297374675885912, 0.75, 'education <= 17.0\ngini = 0.446\nsamples = 220\nvalue = [74, 146]'),
#  Text(0.06522796024200518, 0.7045454545454546, 'years_exp <= 1.5\ngini = 0.38\nsamples = 110\nvalue = [28, 82]'),
#  Text(0.05185825410544512, 0.6590909090909091, 'compensation <= 15000.0\ngini = 0.49\nsamples = 28\nvalue = [12, 16]'),
#  Text(0.05012964563526361, 0.6136363636363636, 'age <= 23.5\ngini = 0.444\nsamples = 24\nvalue = [8, 16]'),
#  Text(0.04407951598962835, 0.5681818181818182, 'python <= 0.5\ngini = 0.36\nsamples = 17\nvalue = [4, 13]'),
#  Text(0.04062229904926534, 0.5227272727272727, 'age <= 20.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.03889369057908384, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.04235090751944685, 0.4772727272727273, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.04753673292999136, 0.5227272727272727, 'Q1_Prefer not to say <= 0.5\ngini = 0.245\nsamples = 14\nvalue = [2, 12]'),
#  Text(0.045808124459809856, 0.4772727272727273, 'sql <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.04407951598962835, 0.4318181818181818, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.04753673292999136, 0.4318181818181818, 'major_other <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.045808124459809856, 0.38636363636363635, 'compensation <= 5000.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.04407951598962835, 0.3409090909090909, 'gini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.04753673292999136, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.049265341400172864, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.049265341400172864, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.056179775280898875, 0.5681818181818182, 'compensation <= 5000.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.05445116681071737, 0.5227272727272727, 'major_other <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.052722558340535866, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.056179775280898875, 0.4772727272727273, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.05445116681071737, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.05790838375108038, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05790838375108038, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.05358686257562662, 0.6136363636363636, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.07859766637856526, 0.6590909090909091, 'age <= 20.0\ngini = 0.314\nsamples = 82\nvalue = [16, 66]'),
#  Text(0.07686905790838375, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08032627484874676, 0.6136363636363636, 'age <= 45.0\ngini = 0.302\nsamples = 81\nvalue = [15, 66]'),
#  Text(0.07859766637856526, 0.5681818181818182, 'years_exp <= 4.5\ngini = 0.289\nsamples = 80\nvalue = [14, 66]'),
#  Text(0.07033275713050995, 0.5227272727272727, 'age <= 23.5\ngini = 0.357\nsamples = 56\nvalue = [13, 43]'),
#  Text(0.06309420916162489, 0.4772727272727273, 'compensation <= 5000.0\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.06136560069144339, 0.4318181818181818, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.06482281763180639, 0.4318181818181818, 'years_exp <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.06309420916162489, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0665514261019879, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.07757130509939499, 0.4772727272727273, 'compensation <= 45000.0\ngini = 0.402\nsamples = 43\nvalue = [12, 31]'),
#  Text(0.07584269662921349, 0.4318181818181818, 'sql <= 0.5\ngini = 0.387\nsamples = 42\nvalue = [11, 31]'),
#  Text(0.07000864304235091, 0.38636363636363635, 'age <= 32.5\ngini = 0.32\nsamples = 25\nvalue = [5, 20]'),
#  Text(0.0682800345721694, 0.3409090909090909, 'age <= 27.5\ngini = 0.351\nsamples = 22\nvalue = [5, 17]'),
#  Text(0.06352636127917027, 0.29545454545454547, 'education <= 14.0\ngini = 0.32\nsamples = 20\nvalue = [4, 16]'),
#  Text(0.05920484010371651, 0.25, 'Q1_Female <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.057476231633535005, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.060933448573898014, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06784788245462403, 0.25, 'compensation <= 5000.0\ngini = 0.278\nsamples = 18\nvalue = [3, 15]'),
#  Text(0.06439066551426102, 0.20454545454545456, 'years_exp <= 3.5\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.06266205704407951, 0.1590909090909091, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.06611927398444252, 0.1590909090909091, 'python <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.06439066551426102, 0.11363636363636363, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06784788245462403, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07130509939498704, 0.20454545454545456, 'Q3_India <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.06957649092480553, 0.1590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.07303370786516854, 0.1590909090909091, 'major_other <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.07130509939498704, 0.11363636363636363, 'years_exp <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.06957649092480553, 0.06818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07303370786516854, 0.06818181818181818, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.07476231633535005, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07303370786516854, 0.29545454545454547, 'years_exp <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.07130509939498704, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07476231633535005, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07173725151253241, 0.3409090909090909, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.08167675021607605, 0.38636363636363635, 'python <= 0.5\ngini = 0.457\nsamples = 17\nvalue = [6, 11]'),
#  Text(0.07994814174589455, 0.3409090909090909, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.08340535868625756, 0.3409090909090909, 'compensation <= 15000.0\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.08167675021607605, 0.29545454545454547, 'compensation <= 5000.0\ngini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(0.07994814174589455, 0.25, 'Q1_Male <= 0.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.07821953327571306, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08167675021607605, 0.20454545454545456, 'years_exp <= 3.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.07994814174589455, 0.1590909090909091, 'years_exp <= 2.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.07821953327571306, 0.11363636363636363, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.08167675021607605, 0.11363636363636363, 'major_other <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.07994814174589455, 0.06818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08340535868625756, 0.06818181818181818, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08340535868625756, 0.1590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.08340535868625756, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.08513396715643906, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0792999135695765, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08686257562662057, 0.5227272727272727, 'compensation <= 25000.0\ngini = 0.08\nsamples = 24\nvalue = [1, 23]'),
#  Text(0.08513396715643906, 0.4772727272727273, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.08859118409680207, 0.4772727272727273, 'Q3_China <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.08686257562662057, 0.4318181818181818, 'age <= 27.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08513396715643906, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08859118409680207, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09031979256698358, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.08205488331892827, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14071953327571304, 0.7045454545454546, 'education <= 19.5\ngini = 0.487\nsamples = 110\nvalue = [46, 64]'),
#  Text(0.1323465859982714, 0.6590909090909091, 'education <= 18.5\ngini = 0.477\nsamples = 102\nvalue = [40, 62]'),
#  Text(0.1242437337942956, 0.6136363636363636, 'sql <= 0.5\ngini = 0.487\nsamples = 93\nvalue = [39, 54]'),
#  Text(0.1132238547968885, 0.5681818181818182, 'compensation <= 15000.0\ngini = 0.461\nsamples = 61\nvalue = [22, 39]'),
#  Text(0.10890233362143474, 0.5227272727272727, 'years_exp <= 7.5\ngini = 0.495\nsamples = 40\nvalue = [18, 22]'),
#  Text(0.10717372515125324, 0.4772727272727273, 'age <= 32.5\ngini = 0.497\nsamples = 39\nvalue = [18, 21]'),
#  Text(0.10544511668107173, 0.4318181818181818, 'years_exp <= 3.5\ngini = 0.491\nsamples = 37\nvalue = [16, 21]'),
#  Text(0.10155574762316336, 0.38636363636363635, 'age <= 27.5\ngini = 0.477\nsamples = 28\nvalue = [11, 17]'),
#  Text(0.09982713915298184, 0.3409090909090909, 'age <= 23.5\ngini = 0.453\nsamples = 26\nvalue = [9, 17]'),
#  Text(0.09377700950734659, 0.29545454545454547, 'years_exp <= 2.5\ngini = 0.496\nsamples = 11\nvalue = [5, 6]'),
#  Text(0.09204840103716508, 0.25, 'Q3_India <= 0.5\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.08859118409680207, 0.20454545454545456, 'years_exp <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.08686257562662057, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09031979256698358, 0.1590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.09550561797752809, 0.20454545454545456, 'years_exp <= 1.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.09377700950734659, 0.1590909090909091, 'major_eng <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.09204840103716508, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09550561797752809, 0.11363636363636363, 'python <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.09377700950734659, 0.06818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0972342264477096, 0.06818181818181818, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.0972342264477096, 0.1590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.09550561797752809, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10587726879861711, 0.29545454545454547, 'Q1_Male <= 0.5\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.10069144338807261, 0.25, 'Q3_India <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.0989628349178911, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1024200518582541, 0.20454545454545456, 'python <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.10069144338807261, 0.1590909090909091, 'major_other <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0989628349178911, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1024200518582541, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10414866032843562, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11106309420916162, 0.25, 'python <= 0.5\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.10933448573898012, 0.20454545454545456, 'years_exp <= 2.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.10760587726879861, 0.1590909090909091, 'major_eng <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.10587726879861711, 0.11363636363636363, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.10933448573898012, 0.11363636363636363, 'years_exp <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.10760587726879861, 0.06818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11106309420916162, 0.06818181818181818, 'Q3_China <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.10933448573898012, 0.022727272727272728, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11279170267934313, 0.022727272727272728, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11106309420916162, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11279170267934313, 0.20454545454545456, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.10328435609334485, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.10933448573898012, 0.38636363636363635, 'age <= 27.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.10760587726879861, 0.3409090909090909, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.11106309420916162, 0.3409090909090909, 'major_other <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.10933448573898012, 0.29545454545454547, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11279170267934313, 0.29545454545454547, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.10890233362143474, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.11063094209161625, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11754537597234227, 0.5227272727272727, 'years_exp <= 7.5\ngini = 0.308\nsamples = 21\nvalue = [4, 17]'),
#  Text(0.11408815903197926, 0.4772727272727273, 'compensation <= 75000.0\ngini = 0.124\nsamples = 15\nvalue = [1, 14]'),
#  Text(0.11235955056179775, 0.4318181818181818, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.11581676750216076, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12100259291270528, 0.4772727272727273, 'years_exp <= 12.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.11927398444252377, 0.4318181818181818, 'age <= 32.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.11754537597234227, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12100259291270528, 0.38636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.12273120138288678, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.13526361279170268, 0.5681818181818182, 'years_exp <= 3.5\ngini = 0.498\nsamples = 32\nvalue = [17, 15]'),
#  Text(0.12964563526361278, 0.5227272727272727, 'compensation <= 107500.0\ngini = 0.415\nsamples = 17\nvalue = [12, 5]'),
#  Text(0.12791702679343128, 0.4772727272727273, 'compensation <= 5000.0\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.12618841832324978, 0.4318181818181818, 'age <= 27.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.12445980985306827, 0.38636363636363635, 'major_other <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.12273120138288678, 0.3409090909090909, 'age <= 23.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.12100259291270528, 0.29545454545454547, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.12445980985306827, 0.29545454545454547, 'years_exp <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.12273120138288678, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12618841832324978, 0.25, 'Q3_China <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.12445980985306827, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12791702679343128, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12618841832324978, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.12791702679343128, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.12964563526361278, 0.4318181818181818, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.1313742437337943, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14088159031979255, 0.5227272727272727, 'compensation <= 35000.0\ngini = 0.444\nsamples = 15\nvalue = [5, 10]'),
#  Text(0.1365600691443388, 0.4772727272727273, 'years_exp <= 7.5\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.1331028522039758, 0.4318181818181818, 'major_eng <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.1313742437337943, 0.38636363636363635, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.1348314606741573, 0.38636363636363635, 'Q3_India <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.1331028522039758, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1365600691443388, 0.3409090909090909, 'Q1_Male <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.1348314606741573, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13828867761452032, 0.29545454545454547, 'years_exp <= 4.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1365600691443388, 0.25, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.14001728608470182, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14001728608470182, 0.4318181818181818, 'compensation <= 25000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.13828867761452032, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14174589455488332, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14520311149524634, 0.4772727272727273, 'compensation <= 90000.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.14347450302506481, 0.4318181818181818, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.14693171996542784, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1404494382022472, 0.6136363636363636, 'age <= 32.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.13872082973206568, 0.5681818181818182, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.1421780466724287, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14909248055315472, 0.6590909090909091, 'python <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.14736387208297322, 0.6136363636363636, 'Q3_China <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1456352636127917, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14909248055315472, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1508210890233362, 0.6136363636363636, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.16119273984442523, 0.75, 'sql <= 0.5\ngini = 0.436\nsamples = 28\nvalue = [19, 9]'),
#  Text(0.15773552290406223, 0.7045454545454546, 'years_exp <= 7.5\ngini = 0.32\nsamples = 20\nvalue = [16, 4]'),
#  Text(0.15600691443388073, 0.6590909090909091, 'python <= 0.5\ngini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.15427830596369924, 0.6136363636363636, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.15773552290406223, 0.6136363636363636, 'compensation <= 15000.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.15600691443388073, 0.5681818181818182, 'age <= 20.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.15427830596369924, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15773552290406223, 0.5227272727272727, 'education <= 17.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.15600691443388073, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.15946413137424373, 0.4772727272727273, 'Q3_China <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.15773552290406223, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.16119273984442523, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15946413137424373, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.15946413137424373, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16464995678478825, 0.7045454545454546, 'Q1_Male <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.16292134831460675, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.16637856525496975, 0.6590909090909091, 'compensation <= 15000.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.16464995678478825, 0.6136363636363636, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.16810717372515124, 0.6136363636363636, 'compensation <= 25000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.16637856525496975, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16983578219533277, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.30808394554883317, 0.8409090909090909, 'years_exp <= 4.5\ngini = 0.434\nsamples = 396\nvalue = [270, 126]'),
#  Text(0.2668809420916162, 0.7954545454545454, 'major_eng <= 0.5\ngini = 0.363\nsamples = 294\nvalue = [224, 70]'),
#  Text(0.23028305963699222, 0.75, 'education <= 19.5\ngini = 0.303\nsamples = 204\nvalue = [166, 38]'),
#  Text(0.20689282627484876, 0.7045454545454546, 'years_exp <= 1.5\ngini = 0.348\nsamples = 147\nvalue = [114, 33]'),
#  Text(0.1905790838375108, 0.6590909090909091, 'Q1_Prefer to self-describe <= 0.5\ngini = 0.263\nsamples = 77\nvalue = [65, 12]'),
#  Text(0.1888504753673293, 0.6136363636363636, 'education <= 18.5\ngini = 0.248\nsamples = 76\nvalue = [65, 11]'),
#  Text(0.1871218668971478, 0.5681818181818182, 'age <= 37.5\ngini = 0.231\nsamples = 75\nvalue = [65, 10]'),
#  Text(0.17847882454624028, 0.5227272727272727, 'compensation <= 75000.0\ngini = 0.205\nsamples = 69\nvalue = [61, 8]'),
#  Text(0.16810717372515124, 0.4772727272727273, 'major_stat <= 0.5\ngini = 0.278\nsamples = 30\nvalue = [25, 5]'),
#  Text(0.16464995678478825, 0.4318181818181818, 'education <= 17.0\ngini = 0.408\nsamples = 14\nvalue = [10, 4]'),
#  Text(0.16292134831460675, 0.38636363636363635, 'age <= 23.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.15946413137424373, 0.3409090909090909, 'compensation <= 60000.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.15773552290406223, 0.29545454545454547, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.16119273984442523, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16637856525496975, 0.3409090909090909, 'compensation <= 65000.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.16464995678478825, 0.29545454545454547, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.16810717372515124, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16637856525496975, 0.38636363636363635, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.17156439066551427, 0.4318181818181818, 'compensation <= 65000.0\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.16983578219533277, 0.38636363636363635, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.17329299913569576, 0.38636363636363635, 'age <= 23.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.17156439066551427, 0.3409090909090909, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.17502160760587726, 0.3409090909090909, 'Q1_Male <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.17329299913569576, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.17675021607605879, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1888504753673293, 0.4772727272727273, 'major_other <= 0.5\ngini = 0.142\nsamples = 39\nvalue = [36, 3]'),
#  Text(0.1853932584269663, 0.4318181818181818, 'compensation <= 112500.0\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.18366464995678478, 0.38636363636363635, 'Q1_Female <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.18193604148660328, 0.3409090909090909, 'education <= 17.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.18020743301642178, 0.29545454545454547, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.18366464995678478, 0.29545454545454547, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1853932584269663, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1871218668971478, 0.38636363636363635, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.19230769230769232, 0.4318181818181818, 'compensation <= 112500.0\ngini = 0.067\nsamples = 29\nvalue = [28, 1]'),
#  Text(0.1905790838375108, 0.38636363636363635, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.19403630077787382, 0.38636363636363635, 'sql <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.19230769230769232, 0.3409090909090909, 'compensation <= 137500.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1905790838375108, 0.29545454545454547, 'age <= 23.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1888504753673293, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.19230769230769232, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19403630077787382, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1957649092480553, 0.3409090909090909, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.1957649092480553, 0.5227272727272727, 'compensation <= 30000.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.19403630077787382, 0.4772727272727273, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.1974935177182368, 0.4772727272727273, 'age <= 45.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1957649092480553, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.19922212618841834, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1905790838375108, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19230769230769232, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2232065687121867, 0.6590909090909091, 'compensation <= 75000.0\ngini = 0.42\nsamples = 70\nvalue = [49, 21]'),
#  Text(0.2139152981849611, 0.6136363636363636, 'compensation <= 10000.0\ngini = 0.499\nsamples = 25\nvalue = [13, 12]'),
#  Text(0.20959377700950735, 0.5681818181818182, 'age <= 27.5\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.20613656006914433, 0.5227272727272727, 'education <= 17.0\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.20440795159896283, 0.4772727272727273, 'Q1_Female <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.20267934312878133, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.20613656006914433, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.20786516853932585, 0.4772727272727273, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.21305099394987034, 0.5227272727272727, 'Q1_Female <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.21132238547968885, 0.4772727272727273, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.21477960242005187, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.21823681936041486, 0.5681818181818182, 'years_exp <= 3.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.21650821089023337, 0.5227272727272727, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.21996542783059636, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.23249783923941228, 0.6136363636363636, 'sql <= 0.5\ngini = 0.32\nsamples = 45\nvalue = [36, 9]'),
#  Text(0.22774416594641314, 0.5681818181818182, 'compensation <= 112500.0\ngini = 0.413\nsamples = 24\nvalue = [17, 7]'),
#  Text(0.22342264477095938, 0.5227272727272727, 'education <= 17.0\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.21996542783059636, 0.4772727272727273, 'education <= 12.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.21823681936041486, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.22169403630077789, 0.4318181818181818, 'years_exp <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.21996542783059636, 0.38636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.22342264477095938, 0.38636363636363635, 'years_exp <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.22169403630077789, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.22515125324114088, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.22687986171132238, 0.4772727272727273, 'age <= 23.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.22515125324114088, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.22860847018150388, 0.4318181818181818, 'compensation <= 95000.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.22687986171132238, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2303370786516854, 0.38636363636363635, 'Q1_Female <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.22860847018150388, 0.3409090909090909, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.22687986171132238, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2303370786516854, 0.29545454545454547, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2320656871218669, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2320656871218669, 0.5227272727272727, 'Q1_Prefer not to say <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.2303370786516854, 0.4772727272727273, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.2337942955920484, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23725151253241142, 0.5681818181818182, 'compensation <= 137500.0\ngini = 0.172\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.2355229040622299, 0.5227272727272727, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.23898012100259292, 0.5227272727272727, 'major_other <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.23725151253241142, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2407087294727744, 0.4772727272727273, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2536732929991357, 0.7045454545454546, 'compensation <= 137500.0\ngini = 0.16\nsamples = 57\nvalue = [52, 5]'),
#  Text(0.24589455488331893, 0.6590909090909091, 'age <= 27.5\ngini = 0.083\nsamples = 46\nvalue = [44, 2]'),
#  Text(0.2424373379429559, 0.6136363636363636, 'compensation <= 90000.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.2407087294727744, 0.5681818181818182, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.24416594641313744, 0.5681818181818182, 'Q1_Male <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2424373379429559, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.24589455488331893, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.24935177182368193, 0.6136363636363636, 'sql <= 0.5\ngini = 0.05\nsamples = 39\nvalue = [38, 1]'),
#  Text(0.24762316335350043, 0.5681818181818182, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.2510803802938634, 0.5681818181818182, 'age <= 32.5\ngini = 0.095\nsamples = 20\nvalue = [19, 1]'),
#  Text(0.24935177182368193, 0.5227272727272727, 'years_exp <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.24762316335350043, 0.4772727272727273, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2510803802938634, 0.4772727272727273, 'years_exp <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.24935177182368193, 0.4318181818181818, 'Q1_Male <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.24762316335350043, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2510803802938634, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.25280898876404495, 0.4318181818181818, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.25280898876404495, 0.5227272727272727, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.26145203111495247, 0.6590909090909091, 'Q1_Female <= 0.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.25972342264477094, 0.6136363636363636, 'sql <= 0.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.25799481417458947, 0.5681818181818182, 'major_other <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.25626620570440795, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.25972342264477094, 0.5227272727272727, 'years_exp <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.25799481417458947, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.26145203111495247, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.26145203111495247, 0.5681818181818182, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.263180639585134, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.30347882454624026, 0.75, 'compensation <= 112500.0\ngini = 0.458\nsamples = 90\nvalue = [58, 32]'),
#  Text(0.2953759723422645, 0.7045454545454546, 'years_exp <= 3.5\ngini = 0.489\nsamples = 66\nvalue = [38, 28]'),
#  Text(0.29364736387208296, 0.6590909090909091, 'age <= 37.5\ngini = 0.475\nsamples = 62\nvalue = [38, 24]'),
#  Text(0.2843560933448574, 0.6136363636363636, 'years_exp <= 0.5\ngini = 0.456\nsamples = 57\nvalue = [37, 20]'),
#  Text(0.27095937770095074, 0.5681818181818182, 'age <= 32.5\ngini = 0.491\nsamples = 23\nvalue = [13, 10]'),
#  Text(0.2692307692307692, 0.5227272727272727, 'Q1_Male <= 0.5\ngini = 0.483\nsamples = 22\nvalue = [13, 9]'),
#  Text(0.26490924805531546, 0.4772727272727273, 'sql <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.263180639585134, 0.4318181818181818, 'compensation <= 45000.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.26145203111495247, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.26490924805531546, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.266637856525497, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.273552290406223, 0.4772727272727273, 'age <= 23.5\ngini = 0.457\nsamples = 17\nvalue = [11, 6]'),
#  Text(0.27009507346586, 0.4318181818181818, 'sql <= 0.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.26836646499567846, 0.38636363636363635, 'compensation <= 75000.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.266637856525497, 0.3409090909090909, 'education <= 19.0\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.26490924805531546, 0.29545454545454547, 'education <= 17.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.263180639585134, 0.25, 'python <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.26145203111495247, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.26490924805531546, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.266637856525497, 0.25, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.26836646499567846, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.27009507346586, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2718236819360415, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.277009507346586, 0.4318181818181818, 'compensation <= 60000.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.2752808988764045, 0.38636363636363635, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.2787381158167675, 0.38636363636363635, 'compensation <= 85000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.277009507346586, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.280466724286949, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2726879861711322, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.29775280898876405, 0.5681818181818182, 'age <= 32.5\ngini = 0.415\nsamples = 34\nvalue = [24, 10]'),
#  Text(0.2960242005185825, 0.5227272727272727, 'compensation <= 95000.0\ngini = 0.444\nsamples = 30\nvalue = [20, 10]'),
#  Text(0.29256698357821953, 0.4772727272727273, 'Q1_Prefer not to say <= 0.5\ngini = 0.469\nsamples = 24\nvalue = [15, 9]'),
#  Text(0.290838375108038, 0.4318181818181818, 'sql <= 0.5\ngini = 0.476\nsamples = 23\nvalue = [14, 9]'),
#  Text(0.28565254969749354, 0.38636363636363635, 'age <= 27.5\ngini = 0.444\nsamples = 15\nvalue = [10, 5]'),
#  Text(0.283923941227312, 0.3409090909090909, 'years_exp <= 2.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.280466724286949, 0.29545454545454547, 'compensation <= 75000.0\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.2787381158167675, 0.25, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.2821953327571305, 0.25, 'age <= 23.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.280466724286949, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.283923941227312, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.287381158167675, 0.29545454545454547, 'Q1_Male <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.28565254969749354, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.28910976663785654, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.287381158167675, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2960242005185825, 0.38636363636363635, 'age <= 27.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.29256698357821953, 0.3409090909090909, 'compensation <= 35000.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.290838375108038, 0.29545454545454547, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.29429559204840106, 0.29545454545454547, 'compensation <= 80000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.29256698357821953, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2960242005185825, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2994814174589456, 0.3409090909090909, 'education <= 19.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.29775280898876405, 0.29545454545454547, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.30121002592912705, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.29429559204840106, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2994814174589456, 0.4772727272727273, 'years_exp <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.29775280898876405, 0.4318181818181818, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.30121002592912705, 0.4318181818181818, 'years_exp <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.2994814174589456, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.30293863439930857, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2994814174589456, 0.5227272727272727, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.30293863439930857, 0.6136363636363636, 'years_exp <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.30121002592912705, 0.5681818181818182, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.30466724286949004, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.297104580812446, 0.6590909090909091, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3115816767502161, 0.7045454545454546, 'education <= 17.0\ngini = 0.278\nsamples = 24\nvalue = [20, 4]'),
#  Text(0.3081244598098531, 0.6590909090909091, 'age <= 23.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.30639585133967157, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.30985306828003456, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3150388936905791, 0.6590909090909091, 'age <= 27.5\ngini = 0.172\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.31331028522039756, 0.6136363636363636, 'years_exp <= 3.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.3115816767502161, 0.5681818181818182, 'sql <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.30985306828003456, 0.5227272727272727, 'compensation <= 137500.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.3081244598098531, 0.4772727272727273, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3115816767502161, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.31331028522039756, 0.5227272727272727, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3150388936905791, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3167675021607606, 0.6136363636363636, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.3492869490060501, 0.7954545454545454, 'education <= 18.5\ngini = 0.495\nsamples = 102\nvalue = [46, 56]'),
#  Text(0.33340535868625754, 0.75, 'education <= 17.0\ngini = 0.438\nsamples = 74\nvalue = [24, 50]'),
#  Text(0.3236819360414866, 0.7045454545454546, 'major_other <= 0.5\ngini = 0.165\nsamples = 22\nvalue = [2, 20]'),
#  Text(0.3219533275713051, 0.6590909090909091, 'age <= 40.0\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.3202247191011236, 0.6136363636363636, 'compensation <= 65000.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.3184961106309421, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3219533275713051, 0.5681818181818182, 'compensation <= 137500.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.3202247191011236, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3236819360414866, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3236819360414866, 0.6136363636363636, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3254105445116681, 0.6590909090909091, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.34312878133102853, 0.7045454545454546, 'compensation <= 112500.0\ngini = 0.488\nsamples = 52\nvalue = [22, 30]'),
#  Text(0.3349178910976664, 0.6590909090909091, 'age <= 32.5\ngini = 0.415\nsamples = 34\nvalue = [10, 24]'),
# ...
#  Text(0.6179775280898876, 0.5681818181818182, 'age <= 32.5\ngini = 0.498\nsamples = 30\nvalue = [16, 14]'),
#  Text(0.6119273984442524, 0.5227272727272727, 'Q3_China <= 0.5\ngini = 0.48\nsamples = 25\nvalue = [15, 10]'),
#  Text(0.6050129645635264, 0.4772727272727273, 'years_exp <= 1.5\ngini = 0.415\nsamples = 17\nvalue = [12, 5]'),
#  Text(0.6032843560933449, 0.4318181818181818, 'compensation <= 112500.0\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.5998271391529818, 0.38636363636363635, 'years_exp <= 0.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.5980985306828004, 0.3409090909090909, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6015557476231633, 0.3409090909090909, 'sql <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.5998271391529818, 0.29545454545454547, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6032843560933449, 0.29545454545454547, 'compensation <= 75000.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.6015557476231633, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6050129645635264, 0.25, 'compensation <= 90000.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.6032843560933449, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6067415730337079, 0.20454545454545456, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6067415730337079, 0.38636363636363635, 'years_exp <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6050129645635264, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6084701815038893, 0.3409090909090909, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6067415730337079, 0.4318181818181818, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6188418323249784, 0.4772727272727273, 'sql <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.6171132238547969, 0.4318181818181818, 'age <= 27.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.6136560069144339, 0.38636363636363635, 'compensation <= 35000.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6119273984442524, 0.3409090909090909, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6153846153846154, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6205704407951599, 0.38636363636363635, 'compensation <= 80000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6188418323249784, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6222990492653414, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6205704407951599, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6240276577355229, 0.5227272727272727, 'sql <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6222990492653414, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6257562662057045, 0.4772727272727273, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6214347450302506, 0.5681818181818182, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6231633535004322, 0.6136363636363636, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.6248919619706137, 0.6590909090909091, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.7062209647796024, 0.8409090909090909, 'education <= 17.0\ngini = 0.334\nsamples = 293\nvalue = [62, 231]'),
#  Text(0.6606795592048401, 0.7954545454545454, 'Q3_China <= 0.5\ngini = 0.233\nsamples = 134\nvalue = [18, 116]'),
#  Text(0.6534680207433017, 0.75, 'years_exp <= 12.5\ngini = 0.203\nsamples = 122\nvalue = [14, 108]'),
#  Text(0.6517394122731202, 0.7045454545454546, 'age <= 42.5\ngini = 0.226\nsamples = 108\nvalue = [14, 94]'),
#  Text(0.6442307692307693, 0.6590909090909091, 'years_exp <= 3.5\ngini = 0.215\nsamples = 106\nvalue = [13, 93]'),
#  Text(0.634399308556612, 0.6136363636363636, 'compensation <= 90000.0\ngini = 0.32\nsamples = 20\nvalue = [4, 16]'),
#  Text(0.6326707000864304, 0.5681818181818182, 'age <= 32.5\ngini = 0.198\nsamples = 18\nvalue = [2, 16]'),
#  Text(0.6309420916162489, 0.5227272727272727, 'python <= 0.5\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(0.6292134831460674, 0.4772727272727273, 'compensation <= 5000.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6274848746758859, 0.4318181818181818, 'age <= 21.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6257562662057045, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6292134831460674, 0.38636363636363635, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6309420916162489, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6326707000864304, 0.4772727272727273, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.634399308556612, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6361279170267934, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6540622299049266, 0.6136363636363636, 'Q3_United States of America <= 0.5\ngini = 0.187\nsamples = 86\nvalue = [9, 77]'),
#  Text(0.652333621434745, 0.5681818181818182, 'compensation <= 85000.0\ngini = 0.27\nsamples = 56\nvalue = [9, 47]'),
#  Text(0.6452031114952463, 0.5227272727272727, 'compensation <= 5000.0\ngini = 0.252\nsamples = 54\nvalue = [8, 46]'),
#  Text(0.6361279170267934, 0.4772727272727273, 'age <= 32.5\ngini = 0.33\nsamples = 24\nvalue = [5, 19]'),
#  Text(0.634399308556612, 0.4318181818181818, 'Q1_Male <= 0.5\ngini = 0.363\nsamples = 21\nvalue = [5, 16]'),
#  Text(0.6326707000864304, 0.38636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6361279170267934, 0.38636363636363635, 'python <= 0.5\ngini = 0.401\nsamples = 18\nvalue = [5, 13]'),
#  Text(0.6300777873811582, 0.3409090909090909, 'years_exp <= 4.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.6283491789109766, 0.29545454545454547, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6318063958513397, 0.29545454545454547, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6300777873811582, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6335350043215212, 0.25, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6421780466724287, 0.3409090909090909, 'years_exp <= 7.5\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.6387208297320657, 0.29545454545454547, 'sql <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.6369922212618842, 0.25, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.6404494382022472, 0.25, 'years_exp <= 4.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6387208297320657, 0.20454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6421780466724287, 0.20454545454545456, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6404494382022472, 0.1590909090909091, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6439066551426103, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6456352636127917, 0.29545454545454547, 'age <= 24.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6439066551426103, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6473638720829732, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6378565254969749, 0.4318181818181818, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6542783059636992, 0.4772727272727273, 'compensation <= 15000.0\ngini = 0.18\nsamples = 30\nvalue = [3, 27]'),
#  Text(0.6525496974935178, 0.4318181818181818, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.6560069144338807, 0.4318181818181818, 'Q1_Female <= 0.5\ngini = 0.255\nsamples = 20\nvalue = [3, 17]'),
#  Text(0.6525496974935178, 0.38636363636363635, 'sql <= 0.5\ngini = 0.198\nsamples = 18\nvalue = [2, 16]'),
#  Text(0.6508210890233362, 0.3409090909090909, 'age <= 27.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.6490924805531547, 0.29545454545454547, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6525496974935178, 0.29545454545454547, 'years_exp <= 4.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.6508210890233362, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6542783059636992, 0.25, 'compensation <= 50000.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6525496974935178, 0.20454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6560069144338807, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6542783059636992, 0.3409090909090909, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.6594641313742438, 0.38636363636363635, 'years_exp <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6577355229040622, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6611927398444253, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6594641313742438, 0.5227272727272727, 'python <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6577355229040622, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6611927398444253, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.655790838375108, 0.5681818181818182, 'gini = 0.0\nsamples = 30\nvalue = [0, 30]'),
#  Text(0.659248055315471, 0.6590909090909091, 'sql <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6575194468452895, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6609766637856526, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6551966292134831, 0.7045454545454546, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.6678910976663786, 0.75, 'sql <= 0.5\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.6644338807260155, 0.7045454545454546, 'age <= 32.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.6627052722558341, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.666162489196197, 0.6590909090909091, 'years_exp <= 4.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6644338807260155, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6678910976663786, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6713483146067416, 0.7045454545454546, 'compensation <= 55000.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.6696197061365601, 0.6590909090909091, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.6730769230769231, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7517623703543648, 0.7954545454545454, 'age <= 20.0\ngini = 0.4\nsamples = 159\nvalue = [44, 115]'),
#  Text(0.7500337618841832, 0.75, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7534909788245462, 0.75, 'age <= 47.5\ngini = 0.392\nsamples = 157\nvalue = [42, 115]'),
#  Text(0.742072709593777, 0.7045454545454546, 'years_exp <= 7.5\ngini = 0.375\nsamples = 148\nvalue = [37, 111]'),
#  Text(0.7296078219533275, 0.6590909090909091, 'education <= 19.5\ngini = 0.422\nsamples = 109\nvalue = [33, 76]'),
#  Text(0.7150496974935178, 0.6136363636363636, 'age <= 37.5\ngini = 0.397\nsamples = 99\nvalue = [27, 72]'),
#  Text(0.7014909248055315, 0.5681818181818182, 'age <= 27.5\ngini = 0.372\nsamples = 93\nvalue = [23, 70]'),
#  Text(0.682800345721694, 0.5227272727272727, 'education <= 18.5\ngini = 0.427\nsamples = 42\nvalue = [13, 29]'),
#  Text(0.6810717372515125, 0.4772727272727273, 'compensation <= 5000.0\ngini = 0.414\nsamples = 41\nvalue = [12, 29]'),
#  Text(0.6707000864304236, 0.4318181818181818, 'years_exp <= 4.5\ngini = 0.298\nsamples = 22\nvalue = [4, 18]'),
#  Text(0.668971477960242, 0.38636363636363635, 'python <= 0.5\ngini = 0.332\nsamples = 19\nvalue = [4, 15]'),
#  Text(0.6646499567847882, 0.3409090909090909, 'years_exp <= 3.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.6629213483146067, 0.29545454545454547, 'age <= 23.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6611927398444253, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6646499567847882, 0.25, 'Q3_India <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6629213483146067, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6663785652549697, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6663785652549697, 0.29545454545454547, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6732929991356957, 0.3409090909090909, 'years_exp <= 3.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.6698357821953328, 0.29545454545454547, 'Q3_United States of America <= 0.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.6681071737251513, 0.25, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.6715643906655142, 0.25, 'Q1_Male <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6698357821953328, 0.20454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6732929991356957, 0.20454545454545456, 'sql <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6715643906655142, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6750216076058773, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6767502160760588, 0.29545454545454547, 'Q1_Male <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6750216076058773, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6784788245462403, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.672428694900605, 0.38636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6914433880726015, 0.4318181818181818, 'compensation <= 125000.0\ngini = 0.488\nsamples = 19\nvalue = [8, 11]'),
#  Text(0.68971477960242, 0.38636363636363635, 'years_exp <= 4.5\ngini = 0.5\nsamples = 16\nvalue = [8, 8]'),
#  Text(0.6879861711322386, 0.3409090909090909, 'python <= 0.5\ngini = 0.498\nsamples = 15\nvalue = [7, 8]'),
#  Text(0.6836646499567848, 0.29545454545454547, 'compensation <= 60000.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6819360414866033, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6853932584269663, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6923076923076923, 0.29545454545454547, 'compensation <= 45000.0\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.6888504753673294, 0.25, 'years_exp <= 3.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.6871218668971478, 0.20454545454545456, 'Q3_India <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6853932584269663, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6888504753673294, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6905790838375108, 0.20454545454545456, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6957649092480553, 0.25, 'Q3_United States of America <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.6940363007778738, 0.20454545454545456, 'compensation <= 55000.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6923076923076923, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6957649092480553, 0.1590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6974935177182369, 0.20454545454545456, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6914433880726015, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.693171996542783, 0.38636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6845289541918755, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7201815038893691, 0.5227272727272727, 'compensation <= 112500.0\ngini = 0.315\nsamples = 51\nvalue = [10, 41]'),
#  Text(0.7152117545375972, 0.4772727272727273, 'compensation <= 75000.0\ngini = 0.263\nsamples = 45\nvalue = [7, 38]'),
#  Text(0.7134831460674157, 0.4318181818181818, 'age <= 32.5\ngini = 0.313\nsamples = 36\nvalue = [7, 29]'),
#  Text(0.7087294727744166, 0.38636363636363635, 'Q1_Female <= 0.5\ngini = 0.257\nsamples = 33\nvalue = [5, 28]'),
#  Text(0.7044079515989629, 0.3409090909090909, 'years_exp <= 3.5\ngini = 0.18\nsamples = 30\nvalue = [3, 27]'),
#  Text(0.7009507346585998, 0.29545454545454547, 'sql <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6992221261884183, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  ...]

# %%
fig, ax = plt.subplots(figsize=(8, 4))
features = list(c for c in X_train.columns)
tree.plot_tree(hi_variance, feature_names=features, filled=True, class_names=hi_variance.classes_,
              max_depth=2, fontsize=6)
# Out:
# [Text(0.5, 0.875, 'r <= 0.5\ngini = 0.496\nsamples = 2110\nvalue = [1153, 957]\nclass = Data Scientist'),
#  Text(0.25, 0.625, 'major_cs <= 0.5\ngini = 0.493\nsamples = 1484\nvalue = [653, 831]\nclass = Software Engineer'),
#  Text(0.125, 0.375, 'Q3_United States of America <= 0.5\ngini = 0.49\nsamples = 718\nvalue = [410, 308]\nclass = Data Scientist'),
#  Text(0.0625, 0.125, '\n  (...)  \n'),
#  Text(0.1875, 0.125, '\n  (...)  \n'),
#  Text(0.375, 0.375, 'years_exp <= 2.5\ngini = 0.433\nsamples = 766\nvalue = [243, 523]\nclass = Software Engineer'),
#  Text(0.3125, 0.125, '\n  (...)  \n'),
#  Text(0.4375, 0.125, '\n  (...)  \n'),
#  Text(0.75, 0.625, 'major_cs <= 0.5\ngini = 0.322\nsamples = 626\nvalue = [500, 126]\nclass = Data Scientist'),
#  Text(0.625, 0.375, 'years_exp <= 22.5\ngini = 0.211\nsamples = 443\nvalue = [390, 53]\nclass = Data Scientist'),
#  Text(0.5625, 0.125, '\n  (...)  \n'),
#  Text(0.6875, 0.125, '\n  (...)  \n'),
#  Text(0.875, 0.375, 'years_exp <= 7.5\ngini = 0.48\nsamples = 183\nvalue = [110, 73]\nclass = Data Scientist'),
#  Text(0.8125, 0.125, '\n  (...)  \n'),
#  Text(0.9375, 0.125, '\n  (...)  \n')]

# %% [markdown]
# ## Tree Hyperparameters
