# %% [markdown]
# # Datasets
#
# ### Cleaup & Loading

# %%
# Data Manipulation
import pandas as pd

# URL Library
import urllib.request
import zipfile

# %%
# Retrieving & storage
url = 'https://github.com/mattharrison/datasets/raw/master/data/'\
'kaggle-survey-2018.zip'
fname = 'kaggle-survey-2018.zip'
member_name = 'multipleChoiceResponses.csv'

# %%
# Function Extration
def extract_zip(src, dst, member_name):
    """Extract a member file from a zip file & read it into pandas
    DataFrame.
    
    Parameters:
        src '(str:)' URL of the zip file to be downloaded and extrated.
        dst 'str': Local file path where the zip file will be written.
        member_name: Name of the member file inside the zip file to be
            read into a DataFrame.
            
    Returns:
        pandas.DataFrame containing the contents of member file.
    """
    url = src
    fname = dst
    fin = urllib.request.urlopen(url)
    data = fin.read()
    with open(dst, mode='wb') as fout:
        fout.write(data)
    with zipfile.ZipFile(dst) as z:
        kag = pd.read_csv(z.open(member_name))
        kag_questions = kag.iloc[0]
        raw = kag.iloc[1:]
        return raw

# %%
raw = extract_zip(url, fname, member_name)
# Out:
# /var/folders/wh/l_q69dcj75z0c82jy8ry71f40000gn/T/ipykernel_32169/3680407660.py:22: DtypeWarning: Columns (0,2,8,10,21,23,24,25,26,27,28,44,56,64,83,85,87,107,109,123,125,150,157,172,174,194,210,218,219,223,246,249,262,264,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,304,306,325,326,329,341,368,371,384,385,389,390,391,393,394) have mixed types. Specify dtype option on import or set low_memory=False.
#   kag = pd.read_csv(z.open(member_name))

# %% [markdown]
# ## CleanUp Pipeline

# %%
def tweak_kag(df_: pd.DataFrame) -> pd.DataFrame:
    """
    Tweak the Kaggle survey data and return a new DataFrame.

    This function takes a Pandas DataFrame containing Kaggle 
    survey data as input and returns a new DataFrame. The 
    modifications include extracting and transforming certain 
    columns, renaming columns, and selecting a subset of columns.

    Parameters
    ----------
    df_ : pd.DataFrame
        The input DataFrame containing Kaggle survey data.

    Returns
    -------
    pd.DataFrame
        The new DataFrame with the modified and selected columns.
    """    
    return (df_
            .assign(age=df_.Q2.str.slice(0,2).astype(int),
                    education=df_.Q4.replace({'Master’s degree': 18,
                         'Bachelor’s degree': 16,
                         'Doctoral degree': 20,
'Some college/university study without earning a bachelor’s degree': 13,
                         'Professional degree': 19,
                         'I prefer not to answer': None,
                         'No formal education past high school': 12}),
                    major=(df_.Q5
                              .pipe(topn, n=3)
                              .replace({
                        'Computer science (software engineering, etc.)': 'cs',
                        'Engineering (non-computer focused)': 'eng',
                        'Mathematics or statistics': 'stat'})
                         ),
                    years_exp=(df_.Q8.str.replace('+','', regex=False)
                           .str.split('-', expand=True)
                           .iloc[:,0]
                           .astype(float)),
                    compensation=(df_.Q9.str.replace('+','', regex=False)
                           .str.replace(',','', regex=False)
                           .str.replace('500000', '500', regex=False)
  .str.replace('I do not wish to disclose my approximate yearly compensation',
             '0', regex=False)
                           .str.split('-', expand=True)
                           .iloc[:,0]
                           .fillna(0)
                           .astype(int)
                           .mul(1_000)
                                    ),
                    python=df_.Q16_Part_1.fillna(0).replace('Python', 1),
                    r=df_.Q16_Part_2.fillna(0).replace('R', 1),
                    sql=df_.Q16_Part_3.fillna(0).replace('SQL', 1)
               )#assign
        .rename(columns=lambda col:col.replace(' ', '_'))
        .loc[:, 'Q1,Q3,age,education,major,years_exp,compensation,'
                'python,r,sql'.split(',')]   
       )

# %%
def topn(ser, n=5, default='other'):
    counts = ser.value_counts()
    return ser.where(ser.isin(counts.index[:n]), default)

# %%
from feature_engine import encoding, imputation
from sklearn import base, pipeline
# Out:
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
class TweakKagTransformer(base.BaseEstimator, base.TransformerMixin):
    
    def __init__(self, ycol=None):
        self.ycol = ycol
        
    def transform(self, X):
        return tweak_kag(X)
    
    def fit(self, X, y=None):
        return self

# %%
def get_rawX_y(df, y_col):
    raw = (df
           .query('Q3.isin(["United States of America", "China", "India"]) '
              'and Q6.isin(["Data Scientist", "Software Engineer"])')
    )
    return raw.drop(columns=[y_col]), raw[y_col]

# %%
# Create Pipeline
kag_pl = pipeline.Pipeline(
    [('tweak', TweakKagTransformer()),
     ('cat', encoding.OneHotEncoder(top_categories=5, drop_last=True, variables=['Q1', 'Q3', 'major'])),
     ('num_impute', imputation.MeanMedianImputer(imputation_method='median', variables=['education', 'years_exp']))]
)

# %%
from sklearn import model_selection

# %%
kag_X, kag_y = get_rawX_y(raw, 'Q6')

kag_X_train, kag_X_test, kag_y_train, kag_y_test = \
model_selection.train_test_split(
    kag_X, kag_y, test_size=.3, random_state=42, stratify=kag_y)

# %%
X_train = kag_pl.fit_transform(kag_X_train, kag_y_train)

X_test = kag_pl.transform(kag_X_test)

# %%
print(X_train)
# Out:
#        age  education  years_exp  compensation  python  r  sql  Q1_Male  \
# 587     25       18.0        4.0             0       1  0    1        1
# 3065    22       16.0        1.0         10000       1  0    0        1
# 8435    22       18.0        1.0             0       1  0    0        1
# 3110    40       20.0        3.0        125000       1  0    1        0
# 16372   45       12.0        5.0        100000       1  0    1        1
# ...    ...        ...        ...           ...     ... ..  ...      ...
# 16608   25       16.0        2.0         10000       0  0    1        1
# 7325    18       16.0        1.0         30000       1  0    1        1
# 21810   18       16.0        2.0             0       0  0    0        1
# 4917    25       18.0        1.0        100000       1  0    1        1
# 639     25       18.0        1.0         10000       1  0    0        0
#
#        Q1_Female  Q1_Prefer not to say  Q1_Prefer to self-describe  \
# 587            0                     0                           0
# 3065           0                     0                           0
# 8435           0                     0                           0
# 3110           1                     0                           0
# 16372          0                     0                           0
# ...          ...                   ...                         ...
# 16608          0                     0                           0
# 7325           0                     0                           0
# 21810          0                     0                           0
# 4917           0                     0                           0
# 639            1                     0                           0
#
#        Q3_United States of America  Q3_India  Q3_China  major_cs  major_other  \
# 587                              0         1         0         0            1
# 3065                             0         1         0         1            0
# 8435                             0         1         0         0            1
# 3110                             1         0         0         0            1
# 16372                            1         0         0         0            1
# ...                            ...       ...       ...       ...          ...
# 16608                            0         1         0         1            0
# 7325                             1         0         0         1            0
# 21810                            0         1         0         1            0
# 4917                             1         0         0         0            0
# 639                              0         1         0         1            0
#
#        major_eng  major_stat
# 587            0           0
# 3065           0           0
# 8435           0           0
# 3110           0           0
# 16372          0           0
# ...          ...         ...
# 16608          0           0
# 7325           0           0
# 21810          0           0
# 4917           0           1
# 639            0           0
#
# [2110 rows x 18 columns]

# %%
kag_y_train
# Out:
# 587      Software Engineer
# 3065        Data Scientist
# 8435        Data Scientist
# 3110        Data Scientist
# 16372    Software Engineer
#                ...
# 16608    Software Engineer
# 7325     Software Engineer
# 21810       Data Scientist
# 4917        Data Scientist
# 639         Data Scientist
# Name: Q6, Length: 2110, dtype: object

# %% [markdown]
# ## Exploratory Data Analysis

# %%
(X_train
 .assign(data_scientist = kag_y_train == 'Data Scientist')
 .corr(method='spearman')
 .style
 .background_gradient(cmap='RdBu', vmax=1, vmin=-1)
 .set_sticky(axis='index')
)
# Out:
# <style type="text/css">
# #T_e438b thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_e438b tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# #T_e438b_row0_col0, #T_e438b_row1_col1, #T_e438b_row2_col2, #T_e438b_row3_col3, #T_e438b_row4_col4, #T_e438b_row5_col5, #T_e438b_row6_col6, #T_e438b_row7_col7, #T_e438b_row8_col8, #T_e438b_row9_col9, #T_e438b_row10_col10, #T_e438b_row11_col11, #T_e438b_row12_col12, #T_e438b_row13_col13, #T_e438b_row14_col14, #T_e438b_row15_col15, #T_e438b_row16_col16, #T_e438b_row17_col17, #T_e438b_row18_col18 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_e438b_row0_col1, #T_e438b_row1_col0 {
#   background-color: #a2cde3;
#   color: #000000;
# }
# #T_e438b_row0_col2, #T_e438b_row2_col0 {
#   background-color: #3b88be;
#   color: #f1f1f1;
# }
# #T_e438b_row0_col3, #T_e438b_row3_col0 {
#   background-color: #7eb8d7;
#   color: #000000;
# }
# #T_e438b_row0_col4, #T_e438b_row0_col10, #T_e438b_row2_col17, #T_e438b_row4_col0, #T_e438b_row4_col7, #T_e438b_row7_col4, #T_e438b_row9_col11, #T_e438b_row10_col0, #T_e438b_row10_col11, #T_e438b_row11_col9, #T_e438b_row11_col10, #T_e438b_row17_col2 {
#   background-color: #eff3f5;
#   color: #000000;
# }
# #T_e438b_row0_col5, #T_e438b_row5_col0, #T_e438b_row8_col11, #T_e438b_row11_col8 {
#   background-color: #deebf2;
#   color: #000000;
# }
# #T_e438b_row0_col6, #T_e438b_row5_col15, #T_e438b_row6_col0, #T_e438b_row15_col5 {
#   background-color: #ddebf2;
#   color: #000000;
# }
# #T_e438b_row0_col7, #T_e438b_row2_col5, #T_e438b_row4_col16, #T_e438b_row4_col17, #T_e438b_row5_col2, #T_e438b_row7_col0, #T_e438b_row9_col15, #T_e438b_row15_col9, #T_e438b_row16_col4, #T_e438b_row17_col4 {
#   background-color: #f5f6f7;
#   color: #000000;
# }
# #T_e438b_row0_col8, #T_e438b_row3_col9, #T_e438b_row8_col0, #T_e438b_row8_col16, #T_e438b_row9_col3, #T_e438b_row9_col12, #T_e438b_row10_col12, #T_e438b_row12_col9, #T_e438b_row12_col10, #T_e438b_row13_col17, #T_e438b_row16_col8, #T_e438b_row17_col13 {
#   background-color: #f8f2ef;
#   color: #000000;
# }
# #T_e438b_row0_col9, #T_e438b_row2_col6, #T_e438b_row3_col10, #T_e438b_row4_col11, #T_e438b_row6_col2, #T_e438b_row7_col13, #T_e438b_row9_col0, #T_e438b_row10_col3, #T_e438b_row10_col15, #T_e438b_row11_col4, #T_e438b_row13_col7, #T_e438b_row15_col10 {
#   background-color: #edf2f5;
#   color: #000000;
# }
# #T_e438b_row0_col11, #T_e438b_row11_col0 {
#   background-color: #9bc9e0;
#   color: #000000;
# }
# #T_e438b_row0_col12, #T_e438b_row12_col0 {
#   background-color: #f6af8e;
#   color: #000000;
# }
# #T_e438b_row0_col13, #T_e438b_row4_col13, #T_e438b_row5_col16, #T_e438b_row6_col10, #T_e438b_row8_col10, #T_e438b_row10_col6, #T_e438b_row10_col8, #T_e438b_row10_col14, #T_e438b_row10_col16, #T_e438b_row10_col17, #T_e438b_row13_col0, #T_e438b_row13_col4, #T_e438b_row14_col10, #T_e438b_row16_col5, #T_e438b_row16_col10, #T_e438b_row17_col10 {
#   background-color: #f8f4f2;
#   color: #000000;
# }
# #T_e438b_row0_col14, #T_e438b_row3_col14, #T_e438b_row7_col9, #T_e438b_row9_col7, #T_e438b_row14_col0, #T_e438b_row14_col3 {
#   background-color: #fcd5bf;
#   color: #000000;
# }
# #T_e438b_row0_col15, #T_e438b_row3_col6, #T_e438b_row6_col3, #T_e438b_row15_col0, #T_e438b_row15_col18, #T_e438b_row18_col15 {
#   background-color: #d1e5f0;
#   color: #000000;
# }
# #T_e438b_row0_col16, #T_e438b_row1_col10, #T_e438b_row2_col16, #T_e438b_row3_col7, #T_e438b_row3_col8, #T_e438b_row5_col9, #T_e438b_row7_col3, #T_e438b_row8_col3, #T_e438b_row9_col5, #T_e438b_row10_col1, #T_e438b_row16_col0, #T_e438b_row16_col2 {
#   background-color: #f6f7f7;
#   color: #000000;
# }
# #T_e438b_row0_col17, #T_e438b_row0_col18, #T_e438b_row6_col17, #T_e438b_row17_col0, #T_e438b_row17_col6, #T_e438b_row18_col0 {
#   background-color: #e9f0f4;
#   color: #000000;
# }
# #T_e438b_row1_col2, #T_e438b_row2_col1, #T_e438b_row4_col15, #T_e438b_row15_col4 {
#   background-color: #e4eef4;
#   color: #000000;
# }
# #T_e438b_row1_col3, #T_e438b_row3_col1, #T_e438b_row3_col15, #T_e438b_row12_col14, #T_e438b_row14_col12, #T_e438b_row15_col3 {
#   background-color: #c5dfec;
#   color: #000000;
# }
# #T_e438b_row1_col4, #T_e438b_row1_col9, #T_e438b_row4_col1, #T_e438b_row9_col1 {
#   background-color: #ecf2f5;
#   color: #000000;
# }
# #T_e438b_row1_col5, #T_e438b_row5_col1, #T_e438b_row11_col17, #T_e438b_row17_col11 {
#   background-color: #dae9f2;
#   color: #000000;
# }
# #T_e438b_row1_col6, #T_e438b_row1_col8, #T_e438b_row5_col8, #T_e438b_row6_col1, #T_e438b_row7_col14, #T_e438b_row8_col1, #T_e438b_row8_col5, #T_e438b_row8_col15, #T_e438b_row13_col14, #T_e438b_row14_col7, #T_e438b_row14_col13, #T_e438b_row15_col8 {
#   background-color: #eaf1f5;
#   color: #000000;
# }
# #T_e438b_row1_col7, #T_e438b_row7_col1 {
#   background-color: #f9ebe3;
#   color: #000000;
# }
# #T_e438b_row1_col11, #T_e438b_row1_col18, #T_e438b_row11_col1, #T_e438b_row11_col15, #T_e438b_row15_col11, #T_e438b_row18_col1 {
#   background-color: #bbdaea;
#   color: #000000;
# }
# #T_e438b_row1_col12, #T_e438b_row11_col14, #T_e438b_row12_col1, #T_e438b_row14_col11 {
#   background-color: #fac8af;
#   color: #000000;
# }
# #T_e438b_row1_col13, #T_e438b_row1_col16, #T_e438b_row4_col9, #T_e438b_row4_col10, #T_e438b_row5_col10, #T_e438b_row9_col4, #T_e438b_row9_col10, #T_e438b_row10_col4, #T_e438b_row10_col5, #T_e438b_row10_col9, #T_e438b_row13_col1, #T_e438b_row16_col1 {
#   background-color: #f7f6f6;
#   color: #000000;
# }
# #T_e438b_row1_col14, #T_e438b_row14_col1 {
#   background-color: #fcd7c2;
#   color: #000000;
# }
# #T_e438b_row1_col15, #T_e438b_row3_col4, #T_e438b_row3_col5, #T_e438b_row4_col3, #T_e438b_row5_col3, #T_e438b_row6_col11, #T_e438b_row11_col6, #T_e438b_row15_col1 {
#   background-color: #d7e8f1;
#   color: #000000;
# }
# #T_e438b_row1_col17, #T_e438b_row2_col11, #T_e438b_row4_col18, #T_e438b_row6_col18, #T_e438b_row11_col2, #T_e438b_row17_col1, #T_e438b_row18_col4, #T_e438b_row18_col6 {
#   background-color: #e0ecf3;
#   color: #000000;
# }
# #T_e438b_row2_col3, #T_e438b_row3_col2 {
#   background-color: #c0dceb;
#   color: #000000;
# }
# #T_e438b_row2_col4, #T_e438b_row3_col16, #T_e438b_row4_col2, #T_e438b_row16_col3 {
#   background-color: #f9efe9;
#   color: #000000;
# }
# #T_e438b_row2_col7, #T_e438b_row7_col2, #T_e438b_row12_col16, #T_e438b_row16_col12 {
#   background-color: #e7f0f4;
#   color: #000000;
# }
# #T_e438b_row2_col8, #T_e438b_row4_col14, #T_e438b_row7_col10, #T_e438b_row8_col2, #T_e438b_row10_col7, #T_e438b_row14_col4 {
#   background-color: #fae9df;
#   color: #000000;
# }
# #T_e438b_row2_col9, #T_e438b_row6_col8, #T_e438b_row8_col6, #T_e438b_row8_col17, #T_e438b_row9_col2, #T_e438b_row17_col8 {
#   background-color: #f0f4f6;
#   color: #000000;
# }
# #T_e438b_row2_col10, #T_e438b_row2_col15, #T_e438b_row9_col17, #T_e438b_row9_col18, #T_e438b_row10_col2, #T_e438b_row10_col18, #T_e438b_row15_col2, #T_e438b_row16_col18, #T_e438b_row17_col9, #T_e438b_row18_col9, #T_e438b_row18_col10, #T_e438b_row18_col16 {
#   background-color: #f3f5f6;
#   color: #000000;
# }
# #T_e438b_row2_col12, #T_e438b_row5_col13, #T_e438b_row12_col2, #T_e438b_row12_col17, #T_e438b_row13_col5, #T_e438b_row17_col12 {
#   background-color: #fbe4d6;
#   color: #000000;
# }
# #T_e438b_row2_col13, #T_e438b_row7_col16, #T_e438b_row9_col16, #T_e438b_row13_col2, #T_e438b_row16_col7, #T_e438b_row16_col9 {
#   background-color: #f2f5f6;
#   color: #000000;
# }
# #T_e438b_row2_col14, #T_e438b_row4_col8, #T_e438b_row4_col12, #T_e438b_row7_col17, #T_e438b_row8_col4, #T_e438b_row8_col9, #T_e438b_row9_col8, #T_e438b_row9_col14, #T_e438b_row12_col4, #T_e438b_row14_col2, #T_e438b_row14_col9, #T_e438b_row17_col7 {
#   background-color: #f8f1ed;
#   color: #000000;
# }
# #T_e438b_row2_col18, #T_e438b_row7_col11, #T_e438b_row11_col7, #T_e438b_row18_col2 {
#   background-color: #fbe3d4;
#   color: #000000;
# }
# #T_e438b_row3_col11, #T_e438b_row11_col3 {
#   background-color: #408fc1;
#   color: #f1f1f1;
# }
# #T_e438b_row3_col12, #T_e438b_row12_col3 {
#   background-color: #dc6e57;
#   color: #f1f1f1;
# }
# #T_e438b_row3_col13, #T_e438b_row13_col3 {
#   background-color: #fbe6da;
#   color: #000000;
# }
# #T_e438b_row3_col17, #T_e438b_r

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 4))
(X_train
 .assign(data_scientist = kag_y_train)
 .groupby('r')
 .data_scientist
 .value_counts()
 .unstack()
 .plot.bar(ax=ax)
)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 4))
(pd.crosstab(index=X_train['major_cs'],
             columns=kag_y)
 .plot.bar(ax=ax)
)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 4))
(X_train
 .plot.scatter(x='years_exp', y='compensation', alpha=.3, ax=ax, c='purple')
)

plt.show()

# %% [markdown]
# #### adding Jitter

# %%
import seaborn.objects as so

# %%
fig = plt.figure(figsize=(8, 4))
(so
 .Plot(X_train.assign(title=kag_y_train), x='years_exp', y='compensation', color='title')
 .add(so.Dots(alpha=.3, pointsize=2), so.Jitter(x=.5, y=10_000))
 .add(so.Line(), so.PolyFit())
 .on(fig)
 .plot()
)

# %% [markdown]
# #### Adjusted Visualization

# %%
fig = plt.figure(figsize=(8, 4))
(so
 .Plot(X_train
       # .query('compensation < 200_000 and years_exp < 16')
       .assign(
           title=kag_y_train,
           country=(X_train
                    .loc[:, 'Q3_United States of America': 'Q3_China']
                    .idxmax(axis='columns')
                   )
       ), x='years_exp', y='compensation', color='title')
 .facet('country')
 .add(so.Dots(alpha=.01, pointsize=2, color='grey'), so.Jitter(x=.5, y=10_000), col=None)
 .add(so.Dots(alpha=.5, pointsize=1.5), so.Jitter(x=.5, y=10_000))
 .add(so.Line(pointsize=1), so.PolyFit(order=2))
 .scale(x=so.Continuous().tick(at=[0, 1, 2, 3, 4, 5]))
 .limit(y=(-10_000, 200_000), x=(-1, 6))
 .on(fig)
 .plot()
 )

# %% [markdown]
# ## Tree Creation

# %%
# Numerical Manipualtion
import numpy as np
import numpy.random as rn

# %%
pos_center = 12
pos_count = 100
neg_center = 7
neg_count = 1000

rs = rn.RandomState(rn.MT19937(rn.SeedSequence(42)))
gini = pd.DataFrame({'value':
                      np.append((pos_center) + rs.randn(pos_count),
                               (neg_center) + rs.randn(neg_count)),
                      'label':
                      ['pos']* pos_count + ['neg'] * neg_count})

# %%
fig, ax = plt.subplots(figsize=(8, 4))
_ = (gini
     .groupby('label')
     [['value']]
     .plot.hist(bins=30, alpha=.5, ax=ax, edgecolor='black')
    )
ax.legend(['Negative', 'Positive'])

plt.show()

# %%
def calc_gini(df, val_col, label_col, pos_val, split_point,
             debug=False):
    """
    This function calculates the Gini impurity of a dataset. Gini Impurity
    is a measure of the probability of a random sample being classified
    incorectly when a feature is sued to split the data. The lower the 
    impurity, the better the split.
    
    Parameters:
    df(pd.DataFrame): The dataframe containing the data
    val_col (str): the column name of the feature used to split the data
    label_col (str): The column name of the target variable
    pos_val (str or int): The value of the target variable that represents
        the positive class
    split_point (float): The threshold used to split the data.
    debug (bool): optional, when set to True, prints the calculated Gini
        impurities and the final weighted aveerage
        
    Returns:
    float: The weighted average of Gini impurity for the positive and
        negative subsets.
    """
    ge_split = df[val_col] >= split_point
    eq_pos = df[label_col] == pos_val
    tp = df[ge_split & eq_pos].shape[0]
    fp = df[ge_split & ~eq_pos].shape[0]
    tn = df[~ge_split & ~eq_pos].shape[0]
    fn = df[~ge_split & eq_pos].shape[0]
    pos_size = tp+fp
    neg_size = tn+fn
    total_size = len(df)
    if pos_size == 0:
        gini_pos = 0
    else:
        gini_pos = 1 - (tp/pos_size)**2 - (fp/pos_size)**2
    if neg_size == 0:
        gini_neg = 0
    else:
        gini_neg = 1 - (tn/neg_size)**2 - (fn/neg_size)**2
    weighted_avg = gini_pos * (pos_size/total_size) * \
    gini_neg * (neg_size/total_size)
    if debug:
        print(f'{gini_pos=:3} {gini_neg=:.3} {weighted_avg=:3}')
    return weighted_avg

# %%
calc_gini(gini, val_col='value', label_col='label', pos_val='pos', split_point=9.24, debug=True)
# Out:
# gini_pos=0.21708826063121614 gini_neg=0.00202 weighted_avg=4.050598243782082e-05
# 4.050598243782082e-05

# %%
values = np.arange(5, 15, .1)
ginis = []
for v in values:
    ginis.append(calc_gini(gini, val_col='value', label_col='label',
                          pos_val='pos', split_point=v))

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(values, ginis)
ax.set_title('Gini Coefficient')
ax.set_ylabel('Gini Coefficient')
ax.set_xlabel('Split Point')

plt.show()

# %%
pd.Series(ginis, index=values).loc[9.5:10.5]
# Out:
# 9.6     0.000022
# 9.7     0.000016
# 9.8     0.000013
# 9.9     0.000007
# 10.0    0.000010
# 10.1    0.000000
# 10.2    0.000000
# 10.3    0.000000
# 10.4    0.000000
# 10.5    0.000000
# dtype: float64

# %%
print(pd.DataFrame({'gini':ginis, 'split':values})
      .query('gini <= gini.min()'))
# Out:
#     gini  split
# 0    0.0    5.0
# 1    0.0    5.1
# 2    0.0    5.2
# 3    0.0    5.3
# 4    0.0    5.4
# ..   ...    ...
# 95   0.0   14.5
# 96   0.0   14.6
# 97   0.0   14.7
# 98   0.0   14.8
# 99   0.0   14.9
#
# [90 rows x 2 columns]

# %% [markdown]
# #### Coeffiecients in Trees

# %%
from sklearn import tree
stump = tree.DecisionTreeClassifier(max_depth=1)
stump.fit(gini[['value']], gini.label)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
fig, ax = plt.subplots(figsize=(8, 4))
tree.plot_tree(stump, feature_names=['value'],
               filled=True, 
               class_names=stump.classes_,
               ax=ax)
# Out:
# [Text(0.5, 0.75, 'value <= 9.708\ngini = 0.165\nsamples = 1100\nvalue = [1000, 100]\nclass = neg'),
#  Text(0.25, 0.25, 'gini = 0.002\nsamples = 999\nvalue = [998, 1]\nclass = neg'),
#  Text(0.75, 0.25, 'gini = 0.039\nsamples = 101\nvalue = [2, 99]\nclass = pos')]

# %%
gini_pos = 0.039
gini_neg = 0.002
pos_size = 101
neg_size = 999
total_size = pos_size + neg_size
weighted_avg = gini_pos * (pos_size/total_size) + \
gini_neg * (neg_size/total_size)

# %%
print(weighted_avg)
# Out:
# 0.005397272727272727

# %%
import xgboost as xgb

# %%
# from graphviz import Digraph

# dot = Digraph(comment='The Round Table')
# dot.node('A', 'King Arthur')
# dot.node('B', 'Sir Bedevere the Wise')
# dot.node('L', 'Sir Lancelot the Brave')

# dot.edges(['AB', 'AL'])
# dot.edge('B', 'L', constraint='false')
# print(dot.source)

# %%
xg_stump = xgb.XGBClassifier(n_estimators=1, max_depth=1)
xg_stump.fit(gini[['value']], (gini.label== 'pos'))
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=1, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=1, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
import os
os.environ["PATH"] += os.pathsep + '/Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/bin'


xgb.plot_tree(xg_stump, num_trees=0)

plt.show()

# %%
import subprocess

def my_dot_export(xg, num_trees, filename, title='', direction='TB'):
    """Exports a specified number of trees from an XGBoost model as a graph 
    visualization in dot and png formats.

    Args:
        xg: An XGBoost model.
        num_trees: The number of tree to export.
        filename: The name of the file to save the exported visualization.
        title: The title to display on the graph visualization (optional).
        direction: The direction to lay out the graph, either 'TB' (top to 
            bottom) or 'LR' (left to right) (optional).
    """
    res = xgb.to_graphviz(xg, num_trees=num_trees)
    content = f'''    node [fontname = "Helvetica"];
    edge [fontname = "Helvetica Thin"];
    label = "{title}"
    fontname = "Helvetica"
    '''
    out = res.source.replace('graph [ rankdir=TB ]', 
                             f'graph [ rankdir={direction} ];\n {content}')
    # dot -Gdpi=300 -Tpng -ocourseflow.png courseflow.dot 
    dot_filename = filename
    with open(dot_filename, 'w') as fout:
        fout.write(out)
    png_filename = dot_filename.replace('.dot', '.png')
    subprocess.run(f'dot -Gdpi=300 -Tpng -o{png_filename} {dot_filename}'.split())

# %%
my_dot_export(xg_stump, num_trees=0, filename='/Users/isisromero/Desktop/img_XGB/stump_xg.dot', title='A demo stump')

# %% [markdown]
# #### Another Visualization Tool

# %%
import dtreeviz
viz = dtreeviz.model(xg_stump, X_train=gini[['value']], 
                     y_train=gini.label=='pos',
    target_name='positive',
    feature_names=['value'], class_names=['negative', 'positive'],
    tree_index=0)
viz.view()

# %% [markdown]
# ## Stumps on Real Data

# %%
stump_dt = tree.DecisionTreeClassifier(max_depth=1)
X_train = kag_pl.fit_transform(kag_X_train)
stump_dt.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
fig, ax = plt.subplots(figsize=(8, 4))
features = list(c for c in X_train.columns)
tree.plot_tree(stump_dt, feature_names=features,
               filled=True,
               class_names=stump_dt.classes_,
               ax=ax)
# Out:
# [Text(0.5, 0.75, 'r <= 0.5\ngini = 0.496\nsamples = 2110\nvalue = [1153, 957]\nclass = Data Scientist'),
#  Text(0.25, 0.25, 'gini = 0.493\nsamples = 1484\nvalue = [653, 831]\nclass = Software Engineer'),
#  Text(0.75, 0.25, 'gini = 0.322\nsamples = 626\nvalue = [500, 126]\nclass = Data Scientist')]

# %%
X_test = kag_pl.transform(kag_X_test)

# %%
stump_dt.score(X_test, kag_y_test)
# Out:
# 0.6243093922651933

# %% [markdown]
# #### The Dummy Classifier

# %%
from sklearn import dummy

# %%
dummy_model = dummy.DummyClassifier()

# %%
dummy_model.fit(X_train, kag_y_train)
# Out:
# DummyClassifier()

# %%
dummy_model.score(X_test, kag_y_test)
# Out:
# 0.5458563535911602

# %%
import xgboost as xgb

# %%
kag_stump = xgb.XGBClassifier(n_estimators=1, max_depth=1)
kag_stump.fit(X_train, kag_y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 2
#       1 kag_stump = xgb.XGBClassifier(n_estimators=1, max_depth=1)
# ----> 2 kag_stump.fit(X_train, kag_y_train)
#
# File ~/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/xgboost/sklearn.py:1440, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1435     expected_classes = np.arange(self.n_classes_)
#    1436 if (
#    1437     self.classes_.shape != expected_classes.shape
#    1438     or not (self.classes_ == expected_classes).all()
#    1439 ):
# -> 1440     raise ValueError(
#    1441         f"Invalid classes inferred from unique values of `y`.  "
#    1442         f"Expected: {expected_classes}, got {self.classes_}"
#    1443     )
#    1445 params = self.get_xgb_params()
#    1447 if callable(self.objective):
#
# ValueError: Invalid classes inferred from unique values of `y`.  Expected: [0 1], got ['Data Scientist' 'Software Engineer']

# %%
print(kag_y_train)
# Out:
# 587      Software Engineer
# 3065        Data Scientist
# 8435        Data Scientist
# 3110        Data Scientist
# 16372    Software Engineer
#                ...
# 16608    Software Engineer
# 7325     Software Engineer
# 21810       Data Scientist
# 4917        Data Scientist
# 639         Data Scientist
# Name: Q6, Length: 2110, dtype: object

# %%
print(kag_y_train == 'Software Engineer')
# Out:
# 587       True
# 3065     False
# 8435     False
# 3110     False
# 16372     True
#          ...
# 16608     True
# 7325      True
# 21810    False
# 4917     False
# 639      False
# Name: Q6, Length: 2110, dtype: bool

# %% [markdown]
# #### Using Label Encoder

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
y_train = label_encoder.fit_transform(kag_y_train)
y_test = label_encoder.transform(kag_y_test)

# %%
y_test[:5]
# Out:
# array([1, 0, 0, 1, 1])

# %%
label_encoder.classes_
# Out:
# array(['Data Scientist', 'Software Engineer'], dtype=object)

# %%
# Inverse Tranformation Procedure
label_encoder.inverse_transform([0, 1])
# Out:
# array(['Data Scientist', 'Software Engineer'], dtype=object)

# %%
kag_stump = xgb.XGBClassifier(n_estimators=1, max_depth=1)
kag_stump.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=1, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=1, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
kag_stump.score(X_test, y_test)
# Out:
# 0.6243093922651933

# %%
my_dot_export(kag_stump, num_trees=0, filename='/Users/isisromero/Desktop/img_XGB/stump_xg.dot',
             title='XGBoost Stump')

# %%
kag_stump.classes_
# Out:
# array([0, 1])

# %%
def inv_logit(p: float) -> float:
    """
    Compute the inverse logit function of a given value.

    The inverse logit function is defined as:
        f(p) = exp(p) / (1 + exp(p))

    Parameters
    ----------
    p : float
        The input value to the inverse logit function.

    Returns
    -------
    float
        The output of the inverse logit function.
    """
    return np.exp(p) / (1 + np.exp(p))

# %%
inv_logit(.07117741922)
# Out:
# 0.5177868460919524

# %%
inv_logit(-.3592)
# Out:
# 0.41115323716754393

# %%
fig, ax = plt.subplots(figsize=(8, 4))
vals = np.linspace(-7, 7)
ax.plot(vals, inv_logit(vals))
ax.annotate('Crossover point', (0,.5), (-5,.8), arrowprops={'color':'k'})
ax.annotate('Predict Positive', (5,.6), (1,.6), va='center', arrowprops={'color':'k'})
ax.annotate('Predict Negative', (-5,.4), (-3,.4), va='center', arrowprops={'color':'k'})
# Out:
# Text(-3, 0.4, 'Predict Negative')

# %% [markdown]
# ## Model Complexity & Hyperparameters
#
# #### Underfit Model

# %%
underfit = tree.DecisionTreeClassifier(max_depth=1)
X_train = kag_pl.fit_transform(kag_X_train)

# %%
underfit.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
underfit.score(X_test, kag_y_test)
# Out:
# 0.6243093922651933

# %% [markdown]
# #### Overfitting with Decision Trees

# %%
hi_variance = tree.DecisionTreeClassifier(max_depth=None)
X_train = kag_pl.fit_transform(kag_X_train)

# %%
hi_variance.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier()

# %%
hi_variance.score(X_test, kag_y_test)
# Out:
# 0.6718232044198895

# %%
fig, ax = plt.subplots(figsize=(8, 4))
features = list(c for c in X_train.columns)
tree.plot_tree(hi_variance, feature_names=features, filled=True)
# Out:
# [Text(0.6631294540465269, 0.9761904761904762, 'r <= 0.5\ngini = 0.496\nsamples = 2110\nvalue = [1153, 957]'),
#  Text(0.4056945240825688, 0.9285714285714286, 'major_cs <= 0.5\ngini = 0.493\nsamples = 1484\nvalue = [653, 831]'),
#  Text(0.2021283857579729, 0.8809523809523809, 'Q3_United States of America <= 0.5\ngini = 0.49\nsamples = 718\nvalue = [410, 308]'),
#  Text(0.08304663608562692, 0.8333333333333334, 'years_exp <= 0.5\ngini = 0.491\nsamples = 322\nvalue = [140, 182]'),
#  Text(0.02490170380078637, 0.7857142857142857, 'education <= 17.0\ngini = 0.463\nsamples = 74\nvalue = [47, 27]'),
#  Text(0.01834862385321101, 0.7380952380952381, 'major_stat <= 0.5\ngini = 0.499\nsamples = 40\nvalue = [21, 19]'),
#  Text(0.016601135867190912, 0.6904761904761905, 'age <= 27.5\ngini = 0.5\nsamples = 38\nvalue = [19, 19]'),
#  Text(0.014853647881170816, 0.6428571428571429, 'compensation <= 55000.0\ngini = 0.498\nsamples = 36\nvalue = [17, 19]'),
#  Text(0.01310615989515072, 0.5952380952380952, 'compensation <= 15000.0\ngini = 0.5\nsamples = 35\nvalue = [17, 18]'),
#  Text(0.011358671909130624, 0.5476190476190477, 'python <= 0.5\ngini = 0.496\nsamples = 33\nvalue = [15, 18]'),
#  Text(0.0069899519440803845, 0.5, 'age <= 23.5\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.0034949759720401923, 0.4523809523809524, 'Q1_Male <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.0017474879860200961, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.005242463958060288, 0.40476190476190477, 'age <= 20.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.0034949759720401923, 0.35714285714285715, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.0069899519440803845, 0.35714285714285715, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.010484927916120577, 0.4523809523809524, 'education <= 14.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.00873743993010048, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.012232415902140673, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.015727391874180863, 0.5, 'Q1_Male <= 0.5\ngini = 0.5\nsamples = 22\nvalue = [11, 11]'),
#  Text(0.013979903888160769, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.01747487986020096, 0.4523809523809524, 'Q3_China <= 0.5\ngini = 0.495\nsamples = 20\nvalue = [9, 11]'),
#  Text(0.015727391874180863, 0.40476190476190477, 'compensation <= 5000.0\ngini = 0.488\nsamples = 19\nvalue = [8, 11]'),
#  Text(0.011358671909130624, 0.35714285714285715, 'age <= 20.0\ngini = 0.469\nsamples = 16\nvalue = [6, 10]'),
#  Text(0.007863695937090432, 0.30952380952380953, 'education <= 14.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.0061162079510703364, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.009611183923110528, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.014853647881170816, 0.30952380952380953, 'age <= 23.5\ngini = 0.426\nsamples = 13\nvalue = [4, 9]'),
#  Text(0.01310615989515072, 0.2619047619047619, 'sql <= 0.5\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.009611183923110528, 0.21428571428571427, 'major_other <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.007863695937090432, 0.16666666666666666, 'gini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.011358671909130624, 0.16666666666666666, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.016601135867190912, 0.21428571428571427, 'major_eng <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.014853647881170816, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01834862385321101, 0.16666666666666666, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.016601135867190912, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.020096111839231105, 0.35714285714285715, 'age <= 20.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.01834862385321101, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.021843599825251202, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.019222367846221056, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.014853647881170816, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.016601135867190912, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01834862385321101, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.020096111839231105, 0.6904761904761905, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.03145478374836173, 0.7380952380952381, 'sql <= 0.5\ngini = 0.36\nsamples = 34\nvalue = [26, 8]'),
#  Text(0.025338575797291395, 0.6904761904761905, 'compensation <= 5000.0\ngini = 0.269\nsamples = 25\nvalue = [21, 4]'),
#  Text(0.021843599825251202, 0.6428571428571429, 'Q3_India <= 0.5\ngini = 0.095\nsamples = 20\nvalue = [19, 1]'),
#  Text(0.020096111839231105, 0.5952380952380952, 'python <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.01834862385321101, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.021843599825251202, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.023591087811271297, 0.5952380952380952, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.028833551769331587, 0.6428571428571429, 'age <= 23.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.02708606378331149, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.03058103975535168, 0.5952380952380952, 'Q1_Male <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.028833551769331587, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03232852774137178, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.037570991699432066, 0.6904761904761905, 'compensation <= 5000.0\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.03582350371341197, 0.6428571428571429, 'age <= 20.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.03407601572739188, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.037570991699432066, 0.5952380952380952, 'age <= 23.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.03582350371341197, 0.5476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.039318479685452164, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.039318479685452164, 0.6428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.14119156837046745, 0.7857142857142857, 'major_stat <= 0.5\ngini = 0.469\nsamples = 248\nvalue = [93, 155]'),
#  Text(0.10894495412844037, 0.7380952380952381, 'education <= 17.0\ngini = 0.446\nsamples = 220\nvalue = [74, 146]'),
#  Text(0.06558540847531673, 0.6904761904761905, 'years_exp <= 1.5\ngini = 0.38\nsamples = 110\nvalue = [28, 82]'),
#  Text(0.05067715159458279, 0.6428571428571429, 'compensation <= 15000.0\ngini = 0.49\nsamples = 28\nvalue = [12, 16]'),
#  Text(0.04892966360856269, 0.5952380952380952, 'age <= 23.5\ngini = 0.444\nsamples = 24\nvalue = [8, 16]'),
#  Text(0.04281345565749235, 0.5476190476190477, 'python <= 0.5\ngini = 0.36\nsamples = 17\nvalue = [4, 13]'),
#  Text(0.039318479685452164, 0.5, 'age <= 20.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.037570991699432066, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.04106596767147226, 0.4523809523809524, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.04630843162953255, 0.5, 'Q1_Prefer not to say <= 0.5\ngini = 0.245\nsamples = 14\nvalue = [2, 12]'),
#  Text(0.04456094364351245, 0.4523809523809524, 'sql <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.04281345565749235, 0.40476190476190477, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.04630843162953255, 0.40476190476190477, 'major_other <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.04456094364351245, 0.35714285714285715, 'compensation <= 5000.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.04281345565749235, 0.30952380952380953, 'gini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.04630843162953255, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.048055919615552646, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.048055919615552646, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.05504587155963303, 0.5476190476190477, 'compensation <= 5000.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.05329838357361293, 0.5, 'major_eng <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.051550895587592835, 0.4523809523809524, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.04980340760157274, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.05329838357361293, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05504587155963303, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.05679335954565312, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.05242463958060288, 0.5952380952380952, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.08049366535605068, 0.6428571428571429, 'age <= 20.0\ngini = 0.314\nsamples = 82\nvalue = [16, 66]'),
#  Text(0.07874617737003058, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08224115334207077, 0.5952380952380952, 'age <= 45.0\ngini = 0.302\nsamples = 81\nvalue = [15, 66]'),
#  Text(0.08049366535605068, 0.5476190476190477, 'years_exp <= 4.5\ngini = 0.289\nsamples = 80\nvalue = [14, 66]'),
#  Text(0.06837046745303627, 0.5, 'age <= 23.5\ngini = 0.357\nsamples = 56\nvalue = [13, 43]'),
#  Text(0.05854084753167322, 0.4523809523809524, 'compensation <= 5000.0\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.05679335954565312, 0.40476190476190477, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.06028833551769332, 0.40476190476190477, 'years_exp <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.05854084753167322, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.062035823503713415, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.0782000873743993, 0.4523809523809524, 'compensation <= 45000.0\ngini = 0.402\nsamples = 43\nvalue = [12, 31]'),
#  Text(0.0764525993883792, 0.40476190476190477, 'sql <= 0.5\ngini = 0.387\nsamples = 42\nvalue = [11, 31]'),
#  Text(0.0655307994757536, 0.35714285714285715, 'age <= 32.5\ngini = 0.32\nsamples = 25\nvalue = [5, 20]'),
#  Text(0.06378331148973351, 0.30952380952380953, 'education <= 14.0\ngini = 0.351\nsamples = 22\nvalue = [5, 17]'),
#  Text(0.06028833551769332, 0.2619047619047619, 'Q1_Male <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.05854084753167322, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.062035823503713415, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0672782874617737, 0.2619047619047619, 'years_exp <= 2.5\ngini = 0.32\nsamples = 20\nvalue = [4, 16]'),
#  Text(0.0655307994757536, 0.21428571428571427, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.0690257754477938, 0.21428571428571427, 'Q3_India <= 0.5\ngini = 0.408\nsamples = 14\nvalue = [4, 10]'),
#  Text(0.0672782874617737, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.07077326343381389, 0.16666666666666666, 'compensation <= 5000.0\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.06640454346876365, 0.11904761904761904, 'age <= 27.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.06290956749672345, 0.07142857142857142, 'years_exp <= 3.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.06116207951070336, 0.023809523809523808, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.06465705548274356, 0.023809523809523808, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06989951944080385, 0.07142857142857142, 'years_exp <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06815203145478375, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07164700742682394, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07514198339886413, 0.11904761904761904, 'major_other <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.07339449541284404, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.07688947138488422, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0672782874617737, 0.30952380952380953, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.08737439930100481, 0.35714285714285715, 'python <= 0.5\ngini = 0.457\nsamples = 17\nvalue = [6, 11]'),
#  Text(0.0856269113149847, 0.30952380952380953, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.0891218872870249, 0.30952380952380953, 'compensation <= 15000.0\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.08737439930100481, 0.2619047619047619, 'compensation <= 5000.0\ngini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(0.0856269113149847, 0.21428571428571427, 'Q1_Female <= 0.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.08387942332896461, 0.16666666666666666, 'years_exp <= 3.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.08213193534294452, 0.11904761904761904, 'years_exp <= 2.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.08038444735692442, 0.07142857142857142, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.08387942332896461, 0.07142857142857142, 'major_other <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.08213193534294452, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0856269113149847, 0.023809523809523808, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0856269113149847, 0.11904761904761904, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.08737439930100481, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0891218872870249, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.09086937527304499, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0799475753604194, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0926168632590651, 0.5, 'compensation <= 25000.0\ngini = 0.08\nsamples = 24\nvalue = [1, 23]'),
#  Text(0.09086937527304499, 0.4523809523809524, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.09436435124508519, 0.4523809523809524, 'compensation <= 45000.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.0926168632590651, 0.40476190476190477, 'Q3_India <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.09086937527304499, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09436435124508519, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09611183923110529, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.08398864132809086, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.152304499781564, 0.6904761904761905, 'education <= 19.5\ngini = 0.487\nsamples = 110\nvalue = [46, 64]'),
#  Text(0.14340323285277415, 0.6428571428571429, 'education <= 18.5\ngini = 0.477\nsamples = 102\nvalue = [40, 62]'),
#  Text(0.1343381389252949, 0.5952380952380952, 'sql <= 0.5\ngini = 0.487\nsamples = 93\nvalue = [39, 54]'),
#  Text(0.12145041502839668, 0.5476190476190477, 'compensation <= 15000.0\ngini = 0.461\nsamples = 61\nvalue = [22, 39]'),
#  Text(0.11708169506334644, 0.5, 'years_exp <= 7.5\ngini = 0.495\nsamples = 40\nvalue = [18, 22]'),
#  Text(0.11533420707732635, 0.4523809523809524, 'age <= 32.5\ngini = 0.497\nsamples = 39\nvalue = [18, 21]'),
#  Text(0.11358671909130624, 0.40476190476190477, 'years_exp <= 3.5\ngini = 0.491\nsamples = 37\nvalue = [16, 21]'),
#  Text(0.10834425513324596, 0.35714285714285715, 'age <= 27.5\ngini = 0.477\nsamples = 28\nvalue = [11, 17]'),
#  Text(0.10659676714722587, 0.30952380952380953, 'age <= 23.5\ngini = 0.453\nsamples = 26\nvalue = [9, 17]'),
#  Text(0.09785932721712538, 0.2619047619047619, 'years_exp <= 2.5\ngini = 0.496\nsamples = 11\nvalue = [5, 6]'),
#  Text(0.09611183923110529, 0.21428571428571427, 'major_other <= 0.5\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.09086937527304499, 0.16666666666666666, 'python <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.0891218872870249, 0.11904761904761904, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.0926168632590651, 0.11904761904761904, 'compensation <= 5000.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.09086937527304499, 0.07142857142857142, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.09436435124508519, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10135430318916558, 0.16666666666666666, 'Q3_China <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.09960681520314547, 0.11904761904761904, 'years_exp <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.09785932721712538, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10135430318916558, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10310179117518567, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09960681520314547, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11533420707732635, 0.2619047619047619, 'Q1_Female <= 0.5\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.11183923110528615, 0.21428571428571427, 'python <= 0.5\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.11009174311926606, 0.16666666666666666, 'years_exp <= 2.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.10834425513324596, 0.11904761904761904, 'Q3_China <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.10484927916120576, 0.07142857142857142, 'years_exp <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.10310179117518567, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10659676714722587, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11183923110528615, 0.07142857142857142, 'major_other <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.11009174311926606, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11358671909130624, 0.023809523809523808, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11183923110528615, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11358671909130624, 0.16666666666666666, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.11882918304936653, 0.21428571428571427, 'Q3_India <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.11708169506334644, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12057667103538663, 0.16666666666666666, 'major_eng <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.11882918304936653, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12232415902140673, 0.11904761904761904, 'years_exp <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.12057667103538663, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12407164700742683, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11009174311926606, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.11882918304936653, 0.35714285714285715, 'age <= 27.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.11708169506334644, 0.30952380952380953, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.12057667103538663, 0.30952380952380953, 'major_other <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.11882918304936653, 0.2619047619047619, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.12232415902140673, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.11708169506334644, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.11882918304936653, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1258191349934469, 0.5, 'years_exp <= 7.5\ngini = 0.308\nsamples = 21\nvalue = [4, 17]'),
#  Text(0.12232415902140673, 0.4523809523809524, 'compensation <= 75000.0\ngini = 0.124\nsamples = 15\nvalue = [1, 14]'),
#  Text(0.12057667103538663, 0.40476190476190477, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.12407164700742683, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12931411096548712, 0.4523809523809524, 'years_exp <= 12.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.12756662297946703, 0.40476190476190477, 'age <= 32.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.1258191349934469, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12931411096548712, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.1310615989515072, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1472258628221931, 0.5476190476190477, 'years_exp <= 3.5\ngini = 0.498\nsamples = 32\nvalue = [17, 15]'),
#  Text(0.1380515508955876, 0.5, 'compensation <= 107500.0\ngini = 0.415\nsamples = 17\nvalue = [12, 5]'),
#  Text(0.1363040629095675, 0.4523809523809524, 'compensation <= 5000.0\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.1345565749235474, 0.40476190476190477, 'age <= 27.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.1328090869375273, 0.35714285714285715, 'major_eng <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.1310615989515072, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1345565749235474, 0.30952380952380953, 'age <= 23.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.1328090869375273, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1363040629095675, 0.2619047619047619, 'Q3_China <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1345565749235474, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1380515508955876, 0.21428571428571427, 'years_exp <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1363040629095675, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1397990388816077, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1363040629095675, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1380515508955876, 0.40476190476190477, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.1397990388816077, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1564001747487986, 0.5, 'compensation <= 35000.0\ngini = 0.444\nsamples = 15\nvalue = [5, 10]'),
#  Text(0.15203145478374835, 0.4523809523809524, 'years_exp <= 7.5\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.14853647881170817, 0.40476190476190477, 'major_other <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.14678899082568808, 0.35714285714285715, 'years_exp <= 4.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.145041502839668, 0.30952380952380953, 'Q1_Female <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.14329401485364787, 0.2619047619047619, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.14154652686762778, 0.21428571428571427, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.145041502839668, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14678899082568808, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14853647881170817, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15028396679772826, 0.35714285714285715, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.15552643075578856, 0.40476190476190477, 'age <= 40.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.15377894276976845, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15727391874180865, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16076889471384884, 0.4523809523809524, 'compensation <= 90000.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.15902140672782875, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.16251638269986893, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15246832678025338, 0.5952380952380952, 'age <= 32.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.15072083879423329, 0.5476190476190477, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.1542158147662735, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16120576671035386, 0.6428571428571429, 'python <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.15945827872433377, 0.5952380952380952, 'Q3_China <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.15771079073831368, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16120576671035386, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.16295325469637395, 0.5952380952380952, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.17343818261249455, 0.7380952380952381, 'sql <= 0.5\ngini = 0.436\nsamples = 28\nvalue = [19, 9]'),
#  Text(0.16994320664045434, 0.6904761904761905, 'years_exp <= 7.5\ngini = 0.32\nsamples = 20\nvalue = [16, 4]'),
#  Text(0.16819571865443425, 0.6428571428571429, 'python <= 0.5\ngini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.16644823066841416, 0.5952380952380952, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.16994320664045434, 0.5952380952380952, 'compensation <= 15000.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.16819571865443425, 0.5476190476190477, 'years_exp <= 2.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.16644823066841416, 0.5, 'age <= 23.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.16470074268239407, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.16819571865443425, 0.4523809523809524, 'Q3_India <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.16644823066841416, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16994320664045434, 0.40476190476190477, 'education <= 17.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.16819571865443425, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17169069462647443, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16994320664045434, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17169069462647443, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.17169069462647443, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17693315858453473, 0.6904761904761905, 'Q1_Male <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.17518567059851464, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.17868064657055482, 0.6428571428571429, 'compensation <= 15000.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.17693315858453473, 0.5952380952380952, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.18042813455657492, 0.5952380952380952, 'Q3_India <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.17868064657055482, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.182175622542595, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3212101354303189, 0.8333333333333334, 'years_exp <= 4.5\ngini = 0.434\nsamples = 396\nvalue = [270, 126]'),
#  Text(0.2805810397553517, 0.7857142857142857, 'major_eng <= 0.5\ngini = 0.363\nsamples = 294\nvalue = [224, 70]'),
#  Text(0.24388379204892965, 0.7380952380952381, 'education <= 19.5\ngini = 0.303\nsamples = 204\nvalue = [166, 38]'),
#  Text(0.2199650502402796, 0.6904761904761905, 'years_exp <= 1.5\ngini = 0.348\nsamples = 147\nvalue = [114, 33]'),
#  Text(0.2038007863695937, 0.6428571428571429, 'education <= 18.5\ngini = 0.263\nsamples = 77\nvalue = [65, 12]'),
#  Text(0.2020532983835736, 0.5952380952380952, 'Q1_Prefer to self-describe <= 0.5\ngini = 0.248\nsamples = 76\nvalue = [65, 11]'),
#  Text(0.20030581039755352, 0.5476190476190477, 'age <= 37.5\ngini = 0.231\nsamples = 75\nvalue = [65, 10]'),
#  Text(0.19222367846221058, 0.5, 'education <= 17.0\ngini = 0.205\nsamples = 69\nvalue = [61, 8]'),
#  Text(0.18304936653560508, 0.4523809523809524, 'major_other <= 0.5\ngini = 0.278\nsamples = 30\nvalue = [25, 5]'),
#  Text(0.17693315858453473, 0.40476190476190477, 'Q1_Female <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.17518567059851464, 0.35714285714285715, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.17868064657055482, 0.35714285714285715, 'compensation <= 85000.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.17693315858453473, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.18042813455657492, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1891655744866754, 0.40476190476190477, 'compensation <= 75000.0\ngini = 0.36\nsamples = 17\nvalue = [13, 4]'),
#  Text(0.1874180865006553, 0.35714285714285715, 'age <= 23.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.18392311052861512, 0.30952380952380953, 'compensation <= 60000.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.182175622542595, 0.2619047619047619, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.18567059851463522, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1909130624726955, 0.30952380952380953, 'compensation <= 65000.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.1891655744866754, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.1926605504587156, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1909130624726955, 0.35714285714285715, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.2013979903888161, 0.4523809523809524, 'major_stat <= 0.5\ngini = 0.142\nsamples = 39\nvalue = [36, 3]'),
#  Text(0.19790301441677588, 0.40476190476190477, 'compensation <= 112500.0\ngini = 0.074\nsamples = 26\nvalue = [25, 1]'),
#  Text(0.1961555264307558, 0.35714285714285715, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.19965050240279597, 0.35714285714285715, 'sql <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.19790301441677588, 0.30952380952380953, 'age <= 23.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1961555264307558, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.19965050240279597, 0.2619047619047619, 'compensation <= 137500.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.19790301441677588, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2013979903888161, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2013979903888161, 0.30952380952380953, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.20489296636085627, 0.40476190476190477, 'sql <= 0.5\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.20314547837483618, 0.35714285714285715, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.20664045434687636, 0.35714285714285715, 'compensation <= 35000.0\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.20489296636085627, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.20838794233289645, 0.30952380952380953, 'compensation <= 112500.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.20664045434687636, 0.2619047619047619, 'Q1_Female <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.20489296636085627, 0.21428571428571427, 'compensation <= 85000.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.20314547837483618, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.20664045434687636, 0.16666666666666666, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.20838794233289645, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.21013543031891654, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.20838794233289645, 0.5, 'compensation <= 30000.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.20664045434687636, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.21013543031891654, 0.4523809523809524, 'age <= 45.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.20838794233289645, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.21188291830493666, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2038007863695937, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2055482743556138, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2361293141109655, 0.6428571428571429, 'compensation <= 75000.0\ngini = 0.42\nsamples = 70\nvalue = [49, 21]'),
#  Text(0.22673656618610746, 0.5952380952380952, 'compensation <= 10000.0\ngini = 0.499\nsamples = 25\nvalue = [13, 12]'),
#  Text(0.22236784622105724, 0.5476190476190477, 'age <= 27.5\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.21887287024901703, 0.5, 'education <= 17.0\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.21712538226299694, 0.4523809523809524, 'sql <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.21537789427697684, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.21887287024901703, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.22062035823503715, 0.4523809523809524, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.22586282219309742, 0.5, 'Q1_Female <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.22411533420707733, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.2276103101791175, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.23110528615115772, 0.5476190476190477, 'years_exp <= 3.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.22935779816513763, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.2328527741371778, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2455220620358235, 0.5952380952380952, 'sql <= 0.5\ngini = 0.32\nsamples = 45\nvalue = [36, 9]'),
#  Text(0.24071647007426825, 0.5476190476190477, 'compensation <= 112500.0\ngini = 0.413\nsamples = 24\nvalue = [17, 7]'),
#  Text(0.236347750109218, 0.5, 'education <= 17.0\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.2328527741371778, 0.4523809523809524, 'education <= 12.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.23110528615115772, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2346002621231979, 0.40476190476190477, 'years_exp <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.2328527741371778, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.236347750109218, 0.35714285714285715, 'years_exp <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2346002621231979, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.23809523809523808, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2398427260812582, 0.4523809523809524, 'python <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.23809523809523808, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2415902140672783, 0.40476190476190477, 'compensation <= 95000.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.2398427260812582, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.24333770205329838, 0.35714285714285715, 'age <= 27.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.2415902140672783, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.24508519003931847, 0.30952380952380953, 'major_stat <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.24333770205329838, 0.2619047619047619, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.24683267802533856, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.24508519003931847, 0.5, 'Q1_Prefer not to say <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.24333770205329838, 0.4523809523809524, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.24683267802533856, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2503276539973788, 0.5476190476190477, 'compensation <= 137500.0\ngini = 0.172\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.24858016601135868, 0.5, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.25207514198339886, 0.5, 'major_other <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.2503276539973788, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.25382262996941896, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.26780253385757974, 0.6904761904761905, 'compensation <= 137500.0\ngini = 0.16\nsamples = 57\nvalue = [52, 5]'),
#  Text(0.2608125819134993, 0.6428571428571429, 'age <= 27.5\ngini = 0.083\nsamples = 46\nvalue = [44, 2]'),
#  Text(0.25557011795543905, 0.5952380952380952, 'compensation <= 90000.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.25382262996941896, 0.5476190476190477, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.25731760594145914, 0.5476190476190477, 'Q1_Female <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.25557011795543905, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.25906509392747923, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.26605504587155965, 0.5952380952380952, 'age <= 32.5\ngini = 0.05\nsamples = 39\nvalue = [38, 1]'),
#  Text(0.26430755788553956, 0.5476190476190477, 'sql <= 0.5\ngini = 0.095\nsamples = 20\nvalue = [19, 1]'),
#  Text(0.26256006989951947, 0.5, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.26605504587155965, 0.5, 'years_exp <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.26430755788553956, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.26780253385757974, 0.4523809523809524, 'years_exp <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.26605504587155965, 0.40476190476190477, 'Q1_Male <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.26430755788553956, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.26780253385757974, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.26955002184359983, 0.40476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.26780253385757974, 0.5476190476190477, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.2747924858016601, 0.6428571428571429, 'Q1_Female <= 0.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.27304499781564, 0.5952380952380952, 'sql <= 0.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.2712975098296199, 0.5476190476190477, 'python <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.26955002184359983, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.27304499781564, 0.5, 'years_exp <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2712975098296199, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2747924858016601, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2747924858016601, 0.5476190476190477, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.2765399737876802, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3172782874617737, 0.7380952380952381, 'compensation <= 112500.0\ngini = 0.458\nsamples = 90\nvalue = [58, 32]'),
#  Text(0.3090869375273045, 0.6904761904761905, 'years_exp <= 3.5\ngini = 0.489\nsamples = 66\nvalue = [38, 28]'),
#  Text(0.3073394495412844, 0.6428571428571429, 'age <= 37.5\ngini = 0.475\nsamples = 62\nvalue = [38, 24]'),
#  Text(0.2979467016164264, 0.5952380952380952, 'years_exp <= 0.5\ngini = 0.456\nsamples = 57\nvalue = [37, 20]'),
#  Text(0.28440366972477066, 0.5476190476190477, 'age <= 32.5\ngini = 0.491\nsamples = 23\nvalue = [13, 10]'),
#  Text(0.28265618173875057, 0.5, 'Q1_Male <= 0.5\ngini = 0.483\nsamples = 22\nvalue = [13, 9]'),
#  Text(0.2782874617737003, 0.4523809523809524, 'sql <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.2765399737876802, 0.40476190476190477, 'compensation <= 45000.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.2747924858016601, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2782874617737003, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2800349497597204, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2870249017038008, 0.4523809523809524, 'age <= 23.5\ngini = 0.457\nsamples = 17\nvalue = [11, 6]'),
#  Text(0.2835299257317606, 0.40476190476190477, 'sql <= 0.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.2817824377457405, 0.35714285714285715, 'compensation <= 75000.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.2800349497597204, 0.30952380952380953, 'education <= 19.0\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.2782874617737003, 0.2619047619047619, 'education <= 17.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.2765399737876802, 0.21428571428571427, 'python <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2747924858016601, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2782874617737003, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2800349497597204, 0.21428571428571427, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2817824377457405, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2835299257317606, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2852774137177807, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.290519877675841, 0.40476190476190477, 'compensation <= 60000.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.2887723896898209, 0.35714285714285715, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.29226736566186107, 0.35714285714285715, 'sql <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.290519877675841, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.29401485364788116, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.28615115771079075, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3114897335080821, 0.5476190476190477, 'age <= 32.5\ngini = 0.415\nsamples = 34\nvalue = [24, 10]'),
#  Text(0.30974224552206203, 0.5, 'compensation <= 95000.0\ngini = 0.444\nsamples = 30\nvalue = [20, 10]'),
#  Text(0.30624726955002185, 0.4523809523809524, 'Q1_Prefer not to say <= 0.5\ngini = 0.469\nsamples = 24\nvalue = [15, 9]'),
#  Text(0.30449978156400176, 0.40476190476190477, 'sql <= 0.5\ngini = 0.476\nsamples = 23\nvalue = [14, 9]'),
#  Text(0.2992573176059415, 0.35714285714285715, 'age <= 27.5\ngini = 0.444\nsamples = 15\nvalue = [10, 5]'),
#  Text(0.29750982961992134, 0.30952380952380953, 'years_exp <= 2.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.29401485364788116, 0.2619047619047619, 'compensation <= 75000.0\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.29226736566186107, 0.21428571428571427, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.29576234163390125, 0.21428571428571427, 'age <= 23.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.29401485364788116, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.29750982961992134, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3010048055919616, 0.2619047619047619, 'Q1_Female <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2992573176059415, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.30275229357798167, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3010048055919616, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.30974224552206203, 0.35714285714285715, 'age <= 27.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.30624726955002185, 0.30952380952380953, 'compensation <= 35000.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.30449978156400176, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.30799475753604194, 0.2619047619047619, 'python <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.30624726955002185, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.30974224552206203, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3132372214941022, 0.30952380952380953, 'education <= 19.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.3114897335080821, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3149847094801223, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.30799475753604194, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3132372214941022, 0.4523809523809524, 'years_exp <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.3114897335080821, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3149847094801223, 0.40476190476190477, 'years_exp <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3132372214941022, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3167321974661424, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3132372214941022, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3167321974661424, 0.5952380952380952, 'education <= 19.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.3149847094801223, 0.5476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.31847968545216254, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3108344255133246, 0.6428571428571429, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3254696373962429, 0.6904761904761905, 'education <= 17.0\ngini = 0.278\nsamples = 24\nvalue = [20, 4]'),
#  Text(0.3219746614242027, 0.6428571428571429, 'age <= 23.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.32022717343818263, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3237221494102228, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3289646133682831, 0.6428571428571429, 'age <= 27.5\ngini = 0.172\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.327217125382263, 0.5952380952380952, 'years_exp <= 3.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.3254696373962429, 0.5476190476190477, 'years_exp <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.3237221494102228, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.327217125382263, 0.5, 'years_exp <= 1.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.3254696373962429, 0.4523809523809524, 'sql <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3237221494102228, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.327217125382263, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3289646133682831, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3289646133682831, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3307121013543032, 0.5952380952380952, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.36183923110528615, 0.7857142857142857, 'education <= 18.5\ngini = 0.495\nsamples = 102\nvalue = [46, 56]'),
#  Text(0.3475316732197466, 0.7380952380952381, 'education <= 17.0\ngini = 0.438\nsamples = 74\nvalue = [24, 50]'),
#  Text(0.3377020532983836, 0.6904761904761905, 'major_other <= 0.5\ngini = 0.165\nsamples = 22\nvalue = [2, 20]'),
#  Text(0.33595456531236345, 0.6428571428571429, 'age <= 40.0\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.33420707732634336, 0.5952380952380952, 'compensation <= 65000.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.33245958934032327, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.33595456531236345, 0.5476190476190477, 'compensation <= 137500.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.33420707732634336, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3377020532983836, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3377020532983836, 0.5952380952380952, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
# ...
#  Text(0.6304062909567497, 0.5952380952380952, 'Q3_India <= 0.5\ngini = 0.48\nsamples = 35\nvalue = [21, 14]'),
#  Text(0.6286588029707296, 0.5476190476190477, 'age <= 32.5\ngini = 0.498\nsamples = 30\nvalue = [16, 14]'),
#  Text(0.6225425950196593, 0.5, 'Q3_China <= 0.5\ngini = 0.48\nsamples = 25\nvalue = [15, 10]'),
#  Text(0.6155526430755789, 0.4523809523809524, 'years_exp <= 1.5\ngini = 0.415\nsamples = 17\nvalue = [12, 5]'),
#  Text(0.6138051550895588, 0.40476190476190477, 'compensation <= 112500.0\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.6103101791175186, 0.35714285714285715, 'age <= 27.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.6085626911314985, 0.30952380952380953, 'compensation <= 75000.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.6068152031454783, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6103101791175186, 0.2619047619047619, 'compensation <= 90000.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.6085626911314985, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6120576671035387, 0.21428571428571427, 'sql <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.6103101791175186, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6138051550895588, 0.16666666666666666, 'years_exp <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.6120576671035387, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6155526430755789, 0.11904761904761904, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6120576671035387, 0.30952380952380953, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.617300131061599, 0.35714285714285715, 'education <= 19.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6155526430755789, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6190476190476191, 0.30952380952380953, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.617300131061599, 0.40476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6295325469637396, 0.4523809523809524, 'sql <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.6277850589777195, 0.40476190476190477, 'years_exp <= 1.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.6242900830056793, 0.35714285714285715, 'compensation <= 35000.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6225425950196593, 0.30952380952380953, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6260375709916994, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6312800349497597, 0.35714285714285715, 'education <= 19.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6295325469637396, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6330275229357798, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6312800349497597, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6347750109217999, 0.5, 'Q3_United States of America <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6330275229357798, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.63652249890782, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6321537789427698, 0.5476190476190477, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6339012669287899, 0.5952380952380952, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.63564875491481, 0.6428571428571429, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.7104869757536042, 0.8333333333333334, 'education <= 17.0\ngini = 0.334\nsamples = 293\nvalue = [62, 231]'),
#  Text(0.6664755351681957, 0.7857142857142857, 'Q3_China <= 0.5\ngini = 0.233\nsamples = 134\nvalue = [18, 116]'),
#  Text(0.6599497597204019, 0.7380952380952381, 'years_exp <= 12.5\ngini = 0.203\nsamples = 122\nvalue = [14, 108]'),
#  Text(0.6582022717343818, 0.6904761904761905, 'age <= 42.5\ngini = 0.226\nsamples = 108\nvalue = [14, 94]'),
#  Text(0.6521406727828746, 0.6428571428571429, 'years_exp <= 3.5\ngini = 0.215\nsamples = 106\nvalue = [13, 93]'),
#  Text(0.6452599388379205, 0.5952380952380952, 'compensation <= 90000.0\ngini = 0.32\nsamples = 20\nvalue = [4, 16]'),
#  Text(0.6435124508519003, 0.5476190476190477, 'age <= 32.5\ngini = 0.198\nsamples = 18\nvalue = [2, 16]'),
#  Text(0.6417649628658803, 0.5, 'python <= 0.5\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(0.6400174748798602, 0.4523809523809524, 'compensation <= 5000.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6382699868938401, 0.40476190476190477, 'age <= 21.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.63652249890782, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6400174748798602, 0.35714285714285715, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6417649628658803, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6435124508519003, 0.4523809523809524, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.6452599388379205, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6470074268239406, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6590214067278287, 0.5952380952380952, 'Q3_India <= 0.5\ngini = 0.187\nsamples = 86\nvalue = [9, 77]'),
#  Text(0.6572739187418086, 0.5476190476190477, 'gini = 0.0\nsamples = 30\nvalue = [0, 30]'),
#  Text(0.6607688947138488, 0.5476190476190477, 'compensation <= 85000.0\ngini = 0.27\nsamples = 56\nvalue = [9, 47]'),
#  Text(0.654434250764526, 0.5, 'compensation <= 5000.0\ngini = 0.252\nsamples = 54\nvalue = [8, 46]'),
#  Text(0.6470074268239406, 0.4523809523809524, 'Q1_Female <= 0.5\ngini = 0.33\nsamples = 24\nvalue = [5, 19]'),
#  Text(0.6452599388379205, 0.40476190476190477, 'age <= 32.5\ngini = 0.363\nsamples = 21\nvalue = [5, 16]'),
#  Text(0.6435124508519003, 0.35714285714285715, 'python <= 0.5\ngini = 0.401\nsamples = 18\nvalue = [5, 13]'),
#  Text(0.6373962429008301, 0.30952380952380953, 'years_exp <= 4.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.63564875491481, 0.2619047619047619, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6391437308868502, 0.2619047619047619, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6373962429008301, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6408912188728703, 0.21428571428571427, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6496286588029707, 0.30952380952380953, 'years_exp <= 7.5\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.6461336828309305, 0.2619047619047619, 'sql <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.6443861948449104, 0.21428571428571427, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.6478811708169506, 0.21428571428571427, 'years_exp <= 4.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6461336828309305, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6496286588029707, 0.16666666666666666, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6478811708169506, 0.11904761904761904, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6513761467889908, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6531236347750109, 0.2619047619047619, 'age <= 24.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6513761467889908, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.654871122761031, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6470074268239406, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6487549148099607, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6618610747051114, 0.4523809523809524, 'compensation <= 15000.0\ngini = 0.18\nsamples = 30\nvalue = [3, 27]'),
#  Text(0.6601135867190913, 0.40476190476190477, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.6636085626911316, 0.40476190476190477, 'Q1_Female <= 0.5\ngini = 0.255\nsamples = 20\nvalue = [3, 17]'),
#  Text(0.6601135867190913, 0.35714285714285715, 'sql <= 0.5\ngini = 0.198\nsamples = 18\nvalue = [2, 16]'),
#  Text(0.6583660987330712, 0.30952380952380953, 'age <= 27.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.6566186107470511, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6601135867190913, 0.2619047619047619, 'years_exp <= 4.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.6583660987330712, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6618610747051114, 0.21428571428571427, 'years_exp <= 7.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6601135867190913, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6636085626911316, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6618610747051114, 0.30952380952380953, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.6671035386631717, 0.35714285714285715, 'age <= 27.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6653560506771516, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6688510266491918, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6671035386631717, 0.5, 'compensation <= 300000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6653560506771516, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6688510266491918, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.664263870685889, 0.6428571428571429, 'years_exp <= 7.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6625163826998689, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6660113586719091, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.661697247706422, 0.6904761904761905, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.6730013106159896, 0.7380952380952381, 'sql <= 0.5\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.6695063346439494, 0.6904761904761905, 'age <= 32.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.6677588466579292, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6712538226299695, 0.6428571428571429, 'years_exp <= 4.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6695063346439494, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6730013106159896, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6764962865880297, 0.6904761904761905, 'compensation <= 55000.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.6747487986020096, 0.6428571428571429, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.6782437745740498, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7544984163390127, 0.7857142857142857, 'age <= 20.0\ngini = 0.4\nsamples = 159\nvalue = [44, 115]'),
#  Text(0.7527509283529926, 0.7380952380952381, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7562459043250328, 0.7380952380952381, 'age <= 47.5\ngini = 0.392\nsamples = 157\nvalue = [42, 115]'),
#  Text(0.7449077107907384, 0.6904761904761905, 'years_exp <= 7.5\ngini = 0.375\nsamples = 148\nvalue = [37, 111]'),
#  Text(0.73271625163827, 0.6428571428571429, 'education <= 19.5\ngini = 0.422\nsamples = 109\nvalue = [33, 76]'),
#  Text(0.7188182612494539, 0.5952380952380952, 'age <= 37.5\ngini = 0.397\nsamples = 99\nvalue = [27, 72]'),
#  Text(0.7067496723460026, 0.5476190476190477, 'age <= 27.5\ngini = 0.372\nsamples = 93\nvalue = [23, 70]'),
#  Text(0.691131498470948, 0.5, 'education <= 18.5\ngini = 0.427\nsamples = 42\nvalue = [13, 29]'),
#  Text(0.6893840104849279, 0.4523809523809524, 'compensation <= 5000.0\ngini = 0.414\nsamples = 41\nvalue = [12, 29]'),
#  Text(0.6784622105723023, 0.40476190476190477, 'years_exp <= 4.5\ngini = 0.298\nsamples = 22\nvalue = [4, 18]'),
#  Text(0.6767147225862822, 0.35714285714285715, 'python <= 0.5\ngini = 0.332\nsamples = 19\nvalue = [4, 15]'),
#  Text(0.672346002621232, 0.30952380952380953, 'years_exp <= 3.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.6705985146352119, 0.2619047619047619, 'age <= 23.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6688510266491918, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.672346002621232, 0.21428571428571427, 'Q3_India <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6705985146352119, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6740934906072521, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6740934906072521, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6810834425513325, 0.30952380952380953, 'years_exp <= 3.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.6775884665792923, 0.2619047619047619, 'Q3_United States of America <= 0.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.6758409785932722, 0.21428571428571427, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.6793359545653124, 0.21428571428571427, 'sql <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6775884665792923, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6810834425513325, 0.16666666666666666, 'age <= 23.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6793359545653124, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6828309305373526, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6845784185233726, 0.2619047619047619, 'Q1_Female <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6828309305373526, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6863259065093927, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6802096985583224, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.7003058103975535, 0.40476190476190477, 'compensation <= 125000.0\ngini = 0.488\nsamples = 19\nvalue = [8, 11]'),
#  Text(0.6985583224115334, 0.35714285714285715, 'years_exp <= 4.5\ngini = 0.5\nsamples = 16\nvalue = [8, 8]'),
#  Text(0.6968108344255133, 0.30952380952380953, 'python <= 0.5\ngini = 0.498\nsamples = 15\nvalue = [7, 8]'),
#  Text(0.691568370467453, 0.2619047619047619, 'compensation <= 60000.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6898208824814329, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6933158584534731, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7020532983835737, 0.2619047619047619, 'compensation <= 45000.0\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.6968108344255133, 0.21428571428571427, 'sql <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.6950633464394932, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6985583224115334, 0.16666666666666666, 'years_exp <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6968108344255133, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7003058103975535, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7072957623416339, 0.21428571428571427, 'Q3_United States of America <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.7055482743556138, 0.16666666666666666, 'compensation <= 55000.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.7038007863695938, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7072957623416339, 0.11904761904761904, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.709043250327654, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.7003058103975535, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7020532983835737, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6928789864569681, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7223678462210572, 0.5, 'compensation <= 112500.0\ngini = 0.315\nsamples = 51\nvalue = [10, 41]'),
#  ...]

# %%
fig, ax = plt.subplots(figsize=(8, 4))
features = list(c for c in X_train.columns)
tree.plot_tree(hi_variance, feature_names=features, filled=True, class_names=hi_variance.classes_,
              max_depth=2, fontsize=6)
# Out:
# [Text(0.5, 0.875, 'r <= 0.5\ngini = 0.496\nsamples = 2110\nvalue = [1153, 957]\nclass = Data Scientist'),
#  Text(0.25, 0.625, 'major_cs <= 0.5\ngini = 0.493\nsamples = 1484\nvalue = [653, 831]\nclass = Software Engineer'),
#  Text(0.125, 0.375, 'Q3_United States of America <= 0.5\ngini = 0.49\nsamples = 718\nvalue = [410, 308]\nclass = Data Scientist'),
#  Text(0.0625, 0.125, '\n  (...)  \n'),
#  Text(0.1875, 0.125, '\n  (...)  \n'),
#  Text(0.375, 0.375, 'years_exp <= 2.5\ngini = 0.433\nsamples = 766\nvalue = [243, 523]\nclass = Software Engineer'),
#  Text(0.3125, 0.125, '\n  (...)  \n'),
#  Text(0.4375, 0.125, '\n  (...)  \n'),
#  Text(0.75, 0.625, 'major_cs <= 0.5\ngini = 0.322\nsamples = 626\nvalue = [500, 126]\nclass = Data Scientist'),
#  Text(0.625, 0.375, 'years_exp <= 22.5\ngini = 0.211\nsamples = 443\nvalue = [390, 53]\nclass = Data Scientist'),
#  Text(0.5625, 0.125, '\n  (...)  \n'),
#  Text(0.6875, 0.125, '\n  (...)  \n'),
#  Text(0.875, 0.375, 'years_exp <= 7.5\ngini = 0.48\nsamples = 183\nvalue = [110, 73]\nclass = Data Scientist'),
#  Text(0.8125, 0.125, '\n  (...)  \n'),
#  Text(0.9375, 0.125, '\n  (...)  \n')]

# %% [markdown]
# ## Tree Hyperparameters

# %%
stump.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 1,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %% [markdown]
# #### Tracking changes with Validation Curves

# %%
accuracies = []
for depth in range(1, 15):
    between = tree.DecisionTreeClassifier(max_depth=depth)
    between.fit(X_train, kag_y_train)
    accuracies.append(between.score(X_test, kag_y_test))

# %%
fig, ax = plt.subplots(figsize=(10, 4))
(pd.Series(accuracies, name='Accuracy', index=range(1, len(accuracies)+1))
 .plot(ax=ax, title='Accuracy at a given Tree Depth'))
ax.set_ylabel('Accuracy')
ax.set_xlabel('max_depth')

plt.grid(True)
plt.show()

# %%
between = tree.DecisionTreeClassifier(max_depth=7)
between.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier(max_depth=7)

# %%
between.score(X_test, kag_y_test)
# Out:
# 0.7359116022099448

# %% [markdown]
# #### Leveraging Yellowbrick

# %%
from yellowbrick.model_selection import validation_curve

# %%
fig, ax = plt.subplots(figsize=(10, 4))
viz = validation_curve(tree.DecisionTreeClassifier(),
                       X=pd.concat([X_train, X_test]),
                       y=pd.concat([kag_y_train, kag_y_test]),
                       param_name='max_depth', param_range=range(1, 14),
                       scoring='accuracy', cv=5, ax=ax, n_jobs=6)

plt.show()
# Out:
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# #### Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'max_depth': [3, 5, 7, 8],
    'min_samples_leaf': [1, 3, 4, 5, 6],
    'min_samples_split': [2, 3, 4, 5, 6],
}

# %%
grid_search = GridSearchCV(estimator=tree.DecisionTreeClassifier(),
                           param_grid=params, cv=4, n_jobs=-1,
                           verbose=1, scoring="accuracy")

# %%
grid_search.fit(pd.concat([X_train, X_test]),
                pd.concat([kag_y_train, kag_y_test]))
# Out:
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [3, 5, 7, 8],
#                          'min_samples_leaf': [1, 3, 4, 5, 6],
#                          'min_samples_split': [2, 3, 4, 5, 6]},
#              scoring='accuracy', verbose=1)

# %%
grid_search.best_params_
# Out:
# {'max_depth': 7, 'min_samples_leaf': 5, 'min_samples_split': 4}

# %%
between2 = tree.DecisionTreeClassifier(**grid_search.best_params_)

# %%
between2.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier(max_depth=7, min_samples_leaf=5, min_samples_split=4)

# %%
between2.score(X_test, kag_y_test)
# Out:
# 0.7259668508287292

# %%
(pd.DataFrame(grid_search.cv_results_)
 .sort_values(by='rank_test_score')
 .style
 .background_gradient(axis='rows')
)
# Out:
# <style type="text/css">
# #T_3be66_row0_col0, #T_3be66_row0_col9, #T_3be66_row0_col12, #T_3be66_row1_col9, #T_3be66_row1_col10, #T_3be66_row3_col9, #T_3be66_row19_col11, #T_3be66_row20_col8, #T_3be66_row25_col11, #T_3be66_row26_col3, #T_3be66_row54_col13, #T_3be66_row83_col1, #T_3be66_row90_col2, #T_3be66_row90_col14, #T_3be66_row91_col14, #T_3be66_row92_col14, #T_3be66_row93_col14, #T_3be66_row94_col14, #T_3be66_row95_col14, #T_3be66_row96_col14, #T_3be66_row97_col14, #T_3be66_row98_col14, #T_3be66_row99_col14 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_3be66_row0_col1, #T_3be66_row73_col13 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_3be66_row0_col2, #T_3be66_row10_col14, #T_3be66_row13_col1, #T_3be66_row18_col2, #T_3be66_row52_col2, #T_3be66_row68_col3, #T_3be66_row74_col2 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_3be66_row0_col3, #T_3be66_row7_col3, #T_3be66_row10_col1, #T_3be66_row12_col1, #T_3be66_row13_col3, #T_3be66_row21_col3, #T_3be66_row28_col1, #T_3be66_row39_col3, #T_3be66_row43_col3, #T_3be66_row51_col1, #T_3be66_row51_col3, #T_3be66_row60_col3, #T_3be66_row62_col1, #T_3be66_row63_col3, #T_3be66_row64_col1, #T_3be66_row65_col3, #T_3be66_row72_col1, #T_3be66_row73_col3, #T_3be66_row74_col1, #T_3be66_row75_col12, #T_3be66_row76_col12, #T_3be66_row77_col12, #T_3be66_row78_col12, #T_3be66_row79_col12, #T_3be66_row80_col12, #T_3be66_row81_col12, #T_3be66_row82_col12, #T_3be66_row83_col12, #T_3be66_row84_col12, #T_3be66_row85_col12, #T_3be66_row86_col12, #T_3be66_row87_col12, #T_3be66_row88_col12, #T_3be66_row89_col12 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_3be66_row0_col8, #T_3be66_row1_col8, #T_3be66_row2_col8, #T_3be66_row3_col8, #T_3be66_row6_col8, #T_3be66_row9_col8, #T_3be66_row10_col12, #T_3be66_row11_col12, #T_3be66_row65_col8, #T_3be66_row69_col8, #T_3be66_row75_col14, #T_3be66_row76_col14, #T_3be66_row77_col14, #T_3be66_row78_col14, #T_3be66_row79_col14, #T_3be66_row80_col14, #T_3be66_row81_col14, #T_3be66_row82_col14, #T_3be66_row83_col14, #T_3be66_row84_col14, #T_3be66_row85_col14, #T_3be66_row86_col14, #T_3be66_row87_col14, #T_3be66_row88_col14, #T_3be66_row89_col14 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_3be66_row0_col10, #T_3be66_row2_col10, #T_3be66_row3_col10, #T_3be66_row4_col10, #T_3be66_row5_col12, #T_3be66_row9_col10, #T_3be66_row14_col10, #T_3be66_row16_col10 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_3be66_row0_col11, #T_3be66_row2_col11, #T_3be66_row20_col11, #T_3be66_row21_col11, #T_3be66_row22_col11, #T_3be66_row27_col11, #T_3be66_row28_col11, #T_3be66_row31_col11, #T_3be66_row32_col11, #T_3be66_row33_col11, #T_3be66_row34_col11, #T_3be66_row36_col11, #T_3be66_row45_col2 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_3be66_row0_col13, #T_3be66_row5_col13 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_3be66_row0_col14, #T_3be66_row4_col1, #T_3be66_row5_col3, #T_3be66_row15_col1, #T_3be66_row50_col8, #T_3be66_row59_col2, #T_3be66_row69_col3, #T_3be66_row69_col10, #T_3be66_row73_col1, #T_3be66_row73_col10, #T_3be66_row74_col3, #T_3be66_row75_col9, #T_3be66_row75_col11, #T_3be66_row76_col9, #T_3be66_row76_col11, #T_3be66_row77_col9, #T_3be66_row77_col11, #T_3be66_row78_col9, #T_3be66_row78_col11, #T_3be66_row79_col9, #T_3be66_row79_col11, #T_3be66_row80_col9, #T_3be66_row80_col11, #T_3be66_row81_col9, #T_3be66_row81_col11, #T_3be66_row82_col9, #T_3be66_row82_col11, #T_3be66_row83_col9, #T_3be66_row83_col11, #T_3be66_row84_col9, #T_3be66_row84_col11, #T_3be66_row85_col9, #T_3be66_row85_col11, #T_3be66_row86_col9, #T_3be66_row86_col11, #T_3be66_row87_col9, #T_3be66_row87_col11, #T_3be66_row88_col9, #T_3be66_row88_col11, #T_3be66_row89_col9, #T_3be66_row89_col11, #T_3be66_row90_col8, #T_3be66_row90_col9, #T_3be66_row90_col11, #T_3be66_row90_col12, #T_3be66_row90_col13, #T_3be66_row91_col8, #T_3be66_row91_col9, #T_3be66_row91_col11, #T_3be66_row91_col12, #T_3be66_row91_col13, #T_3be66_row92_col8, #T_3be66_row92_col9, #T_3be66_row92_col11, #T_3be66_row92_col12, #T_3be66_row92_col13, #T_3be66_row93_col8, #T_3be66_row93_col9, #T_3be66_row93_col11, #T_3be66_row93_col12, #T_3be66_row93_col13, #T_3be66_row94_col8, #T_3be66_row94_col9, #T_3be66_row94_col11, #T_3be66_row94_col12, #T_3be66_row94_col13, #T_3be66_row95_col8, #T_3be66_row95_col9, #T_3be66_row95_col11, #T_3be66_row95_col12, #T_3be66_row95_col13, #T_3be66_row96_col8, #T_3be66_row96_col9, #T_3be66_row96_col11, #T_3be66_row96_col12, #T_3be66_row96_col13, #T_3be66_row97_col8, #T_3be66_row97_col9, #T_3be66_row97_col11, #T_3be66_row97_col12, #T_3be66_row97_col13, #T_3be66_row98_col8, #T_3be66_row98_col9, #T_3be66_row98_col11, #T_3be66_row98_col12, #T_3be66_row98_col13, #T_3be66_row99_col0, #T_3be66_row99_col8, #T_3be66_row99_col9, #T_3be66_row99_col11, #T_3be66_row99_col12, #T_3be66_row99_col13 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_3be66_row1_col0, #T_3be66_row30_col3, #T_3be66_row68_col1, #T_3be66_row92_col0, #T_3be66_row96_col3 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_3be66_row1_col1, #T_3be66_row4_col0, #T_3be66_row10_col0, #T_3be66_row50_col2, #T_3be66_row95_col1 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_3be66_row1_col2, #T_3be66_row5_col2, #T_3be66_row7_col2, #T_3be66_row8_col2, #T_3be66_row9_col14, #T_3be66_row16_col2, #T_3be66_row20_col2, #T_3be66_row21_col2, #T_3be66_row22_col2, #T_3be66_row27_col2, #T_3be66_row32_col1, #T_3be66_row36_col3, #T_3be66_row41_col1, #T_3be66_row43_col2, #T_3be66_row65_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_3be66_row1_col3, #T_3be66_row1_col14, #T_3be66_row16_col3, #T_3be66_row20_col3, #T_3be66_row22_col3, #T_3be66_row41_col3, #T_3be66_row52_col3, #T_3be66_row55_col3, #T_3be66_row62_col3, #T_3be66_row67_col1, #T_3be66_row69_col1, #T_3be66_row70_col3, #T_3be66_row72_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_3be66_row1_col11, #T_3be66_row3_col11, #T_3be66_row4_col11, #T_3be66_row5_col11, #T_3be66_row6_col11, #T_3be66_row7_col11, #T_3be66_row8_col11, #T_3be66_row9_col9, #T_3be66_row10_col11, #T_3be66_row13_col11, #T_3be66_row13_col13, #T_3be66_row16_col9, #T_3be66_row21_col12, #T_3be66_row22_col12, #T_3be66_row23_col11, #T_3be66_row23_col12, #T_3be66_row24_col11, #T_3be66_row24_col12, #T_3be66_row25_col9, #T_3be66_row35_col9, #T_3be66_row37_col9, #T_3be66_row38_col9, #T_3be66_row39_col9, #T_3be66_row40_col9, #T_3be66_row40_col11, #T_3be66_row41_col9, #T_3be66_row41_col11, #T_3be66_row42_col9, #T_3be66_row42_col11, #T_3be66_row43_col9, #T_3be66_row43_col11, #T_3be66_row46_col9, #T_3be66_row49_col9, #T_3be66_row49_col11, #T_3be66_row50_col11 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_3be66_row1_col12 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_3be66_row1_col13, #T_3be66_row17_col13, #T_3be66_row64_col13, #T_3be66_row76_col2 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_3be66_row2_col0 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_3be66_row2_col1, #T_3be66_row21_col14, #T_3be66_row22_col14, #T_3be66_row54_col10, #T_3be66_row67_col0, #T_3be66_row69_col0, #T_3be66_row75_col10, #T_3be66_row76_col10, #T_3be66_row77_col10, #T_3be66_row78_col10, #T_3be66_row79_col10, #T_3be66_row80_col10, #T_3be66_row81_col10, #T_3be66_row82_col10, #T_3be66_row83_col10, #T_3be66_row84_col10, #T_3be66_row85_col10, #T_3be66_row86_col10, #T_3be66_row87_col10, #T_3be66_row88_col10, #T_3be66_row89_col10, #T_3be66_row90_col10, #T_3be66_row91_col10, #T_3be66_row92_col10, #T_3be66_row93_col10, #T_3be66_row94_col10, #T_3be66_row95_col10, #T_3be66_row96_col10, #T_3be66_row97_col10, #T_3be66_row98_col10, #T_3be66_row99_col10 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_3be66_row2_col2, #T_3be66_row55_col12 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_3be66_row2_col3 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_3be66_row2_col9, #T_3be66_row4_col9, #T_3be66_row15_col9, #T_3be66_row24_col9, #T_3be66_row53_col13 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }

# %%
results = model_selection.cross_val_score(
    tree.DecisionTreeClassifier(max_depth=7),
    X=pd.concat([X_train, X_test], axis='index'),
    y=pd.concat([kag_y_train, kag_y_test], axis='index'),
    cv=4
)

# %%
results
# Out:
# array([0.69761273, 0.73474801, 0.70291777, 0.71447543])

# %%
results.mean()
# Out:
# 0.7124384865489413

# %%
results = model_selection.cross_val_score(
    tree.DecisionTreeClassifier(max_depth=7, min_samples_leaf=5,
                               min_samples_split=2),
    X=pd.concat([X_train, X_test], axis='index'),
    y=pd.concat([kag_y_train, kag_y_test], axis='index'),
    cv=4
)

# %%
results
# Out:
# array([0.70689655, 0.74005305, 0.70954907, 0.71978752])

# %%
results.mean()
# Out:
# 0.7190715475850797

# %% [markdown]
# ## Random Forest
#
# #### Scikit-Learn Random Forest

# %%
from sklearn import ensemble

# %%
rf = ensemble.RandomForestClassifier(random_state=42)

# %%
rf.fit(X_train, kag_y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rf.score(X_test, kag_y_test)
# Out:
# 0.7237569060773481

# %%
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %%
len(rf.estimators_)
# Out:
# 100

# %%
print(rf.estimators_[0])
# Out:
# DecisionTreeClassifier(max_features='sqrt', random_state=1608637542)

# %%
fig, ax = plt.subplots(figsize=(8, 4))
features = list(c for c in X_train.columns)
tree.plot_tree(rf.estimators_[0], feature_names=features,
               filled=True, class_names=rf.classes_, ax=ax,
               max_depth=2, fontsize=6)
# Out:
# [Text(0.5, 0.875, 'Q3_United States of America <= 0.5\ngini = 0.496\nsamples = 1354\nvalue = [1146, 964]\nclass = Data Scientist'),
#  Text(0.25, 0.625, 'r <= 0.5\ngini = 0.496\nsamples = 681\nvalue = [496, 588]\nclass = Software Engineer'),
#  Text(0.125, 0.375, 'education <= 17.0\ngini = 0.469\nsamples = 530\nvalue = [317, 528]\nclass = Software Engineer'),
#  Text(0.0625, 0.125, '\n  (...)  \n'),
#  Text(0.1875, 0.125, '\n  (...)  \n'),
#  Text(0.375, 0.375, 'education <= 17.0\ngini = 0.376\nsamples = 151\nvalue = [179, 60]\nclass = Data Scientist'),
#  Text(0.3125, 0.125, '\n  (...)  \n'),
#  Text(0.4375, 0.125, '\n  (...)  \n'),
#  Text(0.75, 0.625, 'education <= 17.0\ngini = 0.464\nsamples = 673\nvalue = [650, 376]\nclass = Data Scientist'),
#  Text(0.625, 0.375, 'major_cs <= 0.5\ngini = 0.485\nsamples = 176\nvalue = [109, 154]\nclass = Software Engineer'),
#  Text(0.5625, 0.125, '\n  (...)  \n'),
#  Text(0.6875, 0.125, '\n  (...)  \n'),
#  Text(0.875, 0.375, 'major_cs <= 0.5\ngini = 0.413\nsamples = 497\nvalue = [541, 222]\nclass = Data Scientist'),
#  Text(0.8125, 0.125, '\n  (...)  \n'),
#  Text(0.9375, 0.125, '\n  (...)  \n')]

# %% [markdown]
# #### XGBoost Random Forest

# %%
import xgboost as xgb

# %%
rf_xg = xgb.XGBRFClassifier(random_state=42)

# %%
rf_xg.fit(X_train, y_train)
# Out:
# XGBRFClassifier(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bytree=None,
#                 early_stopping_rounds=None, enable_categorical=False,
#                 eval_metric=None, feature_types=None, gamma=None, gpu_id=None,
#                 grow_policy=None, importance_type=None,
#                 interaction_constraints=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                 objective='binary:logistic', predictor=None, random_state=42,
#                 reg_alpha=None, ...)

# %%
rf_xg.score(X_test, y_test)
# Out:
# 0.7447513812154696

# %%
rf_xg.get_params()
# Out:
# {'colsample_bynode': 0.8,
#  'learning_rate': 1.0,
#  'reg_lambda': 1e-05,
#  'subsample': 0.8,
#  'objective': 'binary:logistic',
#  'use_label_encoder': None,
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bytree': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'gpu_id': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'predictor': None,
#  'random_state': 42,
#  'reg_alpha': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None}

# %%
fig, ax = plt.subplots(figsize=(6, 12), dpi=600)
xgb.plot_tree(rf_xg, num_trees=0, ax=ax, size='1, 1')
# Out:
# <Axes: >

# %%
my_dot_export(rf_xg, num_trees=0, filename='/Users/isisromero/Desktop/img_XGB/stump_xg.dot',
              title='First Random Forest Tree')
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.960825 to fit

# %%
viz = dtreeviz.model(rf_xg, X_train=X_train,
                     y_train=y_train,
                     target_name='Job', feature_names=list(X_train.columns),
                     class_names=['DS', 'SE'], tree_index=0)

# %%
viz.view(depth_range_to_display=[0, 2])

# %% [markdown]
# #### Training the Number of Trees in the Forest

# %%
from yellowbrick.model_selection import validation_curve

# %%
fig, ax = plt.subplots(figsize=(10, 4))
viz = validation_curve(xgb.XGBClassifier(random_state=42),
                       X=pd.concat([X_train, X_test], axis='index'),
                       y=np.concatenate([y_train, y_test]),
                       param_name='n_estimators', param_range=range(1, 100, 2),
                       scoring='accuracy', cv=3,
                       ax=ax)

# %%
rf_xg29 = xgb.XGBClassifier(random_state=42, n_estimators=29)

# %%
rf_xg29.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=29, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=42, ...)

# %%
rf_xg29.score(X_test, y_test)
# Out:
# 0.7591160220994475

# %% [markdown]
# ## XGBoost
#
# #### Creating an XGBoost Model

# %%
# %matplotlib inline

# Visualization 
import dtreeviz
import matplotlib.pyplot as plt
# Feature Engineering
from feature_engine import encoding, imputation
# Numerical Manipulation
import numpy as np
# Data Manipulation
import pandas as pd

# %%
# Machine Learning Libraries

from sklearn import base, compose, datasets, ensemble, \
metrics, model_selection, pipeline, preprocessing, tree

# %%
# Scikit Plotting
import scikitplot
# Extreme Gradient Boosting
import xgboost as xgb
# Sensical Visualizer & Classifier
import yellowbrick.model_selection as ms
from yellowbrick import classifier

# %%
# Retrieving Data

import urllib
import zipfile

# %%
url = 'https://github.com/mattharrison/datasets/raw/master/data/'\
'kaggle-survey-2018.zip'
fname = 'kaggle-survey-2018.zip'
member_name = 'multipleChoiceResponses.csv'

# %%
# Function Extration
def extract_zip(src, dst, member_name):
    """Extract a member file from a zip file & read it into pandas
    DataFrame.
    
    Parameters:
        src '(str:)' URL of the zip file to be downloaded and extrated.
        dst 'str': Local file path where the zip file will be written.
        member_name: Name of the member file inside the zip file to be
            read into a DataFrame.
            
    Returns:
        pandas.DataFrame containing the contents of member file.
    """
    url = src
    fname = dst
    fin = urllib.request.urlopen(url)
    data = fin.read()
    with open(dst, mode='wb') as fout:
        fout.write(data)
    with zipfile.ZipFile(dst) as z:
        kag = pd.read_csv(z.open(member_name))
        kag_questions = kag.iloc[0]
        raw = kag.iloc[1:]
        return raw

# %%
raw = extract_zip(url, fname, member_name)
# Out:
# /var/folders/wh/l_q69dcj75z0c82jy8ry71f40000gn/T/ipykernel_32169/3680407660.py:22: DtypeWarning: Columns (0,2,8,10,21,23,24,25,26,27,28,44,56,64,83,85,87,107,109,123,125,150,157,172,174,194,210,218,219,223,246,249,262,264,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,304,306,325,326,329,341,368,371,384,385,389,390,391,393,394) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
## Create raw X and raw y
kag_X, kag_y = get_rawX_y(raw, 'Q6')

# %%
## Split data    
kag_X_train, kag_X_test, kag_y_train, kag_y_test = \
    model_selection.train_test_split(
        kag_X, kag_y, test_size=.3, random_state=42, stratify=kag_y)

# %%
## Transform X with pipeline
X_train = kag_pl.fit_transform(kag_X_train)
X_test = kag_pl.transform(kag_X_test)

# %%
## Transform y with label encoder
label_encoder = preprocessing.LabelEncoder()
label_encoder.fit(kag_y_train)
y_train = label_encoder.transform(kag_y_train)
y_test = label_encoder.transform(kag_y_test)

# %%
# Combined Data for cross validation/etc
X = pd.concat([X_train, X_test], axis='index')
y = pd.Series([*y_train, *y_test], index=X.index)

# %% [markdown]
# #### A Boosted Model

# %%
xg_oob = xgb.XGBClassifier()

# %%
xg_oob.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
xg_oob.score(X_test, y_test)
# Out:
# 0.7458563535911602

# %%
# Let's try with depth of 2 and 2 trees

xg2 = xgb.XGBClassifier(max_depth=2, n_estimators=2)

# %%
xg2.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=2, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=2, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
xg2.score(X_test, y_test)
# Out:
# 0.6685082872928176

# %%
# Let's visualize it

viz = dtreeviz.model(xg2, X_train=X, y_train=y, target_name='Job',
                     feature_names=list(X_train.columns),
                     class_names=['DS', 'SE'], tree_index=0)

# %%
viz.view(depth_range_to_display=[0, 2])

# %% [markdown]
# #### Understanding the Output of the Trees

# %%
my_dot_export(xg2, num_trees=0, filename='/Users/isisromero/Desktop/img_XGB/stump_xg.dot', title='First Tree')

# %%
xgb.plot_tree(xg2, num_trees=0)
# Out:
# <Axes: >

# %%
# Predicts 1 - Software engineer

se7894 = pd.DataFrame({'age': {7894: 22},
                       'education': {7894:16.0},
                       'years_exp': {7894: 1.0},
                       'compensation': {7894: 0},
                       'python': {7894:1},
                       'r':{7894: 0},
                       'sql':{7894: 0},
                       'Q1_Male':{7894: 1},
                       'Q1_Female': {7894: 0},
                       'Q1_Prefer not to say': {7894: 0},
                       'Q1_Prefer to self-describe': {7894: 0},
                       'Q3_United States of America': {7894: 0},
                       'Q3_India': {7894: 1},
                       'Q3_China': {7894: 0},
                       'major_cs': {7894: 0},
                       'major_other': {7894: 0},
                       'major_eng': {7894: 0},
                       'major_stat': {7894: 0}})

# %%
xg2.predict_proba(se7894)
# Out:
# array([[0.4986236, 0.5013764]], dtype=float32)

# %%
xg2.predict(pd.DataFrame(se7894))
# Out:
# array([1])

# %%
my_dot_export(xg2, num_trees=1, filename='/Users/isisromero/Desktop/img_XGB/stump_xg.dot', title='Second Tree')

# %%
xgb.plot_tree(xg2, num_trees=1)
# Out:
# <Axes: >

# %%
def inv_logit(p):
    return np.exp(p) / (1 + np.exp(p))

# %%
inv_logit(-0.08476+0.0902701)
# Out:
# 0.5013775215147345

# %% [markdown]
# ## Early Stopping
#
# #### Early stopping Rounds

# %%
# Defaults
xg = xgb.XGBClassifier()
xg.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
xg.score(X_test, y_test)
# Out:
# 0.7458563535911602

# %%
xg = xgb.XGBClassifier(early_stopping_rounds=20)
xg.fit(X_train, y_train,
       eval_set=[(X_train, y_train),
                 (X_test, y_test)
                ]
      )
# Out:
# [0]	validation_0-logloss:0.61534	validation_1-logloss:0.61775
# [1]	validation_0-logloss:0.57046	validation_1-logloss:0.57623
# [2]	validation_0-logloss:0.54011	validation_1-logloss:0.55333
# [3]	validation_0-logloss:0.51965	validation_1-logloss:0.53711
# [4]	validation_0-logloss:0.50419	validation_1-logloss:0.52511
# [5]	validation_0-logloss:0.49176	validation_1-logloss:0.51741
# [6]	validation_0-logloss:0.48159	validation_1-logloss:0.51277
# [7]	validation_0-logloss:0.47221	validation_1-logloss:0.51040
# [8]	validation_0-logloss:0.46221	validation_1-logloss:0.50713
# [9]	validation_0-logloss:0.45700	validation_1-logloss:0.50583
# [10]	validation_0-logloss:0.45062	validation_1-logloss:0.50430
# [11]	validation_0-logloss:0.44533	validation_1-logloss:0.50338
# [12]	validation_0-logloss:0.43736	validation_1-logloss:0.50033
# [13]	validation_0-logloss:0.43399	validation_1-logloss:0.50034
# [14]	validation_0-logloss:0.43004	validation_1-logloss:0.50192
# [15]	validation_0-logloss:0.42550	validation_1-logloss:0.50268
# [16]	validation_0-logloss:0.42169	validation_1-logloss:0.50196
# [17]	validation_0-logloss:0.41854	validation_1-logloss:0.50223
# [18]	validation_0-logloss:0.41485	validation_1-logloss:0.50360
# [19]	validation_0-logloss:0.41228	validation_1-logloss:0.50527
# [20]	validation_0-logloss:0.40872	validation_1-logloss:0.50839
# [21]	validation_0-logloss:0.40490	validation_1-logloss:0.50623
# [22]	validation_0-logloss:0.40280	validation_1-logloss:0.50806
# [23]	validation_0-logloss:0.39942	validation_1-logloss:0.51007
# [24]	validation_0-logloss:0.39807	validation_1-logloss:0.50987
# [25]	validation_0-logloss:0.39473	validation_1-logloss:0.51189
# [26]	validation_0-logloss:0.39389	validation_1-logloss:0.51170
# [27]	validation_0-logloss:0.39040	validation_1-logloss:0.51218
# [28]	validation_0-logloss:0.38837	validation_1-logloss:0.51135
# [29]	validation_0-logloss:0.38569	validation_1-logloss:0.51202
# [30]	validation_0-logloss:0.37945	validation_1-logloss:0.51352
# [31]	validation_0-logloss:0.37840	validation_1-logloss:0.51545
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=20,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
xg.score(X_test, y_test)
# Out:
# 0.7558011049723757

# %%
xg.best_ntree_limit
# Out:
# 13

# %% [markdown]
# #### Plotting Tree Performance

# %%
results = xg.evals_result()
results
# Out:
# {'validation_0': OrderedDict([('logloss',
#                [0.6153406503923696,
#                 0.570456665259967,
#                 0.5401074953836288,
#                 0.519646179894983,
#                 0.5041859194636344,
#                 0.49175883369140716,
#                 0.48158584668243665,
#                 0.47221356730254904,
#                 0.46221246071407013,
#                 0.4570046101436372,
#                 0.4506211909637632,
#                 0.4453310158703988,
#                 0.4373589512737583,
#                 0.4339914069144647,
#                 0.4300442739147075,
#                 0.4255026599652712,
#                 0.4216894939687474,
#                 0.4185393191472367,
#                 0.41485192587387293,
#                 0.4122836277407475,
#                 0.4087179541126582,
#                 0.4048982679969697,
#                 0.4027963529939,
#                 0.39941699937851083,
#                 0.3980718078018912,
#                 0.39473153130025534,
#                 0.3938853894103257,
#                 0.39039599381550544,
#                 0.38837148116678616,
#                 0.38569152618546515,
#                 0.3794510698323337,
#                 0.37840359453862243,
#                 0.3753846618694461])]),
#  'validation_1': OrderedDict([('logloss',
#                [0.6177459120091813,
#                 0.5762297137336836,
#                 0.5533292921537852,
#                 0.5371078261354352,
#                 0.5251118483629016,
#                 0.5174100387491574,
#                 0.5127666982333304,
#                 0.5103968676611863,
#                 0.507134911619662,
#                 0.5058257413585542,
#                 0.5043005664745418,
#                 0.5033770955193438,
#                 0.5003349146419797,
#                 0.5003436392574514,
#                 0.5019165393438457,
#                 0.5026775171867063,
#                 0.5019612927483755,
#                 0.502226200336539,
#                 0.5035970173755568,
#                 0.5052709657616543,
#                 0.5083886558951511,
#                 0.5062287506158593,
#                 0.5080608450802485,
#                 0.5100736724202475,
#                 0.5098673964536733,
#                 0.5118910037855828,
#                 0.5117007329607207,
#                 0.5121825189252502,
#                 0.511347598580448,
#                 0.512018582177508,
#                 0.513518928078348,
#                 0.5154504017214914,
#                 0.5158137126403824])])}

# %%
# Testing score is best at 13 trees
results = xg.evals_result()

fig, ax = plt.subplots(figsize=(8, 4))
ax = (pd.DataFrame({'training': results['validation_0']['logloss'],
                    'testing': results['validation_1']['logloss']})
      .assign(ntrees=lambda adf: range(1, len(adf)+1))
      .set_index('ntrees')
      .plot(figsize=(5, 4), ax=ax,
           title='eval_results with early_stopping')
     )
ax.annotate('Best number \n of trees (13)', xy=(13, .498),
           xytext=(20,.42), arrowprops={'color': 'k'})

ax.set_label('ntrees')

# %%
xg13 = xgb.XGBClassifier(n_estimators=13)
xg13.fit(X_train, y_train,
         eval_set=[(X_train, y_train),
                   (X_test, y_test)]
        )
# Out:
# [0]	validation_0-logloss:0.61534	validation_1-logloss:0.61775
# [1]	validation_0-logloss:0.57046	validation_1-logloss:0.57623
# [2]	validation_0-logloss:0.54011	validation_1-logloss:0.55333
# [3]	validation_0-logloss:0.51965	validation_1-logloss:0.53711
# [4]	validation_0-logloss:0.50419	validation_1-logloss:0.52511
# [5]	validation_0-logloss:0.49176	validation_1-logloss:0.51741
# [6]	validation_0-logloss:0.48159	validation_1-logloss:0.51277
# [7]	validation_0-logloss:0.47221	validation_1-logloss:0.51040
# [8]	validation_0-logloss:0.46221	validation_1-logloss:0.50713
# [9]	validation_0-logloss:0.45700	validation_1-logloss:0.50583
# [10]	validation_0-logloss:0.45062	validation_1-logloss:0.50430
# [11]	validation_0-logloss:0.44533	validation_1-logloss:0.50338
# [12]	validation_0-logloss:0.43736	validation_1-logloss:0.50033
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=13, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
xg13.score(X_test, y_test)
# Out:
# 0.7558011049723757

# %%
# No early stopping uses all estimators
xg_no_es = xgb.XGBClassifier()
xg_no_es.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
xg_no_es.score(X_test, y_test)
# Out:
# 0.7458563535911602

# %%
xg_err = xgb.XGBClassifier(early_stopping_rounds=20,
                          eval_metric='error')

# %%
xg_err.fit(X_train, y_train,
           eval_set=[(X_train, y_train),
                     (X_test, y_test)]
          )
# Out:
# [0]	validation_0-error:0.24739	validation_1-error:0.27072
# [1]	validation_0-error:0.24218	validation_1-error:0.26188
# [2]	validation_0-error:0.23839	validation_1-error:0.24751
# [3]	validation_0-error:0.23697	validation_1-error:0.25193
# [4]	validation_0-error:0.23081	validation_1-error:0.24530
# [5]	validation_0-error:0.22607	validation_1-error:0.24420
# [6]	validation_0-error:0.22180	validation_1-error:0.24862
# [7]	validation_0-error:0.21801	validation_1-error:0.24862
# [8]	validation_0-error:0.21280	validation_1-error:0.25304
# [9]	validation_0-error:0.21043	validation_1-error:0.25304
# [10]	validation_0-error:0.20806	validation_1-error:0.24641
# [11]	validation_0-error:0.20284	validation_1-error:0.25193
# [12]	validation_0-error:0.20047	validation_1-error:0.24420
# [13]	validation_0-error:0.19668	validation_1-error:0.24420
# [14]	validation_0-error:0.19384	validation_1-error:0.24530
# [15]	validation_0-error:0.18815	validation_1-error:0.24199
# [16]	validation_0-error:0.18531	validation_1-error:0.24199
# [17]	validation_0-error:0.18389	validation_1-error:0.23867
# [18]	validation_0-error:0.18531	validation_1-error:0.23757
# [19]	validation_0-error:0.18815	validation_1-error:0.23867
# [20]	validation_0-error:0.18246	validation_1-error:0.24199
# [21]	validation_0-error:0.17915	validation_1-error:0.24862
# [22]	validation_0-error:0.17867	validation_1-error:0.24751
# [23]	validation_0-error:0.17630	validation_1-error:0.24199
# [24]	validation_0-error:0.17488	validation_1-error:0.24309
# [25]	validation_0-error:0.17251	validation_1-error:0.24530
# [26]	validation_0-error:0.17204	validation_1-error:0.24309
# [27]	validation_0-error:0.16825	validation_1-error:0.24199
# [28]	validation_0-error:0.16730	validation_1-error:0.24088
# [29]	validation_0-error:0.16019	validation_1-error:0.24199
# [30]	validation_0-error:0.15782	validation_1-error:0.24972
# [31]	validation_0-error:0.15972	validation_1-error:0.24862
# [32]	validation_0-error:0.15924	validation_1-error:0.24641
# [33]	validation_0-error:0.15403	validation_1-error:0.25635
# [34]	validation_0-error:0.15261	validation_1-error:0.25525
# [35]	validation_0-error:0.15213	validation_1-error:0.25525
# [36]	validation_0-error:0.15166	validation_1-error:0.25525
# [37]	validation_0-error:0.14550	validation_1-error:0.25525
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=20,
#               enable_categorical=False, eval_metric='error', feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
xg_err.score(X_test, y_test)
# Out:
# 0.7624309392265194

# %%
xg_err.best_ntree_limit
# Out:
# 19
