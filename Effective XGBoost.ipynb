# %% [markdown]
# # Datasets
#
# ### Cleaup & Loading

# %%
# Data Manipulation
import pandas as pd

# URL Library
import urllib.request
import zipfile

# %%
# Retrieving & storage
url = 'https://github.com/mattharrison/datasets/raw/master/data/'\
'kaggle-survey-2018.zip'
fname = 'kaggle-survey-2018.zip'
member_name = 'multipleChoiceResponses.csv'

# %%
# Function Extration
def extract_zip(src, dst, member_name):
    """Extract a member file from a zip file & read it into pandas
    DataFrame.
    
    Parameters:
        src '(str:)' URL of the zip file to be downloaded and extrated.
        dst 'str': Local file path where the zip file will be written.
        member_name: Name of the member file inside the zip file to be
            read into a DataFrame.
            
    Returns:
        pandas.DataFrame containing the contents of member file.
    """
    url = src
    fname = dst
    fin = urllib.request.urlopen(url)
    data = fin.read()
    with open(dst, mode='wb') as fout:
        fout.write(data)
    with zipfile.ZipFile(dst) as z:
        kag = pd.read_csv(z.open(member_name))
        kag_questions = kag.iloc[0]
        raw = kag.iloc[1:]
        return raw

# %%
raw = extract_zip(url, fname, member_name)
# Out:
# /var/folders/wh/l_q69dcj75z0c82jy8ry71f40000gn/T/ipykernel_22970/3680407660.py:22: DtypeWarning: Columns (0,2,8,10,21,23,24,25,26,27,28,44,56,64,83,85,87,107,109,123,125,150,157,172,174,194,210,218,219,223,246,249,262,264,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,304,306,325,326,329,341,368,371,384,385,389,390,391,393,394) have mixed types. Specify dtype option on import or set low_memory=False.
#   kag = pd.read_csv(z.open(member_name))

# %% [markdown]
# ## CleanUp Pipeline

# %%
def tweak_kag(df_: pd.DataFrame) -> pd.DataFrame:
    """
    Tweak the Kaggle survey data and return a new DataFrame.

    This function takes a Pandas DataFrame containing Kaggle 
    survey data as input and returns a new DataFrame. The 
    modifications include extracting and transforming certain 
    columns, renaming columns, and selecting a subset of columns.

    Parameters
    ----------
    df_ : pd.DataFrame
        The input DataFrame containing Kaggle survey data.

    Returns
    -------
    pd.DataFrame
        The new DataFrame with the modified and selected columns.
    """    
    return (df_
            .assign(age=df_.Q2.str.slice(0,2).astype(int),
                    education=df_.Q4.replace({'Master’s degree': 18,
                         'Bachelor’s degree': 16,
                         'Doctoral degree': 20,
'Some college/university study without earning a bachelor’s degree': 13,
                         'Professional degree': 19,
                         'I prefer not to answer': None,
                         'No formal education past high school': 12}),
                    major=(df_.Q5
                              .pipe(topn, n=3)
                              .replace({
                        'Computer science (software engineering, etc.)': 'cs',
                        'Engineering (non-computer focused)': 'eng',
                        'Mathematics or statistics': 'stat'})
                         ),
                    years_exp=(df_.Q8.str.replace('+','', regex=False)
                           .str.split('-', expand=True)
                           .iloc[:,0]
                           .astype(float)),
                    compensation=(df_.Q9.str.replace('+','', regex=False)
                           .str.replace(',','', regex=False)
                           .str.replace('500000', '500', regex=False)
  .str.replace('I do not wish to disclose my approximate yearly compensation',
             '0', regex=False)
                           .str.split('-', expand=True)
                           .iloc[:,0]
                           .fillna(0)
                           .astype(int)
                           .mul(1_000)
                                    ),
                    python=df_.Q16_Part_1.fillna(0).replace('Python', 1),
                    r=df_.Q16_Part_2.fillna(0).replace('R', 1),
                    sql=df_.Q16_Part_3.fillna(0).replace('SQL', 1)
               )#assign
        .rename(columns=lambda col:col.replace(' ', '_'))
        .loc[:, 'Q1,Q3,age,education,major,years_exp,compensation,'
                'python,r,sql'.split(',')]   
       )

# %%
def topn(ser, n=5, default='other'):
    counts = ser.value_counts()
    return ser.where(ser.isin(counts.index[:n]), default)

# %%
from feature_engine import encoding, imputation
from sklearn import base, pipeline
# Out:
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
class TweakKagTransformer(base.BaseEstimator, base.TransformerMixin):
    
    def __init__(self, ycol=None):
        self.ycol = ycol
        
    def transform(self, X):
        return tweak_kag(X)
    
    def fit(self, X, y=None):
        return self

# %%
def get_rawX_y(df, y_col):
    raw = (df
           .query('Q3.isin(["United States of America", "China", "India"]) '
              'and Q6.isin(["Data Scientist", "Software Engineer"])')
    )
    return raw.drop(columns=[y_col]), raw[y_col]

# %%
# Create Pipeline
kag_pl = pipeline.Pipeline(
    [('tweak', TweakKagTransformer()),
     ('cat', encoding.OneHotEncoder(top_categories=5, drop_last=True, variables=['Q1', 'Q3', 'major'])),
     ('num_impute', imputation.MeanMedianImputer(imputation_method='median', variables=['education', 'years_exp']))]
)

# %%
from sklearn import model_selection

# %%
kag_X, kag_y = get_rawX_y(raw, 'Q6')

kag_X_train, kag_X_test, kag_y_train, kag_y_test = \
model_selection.train_test_split(
    kag_X, kag_y, test_size=.3, random_state=42, stratify=kag_y)

# %%
X_train = kag_pl.fit_transform(kag_X_train, kag_y_train)

X_test = kag_pl.transform(kag_X_test)

# %%
print(X_train)
# Out:
#        age  education  years_exp  compensation  python  r  sql  Q1_Male  \
# 587     25       18.0        4.0             0       1  0    1        1
# 3065    22       16.0        1.0         10000       1  0    0        1
# 8435    22       18.0        1.0             0       1  0    0        1
# 3110    40       20.0        3.0        125000       1  0    1        0
# 16372   45       12.0        5.0        100000       1  0    1        1
# ...    ...        ...        ...           ...     ... ..  ...      ...
# 16608   25       16.0        2.0         10000       0  0    1        1
# 7325    18       16.0        1.0         30000       1  0    1        1
# 21810   18       16.0        2.0             0       0  0    0        1
# 4917    25       18.0        1.0        100000       1  0    1        1
# 639     25       18.0        1.0         10000       1  0    0        0
#
#        Q1_Female  Q1_Prefer not to say  Q1_Prefer to self-describe  \
# 587            0                     0                           0
# 3065           0                     0                           0
# 8435           0                     0                           0
# 3110           1                     0                           0
# 16372          0                     0                           0
# ...          ...                   ...                         ...
# 16608          0                     0                           0
# 7325           0                     0                           0
# 21810          0                     0                           0
# 4917           0                     0                           0
# 639            1                     0                           0
#
#        Q3_United States of America  Q3_India  Q3_China  major_cs  major_other  \
# 587                              0         1         0         0            1
# 3065                             0         1         0         1            0
# 8435                             0         1         0         0            1
# 3110                             1         0         0         0            1
# 16372                            1         0         0         0            1
# ...                            ...       ...       ...       ...          ...
# 16608                            0         1         0         1            0
# 7325                             1         0         0         1            0
# 21810                            0         1         0         1            0
# 4917                             1         0         0         0            0
# 639                              0         1         0         1            0
#
#        major_eng  major_stat
# 587            0           0
# 3065           0           0
# 8435           0           0
# 3110           0           0
# 16372          0           0
# ...          ...         ...
# 16608          0           0
# 7325           0           0
# 21810          0           0
# 4917           0           1
# 639            0           0
#
# [2110 rows x 18 columns]

# %%
kag_y_train
# Out:
# 587      Software Engineer
# 3065        Data Scientist
# 8435        Data Scientist
# 3110        Data Scientist
# 16372    Software Engineer
#                ...
# 16608    Software Engineer
# 7325     Software Engineer
# 21810       Data Scientist
# 4917        Data Scientist
# 639         Data Scientist
# Name: Q6, Length: 2110, dtype: object

# %% [markdown]
# ## Exploratory Data Analysis

# %%
(X_train
 .assign(data_scientist = kag_y_train == 'Data Scientist')
 .corr(method='spearman')
 .style
 .background_gradient(cmap='RdBu', vmax=1, vmin=-1)
 .set_sticky(axis='index')
)
# Out:
# <style type="text/css">
# #T_9ea73 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_9ea73 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# #T_9ea73_row0_col0, #T_9ea73_row1_col1, #T_9ea73_row2_col2, #T_9ea73_row3_col3, #T_9ea73_row4_col4, #T_9ea73_row5_col5, #T_9ea73_row6_col6, #T_9ea73_row7_col7, #T_9ea73_row8_col8, #T_9ea73_row9_col9, #T_9ea73_row10_col10, #T_9ea73_row11_col11, #T_9ea73_row12_col12, #T_9ea73_row13_col13, #T_9ea73_row14_col14, #T_9ea73_row15_col15, #T_9ea73_row16_col16, #T_9ea73_row17_col17, #T_9ea73_row18_col18 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_9ea73_row0_col1, #T_9ea73_row1_col0 {
#   background-color: #a2cde3;
#   color: #000000;
# }
# #T_9ea73_row0_col2, #T_9ea73_row2_col0 {
#   background-color: #3b88be;
#   color: #f1f1f1;
# }
# #T_9ea73_row0_col3, #T_9ea73_row3_col0 {
#   background-color: #7eb8d7;
#   color: #000000;
# }
# #T_9ea73_row0_col4, #T_9ea73_row0_col10, #T_9ea73_row2_col17, #T_9ea73_row4_col0, #T_9ea73_row4_col7, #T_9ea73_row7_col4, #T_9ea73_row9_col11, #T_9ea73_row10_col0, #T_9ea73_row10_col11, #T_9ea73_row11_col9, #T_9ea73_row11_col10, #T_9ea73_row17_col2 {
#   background-color: #eff3f5;
#   color: #000000;
# }
# #T_9ea73_row0_col5, #T_9ea73_row5_col0, #T_9ea73_row8_col11, #T_9ea73_row11_col8 {
#   background-color: #deebf2;
#   color: #000000;
# }
# #T_9ea73_row0_col6, #T_9ea73_row5_col15, #T_9ea73_row6_col0, #T_9ea73_row15_col5 {
#   background-color: #ddebf2;
#   color: #000000;
# }
# #T_9ea73_row0_col7, #T_9ea73_row2_col5, #T_9ea73_row4_col16, #T_9ea73_row4_col17, #T_9ea73_row5_col2, #T_9ea73_row7_col0, #T_9ea73_row9_col15, #T_9ea73_row15_col9, #T_9ea73_row16_col4, #T_9ea73_row17_col4 {
#   background-color: #f5f6f7;
#   color: #000000;
# }
# #T_9ea73_row0_col8, #T_9ea73_row3_col9, #T_9ea73_row8_col0, #T_9ea73_row8_col16, #T_9ea73_row9_col3, #T_9ea73_row9_col12, #T_9ea73_row10_col12, #T_9ea73_row12_col9, #T_9ea73_row12_col10, #T_9ea73_row13_col17, #T_9ea73_row16_col8, #T_9ea73_row17_col13 {
#   background-color: #f8f2ef;
#   color: #000000;
# }
# #T_9ea73_row0_col9, #T_9ea73_row2_col6, #T_9ea73_row3_col10, #T_9ea73_row4_col11, #T_9ea73_row6_col2, #T_9ea73_row7_col13, #T_9ea73_row9_col0, #T_9ea73_row10_col3, #T_9ea73_row10_col15, #T_9ea73_row11_col4, #T_9ea73_row13_col7, #T_9ea73_row15_col10 {
#   background-color: #edf2f5;
#   color: #000000;
# }
# #T_9ea73_row0_col11, #T_9ea73_row11_col0 {
#   background-color: #9bc9e0;
#   color: #000000;
# }
# #T_9ea73_row0_col12, #T_9ea73_row12_col0 {
#   background-color: #f6af8e;
#   color: #000000;
# }
# #T_9ea73_row0_col13, #T_9ea73_row4_col13, #T_9ea73_row5_col16, #T_9ea73_row6_col10, #T_9ea73_row8_col10, #T_9ea73_row10_col6, #T_9ea73_row10_col8, #T_9ea73_row10_col14, #T_9ea73_row10_col16, #T_9ea73_row10_col17, #T_9ea73_row13_col0, #T_9ea73_row13_col4, #T_9ea73_row14_col10, #T_9ea73_row16_col5, #T_9ea73_row16_col10, #T_9ea73_row17_col10 {
#   background-color: #f8f4f2;
#   color: #000000;
# }
# #T_9ea73_row0_col14, #T_9ea73_row3_col14, #T_9ea73_row7_col9, #T_9ea73_row9_col7, #T_9ea73_row14_col0, #T_9ea73_row14_col3 {
#   background-color: #fcd5bf;
#   color: #000000;
# }
# #T_9ea73_row0_col15, #T_9ea73_row3_col6, #T_9ea73_row6_col3, #T_9ea73_row15_col0, #T_9ea73_row15_col18, #T_9ea73_row18_col15 {
#   background-color: #d1e5f0;
#   color: #000000;
# }
# #T_9ea73_row0_col16, #T_9ea73_row1_col10, #T_9ea73_row2_col16, #T_9ea73_row3_col7, #T_9ea73_row3_col8, #T_9ea73_row5_col9, #T_9ea73_row7_col3, #T_9ea73_row8_col3, #T_9ea73_row9_col5, #T_9ea73_row10_col1, #T_9ea73_row16_col0, #T_9ea73_row16_col2 {
#   background-color: #f6f7f7;
#   color: #000000;
# }
# #T_9ea73_row0_col17, #T_9ea73_row0_col18, #T_9ea73_row6_col17, #T_9ea73_row17_col0, #T_9ea73_row17_col6, #T_9ea73_row18_col0 {
#   background-color: #e9f0f4;
#   color: #000000;
# }
# #T_9ea73_row1_col2, #T_9ea73_row2_col1, #T_9ea73_row4_col15, #T_9ea73_row15_col4 {
#   background-color: #e4eef4;
#   color: #000000;
# }
# #T_9ea73_row1_col3, #T_9ea73_row3_col1, #T_9ea73_row3_col15, #T_9ea73_row12_col14, #T_9ea73_row14_col12, #T_9ea73_row15_col3 {
#   background-color: #c5dfec;
#   color: #000000;
# }
# #T_9ea73_row1_col4, #T_9ea73_row1_col9, #T_9ea73_row4_col1, #T_9ea73_row9_col1 {
#   background-color: #ecf2f5;
#   color: #000000;
# }
# #T_9ea73_row1_col5, #T_9ea73_row5_col1, #T_9ea73_row11_col17, #T_9ea73_row17_col11 {
#   background-color: #dae9f2;
#   color: #000000;
# }
# #T_9ea73_row1_col6, #T_9ea73_row1_col8, #T_9ea73_row5_col8, #T_9ea73_row6_col1, #T_9ea73_row7_col14, #T_9ea73_row8_col1, #T_9ea73_row8_col5, #T_9ea73_row8_col15, #T_9ea73_row13_col14, #T_9ea73_row14_col7, #T_9ea73_row14_col13, #T_9ea73_row15_col8 {
#   background-color: #eaf1f5;
#   color: #000000;
# }
# #T_9ea73_row1_col7, #T_9ea73_row7_col1 {
#   background-color: #f9ebe3;
#   color: #000000;
# }
# #T_9ea73_row1_col11, #T_9ea73_row1_col18, #T_9ea73_row11_col1, #T_9ea73_row11_col15, #T_9ea73_row15_col11, #T_9ea73_row18_col1 {
#   background-color: #bbdaea;
#   color: #000000;
# }
# #T_9ea73_row1_col12, #T_9ea73_row11_col14, #T_9ea73_row12_col1, #T_9ea73_row14_col11 {
#   background-color: #fac8af;
#   color: #000000;
# }
# #T_9ea73_row1_col13, #T_9ea73_row1_col16, #T_9ea73_row4_col9, #T_9ea73_row4_col10, #T_9ea73_row5_col10, #T_9ea73_row9_col4, #T_9ea73_row9_col10, #T_9ea73_row10_col4, #T_9ea73_row10_col5, #T_9ea73_row10_col9, #T_9ea73_row13_col1, #T_9ea73_row16_col1 {
#   background-color: #f7f6f6;
#   color: #000000;
# }
# #T_9ea73_row1_col14, #T_9ea73_row14_col1 {
#   background-color: #fcd7c2;
#   color: #000000;
# }
# #T_9ea73_row1_col15, #T_9ea73_row3_col4, #T_9ea73_row3_col5, #T_9ea73_row4_col3, #T_9ea73_row5_col3, #T_9ea73_row6_col11, #T_9ea73_row11_col6, #T_9ea73_row15_col1 {
#   background-color: #d7e8f1;
#   color: #000000;
# }
# #T_9ea73_row1_col17, #T_9ea73_row2_col11, #T_9ea73_row4_col18, #T_9ea73_row6_col18, #T_9ea73_row11_col2, #T_9ea73_row17_col1, #T_9ea73_row18_col4, #T_9ea73_row18_col6 {
#   background-color: #e0ecf3;
#   color: #000000;
# }
# #T_9ea73_row2_col3, #T_9ea73_row3_col2 {
#   background-color: #c0dceb;
#   color: #000000;
# }
# #T_9ea73_row2_col4, #T_9ea73_row3_col16, #T_9ea73_row4_col2, #T_9ea73_row16_col3 {
#   background-color: #f9efe9;
#   color: #000000;
# }
# #T_9ea73_row2_col7, #T_9ea73_row7_col2, #T_9ea73_row12_col16, #T_9ea73_row16_col12 {
#   background-color: #e7f0f4;
#   color: #000000;
# }
# #T_9ea73_row2_col8, #T_9ea73_row4_col14, #T_9ea73_row7_col10, #T_9ea73_row8_col2, #T_9ea73_row10_col7, #T_9ea73_row14_col4 {
#   background-color: #fae9df;
#   color: #000000;
# }
# #T_9ea73_row2_col9, #T_9ea73_row6_col8, #T_9ea73_row8_col6, #T_9ea73_row8_col17, #T_9ea73_row9_col2, #T_9ea73_row17_col8 {
#   background-color: #f0f4f6;
#   color: #000000;
# }
# #T_9ea73_row2_col10, #T_9ea73_row2_col15, #T_9ea73_row9_col17, #T_9ea73_row9_col18, #T_9ea73_row10_col2, #T_9ea73_row10_col18, #T_9ea73_row15_col2, #T_9ea73_row16_col18, #T_9ea73_row17_col9, #T_9ea73_row18_col9, #T_9ea73_row18_col10, #T_9ea73_row18_col16 {
#   background-color: #f3f5f6;
#   color: #000000;
# }
# #T_9ea73_row2_col12, #T_9ea73_row5_col13, #T_9ea73_row12_col2, #T_9ea73_row12_col17, #T_9ea73_row13_col5, #T_9ea73_row17_col12 {
#   background-color: #fbe4d6;
#   color: #000000;
# }
# #T_9ea73_row2_col13, #T_9ea73_row7_col16, #T_9ea73_row9_col16, #T_9ea73_row13_col2, #T_9ea73_row16_col7, #T_9ea73_row16_col9 {
#   background-color: #f2f5f6;
#   color: #000000;
# }
# #T_9ea73_row2_col14, #T_9ea73_row4_col8, #T_9ea73_row4_col12, #T_9ea73_row7_col17, #T_9ea73_row8_col4, #T_9ea73_row8_col9, #T_9ea73_row9_col8, #T_9ea73_row9_col14, #T_9ea73_row12_col4, #T_9ea73_row14_col2, #T_9ea73_row14_col9, #T_9ea73_row17_col7 {
#   background-color: #f8f1ed;
#   color: #000000;
# }
# #T_9ea73_row2_col18, #T_9ea73_row7_col11, #T_9ea73_row11_col7, #T_9ea73_row18_col2 {
#   background-color: #fbe3d4;
#   color: #000000;
# }
# #T_9ea73_row3_col11, #T_9ea73_row11_col3 {
#   background-color: #408fc1;
#   color: #f1f1f1;
# }
# #T_9ea73_row3_col12, #T_9ea73_row12_col3 {
#   background-color: #dc6e57;
#   color: #f1f1f1;
# }
# #T_9ea73_row3_col13, #T_9ea73_row13_col3 {
#   background-color: #fbe6da;
#   color: #000000;
# }
# #T_9ea73_row3_col17, #T_9ea73_r

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 4))
(X_train
 .assign(data_scientist = kag_y_train)
 .groupby('r')
 .data_scientist
 .value_counts()
 .unstack()
 .plot.bar(ax=ax)
)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 4))
(pd.crosstab(index=X_train['major_cs'],
             columns=kag_y)
 .plot.bar(ax=ax)
)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 4))
(X_train
 .plot.scatter(x='years_exp', y='compensation', alpha=.3, ax=ax, c='purple')
)

plt.show()

# %% [markdown]
# #### adding Jitter

# %%
import seaborn.objects as so

# %%
fig = plt.figure(figsize=(8, 4))
(so
 .Plot(X_train.assign(title=kag_y_train), x='years_exp', y='compensation', color='title')
 .add(so.Dots(alpha=.3, pointsize=2), so.Jitter(x=.5, y=10_000))
 .add(so.Line(), so.PolyFit())
 .on(fig)
 .plot()
)

# %% [markdown]
# #### Adjusted Visualization

# %%
fig = plt.figure(figsize=(8, 4))
(so
 .Plot(X_train
       # .query('compensation < 200_000 and years_exp < 16')
       .assign(
           title=kag_y_train,
           country=(X_train
                    .loc[:, 'Q3_United States of America': 'Q3_China']
                    .idxmax(axis='columns')
                   )
       ), x='years_exp', y='compensation', color='title')
 .facet('country')
 .add(so.Dots(alpha=.01, pointsize=2, color='grey'), so.Jitter(x=.5, y=10_000), col=None)
 .add(so.Dots(alpha=.5, pointsize=1.5), so.Jitter(x=.5, y=10_000))
 .add(so.Line(pointsize=1), so.PolyFit(order=2))
 .scale(x=so.Continuous().tick(at=[0, 1, 2, 3, 4, 5]))
 .limit(y=(-10_000, 200_000), x=(-1, 6))
 .on(fig)
 .plot()
 )

# %% [markdown]
# ## Tree Creation

# %%
# Numerical Manipualtion
import numpy as np
import numpy.random as rn

# %%
pos_center = 12
pos_count = 100
neg_center = 7
neg_count = 1000

rs = rn.RandomState(rn.MT19937(rn.SeedSequence(42)))
gini = pd.DataFrame({'value':
                      np.append((pos_center) + rs.randn(pos_count),
                               (neg_center) + rs.randn(neg_count)),
                      'label':
                      ['pos']* pos_count + ['neg'] * neg_count})

# %%
fig, ax = plt.subplots(figsize=(8, 4))
_ = (gini
     .groupby('label')
     [['value']]
     .plot.hist(bins=30, alpha=.5, ax=ax, edgecolor='black')
    )
ax.legend(['Negative', 'Positive'])

plt.show()

# %%
def calc_gini(df, val_col, label_col, pos_val, split_point,
             debug=False):
    """
    This function calculates the Gini impurity of a dataset. Gini Impurity
    is a measure of the probability of a random sample being classified
    incorectly when a feature is sued to split the data. The lower the 
    impurity, the better the split.
    
    Parameters:
    df(pd.DataFrame): The dataframe containing the data
    val_col (str): the column name of the feature used to split the data
    label_col (str): The column name of the target variable
    pos_val (str or int): The value of the target variable that represents
        the positive class
    split_point (float): The threshold used to split the data.
    debug (bool): optional, when set to True, prints the calculated Gini
        impurities and the final weighted aveerage
        
    Returns:
    float: The weighted average of Gini impurity for the positive and
        negative subsets.
    """
    ge_split = df[val_col] >= split_point
    eq_pos = df[label_col] == pos_val
    tp = df[ge_split & eq_pos].shape[0]
    fp = df[ge_split & ~eq_pos].shape[0]
    tn = df[~ge_split & ~eq_pos].shape[0]
    fn = df[~ge_split & eq_pos].shape[0]
    pos_size = tp+fp
    neg_size = tn+fn
    total_size = len(df)
    if pos_size == 0:
        gini_pos = 0
    else:
        gini_pos = 1 - (tp/pos_size)**2 - (fp/pos_size)**2
    if neg_size == 0:
        gini_neg = 0
    else:
        gini_neg = 1 - (tn/neg_size)**2 - (fn/neg_size)**2
    weighted_avg = gini_pos * (pos_size/total_size) * \
    gini_neg * (neg_size/total_size)
    if debug:
        print(f'{gini_pos=:3} {gini_neg=:.3} {weighted_avg=:3}')
    return weighted_avg

# %%
calc_gini(gini, val_col='value', label_col='label', pos_val='pos', split_point=9.24, debug=True)
# Out:
# gini_pos=0.21708826063121614 gini_neg=0.00202 weighted_avg=4.050598243782082e-05
# 4.050598243782082e-05

# %%
values = np.arange(5, 15, .1)
ginis = []
for v in values:
    ginis.append(calc_gini(gini, val_col='value', label_col='label',
                          pos_val='pos', split_point=v))

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(values, ginis)
ax.set_title('Gini Coefficient')
ax.set_ylabel('Gini Coefficient')
ax.set_xlabel('Split Point')

plt.show()

# %%
pd.Series(ginis, index=values).loc[9.5:10.5]
# Out:
# 9.6     0.000022
# 9.7     0.000016
# 9.8     0.000013
# 9.9     0.000007
# 10.0    0.000010
# 10.1    0.000000
# 10.2    0.000000
# 10.3    0.000000
# 10.4    0.000000
# 10.5    0.000000
# dtype: float64

# %%
print(pd.DataFrame({'gini':ginis, 'split':values})
      .query('gini <= gini.min()'))
# Out:
#     gini  split
# 0    0.0    5.0
# 1    0.0    5.1
# 2    0.0    5.2
# 3    0.0    5.3
# 4    0.0    5.4
# ..   ...    ...
# 95   0.0   14.5
# 96   0.0   14.6
# 97   0.0   14.7
# 98   0.0   14.8
# 99   0.0   14.9
#
# [90 rows x 2 columns]

# %% [markdown]
# #### Coeffiecients in Trees

# %%
from sklearn import tree
stump = tree.DecisionTreeClassifier(max_depth=1)
stump.fit(gini[['value']], gini.label)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
fig, ax = plt.subplots(figsize=(8, 4))
tree.plot_tree(stump, feature_names=['value'],
               filled=True, 
               class_names=stump.classes_,
               ax=ax)
# Out:
# [Text(0.5, 0.75, 'value <= 9.708\ngini = 0.165\nsamples = 1100\nvalue = [1000, 100]\nclass = neg'),
#  Text(0.25, 0.25, 'gini = 0.002\nsamples = 999\nvalue = [998, 1]\nclass = neg'),
#  Text(0.75, 0.25, 'gini = 0.039\nsamples = 101\nvalue = [2, 99]\nclass = pos')]

# %%
gini_pos = 0.039
gini_neg = 0.002
pos_size = 101
neg_size = 999
total_size = pos_size + neg_size
weighted_avg = gini_pos * (pos_size/total_size) + \
gini_neg * (neg_size/total_size)

# %%
print(weighted_avg)
# Out:
# 0.005397272727272727

# %%
import xgboost as xgb

# %%
# from graphviz import Digraph

# dot = Digraph(comment='The Round Table')
# dot.node('A', 'King Arthur')
# dot.node('B', 'Sir Bedevere the Wise')
# dot.node('L', 'Sir Lancelot the Brave')

# dot.edges(['AB', 'AL'])
# dot.edge('B', 'L', constraint='false')
# print(dot.source)

# %%
xg_stump = xgb.XGBClassifier(n_estimators=1, max_depth=1)
xg_stump.fit(gini[['value']], (gini.label== 'pos'))
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=1, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=1, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
import os
os.environ["PATH"] += os.pathsep + '/Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/bin'


xgb.plot_tree(xg_stump, num_trees=0)

plt.show()

# %%
import subprocess

def my_dot_export(xg, num_trees, filename, title='', direction='TB'):
    """Exports a specified number of trees from an XGBoost model as a graph 
    visualization in dot and png formats.

    Args:
        xg: An XGBoost model.
        num_trees: The number of tree to export.
        filename: The name of the file to save the exported visualization.
        title: The title to display on the graph visualization (optional).
        direction: The direction to lay out the graph, either 'TB' (top to 
            bottom) or 'LR' (left to right) (optional).
    """
    res = xgb.to_graphviz(xg, num_trees=num_trees)
    content = f'''    node [fontname = "Helvetica"];
    edge [fontname = "Helvetica Thin"];
    label = "{title}"
    fontname = "Helvetica"
    '''
    out = res.source.replace('graph [ rankdir=TB ]', 
                             f'graph [ rankdir={direction} ];\n {content}')
    # dot -Gdpi=300 -Tpng -ocourseflow.png courseflow.dot 
    dot_filename = filename
    with open(dot_filename, 'w') as fout:
        fout.write(out)
    png_filename = dot_filename.replace('.dot', '.png')
    subprocess.run(f'dot -Gdpi=300 -Tpng -o{png_filename} {dot_filename}'.split())

# %%
my_dot_export(xg_stump, num_trees=0, filename='/Users/isisromero/Desktop/img_XGB/stump_xg.dot', title='A demo stump')

# %% [markdown]
# #### Another Visualization Tool

# %%
import dtreeviz
viz = dtreeviz.model(xg_stump, X_train=gini[['value']], 
                     y_train=gini.label=='pos',
    target_name='positive',
    feature_names=['value'], class_names=['negative', 'positive'],
    tree_index=0)
viz.view()

# %% [markdown]
# ## Stumps on Real Data

# %%
stump_dt = tree.DecisionTreeClassifier(max_depth=1)
X_train = kag_pl.fit_transform(kag_X_train)
stump_dt.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
fig, ax = plt.subplots(figsize=(8, 4))
features = list(c for c in X_train.columns)
tree.plot_tree(stump_dt, feature_names=features,
               filled=True,
               class_names=stump_dt.classes_,
               ax=ax)
# Out:
# [Text(0.5, 0.75, 'r <= 0.5\ngini = 0.496\nsamples = 2110\nvalue = [1153, 957]\nclass = Data Scientist'),
#  Text(0.25, 0.25, 'gini = 0.493\nsamples = 1484\nvalue = [653, 831]\nclass = Software Engineer'),
#  Text(0.75, 0.25, 'gini = 0.322\nsamples = 626\nvalue = [500, 126]\nclass = Data Scientist')]

# %%
X_test = kag_pl.transform(kag_X_test)

# %%
stump_dt.score(X_test, kag_y_test)
# Out:
# 0.6243093922651933

# %% [markdown]
# #### The Dummy Classifier

# %%
from sklearn import dummy

# %%
dummy_model = dummy.DummyClassifier()

# %%
dummy_model.fit(X_train, kag_y_train)
# Out:
# DummyClassifier()

# %%
dummy_model.score(X_test, kag_y_test)
# Out:
# 0.5458563535911602

# %%
import xgboost as xgb

# %%
kag_stump = xgb.XGBClassifier(n_estimators=1, max_depth=1)
kag_stump.fit(X_train, kag_y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 2
#       1 kag_stump = xgb.XGBClassifier(n_estimators=1, max_depth=1)
# ----> 2 kag_stump.fit(X_train, kag_y_train)
#
# File ~/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/xgboost/sklearn.py:1440, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1435     expected_classes = np.arange(self.n_classes_)
#    1436 if (
#    1437     self.classes_.shape != expected_classes.shape
#    1438     or not (self.classes_ == expected_classes).all()
#    1439 ):
# -> 1440     raise ValueError(
#    1441         f"Invalid classes inferred from unique values of `y`.  "
#    1442         f"Expected: {expected_classes}, got {self.classes_}"
#    1443     )
#    1445 params = self.get_xgb_params()
#    1447 if callable(self.objective):
#
# ValueError: Invalid classes inferred from unique values of `y`.  Expected: [0 1], got ['Data Scientist' 'Software Engineer']

# %%
print(kag_y_train)
# Out:
# 587      Software Engineer
# 3065        Data Scientist
# 8435        Data Scientist
# 3110        Data Scientist
# 16372    Software Engineer
#                ...
# 16608    Software Engineer
# 7325     Software Engineer
# 21810       Data Scientist
# 4917        Data Scientist
# 639         Data Scientist
# Name: Q6, Length: 2110, dtype: object

# %%
print(kag_y_train == 'Software Engineer')
# Out:
# 587       True
# 3065     False
# 8435     False
# 3110     False
# 16372     True
#          ...
# 16608     True
# 7325      True
# 21810    False
# 4917     False
# 639      False
# Name: Q6, Length: 2110, dtype: bool

# %% [markdown]
# #### Using Label Encoder

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
y_train = label_encoder.fit_transform(kag_y_train)
y_test = label_encoder.transform(kag_y_test)

# %%
y_test[:5]
# Out:
# array([1, 0, 0, 1, 1])

# %%
label_encoder.classes_
# Out:
# array(['Data Scientist', 'Software Engineer'], dtype=object)

# %%
# Inverse Tranformation Procedure
label_encoder.inverse_transform([0, 1])
# Out:
# array(['Data Scientist', 'Software Engineer'], dtype=object)

# %%
kag_stump = xgb.XGBClassifier(n_estimators=1, max_depth=1)
kag_stump.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=1, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=1, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
kag_stump.score(X_test, y_test)
# Out:
# 0.6243093922651933

# %%
my_dot_export(kag_stump, num_trees=0, filename='/Users/isisromero/Desktop/img_XGB/stump_xg.dot',
             title='XGBoost Stump')

# %%
kag_stump.classes_
# Out:
# array([0, 1])

# %%
def inv_logit(p: float) -> float:
    """
    Compute the inverse logit function of a given value.

    The inverse logit function is defined as:
        f(p) = exp(p) / (1 + exp(p))

    Parameters
    ----------
    p : float
        The input value to the inverse logit function.

    Returns
    -------
    float
        The output of the inverse logit function.
    """
    return np.exp(p) / (1 + np.exp(p))

# %%
inv_logit(.07117741922)
# Out:
# 0.5177868460919524

# %%
inv_logit(-.3592)
# Out:
# 0.41115323716754393

# %%
fig, ax = plt.subplots(figsize=(8, 4))
vals = np.linspace(-7, 7)
ax.plot(vals, inv_logit(vals))
ax.annotate('Crossover point', (0,.5), (-5,.8), arrowprops={'color':'k'})
ax.annotate('Predict Positive', (5,.6), (1,.6), va='center', arrowprops={'color':'k'})
ax.annotate('Predict Negative', (-5,.4), (-3,.4), va='center', arrowprops={'color':'k'})
# Out:
# Text(-3, 0.4, 'Predict Negative')

# %% [markdown]
# ## Model Complexity & Hyperparameters
#
# #### Underfit Model

# %%
underfit = tree.DecisionTreeClassifier(max_depth=1)
X_train = kag_pl.fit_transform(kag_X_train)

# %%
underfit.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
underfit.score(X_test, kag_y_test)
# Out:
# 0.6243093922651933

# %% [markdown]
# #### Overfitting with Decision Trees

# %%
hi_variance = tree.DecisionTreeClassifier(max_depth=None)
X_train = kag_pl.fit_transform(kag_X_train)

# %%
hi_variance.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier()

# %%
hi_variance.score(X_test, kag_y_test)
# Out:
# 0.6651933701657459

# %%
fig, ax = plt.subplots(figsize=(8, 4))
features = list(c for c in X_train.columns)
tree.plot_tree(hi_variance, feature_names=features, filled=True)
# Out:
# [Text(0.6539808781386462, 0.9772727272727273, 'r <= 0.5\ngini = 0.496\nsamples = 2110\nvalue = [1153, 957]'),
#  Text(0.39504554448689955, 0.9318181818181818, 'major_cs <= 0.5\ngini = 0.493\nsamples = 1484\nvalue = [653, 831]'),
#  Text(0.19097980349344978, 0.8863636363636364, 'Q3_United States of America <= 0.5\ngini = 0.49\nsamples = 718\nvalue = [410, 308]'),
#  Text(0.07913482532751091, 0.8409090909090909, 'years_exp <= 0.5\ngini = 0.491\nsamples = 322\nvalue = [140, 182]'),
#  Text(0.026637554585152837, 0.7954545454545454, 'education <= 17.0\ngini = 0.463\nsamples = 74\nvalue = [47, 27]'),
#  Text(0.020087336244541485, 0.75, 'major_stat <= 0.5\ngini = 0.499\nsamples = 40\nvalue = [21, 19]'),
#  Text(0.01834061135371179, 0.7045454545454546, 'age <= 27.5\ngini = 0.5\nsamples = 38\nvalue = [19, 19]'),
#  Text(0.016593886462882096, 0.6590909090909091, 'compensation <= 55000.0\ngini = 0.498\nsamples = 36\nvalue = [17, 19]'),
#  Text(0.014847161572052401, 0.6136363636363636, 'compensation <= 15000.0\ngini = 0.5\nsamples = 35\nvalue = [17, 18]'),
#  Text(0.013100436681222707, 0.5681818181818182, 'python <= 0.5\ngini = 0.496\nsamples = 33\nvalue = [15, 18]'),
#  Text(0.0069868995633187774, 0.5227272727272727, 'age <= 23.5\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.0034934497816593887, 0.4772727272727273, 'Q1_Male <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.0017467248908296944, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.005240174672489083, 0.4318181818181818, 'age <= 20.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0
 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07740174672489084, 0.6136363636363636, 'age <= 45.0\ngini = 0.302\nsamples = 81\nvalue = [15, 66]'),
#  Text(0.07565502183406113, 0.5681818181818182, 'years_exp <= 4.5\ngini = 0.289\nsamples = 80\nvalue = [14, 66]'),
#  Text(0.06746724890829695, 0.5227272727272727, 'age <= 23.5\ngini = 0.357\nsamples = 56\nvalue = [13, 43]'),
#  Text(0.06026200873362445, 0.4772727272727273, 'compensation <= 5000.0\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.05851528384279476, 0.4318181818181818, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.06200873362445415, 0.4318181818181818, 'years_exp <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.06026200873362445, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06375545851528384, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.07467248908296943, 0.4772727272727273, 'compensation <= 45000.0\ngini = 0.402\nsamples = 43\nvalue = [12, 31]'),
#  Text(0.07292576419213974, 0.4318181818181818, 'sql <= 0.5\ngini = 0.387\nsamples = 42\nvalue = [11, 31]'),
#  Text(0.06724890829694323, 0.38636363636363635, 'age <= 32.5\ngini = 0.32\nsamples = 25\nvalue = [5, 20]'),
#  Text(0.06550218340611354, 0.3409090909090909, 'age <= 27.5\ngini = 0.351\nsamples = 22\nvalue = [5, 17]'),
#  Text(0.0611353711790393, 0.29545454545454547, 'education <= 14.0\ngini = 0.32\nsamples = 20\nvalue = [4, 16]'),
#  Text(0.05764192139737991, 0.25, 'Q1_Male <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.05589519650655022, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.059388646288209605, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06462882096069869, 0.25, 'years_exp <= 2.5\ngini = 0.278\nsamples = 18\nvalue = [3, 15]'),
#  Text(0.062882096069869, 0.20454545454545456, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.06637554585152838, 0.20454545454545456, 'Q3_China <= 0.5\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(0.06462882096069869, 0.1590909090909091, 'compensation <= 5000.0\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.0611353711790393, 0.11363636363636363, 'years_exp <= 3.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.059388646288209605, 0.06818181818181818, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.062882096069869, 0.06818181818181818, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06812227074235808, 0.11363636363636363, 'major_eng <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.06637554585152838, 0.06818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06986899563318777, 0.06818181818181818, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.06812227074235808, 0.1590909090909091, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.06986899563318777, 0.29545454545454547, 'years_exp <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06812227074235808, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07161572052401746, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06899563318777292, 0.3409090909090909, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.07860262008733625, 0.38636363636363635, 'python <= 0.5\ngini = 0.457\nsamples = 17\nvalue = [6, 11]'),
#  Text(0.07685589519650655, 0.3409090909090909, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.08034934497816594, 0.3409090909090909, 'compensation <= 15000.0\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.07860262008733625, 0.29545454545454547, 'compensation <= 5000.0\ngini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(0.07685589519650655, 0.25, 'Q1_Female <= 0.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.07510917030567686, 0.20454545454545456, 'years_exp <= 3.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.07336244541484715, 0.1590909090909091, 'years_exp <= 2.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.07161572052401746, 0.11363636363636363, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.07510917030567686, 0.11363636363636363, 'major_eng <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.07336244541484715, 0.06818181818181818, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.07685589519650655, 0.06818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07685589519650655, 0.1590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.07860262008733625, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08034934497816594, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.08209606986899563, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07641921397379912, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08384279475982533, 0.5227272727272727, 'compensation <= 25000.0\ngini = 0.08\nsamples = 24\nvalue = [1, 23]'),
#  Text(0.08209606986899563, 0.4772727272727273, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.08558951965065502, 0.4772727272727273, 'Q3_China <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.08384279475982533, 0.4318181818181818, 'python <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08209606986899563, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08558951965065502, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08733624454148471, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.07914847161572053, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1402292576419214, 0.7045454545454546, 'education <= 19.5\ngini = 0.487\nsamples = 110\nvalue = [46, 64]'),
#  Text(0.13155021834061134, 0.6590909090909091, 'education <= 18.5\ngini = 0.477\nsamples = 102\nvalue = [40, 62]'),
#  Text(0.12292576419213974, 0.6136363636363636, 'sql <= 0.5\ngini = 0.487\nsamples = 93\nvalue = [39, 54]'),
#  Text(0.11091703056768559, 0.5681818181818182, 'compensation <= 15000.0\ngini = 0.461\nsamples = 61\nvalue = [22, 39]'),
#  Text(0.10655021834061135, 0.5227272727272727, 'years_exp <= 7.5\ngini = 0.495\nsamples = 40\nvalue = [18, 22]'),
#  Text(0.10480349344978165, 0.4772727272727273, 'age <= 32.5\ngini = 0.497\nsamples = 39\nvalue = [18, 21]'),
#  Text(0.10305676855895196, 0.4318181818181818, 'years_exp <= 3.5\ngini = 0.491\nsamples = 37\nvalue = [16, 21]'),
#  Text(0.09781659388646288, 0.38636363636363635, 'age <= 27.5\ngini = 0.477\nsamples = 28\nvalue = [11, 17]'),
#  Text(0
 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.29705240174672487, 0.75, 'compensation <= 112500.0\ngini = 0.458\nsamples = 90\nvalue = [58, 32]'),
#  Text(0.28973799126637556, 0.7045454545454546, 'years_exp <= 3.5\ngini = 0.489\nsamples = 66\nvalue = [38, 28]'),
#  Text(0.28799126637554584, 0.6590909090909091, 'age <= 37.5\ngini = 0.475\nsamples = 62\nvalue = [38, 24]'),
#  Text(0.28034934497816594, 0.6136363636363636, 'years_exp <= 0.5\ngini = 0.456\nsamples = 57\nvalue = [37, 20]'),
#  Text(0.2703056768558952, 0.5681818181818182, 'age <= 32.5\ngini = 0.491\nsamples = 23\nvalue = [13, 10]'),
#  Text(0.2685589519650655, 0.5227272727272727, 'Q1_Female <= 0.5\ngini = 0.483\nsamples = 22\nvalue = [13, 9]'),
#  Text(0.26244541484716155, 0.4772727272727273, 'age <= 23.5\ngini = 0.457\nsamples = 17\nvalue = [11, 6]'),
#  Text(0.25895196506550217, 0.4318181818181818, 'sql <= 0.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.2572052401746725, 0.38636363636363635, 'compensation <= 75000.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.2554585152838428, 0.3409090909090909, 'education <= 19.0\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.2537117903930131, 0.29545454545454547, 'education <= 17.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.2519650655021834, 0.25, 'compensation <= 35000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.25021834061135373, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2537117903930131, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2554585152838428, 0.25, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2572052401746725, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.25895196506550217, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2606986899563319, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.26593886462882094, 0.4318181818181818, 'compensation <= 60000.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.26419213973799127, 0.38636363636363635, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.26768558951965066, 0.38636363636363635, 'compensation <= 85000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.26593886462882094, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2694323144104803, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.27467248908296943, 0.4772727272727273, 'sql <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.27292576419213976, 0.4318181818181818, 'compensation <= 45000.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.27117903930131004, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.27467248908296943, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.27641921397379915, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2720524017467249, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2903930131004367, 0.5681818181818182, 'age <= 32.5\ngini = 0.415\nsamples = 34\nvalue = [24, 10]'),
#  Text(0.28864628820960697, 0.5227272727272727, 'compensation <= 95000.0\ngini = 0.444\nsamples = 30\nvalue = [20, 10]'),
#  Text(0.2851528384279476, 0.4772727272727273, 'Q1_Prefer not to say <= 0.5\ngini = 0.469\nsamples = 24\nvalue = [15, 9]'),
#  Text(0.2834061135371179, 0.4318181818181818, 'sql <= 0.5\ngini = 0.476\nsamples = 23\nvalue = [14, 9]'),
#  Text(0.2781659388646288, 0.38636363636363635, 'age <= 27.5\ngini = 0.444\nsamples = 15\nvalue = [10, 5]'),
#  Text(0.27641921397379915, 0.3409090909090909, 'years_exp <= 2.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.27292576419213976, 0.29545454545454547, 'compensation <= 75000.0\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.27117903930131004, 0.25, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.27467248908296943, 0.25, 'compensation <= 85000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.27292576419213976, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.27641921397379915, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.27991266375545854, 0.29545454545454547, 'Q1_Female <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2781659388646288, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2816593886462882, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.27991266375545854, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.28864628820960697, 0.38636363636363635, 'age <= 27.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.2851528384279476, 0.3409090909090909, 'compensation <= 35000.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.2834061135371179, 0.29545454545454547, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2868995633187773, 0.29545454545454547, 'compensation <= 80000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2851528384279476, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.28864628820960697, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.29213973799126636, 0.3409090909090909, 'education <= 19.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.2903930131004367, 0.29545454545454547, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.2938864628820961, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2868995633187773, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.29213973799126636, 0.4772727272727273, 'years_exp <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.2903930131004367, 0.4318181818181818, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.2938864628820961, 0.4318181818181818, 'years_exp <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.29213973799126636, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.29563318777292574, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.29213973799126636, 0.5227272727272727, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.29563318777292574, 0.6136363636363636, 'years_exp <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.2938864628820961, 0.5681818181818182, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.29737991266375546, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2914847161572052, 0.6590909090909091, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.30436681222707423, 0.7045454545454546, 'education <= 17.0\ngini = 0.278\nsamples = 24\nvalue = [20, 4]'),
#  Text(0.30087336244541485, 0.6590909090909091, 'age <= 23.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.29912663755458513, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3026200873362445, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3078602620087336, 0.6590909090909091, 'age <= 27.5\ngini = 0.172\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.30611353711790396, 0.6136363636363636, 'years_exp <= 3.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.30436681222707423, 0.5681818181818182, 'compensation <= 137500.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.3026200873362445, 0.5227272727272727, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.30611353711790396, 0.5227272727272727, 'sql <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.30436681222707423, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3078602620087336, 0.4772727272727273, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3078602620087336, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.30960698689956334, 0.6136363636363636, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.34268558951965067, 0.7954545454545454, 'education <= 18.5\ngini = 0.495\nsamples = 102\nvalue = [46, 56]'),
#  Text(0.32685589519650654, 0.75, 'education <= 17.0\ngini = 0.438\nsamples = 74\nvalue = [24, 50]'),
#  Text(0.3165938864628821, 0.7045454545454546, 'major_other <= 0.5\ngini = 0.165\nsamples = 22\nvalue = [2, 20]'),
#  Text(0.3148471615720524, 0.6590909090909091, 'age <= 40.0\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.3131004366812227, 0.6136363636363636, 'compensation <= 65000.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.311353711790393, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3148471615720524, 0.5681818181818182, 'compensation <= 137500.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.3131004366812227, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3165938864628821, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3165938864628821, 0.6136363636363636, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3183406113537118, 0.6590909090909091, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.337117903930131, 0.7045454545454546, 'compensation <= 112500.0\ngini = 0.488\nsamples = 52\nvalue = [22, 30]'),
#  Text(0.32794759825327513, 0.6590909090909091, 'age <= 32.5\ngini = 0.415\nsamples = 34\nvalue = [10, 24]'),
# ...
#  Text(0.6200873362445415, 0.5681818181818182, 'age <= 32.5\ngini = 0.498\nsamples = 30\nvalue = [16, 14]'),
#  Text(0.6139737991266375, 0.5227272727272727, 'Q3_China <= 0.5\ngini = 0.48\nsamples = 25\nvalue = [15, 10]'),
#  Text(0.6069868995633187, 0.4772727272727273, 'years_exp <= 1.5\ngini = 0.415\nsamples = 17\nvalue = [12, 5]'),
#  Text(0.605240174672489, 0.4318181818181818, 'compensation <= 112500.0\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.6017467248908297, 0.38636363636363635, 'years_exp <= 0.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.6, 0.3409090909090909, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6034934497816594, 0.3409090909090909, 'sql <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.6017467248908297, 0.29545454545454547, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.605240174672489, 0.29545454545454547, 'compensation <= 75000.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.6034934497816594, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6069868995633187, 0.25, 'compensation <= 90000.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.605240174672489, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6087336244541485, 0.20454545454545456, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6087336244541485, 0.38636363636363635, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6069868995633187, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6104803493449782, 0.3409090909090909, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6087336244541485, 0.4318181818181818, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6209606986899563, 0.4772727272727273, 'sql <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.6192139737991267, 0.4318181818181818, 'years_exp <= 1.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.6157205240174672, 0.38636363636363635, 'compensation <= 35000.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6139737991266375, 0.3409090909090909, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.617467248908297, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.622707423580786, 0.38636363636363635, 'compensation <= 80000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6209606986899563, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6244541484716157, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.622707423580786, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6262008733624455, 0.5227272727272727, 'sql <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6244541484716157, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6279475982532751, 0.4772727272727273, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6235807860262009, 0.5681818181818182, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6253275109170305, 0.6136363636363636, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.6270742358078603, 0.6590909090909091, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.703073826419214, 0.8409090909090909, 'education <= 17.0\ngini = 0.334\nsamples = 293\nvalue = [62, 231]'),
#  Text(0.6632368995633188, 0.7954545454545454, 'Q3_China <= 0.5\ngini = 0.233\nsamples = 134\nvalue = [18, 116]'),
#  Text(0.6559497816593887, 0.75, 'years_exp <= 12.5\ngini = 0.203\nsamples = 122\nvalue = [14, 108]'),
#  Text(0.6542030567685589, 0.7045454545454546, 'age <= 42.5\ngini = 0.226\nsamples = 108\nvalue = [14, 94]'),
#  Text(0.6466157205240175, 0.6590909090909091, 'years_exp <= 3.5\ngini = 0.215\nsamples = 106\nvalue = [13, 93]'),
#  Text(0.6366812227074236, 0.6136363636363636, 'compensation <= 90000.0\ngini = 0.32\nsamples = 20\nvalue = [4, 16]'),
#  Text(0.6349344978165938, 0.5681818181818182, 'age <= 32.5\ngini = 0.198\nsamples = 18\nvalue = [2, 16]'),
#  Text(0.6331877729257642, 0.5227272727272727, 'python <= 0.5\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(0.6314410480349345, 0.4772727272727273, 'compensation <= 5000.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6296943231441048, 0.4318181818181818, 'age <= 21.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6279475982532751, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6314410480349345, 0.38636363636363635, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6331877729257642, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6349344978165938, 0.4772727272727273, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.6366812227074236, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6384279475982533, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6565502183406113, 0.6136363636363636, 'Q3_United States of America <= 0.5\ngini = 0.187\nsamples = 86\nvalue = [9, 77]'),
#  Text(0.6548034934497816, 0.5681818181818182, 'compensation <= 85000.0\ngini = 0.27\nsamples = 56\nvalue = [9, 47]'),
#  Text(0.6475982532751092, 0.5227272727272727, 'compensation <= 5000.0\ngini = 0.252\nsamples = 54\nvalue = [8, 46]'),
#  Text(0.6384279475982533, 0.4772727272727273, 'age <= 32.5\ngini = 0.33\nsamples = 24\nvalue = [5, 19]'),
#  Text(0.6366812227074236, 0.4318181818181818, 'Q1_Male <= 0.5\ngini = 0.363\nsamples = 21\nvalue = [5, 16]'),
#  Text(0.6349344978165938, 0.38636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6384279475982533, 0.38636363636363635, 'python <= 0.5\ngini = 0.401\nsamples = 18\nvalue = [5, 13]'),
#  Text(0.6323144104803493, 0.3409090909090909, 'years_exp <= 4.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.6305676855895197, 0.29545454545454547, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.634061135371179, 0.29545454545454547, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6323144104803493, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6358078602620088, 0.25, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6445414847161572, 0.3409090909090909, 'years_exp <= 7.5\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.6410480349344978, 0.29545454545454547, 'sql <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.6393013100436681, 0.25, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.6427947598253275, 0.25, 'years_exp <= 4.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6410480349344978, 0.20454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6445414847161572, 0.20454545454545456, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6427947598253275, 0.1590909090909091, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6462882096069869, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6480349344978166, 0.29545454545454547, 'age <= 24.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6462882096069869, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6497816593886463, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.640174672489083, 0.4318181818181818, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6567685589519651, 0.4772727272727273, 'compensation <= 15000.0\ngini = 0.18\nsamples = 30\nvalue = [3, 27]'),
#  Text(0.6550218340611353, 0.4318181818181818, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.6585152838427948, 0.4318181818181818, 'Q1_Female <= 0.5\ngini = 0.255\nsamples = 20\nvalue = [3, 17]'),
#  Text(0.6550218340611353, 0.38636363636363635, 'sql <= 0.5\ngini = 0.198\nsamples = 18\nvalue = [2, 16]'),
#  Text(0.6532751091703056, 0.3409090909090909, 'age <= 27.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.651528384279476, 0.29545454545454547, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6550218340611353, 0.29545454545454547, 'compensation <= 50000.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.6532751091703056, 0.25, 'years_exp <= 4.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.651528384279476, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6550218340611353, 0.20454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6567685589519651, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6567685589519651, 0.3409090909090909, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.6620087336244541, 0.38636363636363635, 'sql <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6602620087336245, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6637554585152838, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6620087336244541, 0.5227272727272727, 'years_exp <= 7.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6602620087336245, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6637554585152838, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6582969432314411, 0.5681818181818182, 'gini = 0.0\nsamples = 30\nvalue = [0, 30]'),
#  Text(0.6617903930131004, 0.6590909090909091, 'years_exp <= 7.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6600436681222708, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6635371179039301, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6576965065502184, 0.7045454545454546, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.6705240174672489, 0.75, 'sql <= 0.5\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.6670305676855895, 0.7045454545454546, 'age <= 32.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.6652838427947598, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6687772925764193, 0.6590909090909091, 'years_exp <= 4.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6670305676855895, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6705240174672489, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6740174672489083, 0.7045454545454546, 'compensation <= 55000.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.6722707423580786, 0.6590909090909091, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.675764192139738, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7429107532751091, 0.7954545454545454, 'age <= 20.0\ngini = 0.4\nsamples = 159\nvalue = [44, 115]'),
#  Text(0.7411640283842795, 0.75, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7446574781659389, 0.75, 'age <= 47.5\ngini = 0.392\nsamples = 157\nvalue = [42, 115]'),
#  Text(0.7338564410480349, 0.7045454545454546, 'years_exp <= 7.5\ngini = 0.375\nsamples = 148\nvalue = [37, 111]'),
#  Text(0.7227347161572052, 0.6590909090909091, 'education <= 19.5\ngini = 0.422\nsamples = 109\nvalue = [33, 76]'),
#  Text(0.710971615720524, 0.6136363636363636, 'age <= 37.5\ngini = 0.397\nsamples = 99\nvalue = [27, 72]'),
#  Text(0.6996724890829694, 0.5681818181818182, 'age <= 27.5\ngini = 0.372\nsamples = 93\nvalue = [23, 70]'),
#  Text(0.6855895196506551, 0.5227272727272727, 'education <= 18.5\ngini = 0.427\nsamples = 42\nvalue = [13, 29]'),
#  Text(0.6838427947598253, 0.4772727272727273, 'compensation <= 5000.0\ngini = 0.414\nsamples = 41\nvalue = [12, 29]'),
#  Text(0.6733624454148471, 0.4318181818181818, 'years_exp <= 4.5\ngini = 0.298\nsamples = 22\nvalue = [4, 18]'),
#  Text(0.6716157205240174, 0.38636363636363635, 'python <= 0.5\ngini = 0.332\nsamples = 19\nvalue = [4, 15]'),
#  Text(0.6672489082969433, 0.3409090909090909, 'years_exp <= 3.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.6655021834061136, 0.29545454545454547, 'age <= 23.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6637554585152838, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6672489082969433, 0.25, 'Q3_China <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6655021834061136, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6689956331877729, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6689956331877729, 0.29545454545454547, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6759825327510917, 0.3409090909090909, 'years_exp <= 3.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.6724890829694323, 0.29545454545454547, 'Q3_United States of America <= 0.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.6707423580786026, 0.25, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.674235807860262, 0.25, 'sql <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6724890829694323, 0.20454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6759825327510917, 0.20454545454545456, 'Q1_Female <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.674235807860262, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6777292576419214, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6794759825327511, 0.29545454545454547, 'Q1_Male <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6777292576419214, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6812227074235808, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6751091703056769, 0.38636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6943231441048034, 0.4318181818181818, 'compensation <= 125000.0\ngini = 0.488\nsamples = 19\nvalue = [8, 11]'),
#  Text(0.6925764192139738, 0.38636363636363635, 'years_exp <= 4.5\ngini = 0.5\nsamples = 16\nvalue = [8, 8]'),
#  Text(0.6908296943231441, 0.3409090909090909, 'python <= 0.5\ngini = 0.498\nsamples = 15\nvalue = [7, 8]'),
#  Text(0.6864628820960699, 0.29545454545454547, 'compensation <= 60000.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6847161572052402, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6882096069868996, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6951965065502184, 0.29545454545454547, 'compensation <= 45000.0\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.6917030567685589, 0.25, 'years_exp <= 3.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.6899563318777293, 0.20454545454545456, 'Q3_United States of America <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6882096069868996, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6917030567685589, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6934497816593886, 0.20454545454545456, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6986899563318777, 0.25, 'Q3_United States of America <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.6969432314410481, 0.20454545454545456, 'compensation <= 55000.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6951965065502184, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6986899563318777, 0.1590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7004366812227074, 0.20454545454545456, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6943231441048034, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6960698689956332, 0.38636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6873362445414847, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7137554585152839, 0.5227272727272727, 'compensation <= 112500.0\ngini = 0.315\nsamples = 51\nvalue = [10, 41]'),
#  Text(0.7087336244541484, 0.4772727272727273, 'compensation <= 75000.0\ngini = 0.263\nsamples = 45\nvalue = [7, 38]'),
#  Text(0.7069868995633187, 0.4318181818181818, 'Q1_Male <= 0.5\ngini = 0.313\nsamples = 36\nvalue = [7, 29]'),
#  Text(0.7021834061135371, 0.38636363636363635, 'Q3_United States of America <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.7004366812227074, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7039301310043669, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7117903930131004, 0.38636363636363635, 'age <= 32.5\ngini = 0.257\nsamples = 33\nvalue = [5, 28]'),
#  ...]

# %%
fig, ax = plt.subplots(figsize=(8, 4))
features = list(c for c in X_train.columns)
tree.plot_tree(hi_variance, feature_names=features, filled=True, class_names=hi_variance.classes_,
              max_depth=2, fontsize=6)
# Out:
# [Text(0.5, 0.875, 'r <= 0.5\ngini = 0.496\nsamples = 2110\nvalue = [1153, 957]\nclass = Data Scientist'),
#  Text(0.25, 0.625, 'major_cs <= 0.5\ngini = 0.493\nsamples = 1484\nvalue = [653, 831]\nclass = Software Engineer'),
#  Text(0.125, 0.375, 'Q3_United States of America <= 0.5\ngini = 0.49\nsamples = 718\nvalue = [410, 308]\nclass = Data Scientist'),
#  Text(0.0625, 0.125, '\n  (...)  \n'),
#  Text(0.1875, 0.125, '\n  (...)  \n'),
#  Text(0.375, 0.375, 'years_exp <= 2.5\ngini = 0.433\nsamples = 766\nvalue = [243, 523]\nclass = Software Engineer'),
#  Text(0.3125, 0.125, '\n  (...)  \n'),
#  Text(0.4375, 0.125, '\n  (...)  \n'),
#  Text(0.75, 0.625, 'major_cs <= 0.5\ngini = 0.322\nsamples = 626\nvalue = [500, 126]\nclass = Data Scientist'),
#  Text(0.625, 0.375, 'years_exp <= 22.5\ngini = 0.211\nsamples = 443\nvalue = [390, 53]\nclass = Data Scientist'),
#  Text(0.5625, 0.125, '\n  (...)  \n'),
#  Text(0.6875, 0.125, '\n  (...)  \n'),
#  Text(0.875, 0.375, 'years_exp <= 7.5\ngini = 0.48\nsamples = 183\nvalue = [110, 73]\nclass = Data Scientist'),
#  Text(0.8125, 0.125, '\n  (...)  \n'),
#  Text(0.9375, 0.125, '\n  (...)  \n')]

# %% [markdown]
# ## Tree Hyperparameters

# %%
stump.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 1,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %% [markdown]
# #### Tracking changes with Validation Curves

# %%
accuracies = []
for depth in range(1, 15):
    between = tree.DecisionTreeClassifier(max_depth=depth)
    between.fit(X_train, kag_y_train)
    accuracies.append(between.score(X_test, kag_y_test))

# %%
fig, ax = plt.subplots(figsize=(10, 4))
(pd.Series(accuracies, name='Accuracy', index=range(1, len(accuracies)+1))
 .plot(ax=ax, title='Accuracy at a given Tree Depth'))
ax.set_ylabel('Accuracy')
ax.set_xlabel('max_depth')

plt.grid(True)
plt.show()

# %%
between = tree.DecisionTreeClassifier(max_depth=7)
between.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier(max_depth=7)

# %%
between.score(X_test, kag_y_test)
# Out:
# 0.7325966850828729

# %% [markdown]
# #### Leveraging Yellowbrick

# %%
from yellowbrick.model_selection import validation_curve

# %%
fig, ax = plt.subplots(figsize=(10, 4))
viz = validation_curve(tree.DecisionTreeClassifier(),
                       X=pd.concat([X_train, X_test]),
                       y=pd.concat([kag_y_train, kag_y_test]),
                       param_name='max_depth', param_range=range(1, 14),
                       scoring='accuracy', cv=5, ax=ax, n_jobs=6)

plt.show()
# Out:
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# #### Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'max_depth': [3, 5, 7, 8],
    'min_samples_leaf': [1, 3, 4, 5, 6],
    'min_samples_split': [2, 3, 4, 5, 6],
}

# %%
grid_search = GridSearchCV(estimator=tree.DecisionTreeClassifier(),
                           param_grid=params, cv=4, n_jobs=-1,
                           verbose=1, scoring="accuracy")

# %%
grid_search.fit(pd.concat([X_train, X_test]),
                pd.concat([kag_y_train, kag_y_test]))
# Out:
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [3, 5, 7, 8],
#                          'min_samples_leaf': [1, 3, 4, 5, 6],
#                          'min_samples_split': [2, 3, 4, 5, 6]},
#              scoring='accuracy', verbose=1)

# %%
grid_search.best_params_
# Out:
# {'max_depth': 7, 'min_samples_leaf': 5, 'min_samples_split': 2}

# %%
between2 = tree.DecisionTreeClassifier(**grid_search.best_params_)

# %%
between2.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier(max_depth=7, min_samples_leaf=5)

# %%
between2.score(X_test, kag_y_test)
# Out:
# 0.7259668508287292

# %%
(pd.DataFrame(grid_search.cv_results_)
 .sort_values(by='rank_test_score')
 .style
 .background_gradient(axis='rows')
)
# Out:
# <style type="text/css">
# #T_535cc_row0_col0, #T_535cc_row56_col12, #T_535cc_row57_col12 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_535cc_row0_col1, #T_535cc_row38_col14, #T_535cc_row39_col14, #T_535cc_row53_col0 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_535cc_row0_col2, #T_535cc_row2_col2, #T_535cc_row9_col2, #T_535cc_row23_col2, #T_535cc_row31_col2, #T_535cc_row34_col2, #T_535cc_row48_col2, #T_535cc_row53_col2, #T_535cc_row77_col0, #T_535cc_row79_col0, #T_535cc_row81_col0, #T_535cc_row87_col0, #T_535cc_row88_col0 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_535cc_row0_col3, #T_535cc_row5_col3, #T_535cc_row11_col1, #T_535cc_row13_col1, #T_535cc_row18_col3, #T_535cc_row23_col3, #T_535cc_row27_col3, #T_535cc_row34_col1, #T_535cc_row36_col3, #T_535cc_row38_col3, #T_535cc_row40_col3, #T_535cc_row43_col3, #T_535cc_row49_col1, #T_535cc_row50_col1, #T_535cc_row53_col3, #T_535cc_row54_col1, #T_535cc_row60_col3, #T_535cc_row61_col1, #T_535cc_row67_col3, #T_535cc_row68_col3, #T_535cc_row77_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_535cc_row0_col8, #T_535cc_row1_col8, #T_535cc_row4_col8, #T_535cc_row6_col8, #T_535cc_row8_col8, #T_535cc_row10_col8, #T_535cc_row11_col8, #T_535cc_row14_col8, #T_535cc_row14_col12, #T_535cc_row68_col8, #T_535cc_row69_col8 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T
_col12, #T_535cc_row93_col13, #T_535cc_row94_col9, #T_535cc_row94_col11, #T_535cc_row94_col12, #T_535cc_row94_col13, #T_535cc_row95_col9, #T_535cc_row95_col11, #T_535cc_row95_col12, #T_535cc_row95_col13, #T_535cc_row96_col9, #T_535cc_row96_col11, #T_535cc_row96_col12, #T_535cc_row96_col13, #T_535cc_row97_col9, #T_535cc_row97_col11, #T_535cc_row97_col12, #T_535cc_row97_col13, #T_535cc_row98_col9, #T_535cc_row98_col11, #T_535cc_row98_col12, #T_535cc_row98_col13, #T_535cc_row99_col0, #T_535cc_row99_col2, #T_535cc_row99_col9, #T_535cc_row99_col11, #T_535cc_row99_col12, #T_535cc_row99_col13 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_535cc_row1_col0, #T_535cc_row6_col0, #T_535cc_row27_col0, #T_535cc_row28_col0 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_535cc_row1_col1, #T_535cc_row15_col1, #T_535cc_row24_col1 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_535cc_row1_col2, #T_535cc_row11_col2, #T_535cc_row15_col2, #T_535cc_row29_col2, #T_535cc_row58_col2, #T_535cc_row62_col2, #T_535cc_row65_col1, #T_535cc_row72_col1, #T_535cc_row78_col2 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_535cc_row1_col3, #T_535cc_row2_col1, #T_535cc_row2_col3, #T_535cc_row4_col3, #T_535cc_row8_col3, #T_535cc_row12_col1, #T_535cc_row14_col1, #T_535cc_row17_col1, #T_535cc_row24_col3, #T_535cc_row28_col1, #T_535cc_row29_col3, #T_535cc_row30_col3, #T_535cc_row31_col3, #T_535cc_row34_col3, #T_535cc_row35_col1, #T_535cc_row35_col3, #T_535cc_row41_col3, #T_535cc_row42_col1, #T_535cc_row45_col1, #T_535cc_row48_col1, #T_535cc_row48_col3, #T_535cc_row51_col3, #T_535cc_row54_col3, #T_535cc_row56_col3, #T_535cc_row58_col3, #T_535cc_row60_col1, #T_535cc_row62_col3, #T_535cc_row66_col3, #T_535cc_row75_col12, #T_535cc_row76_col12, #T_535cc_row77_col12, #T_535cc_row78_col1, #T_535cc_row78_col3, #T_535cc_row78_col12, #T_535cc_row79_col12, #T_535cc_row80_col3, #T_535cc_row80_col12, #T_535cc_row81_col12, #T_535cc_row82_col12, #T_535cc_row83_col12, #T_535cc_row84_col1, #T_535cc_row84_col3, #T_535cc_row84_col12, #T_535cc_row85_col3, #T_535cc_row85_col12, #T_535cc_row86_col1, #T_535cc_row86_col12, #T_535cc_row87_col12, #T_535cc_row88_col12, #T_535cc_row89_col12, #T_535cc_row91_col3, #T_535cc_row92_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_535cc_row2_col0, #T_535cc_row63_col13, #T_535cc_row64_col0, #T_535cc_row69_col13 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_535cc_row2_col8, #T_535cc_row3_col8, #T_535cc_row5_col8, #T_535cc_row6_col12 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_535cc_row2_col11, #T_535cc_row3_col11, #T_535cc_row4_col11, #T_535cc_row5_col11, #T_535cc_row9_col11, #T_535cc_row10_col9, #T_535cc_row13_col9, #T_535cc_row14_col9, #T_535cc_row16_col11, #T_535cc_row24_col9, #T_535cc_row25_col9, #T_535cc_row29_col9, #T_535cc_row30_col9, #T_535cc_row34_col9, #T_535cc_row37_col9, #T_535cc_row40_col9, #T_535cc_row41_col9, #T_535cc_row42_col9, #T_535cc_row43_col9, #T_535cc_row43_col11, #T_535cc_row44_col9, #T_535cc_row44_col11, #T_535cc_row45_col9, #T_535cc_row45_col11, #T_535cc_row48_col9, #T_535cc_row48_col11, #T_535cc_row49_col11, #T_535cc_row54_col9, #T_535cc_row54_col11 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_535cc_row2_col13, #T_535cc_row3_col13, #T_535cc_row16_col2, #T_535cc_row55_col0, #T_535cc_row60_col8, #T_535cc_row71_col8, #T_535cc_row73_col8 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_535cc_row2_col14, #T_535cc_row3_col14, #T_535cc_row7_col3, #T_535cc_row19_col1, #T_535cc_row19_col3, #T_535cc_row37_col3, #T_535cc_row47_col3, #T_535cc_row49_col3, #T_535cc_row55_col3, #T_535cc_row69_col1, #T_535cc_row75_col3, #T_535cc_row88_col3, #T_535cc_row99_col1 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_535cc_row3_col0, #T_535cc_row37_col14, #T_535cc_row63_col0 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_535cc_row3_col1, #T_535cc_row6_col2, #T_535cc_row20_col14, #T_535cc_row21_col1

# %%
results = model_selection.cross_val_score(
    tree.DecisionTreeClassifier(max_depth=7),
    X=pd.concat([X_train, X_test], axis='index'),
    y=pd.concat([kag_y_train, kag_y_test], axis='index'),
    cv=4
)

# %%
results
# Out:
# array([0.69761273, 0.73740053, 0.70291777, 0.71580345])

# %%
results.mean()
# Out:
# 0.713433621834501

# %%
results = model_selection.cross_val_score(
    tree.DecisionTreeClassifier(max_depth=7, min_samples_leaf=5,
                               min_samples_split=2),
    X=pd.concat([X_train, X_test], axis='index'),
    y=pd.concat([kag_y_train, kag_y_test], axis='index'),
    cv=4
)

# %%
results
# Out:
# array([0.70689655, 0.73740053, 0.70954907, 0.71580345])

# %%
results.mean()
# Out:
# 0.7174124016753498

# %% [markdown]
# ## Random Forest
#
# #### Scikit-Learn Random Forest

# %%
from sklearn import ensemble

# %%
rf = ensemble.RandomForestClassifier(random_state=42)

# %%
rf.fit(X_train, kag_y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rf.score(X_test, kag_y_test)
# Out:
# 0.7237569060773481

# %%
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %%
len(rf.estimators_)
# Out:
# 100

# %%
print(rf.estimators_[0])
# Out:
# DecisionTreeClassifier(max_features='sqrt', random_state=1608637542)

# %%
fig, ax = plt.subplots(figsize=(8, 4))
features = list(c for c in X_train.columns)
tree.plot_tree(rf.estimators_[0], feature_names=features,
               filled=True, class_names=rf.classes_, ax=ax,
               max_depth=2, fontsize=6)
# Out:
# [Text(0.5, 0.875, 'Q3_United States of America <= 0.5\ngini = 0.496\nsamples = 1354\nvalue = [1146, 964]\nclass = Data Scientist'),
#  Text(0.25, 0.625, 'r <= 0.5\ngini = 0.496\nsamples = 681\nvalue = [496, 588]\nclass = Software Engineer'),
#  Text(0.125, 0.375, 'education <= 17.0\ngini = 0.469\nsamples = 530\nvalue = [317, 528]\nclass = Software Engineer'),
#  Text(0.0625, 0.125, '\n  (...)  \n'),
#  Text(0.1875, 0.125, '\n  (...)  \n'),
#  Text(0.375, 0.375, 'education <= 17.0\ngini = 0.376\nsamples = 151\nvalue = [179, 60]\nclass = Data Scientist'),
#  Text(0.3125, 0.125, '\n  (...)  \n'),
#  Text(0.4375, 0.125, '\n  (...)  \n'),
#  Text(0.75, 0.625, 'education <= 17.0\ngini = 0.464\nsamples = 673\nvalue = [650, 376]\nclass = Data Scientist'),
#  Text(0.625, 0.375, 'major_cs <= 0.5\ngini = 0.485\nsamples = 176\nvalue = [109, 154]\nclass = Software Engineer'),
#  Text(0.5625, 0.125, '\n  (...)  \n'),
#  Text(0.6875, 0.125, '\n  (...)  \n'),
#  Text(0.875, 0.375, 'major_cs <= 0.5\ngini = 0.413\nsamples = 497\nvalue = [541, 222]\nclass = Data Scientist'),
#  Text(0.8125, 0.125, '\n  (...)  \n'),
#  Text(0.9375, 0.125, '\n  (...)  \n')]

# %% [markdown]
# #### XGBoost Random Forest

# %%
import xgboost as xgb

# %%
rf_xg = xgb.XGBRFClassifier(random_state=42)

# %%
rf_xg.fit(X_train, y_train)
# Out:
# XGBRFClassifier(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bytree=None,
#                 early_stopping_rounds=None, enable_categorical=False,
#                 eval_metric=None, feature_types=None, gamma=None, gpu_id=None,
#                 grow_policy=None, importance_type=None,
#                 interaction_constraints=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                 objective='binary:logistic', predictor=None, random_state=42,
#                 reg_alpha=None, ...)

# %%
rf_xg.score(X_test, y_test)
# Out:
# 0.7447513812154696

# %%
rf_xg.get_params()
# Out:
# {'colsample_bynode': 0.8,
#  'learning_rate': 1.0,
#  'reg_lambda': 1e-05,
#  'subsample': 0.8,
#  'objective': 'binary:logistic',
#  'use_label_encoder': None,
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bytree': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'gpu_id': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'predictor': None,
#  'random_state': 42,
#  'reg_alpha': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None}

# %%
fig, ax = plt.subplots(figsize=(6, 12), dpi=600)
xgb.plot_tree(rf_xg, num_trees=0, ax=ax, size='1, 1')
# Out:
# <Axes: >

# %%
my_dot_export(rf_xg, num_trees=0, filename='/Users/isisromero/Desktop/img_XGB/stump_xg.dot',
              title='First Random Forest Tree')
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.960825 to fit

# %%
viz = dtreeviz.model(rf_xg, X_train=X_train,
                     y_train=y_train,
                     target_name='Job', feature_names=list(X_train.columns),
                     class_names=['DS', 'SE'], tree_index=0)

# %%
viz.view(depth_range_to_display=[0, 2])

# %% [markdown]
# #### Training the Number of Trees in the Forest

# %%
from yellowbrick.model_selection import validation_curve

# %%
fig, ax = plt.subplots(figsize=(10, 4))
viz = validation_curve(xgb.XGBClassifier(random_state=42),
                       X=pd.concat([X_train, X_test], axis='index'),
                       y=np.concatenate([y_train, y_test]),
                       param_name='n_estimators', param_range=range(1, 100, 2),
                       scoring='accuracy', cv=3,
                       ax=ax)

# %%
rf_xg29 = xgb.XGBClassifier(random_state=42, n_estimators=29)

# %%
rf_xg29.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=29, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=42, ...)

# %%
rf_xg29.score(X_test, y_test)
# Out:
# 0.7591160220994475

# %% [markdown]
# ## XGBoost
#
# #### Creating an XGBoost Model

# %%
# %matplotlib inline

# Visualization 
import dtreeviz
import matplotlib.pyplot as plt
# Feature Engineering
from feature_engine import encoding, imputation
# Numerical Manipulation
import numpy as np
# Data Manipulation
import pandas as pd

# %%
# Machine Learning Libraries

from sklearn import base, compose, datasets, ensemble, \
metrics, model_selection, pipeline, preprocessing, tree

# %%
# Scikit Plotting
import scikitplot
# Extreme Gradient Boosting
import xgboost as xgb
# Sensical Visualizer & Classifier
import yellowbrick.model_selection as ms
from yellowbrick import classifier

# %%
# Retrieving Data

import urllib
import zipfile

# %%
url = 'https://github.com/mattharrison/datasets/raw/master/data/'\
'kaggle-survey-2018.zip'
fname = 'kaggle-survey-2018.zip'
member_name = 'multipleChoiceResponses.csv'

# %%
# Function Extration
def extract_zip(src, dst, member_name):
    """Extract a member file from a zip file & read it into pandas
    DataFrame.
    
    Parameters:
        src '(str:)' URL of the zip file to be downloaded and extrated.
        dst 'str': Local file path where the zip file will be written.
        member_name: Name of the member file inside the zip file to be
            read into a DataFrame.
            
    Returns:
        pandas.DataFrame containing the contents of member file.
    """
    url = src
    fname = dst
    fin = urllib.request.urlopen(url)
    data = fin.read()
    with open(dst, mode='wb') as fout:
        fout.write(data)
    with zipfile.ZipFile(dst) as z:
        kag = pd.read_csv(z.open(member_name))
        kag_questions = kag.iloc[0]
        raw = kag.iloc[1:]
        return raw

# %%
raw = extract_zip(url, fname, member_name)
# Out:
# /var/folders/wh/l_q69dcj75z0c82jy8ry71f40000gn/T/ipykernel_22970/3680407660.py:22: DtypeWarning: Columns (0,2,8,10,21,23,24,25,26,27,28,44,56,64,83,85,87,107,109,123,125,150,157,172,174,194,210,218,219,223,246,249,262,264,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,304,306,325,326,329,341,368,371,384,385,389,390,391,393,394) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
## Create raw X and raw y
kag_X, kag_y = get_rawX_y(raw, 'Q6')

# %%
## Split data    
kag_X_train, kag_X_test, kag_y_train, kag_y_test = \
    model_selection.train_test_split(
        kag_X, kag_y, test_size=.3, random_state=42, stratify=kag_y)

# %%
## Transform X with pipeline
X_train = kag_pl.fit_transform(kag_X_train)
X_test = kag_pl.transform(kag_X_test)

# %%
## Transform y with label encoder
label_encoder = preprocessing.LabelEncoder()
label_encoder.fit(kag_y_train)
y_train = label_encoder.transform(kag_y_train)
y_test = label_encoder.transform(kag_y_test)

# %%
# Combined Data for cross validation/etc
X = pd.concat([X_train, X_test], axis='index')
y = pd.Series([*y_train, *y_test], index=X.index)

# %% [markdown]
# #### A Boosted Model

# %%
xg_oob = xgb.XGBClassifier()

# %%
xg_oob.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
xg_oob.score(X_test, y_test)
# Out:
# 0.7458563535911602

# %%
# Let's try with depth of 2 and 2 trees

xg2 = xgb.XGBClassifier(max_depth=2, n_estimators=2)

# %%
xg2.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=2, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=2, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
xg2.score(X_test, y_test)
# Out:
# 0.6685082872928176

# %%
# Let's visualize it

viz = dtreeviz.model(xg2, X_train=X, y_train=y, target_name='Job',
                     feature_names=list(X_train.columns),
                     class_names=['DS', 'SE'], tree_index=0)

# %%
viz.view(depth_range_to_display=[0, 2])

# %% [markdown]
# #### Understanding the Output of the Trees

# %%
my_dot_export(xg2, num_trees=0, filename='/Users/isisromero/Desktop/img_XGB/stump_xg.dot', title='First Tree')

# %%
xgb.plot_tree(xg2, num_trees=0)
# Out:
# <Axes: >

# %%
# Predicts 1 - Software engineer

se7894 = pd.DataFrame({'age': {7894: 22},
                       'education': {7894:16.0},
                       'years_exp': {7894: 1.0},
                       'compensation': {7894: 0},
                       'python': {7894:1},
                       'r':{7894: 0},
                       'sql':{7894: 0},
                       'Q1_Male':{7894: 1},
                       'Q1_Female': {7894: 0},
                       'Q1_Prefer not to say': {7894: 0},
                       'Q1_Prefer to self-describe': {7894: 0},
                       'Q3_United States of America': {7894: 0},
                       'Q3_India': {7894: 1},
                       'Q3_China': {7894: 0},
                       'major_cs': {7894: 0},
                       'major_other': {7894: 0},
                       'major_eng': {7894: 0},
                       'major_stat': {7894: 0}})

# %%
xg2.predict_proba(se7894)
# Out:
# array([[0.4986236, 0.5013764]], dtype=float32)

# %%
xg2.predict(pd.DataFrame(se7894))
# Out:
# array([1])

# %%
my_dot_export(xg2, num_trees=1, filename='/Users/isisromero/Desktop/img_XGB/stump_xg.dot', title='Second Tree')

# %%
xgb.plot_tree(xg2, num_trees=1)
# Out:
# <Axes: >

# %%
def inv_logit(p):
    return np.exp(p) / (1 + np.exp(p))

# %%
inv_logit(-0.08476+0.0902701)
# Out:
# 0.5013775215147345

# %% [markdown]
# ## Early Stopping
