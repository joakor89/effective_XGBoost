# %% [markdown]
# # Datasets
#
# ### Cleaup & Loading

# %%
# Data Manipulation
import pandas as pd

# URL Library
import urllib.request
import zipfile

# %%
# Retrieving & storage
url = 'https://github.com/mattharrison/datasets/raw/master/data/'\
'kaggle-survey-2018.zip'
fname = 'kaggle-survey-2018.zip'
member_name = 'multipleChoiceResponses.csv'

# %%
# Function Extration
def extract_zip(src, dst, member_name):
    """Extract a member file from a zip file & read it into pandas
    DataFrame.
    
    Parameters:
        src '(str:)' URL of the zip file to be downloaded and extrated.
        dst 'str': Local file path where the zip file will be written.
        member_name: Name of the member file inside the zip file to be
            read into a DataFrame.
            
    Returns:
        pandas.DataFrame containing the contents of member file.
    """
    url = src
    fname = dst
    fin = urllib.request.urlopen(url)
    data = fin.read()
    with open(dst, mode='wb') as fout:
        fout.write(data)
    with zipfile.ZipFile(dst) as z:
        kag = pd.read_csv(z.open(member_name))
        kag_questions = kag.iloc[0]
        raw = kag.iloc[1:]
        return raw

# %%
raw = extract_zip(url, fname, member_name)
# Out:
# /var/folders/wh/l_q69dcj75z0c82jy8ry71f40000gn/T/ipykernel_9868/3680407660.py:22: DtypeWarning: Columns (0,2,8,10,21,23,24,25,26,27,28,44,56,64,83,85,87,107,109,123,125,150,157,172,174,194,210,218,219,223,246,249,262,264,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,304,306,325,326,329,341,368,371,384,385,389,390,391,393,394) have mixed types. Specify dtype option on import or set low_memory=False.
#   kag = pd.read_csv(z.open(member_name))

# %% [markdown]
# ## CleanUp Pipeline

# %%
def tweak_kag(df_: pd.DataFrame) -> pd.DataFrame:
    """
    Tweak the Kaggle survey data and return a new DataFrame.

    This function takes a Pandas DataFrame containing Kaggle 
    survey data as input and returns a new DataFrame. The 
    modifications include extracting and transforming certain 
    columns, renaming columns, and selecting a subset of columns.

    Parameters
    ----------
    df_ : pd.DataFrame
        The input DataFrame containing Kaggle survey data.

    Returns
    -------
    pd.DataFrame
        The new DataFrame with the modified and selected columns.
    """    
    return (df_
            .assign(age=df_.Q2.str.slice(0,2).astype(int),
                    education=df_.Q4.replace({'Master’s degree': 18,
                         'Bachelor’s degree': 16,
                         'Doctoral degree': 20,
'Some college/university study without earning a bachelor’s degree': 13,
                         'Professional degree': 19,
                         'I prefer not to answer': None,
                         'No formal education past high school': 12}),
                    major=(df_.Q5
                              .pipe(topn, n=3)
                              .replace({
                        'Computer science (software engineering, etc.)': 'cs',
                        'Engineering (non-computer focused)': 'eng',
                        'Mathematics or statistics': 'stat'})
                         ),
                    years_exp=(df_.Q8.str.replace('+','', regex=False)
                           .str.split('-', expand=True)
                           .iloc[:,0]
                           .astype(float)),
                    compensation=(df_.Q9.str.replace('+','', regex=False)
                           .str.replace(',','', regex=False)
                           .str.replace('500000', '500', regex=False)
  .str.replace('I do not wish to disclose my approximate yearly compensation',
             '0', regex=False)
                           .str.split('-', expand=True)
                           .iloc[:,0]
                           .fillna(0)
                           .astype(int)
                           .mul(1_000)
                                    ),
                    python=df_.Q16_Part_1.fillna(0).replace('Python', 1),
                    r=df_.Q16_Part_2.fillna(0).replace('R', 1),
                    sql=df_.Q16_Part_3.fillna(0).replace('SQL', 1)
               )#assign
        .rename(columns=lambda col:col.replace(' ', '_'))
        .loc[:, 'Q1,Q3,age,education,major,years_exp,compensation,'
                'python,r,sql'.split(',')]   
       )

# %%
def topn(ser, n=5, default='other'):
    counts = ser.value_counts()
    return ser.where(ser.isin(counts.index[:n]), default)

# %%
from feature_engine import encoding, imputation
from sklearn import base, pipeline
# Out:
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
class TweakKagTransformer(base.BaseEstimator, base.TransformerMixin):
    
    def __init__(self, ycol=None):
        self.ycol = ycol
        
    def transform(self, X):
        return tweak_kag(X)
    
    def fit(self, X, y=None):
        return self

# %%
def get_rawX_y(df, y_col):
    raw = (df
           .query('Q3.isin(["United States of America", "China", "India"]) '
              'and Q6.isin(["Data Scientist", "Software Engineer"])')
    )
    return raw.drop(columns=[y_col]), raw[y_col]

# %%
# Create Pipeline
kag_pl = pipeline.Pipeline(
    [('tweak', TweakKagTransformer()),
     ('cat', encoding.OneHotEncoder(top_categories=5, drop_last=True, variables=['Q1', 'Q3', 'major'])),
     ('num_impute', imputation.MeanMedianImputer(imputation_method='median', variables=['education', 'years_exp']))]
)

# %%
from sklearn import model_selection

# %%
kag_X, kag_y = get_rawX_y(raw, 'Q6')

kag_X_train, kag_X_test, kag_y_train, kag_y_test = \
model_selection.train_test_split(
    kag_X, kag_y, test_size=.3, random_state=42, stratify=kag_y)

# %%
X_train = kag_pl.fit_transform(kag_X_train, kag_y_train)

X_test = kag_pl.transform(kag_X_test)

# %%
print(X_train)
# Out:
#        age  education  years_exp  compensation  python  r  sql  Q1_Male  \
# 587     25       18.0        4.0             0       1  0    1        1
# 3065    22       16.0        1.0         10000       1  0    0        1
# 8435    22       18.0        1.0             0       1  0    0        1
# 3110    40       20.0        3.0        125000       1  0    1        0
# 16372   45       12.0        5.0        100000       1  0    1        1
# ...    ...        ...        ...           ...     ... ..  ...      ...
# 16608   25       16.0        2.0         10000       0  0    1        1
# 7325    18       16.0        1.0         30000       1  0    1        1
# 21810   18       16.0        2.0             0       0  0    0        1
# 4917    25       18.0        1.0        100000       1  0    1        1
# 639     25       18.0        1.0         10000       1  0    0        0
#
#        Q1_Female  Q1_Prefer not to say  Q1_Prefer to self-describe  \
# 587            0                     0                           0
# 3065           0                     0                           0
# 8435           0                     0                           0
# 3110           1                     0                           0
# 16372          0                     0                           0
# ...          ...                   ...                         ...
# 16608          0                     0                           0
# 7325           0                     0                           0
# 21810          0                     0                           0
# 4917           0                     0                           0
# 639            1                     0                           0
#
#        Q3_United States of America  Q3_India  Q3_China  major_cs  major_other  \
# 587                              0         1         0         0            1
# 3065                             0         1         0         1            0
# 8435                             0         1         0         0            1
# 3110                             1         0         0         0            1
# 16372                            1         0         0         0            1
# ...                            ...       ...       ...       ...          ...
# 16608                            0         1         0         1            0
# 7325                             1         0         0         1            0
# 21810                            0         1         0         1            0
# 4917                             1         0         0         0            0
# 639                              0         1         0         1            0
#
#        major_eng  major_stat
# 587            0           0
# 3065           0           0
# 8435           0           0
# 3110           0           0
# 16372          0           0
# ...          ...         ...
# 16608          0           0
# 7325           0           0
# 21810          0           0
# 4917           0           1
# 639            0           0
#
# [2110 rows x 18 columns]

# %%
kag_y_train
# Out:
# 587      Software Engineer
# 3065        Data Scientist
# 8435        Data Scientist
# 3110        Data Scientist
# 16372    Software Engineer
#                ...
# 16608    Software Engineer
# 7325     Software Engineer
# 21810       Data Scientist
# 4917        Data Scientist
# 639         Data Scientist
# Name: Q6, Length: 2110, dtype: object

# %% [markdown]
# ## Exploratory Data Analysis

# %%
(X_train
 .assign(data_scientist = kag_y_train == 'Data Scientist')
 .corr(method='spearman')
 .style
 .background_gradient(cmap='RdBu', vmax=1, vmin=-1)
 .set_sticky(axis='index')
)
# Out:
# <style type="text/css">
# #T_eb7e8 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_eb7e8 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# #T_eb7e8_row0_col0, #T_eb7e8_row1_col1, #T_eb7e8_row2_col2, #T_eb7e8_row3_col3, #T_eb7e8_row4_col4, #T_eb7e8_row5_col5, #T_eb7e8_row6_col6, #T_eb7e8_row7_col7, #T_eb7e8_row8_col8, #T_eb7e8_row9_col9, #T_eb7e8_row10_col10, #T_eb7e8_row11_col11, #T_eb7e8_row12_col12, #T_eb7e8_row13_col13, #T_eb7e8_row14_col14, #T_eb7e8_row15_col15, #T_eb7e8_row16_col16, #T_eb7e8_row17_col17, #T_eb7e8_row18_col18 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_eb7e8_row0_col1, #T_eb7e8_row1_col0 {
#   background-color: #a2cde3;
#   color: #000000;
# }
# #T_eb7e8_row0_col2, #T_eb7e8_row2_col0 {
#   background-color: #3b88be;
#   color: #f1f1f1;
# }
# #T_eb7e8_row0_col3, #T_eb7e8_row3_col0 {
#   background-color: #7eb8d7;
#   color: #000000;
# }
# #T_eb7e8_row0_col4, #T_eb7e8_row0_col10, #T_eb7e8_row2_col17, #T_eb7e8_row4_col0, #T_eb7e8_row4_col7, #T_eb7e8_row7_col4, #T_eb7e8_row9_col11, #T_eb7e8_row10_col0, #T_eb7e8_row10_col11, #T_eb7e8_row11_col9, #T_eb7e8_row11_col10, #T_eb7e8_row17_col2 {
#   background-color: #eff3f5;
#   color: #000000;
# }
# #T_eb7e8_row0_col5, #T_eb7e8_row5_col0, #T_eb7e8_row8_col11, #T_eb7e8_row11_col8 {
#   background-color: #deebf2;
#   color: #000000;
# }
# #T_eb7e8_row0_col6, #T_eb7e8_row5_col15, #T_eb7e8_row6_col0, #T_eb7e8_row15_col5 {
#   background-color: #ddebf2;
#   color: #000000;
# }
# #T_eb7e8_row0_col7, #T_eb7e8_row2_col5, #T_eb7e8_row4_col16, #T_eb7e8_row4_col17, #T_eb7e8_row5_col2, #T_eb7e8_row7_col0, #T_eb7e8_row9_col15, #T_eb7e8_row15_col9, #T_eb7e8_row16_col4, #T_eb7e8_row17_col4 {
#   background-color: #f5f6f7;
#   color: #000000;
# }
# #T_eb7e8_row0_col8, #T_eb7e8_row3_col9, #T_eb7e8_row8_col0, #T_eb7e8_row8_col16, #T_eb7e8_row9_col3, #T_eb7e8_row9_col12, #T_eb7e8_row10_col12, #T_eb7e8_row12_col9, #T_eb7e8_row12_col10, #T_eb7e8_row13_col17, #T_eb7e8_row16_col8, #T_eb7e8_row17_col13 {
#   background-color: #f8f2ef;
#   color: #000000;
# }
# #T_eb7e8_row0_col9, #T_eb7e8_row2_col6, #T_eb7e8_row3_col10, #T_eb7e8_row4_col11, #T_eb7e8_row6_col2, #T_eb7e8_row7_col13, #T_eb7e8_row9_col0, #T_eb7e8_row10_col3, #T_eb7e8_row10_col15, #T_eb7e8_row11_col4, #T_eb7e8_row13_col7, #T_eb7e8_row15_col10 {
#   background-color: #edf2f5;
#   color: #000000;
# }
# #T_eb7e8_row0_col11, #T_eb7e8_row11_col0 {
#   background-color: #9bc9e0;
#   color: #000000;
# }
# #T_eb7e8_row0_col12, #T_eb7e8_row12_col0 {
#   background-color: #f6af8e;
#   color: #000000;
# }
# #T_eb7e8_row0_col13, #T_eb7e8_row4_col13, #T_eb7e8_row5_col16, #T_eb7e8_row6_col10, #T_eb7e8_row8_col10, #T_eb7e8_row10_col6, #T_eb7e8_row10_col8, #T_eb7e8_row10_col14, #T_eb7e8_row10_col16, #T_eb7e8_row10_col17, #T_eb7e8_row13_col0, #T_eb7e8_row13_col4, #T_eb7e8_row14_col10, #T_eb7e8_row16_col5, #T_eb7e8_row16_col10, #T_eb7e8_row17_col10 {
#   background-color: #f8f4f2;
#   color: #000000;
# }
# #T_eb7e8_row0_col14, #T_eb7e8_row3_col14, #T_eb7e8_row7_col9, #T_eb7e8_row9_col7, #T_eb7e8_row14_col0, #T_eb7e8_row14_col3 {
#   background-color: #fcd5bf;
#   color: #000000;
# }
# #T_eb7e8_row0_col15, #T_eb7e8_row3_col6, #T_eb7e8_row6_col3, #T_eb7e8_row15_col0, #T_eb7e8_row15_col18, #T_eb7e8_row18_col15 {
#   background-color: #d1e5f0;
#   color: #000000;
# }
# #T_eb7e8_row0_col16, #T_eb7e8_row1_col10, #T_eb7e8_row2_col16, #T_eb7e8_row3_col7, #T_eb7e8_row3_col8, #T_eb7e8_row5_col9, #T_eb7e8_row7_col3, #T_eb7e8_row8_col3, #T_eb7e8_row9_col5, #T_eb7e8_row10_col1, #T_eb7e8_row16_col0, #T_eb7e8_row16_col2 {
#   background-color: #f6f7f7;
#   color: #000000;
# }
# #T_eb7e8_row0_col17, #T_eb7e8_row0_col18, #T_eb7e8_row6_col17, #T_eb7e8_row17_col0, #T_eb7e8_row17_col6, #T_eb7e8_row18_col0 {
#   background-color: #e9f0f4;
#   color: #000000;
# }
# #T_eb7e8_row1_col2, #T_eb7e8_row2_col1, #T_eb7e8_row4_col15, #T_eb7e8_row15_col4 {
#   background-color: #e4eef4;
#   color: #000000;
# }
# #T_eb7e8_row1_col3, #T_eb7e8_row3_col1, #T_eb7e8_row3_col15, #T_eb7e8_row12_col14, #T_eb7e8_row14_col12, #T_eb7e8_row15_col3 {
#   background-color: #c5dfec;
#   color: #000000;
# }
# #T_eb7e8_row1_col4, #T_eb7e8_row1_col9, #T_eb7e8_row4_col1, #T_eb7e8_row9_col1 {
#   background-color: #ecf2f5;
#   color: #000000;
# }
# #T_eb7e8_row1_col5, #T_eb7e8_row5_col1, #T_eb7e8_row11_col17, #T_eb7e8_row17_col11 {
#   background-color: #dae9f2;
#   color: #000000;
# }
# #T_eb7e8_row1_col6, #T_eb7e8_row1_col8, #T_eb7e8_row5_col8, #T_eb7e8_row6_col1, #T_eb7e8_row7_col14, #T_eb7e8_row8_col1, #T_eb7e8_row8_col5, #T_eb7e8_row8_col15, #T_eb7e8_row13_col14, #T_eb7e8_row14_col7, #T_eb7e8_row14_col13, #T_eb7e8_row15_col8 {
#   background-color: #eaf1f5;
#   color: #000000;
# }
# #T_eb7e8_row1_col7, #T_eb7e8_row7_col1 {
#   background-color: #f9ebe3;
#   color: #000000;
# }
# #T_eb7e8_row1_col11, #T_eb7e8_row1_col18, #T_eb7e8_row11_col1, #T_eb7e8_row11_col15, #T_eb7e8_row15_col11, #T_eb7e8_row18_col1 {
#   background-color: #bbdaea;
#   color: #000000;
# }
# #T_eb7e8_row1_col12, #T_eb7e8_row11_col14, #T_eb7e8_row12_col1, #T_eb7e8_row14_col11 {
#   background-color: #fac8af;
#   color: #000000;
# }
# #T_eb7e8_row1_col13, #T_eb7e8_row1_col16, #T_eb7e8_row4_col9, #T_eb7e8_row4_col10, #T_eb7e8_row5_col10, #T_eb7e8_row9_col4, #T_eb7e8_row9_col10, #T_eb7e8_row10_col4, #T_eb7e8_row10_col5, #T_eb7e8_row10_col9, #T_eb7e8_row13_col1, #T_eb7e8_row16_col1 {
#   background-color: #f7f6f6;
#   color: #000000;
# }
# #T_eb7e8_row1_col14, #T_eb7e8_row14_col1 {
#   background-color: #fcd7c2;
#   color: #000000;
# }
# #T_eb7e8_row1_col15, #T_eb7e8_row3_col4, #T_eb7e8_row3_col5, #T_eb7e8_row4_col3, #T_eb7e8_row5_col3, #T_eb7e8_row6_col11, #T_eb7e8_row11_col6, #T_eb7e8_row15_col1 {
#   background-color: #d7e8f1;
#   color: #000000;
# }
# #T_eb7e8_row1_col17, #T_eb7e8_row2_col11, #T_eb7e8_row4_col18, #T_eb7e8_row6_col18, #T_eb7e8_row11_col2, #T_eb7e8_row17_col1, #T_eb7e8_row18_col4, #T_eb7e8_row18_col6 {
#   background-color: #e0ecf3;
#   color: #000000;
# }
# #T_eb7e8_row2_col3, #T_eb7e8_row3_col2 {
#   background-color: #c0dceb;
#   color: #000000;
# }
# #T_eb7e8_row2_col4, #T_eb7e8_row3_col16, #T_eb7e8_row4_col2, #T_eb7e8_row16_col3 {
#   background-color: #f9efe9;
#   color: #000000;
# }
# #T_eb7e8_row2_col7, #T_eb7e8_row7_col2, #T_eb7e8_row12_col16, #T_eb7e8_row16_col12 {
#   background-color: #e7f0f4;
#   color: #000000;
# }
# #T_eb7e8_row2_col8, #T_eb7e8_row4_col14, #T_eb7e8_row7_col10, #T_eb7e8_row8_col2, #T_eb7e8_row10_col7, #T_eb7e8_row14_col4 {
#   background-color: #fae9df;
#   color: #000000;
# }
# #T_eb7e8_row2_col9, #T_eb7e8_row6_col8, #T_eb7e8_row8_col6, #T_eb7e8_row8_col17, #T_eb7e8_row9_col2, #T_eb7e8_row17_col8 {
#   background-color: #f0f4f6;
#   color: #000000;
# }
# #T_eb7e8_row2_col10, #T_eb7e8_row2_col15, #T_eb7e8_row9_col17, #T_eb7e8_row9_col18, #T_eb7e8_row10_col2, #T_eb7e8_row10_col18, #T_eb7e8_row15_col2, #T_eb7e8_row16_col18, #T_eb7e8_row17_col9, #T_eb7e8_row18_col9, #T_eb7e8_row18_col10, #T_eb7e8_row18_col16 {
#   background-color: #f3f5f6;
#   color: #000000;
# }
# #T_eb7e8_row2_col12, #T_eb7e8_row5_col13, #T_eb7e8_row12_col2, #T_eb7e8_row12_col17, #T_eb7e8_row13_col5, #T_eb7e8_row17_col12 {
#   background-color: #fbe4d6;
#   color: #000000;
# }
# #T_eb7e8_row2_col13, #T_eb7e8_row7_col16, #T_eb7e8_row9_col16, #T_eb7e8_row13_col2, #T_eb7e8_row16_col7, #T_eb7e8_row16_col9 {
#   background-color: #f2f5f6;
#   color: #000000;
# }
# #T_eb7e8_row2_col14, #T_eb7e8_row4_col8, #T_eb7e8_row4_col12, #T_eb7e8_row7_col17, #T_eb7e8_row8_col4, #T_eb7e8_row8_col9, #T_eb7e8_row9_col8, #T_eb7e8_row9_col14, #T_eb7e8_row12_col4, #T_eb7e8_row14_col2, #T_eb7e8_row14_col9, #T_eb7e8_row17_col7 {
#   background-color: #f8f1ed;
#   color: #000000;
# }
# #T_eb7e8_row2_col18, #T_eb7e8_row7_col11, #T_eb7e8_row11_col7, #T_eb7e8_row18_col2 {
#   background-color: #fbe3d4;
#   color: #000000;
# }
# #T_eb7e8_row3_col11, #T_eb7e8_row11_col3 {
#   background-color: #408fc1;
#   color: #f1f1f1;
# }
# #T_eb7e8_row3_col12, #T_eb7e8_row12_col3 {
#   background-color: #dc6e57;
#   color: #f1f1f1;
# }
# #T_eb7e8_row3_col13, #T_eb7e8_row13_col3 {
#   background-color: #fbe6da;
#   color: #000000;
# }
# #T_eb7e8_row3_col17, #T_eb7e8_r

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 4))
(X_train
 .assign(data_scientist = kag_y_train)
 .groupby('r')
 .data_scientist
 .value_counts()
 .unstack()
 .plot.bar(ax=ax)
)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 4))
(pd.crosstab(index=X_train['major_cs'],
             columns=kag_y)
 .plot.bar(ax=ax)
)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 4))
(X_train
 .plot.scatter(x='years_exp', y='compensation', alpha=.3, ax=ax, c='purple')
)

plt.show()

# %% [markdown]
# #### adding Jitter

# %%
import seaborn.objects as so

# %%
fig = plt.figure(figsize=(8, 4))
(so
 .Plot(X_train.assign(title=kag_y_train), x='years_exp', y='compensation', color='title')
 .add(so.Dots(alpha=.3, pointsize=2), so.Jitter(x=.5, y=10_000))
 .add(so.Line(), so.PolyFit())
 .on(fig)
 .plot()
)

# %% [markdown]
# #### Adjusted Visualization

# %%
fig = plt.figure(figsize=(8, 4))
(so
 .Plot(X_train
       # .query('compensation < 200_000 and years_exp < 16')
       .assign(
           title=kag_y_train,
           country=(X_train
                    .loc[:, 'Q3_United States of America': 'Q3_China']
                    .idxmax(axis='columns')
                   )
       ), x='years_exp', y='compensation', color='title')
 .facet('country')
 .add(so.Dots(alpha=.01, pointsize=2, color='grey'), so.Jitter(x=.5, y=10_000), col=None)
 .add(so.Dots(alpha=.5, pointsize=1.5), so.Jitter(x=.5, y=10_000))
 .add(so.Line(pointsize=1), so.PolyFit(order=2))
 .scale(x=so.Continuous().tick(at=[0, 1, 2, 3, 4, 5]))
 .limit(y=(-10_000, 200_000), x=(-1, 6))
 .on(fig)
 .plot()
 )

# %% [markdown]
# ## Tree Creation

# %%
# Numerical Manipualtion
import numpy as np
import numpy.random as rn

# %%
pos_center = 12
pos_count = 100
neg_center = 7
neg_count = 1000

rs = rn.RandomState(rn.MT19937(rn.SeedSequence(42)))
gini = pd.DataFrame({'value':
                      np.append((pos_center) + rs.randn(pos_count),
                               (neg_center) + rs.randn(neg_count)),
                      'label':
                      ['pos']* pos_count + ['neg'] * neg_count})

# %%
fig, ax = plt.subplots(figsize=(8, 4))
_ = (gini
     .groupby('label')
     [['value']]
     .plot.hist(bins=30, alpha=.5, ax=ax, edgecolor='black')
    )
ax.legend(['Negative', 'Positive'])

plt.show()

# %%
def calc_gini(df, val_col, label_col, pos_val, split_point,
             debug=False):
    """
    This function calculates the Gini impurity of a dataset. Gini Impurity
    is a measure of the probability of a random sample being classified
    incorectly when a feature is sued to split the data. The lower the 
    impurity, the better the split.
    
    Parameters:
    df(pd.DataFrame): The dataframe containing the data
    val_col (str): the column name of the feature used to split the data
    label_col (str): The column name of the target variable
    pos_val (str or int): The value of the target variable that represents
        the positive class
    split_point (float): The threshold used to split the data.
    debug (bool): optional, when set to True, prints the calculated Gini
        impurities and the final weighted aveerage
        
    Returns:
    float: The weighted average of Gini impurity for the positive and
        negative subsets.
    """
    ge_split = df[val_col] >= split_point
    eq_pos = df[label_col] == pos_val
    tp = df[ge_split & eq_pos].shape[0]
    fp = df[ge_split & ~eq_pos].shape[0]
    tn = df[~ge_split & ~eq_pos].shape[0]
    fn = df[~ge_split & eq_pos].shape[0]
    pos_size = tp+fp
    neg_size = tn+fn
    total_size = len(df)
    if pos_size == 0:
        gini_pos = 0
    else:
        gini_pos = 1 - (tp/pos_size)**2 - (fp/pos_size)**2
    if neg_size == 0:
        gini_neg = 0
    else:
        gini_neg = 1 - (tn/neg_size)**2 - (fn/neg_size)**2
    weighted_avg = gini_pos * (pos_size/total_size) * \
    gini_neg * (neg_size/total_size)
    if debug:
        print(f'{gini_pos=:3} {gini_neg=:.3} {weighted_avg=:3}')
    return weighted_avg

# %%
calc_gini(gini, val_col='value', label_col='label', pos_val='pos', split_point=9.24, debug=True)
# Out:
# gini_pos=0.21708826063121614 gini_neg=0.00202 weighted_avg=4.050598243782082e-05
# 4.050598243782082e-05

# %%
values = np.arange(5, 15, .1)
ginis = []
for v in values:
    ginis.append(calc_gini(gini, val_col='value', label_col='label',
                          pos_val='pos', split_point=v))

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(values, ginis)
ax.set_title('Gini Coefficient')
ax.set_ylabel('Gini Coefficient')
ax.set_xlabel('Split Point')

plt.show()

# %%
pd.Series(ginis, index=values).loc[9.5:10.5]
# Out:
# 9.6     0.000022
# 9.7     0.000016
# 9.8     0.000013
# 9.9     0.000007
# 10.0    0.000010
# 10.1    0.000000
# 10.2    0.000000
# 10.3    0.000000
# 10.4    0.000000
# 10.5    0.000000
# dtype: float64

# %%
print(pd.DataFrame({'gini':ginis, 'split':values})
      .query('gini <= gini.min()'))
# Out:
#     gini  split
# 0    0.0    5.0
# 1    0.0    5.1
# 2    0.0    5.2
# 3    0.0    5.3
# 4    0.0    5.4
# ..   ...    ...
# 95   0.0   14.5
# 96   0.0   14.6
# 97   0.0   14.7
# 98   0.0   14.8
# 99   0.0   14.9
#
# [90 rows x 2 columns]

# %% [markdown]
# #### Coeffiecients in Trees

# %%
from sklearn import tree
stump = tree.DecisionTreeClassifier(max_depth=1)
stump.fit(gini[['value']], gini.label)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
fig, ax = plt.subplots(figsize=(8, 4))
tree.plot_tree(stump, feature_names=['value'],
               filled=True, 
               class_names=stump.classes_,
               ax=ax)
# Out:
# [Text(0.5, 0.75, 'value <= 9.708\ngini = 0.165\nsamples = 1100\nvalue = [1000, 100]\nclass = neg'),
#  Text(0.25, 0.25, 'gini = 0.002\nsamples = 999\nvalue = [998, 1]\nclass = neg'),
#  Text(0.75, 0.25, 'gini = 0.039\nsamples = 101\nvalue = [2, 99]\nclass = pos')]

# %%
gini_pos = 0.039
gini_neg = 0.002
pos_size = 101
neg_size = 999
total_size = pos_size + neg_size
weighted_avg = gini_pos * (pos_size/total_size) + \
gini_neg * (neg_size/total_size)

# %%
print(weighted_avg)
# Out:
# 0.005397272727272727

# %%
import xgboost as xgb

# %%
# from graphviz import Digraph

# dot = Digraph(comment='The Round Table')
# dot.node('A', 'King Arthur')
# dot.node('B', 'Sir Bedevere the Wise')
# dot.node('L', 'Sir Lancelot the Brave')

# dot.edges(['AB', 'AL'])
# dot.edge('B', 'L', constraint='false')
# print(dot.source)

# %%
xg_stump = xgb.XGBClassifier(n_estimators=1, max_depth=1)
xg_stump.fit(gini[['value']], (gini.label== 'pos'))
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=1, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=1, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
import os
os.environ["PATH"] += os.pathsep + '/Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/bin'


xgb.plot_tree(xg_stump, num_trees=0)

plt.show()

# %%
import subprocess

def my_dot_export(xg, num_trees, filename, title='', direction='TB'):
    """Exports a specified number of trees from an XGBoost model as a graph 
    visualization in dot and png formats.

    Args:
        xg: An XGBoost model.
        num_trees: The number of tree to export.
        filename: The name of the file to save the exported visualization.
        title: The title to display on the graph visualization (optional).
        direction: The direction to lay out the graph, either 'TB' (top to 
            bottom) or 'LR' (left to right) (optional).
    """
    res = xgb.to_graphviz(xg, num_trees=num_trees)
    content = f'''    node [fontname = "Helvetica"];
    edge [fontname = "Helvetica Thin"];
    label = "{title}"
    fontname = "Helvetica"
    '''
    out = res.source.replace('graph [ rankdir=TB ]', 
                             f'graph [ rankdir={direction} ];\n {content}')
    # dot -Gdpi=300 -Tpng -ocourseflow.png courseflow.dot 
    dot_filename = filename
    with open(dot_filename, 'w') as fout:
        fout.write(out)
    png_filename = dot_filename.replace('.dot', '.png')
    subprocess.run(f'dot -Gdpi=300 -Tpng -o{png_filename} {dot_filename}'.split())

# %%
my_dot_export(xg_stump, num_trees=0, filename='/Users/isisromero/Desktop/img_XGB/stump_xg.dot', title='A demo stump')

# %% [markdown]
# #### Another Visualization Tool

# %%
import dtreeviz
viz = dtreeviz.model(xg_stump, X_train=gini[['value']], 
                     y_train=gini.label=='pos',
    target_name='positive',
    feature_names=['value'], class_names=['negative', 'positive'],
    tree_index=0)
viz.view()

# %% [markdown]
# ## Stumps on Real Data

# %%
stump_dt = tree.DecisionTreeClassifier(max_depth=1)
X_train = kag_pl.fit_transform(kag_X_train)
stump_dt.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
fig, ax = plt.subplots(figsize=(8, 4))
features = list(c for c in X_train.columns)
tree.plot_tree(stump_dt, feature_names=features,
               filled=True,
               class_names=stump_dt.classes_,
               ax=ax)
# Out:
# [Text(0.5, 0.75, 'r <= 0.5\ngini = 0.496\nsamples = 2110\nvalue = [1153, 957]\nclass = Data Scientist'),
#  Text(0.25, 0.25, 'gini = 0.493\nsamples = 1484\nvalue = [653, 831]\nclass = Software Engineer'),
#  Text(0.75, 0.25, 'gini = 0.322\nsamples = 626\nvalue = [500, 126]\nclass = Data Scientist')]

# %%
X_test = kag_pl.transform(kag_X_test)

# %%
stump_dt.score(X_test, kag_y_test)
# Out:
# 0.6243093922651933

# %% [markdown]
# #### The Dummy Classifier

# %%
from sklearn import dummy

# %%
dummy_model = dummy.DummyClassifier()

# %%
dummy_model.fit(X_train, kag_y_train)
# Out:
# DummyClassifier()

# %%
dummy_model.score(X_test, kag_y_test)
# Out:
# 0.5458563535911602

# %%
import xgboost as xgb

# %%
kag_stump = xgb.XGBClassifier(n_estimators=1, max_depth=1)
kag_stump.fit(X_train, kag_y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 2
#       1 kag_stump = xgb.XGBClassifier(n_estimators=1, max_depth=1)
# ----> 2 kag_stump.fit(X_train, kag_y_train)
#
# File ~/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/xgboost/sklearn.py:1440, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1435     expected_classes = np.arange(self.n_classes_)
#    1436 if (
#    1437     self.classes_.shape != expected_classes.shape
#    1438     or not (self.classes_ == expected_classes).all()
#    1439 ):
# -> 1440     raise ValueError(
#    1441         f"Invalid classes inferred from unique values of `y`.  "
#    1442         f"Expected: {expected_classes}, got {self.classes_}"
#    1443     )
#    1445 params = self.get_xgb_params()
#    1447 if callable(self.objective):
#
# ValueError: Invalid classes inferred from unique values of `y`.  Expected: [0 1], got ['Data Scientist' 'Software Engineer']

# %%
print(kag_y_train)
# Out:
# 587      Software Engineer
# 3065        Data Scientist
# 8435        Data Scientist
# 3110        Data Scientist
# 16372    Software Engineer
#                ...
# 16608    Software Engineer
# 7325     Software Engineer
# 21810       Data Scientist
# 4917        Data Scientist
# 639         Data Scientist
# Name: Q6, Length: 2110, dtype: object

# %%
print(kag_y_train == 'Software Engineer')
# Out:
# 587       True
# 3065     False
# 8435     False
# 3110     False
# 16372     True
#          ...
# 16608     True
# 7325      True
# 21810    False
# 4917     False
# 639      False
# Name: Q6, Length: 2110, dtype: bool

# %% [markdown]
# #### Using Label Encoder

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
y_train = label_encoder.fit_transform(kag_y_train)
y_test = label_encoder.transform(kag_y_test)

# %%
y_test[:5]
# Out:
# array([1, 0, 0, 1, 1])

# %%
label_encoder.classes_
# Out:
# array(['Data Scientist', 'Software Engineer'], dtype=object)

# %%
# Inverse Tranformation Procedure
label_encoder.inverse_transform([0, 1])
# Out:
# array(['Data Scientist', 'Software Engineer'], dtype=object)

# %%
kag_stump = xgb.XGBClassifier(n_estimators=1, max_depth=1)
kag_stump.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=1, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=1, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
kag_stump.score(X_test, y_test)
# Out:
# 0.6243093922651933

# %%
my_dot_export(kag_stump, num_trees=0, filename='/Users/isisromero/Desktop/img_XGB/stump_xg.dot',
             title='XGBoost Stump')

# %%
kag_stump.classes_
# Out:
# array([0, 1])

# %%
def inv_logit(p: float) -> float:
    """
    Compute the inverse logit function of a given value.

    The inverse logit function is defined as:
        f(p) = exp(p) / (1 + exp(p))

    Parameters
    ----------
    p : float
        The input value to the inverse logit function.

    Returns
    -------
    float
        The output of the inverse logit function.
    """
    return np.exp(p) / (1 + np.exp(p))

# %%
inv_logit(.07117741922)
# Out:
# 0.5177868460919524

# %%
inv_logit(-.3592)
# Out:
# 0.41115323716754393

# %%
fig, ax = plt.subplots(figsize=(8, 4))
vals = np.linspace(-7, 7)
ax.plot(vals, inv_logit(vals))
ax.annotate('Crossover point', (0,.5), (-5,.8), arrowprops={'color':'k'})
ax.annotate('Predict Positive', (5,.6), (1,.6), va='center', arrowprops={'color':'k'})
ax.annotate('Predict Negative', (-5,.4), (-3,.4), va='center', arrowprops={'color':'k'})
# Out:
# Text(-3, 0.4, 'Predict Negative')

# %% [markdown]
# ## Model Complexity & Hyperparameters
#
# #### Underfit Model

# %%
underfit = tree.DecisionTreeClassifier(max_depth=1)
X_train = kag_pl.fit_transform(kag_X_train)

# %%
underfit.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
underfit.score(X_test, kag_y_test)
# Out:
# 0.6243093922651933

# %% [markdown]
# #### Overfitting with Decision Trees

# %%
hi_variance = tree.DecisionTreeClassifier(max_depth=None)
X_train = kag_pl.fit_transform(kag_X_train)

# %%
hi_variance.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier()

# %%
hi_variance.score(X_test, kag_y_test)
# Out:
# 0.6729281767955801

# %%
fig, ax = plt.subplots(figsize=(8, 4))
features = list(c for c in X_train.columns)
tree.plot_tree(hi_variance, feature_names=features, filled=True)
# Out:
# [Text(0.660478212084673, 0.9761904761904762, 'r <= 0.5\ngini = 0.496\nsamples = 2110\nvalue = [1153, 957]'),
#  Text(0.4021260383172562, 0.9285714285714286, 'major_cs <= 0.5\ngini = 0.493\nsamples = 1484\nvalue = [653, 831]'),
#  Text(0.19894828510182208, 0.8809523809523809, 'Q3_United States of America <= 0.5\ngini = 0.49\nsamples = 718\nvalue = [410, 308]'),
#  Text(0.08331993569131833, 0.8333333333333334, 'years_exp <= 0.5\ngini = 0.491\nsamples = 322\nvalue = [140, 182]'),
#  Text(0.02615219721329046, 0.7857142857142857, 'education <= 17.0\ngini = 0.463\nsamples = 74\nvalue = [47, 27]'),
#  Text(0.01972132904608789, 0.7380952380952381, 'age <= 27.5\ngini = 0.499\nsamples = 40\nvalue = [21, 19]'),
#  Text(0.0180064308681672, 0.6904761904761905, 'major_stat <= 0.5\ngini = 0.5\nsamples = 38\nvalue = [19, 19]'),
#  Text(0.016291532690246517, 0.6428571428571429, 'compensation <= 55000.0\ngini = 0.498\nsamples = 36\nvalue = [17, 19]'),
#  Text(0.01457663451232583, 0.5952380952380952, 'compensation <= 15000.0\ngini = 0.5\nsamples = 35\nvalue = [17, 18]'),
#  Text(0.012861736334405145, 0.5476190476190477, 'python <= 0.5\ngini = 0.496\nsamples = 33\nvalue = [15, 18]'),
#  Text(0.006859592711682743, 0.5, 'age <= 23.5\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.0034297963558413717, 0.4523809523809524, 'Q1_Male <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.0017148981779206859, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.005144694533762058, 0.40476190476190477, 'age <= 20.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.0034297963558413717, 0.35714285714285715, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.006859592711682743, 0.35714285714285715, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.010289389067524116, 0.4523809523809524, 'compensation <= 5000.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.00857449088960343, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.012004287245444802, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.018863879957127544, 0.5, 'Q1_Female <= 0.5\ngini = 0.5\nsamples = 22\nvalue = [11, 11]'),
#  Text(0.01714898177920686, 0.4523809523809524, 'Q3_China <= 0.5\ngini = 0.495\nsamples = 20\nvalue = [9, 11]'),
#  Text(0.015434083601286173, 0.40476190476190477, 'compensation <= 5000.0\ngini = 0.488\nsamples = 19\nvalue = [8, 11]'),
#  Text(0.011146838156484458, 0.35714285714285715, 'age <= 20.0\ngini = 0.469\nsamples = 16\nvalue = [6, 10]'),
#  Text(0.0077170418006430866, 0.30952380952380953, 'education <= 14.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.006002143622722401, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.009431939978563772, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.01457663451232583, 0.30952380952380953, 'age <= 23.5\ngini = 0.426\nsamples = 13\nvalue = [4, 9]'),
#  Text(0.012861736334405145, 0.2619047619047619, 'sql <= 0.5\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.009431939978563772, 0.21428571428571427, 'major_eng <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.0077170418006430866, 0.16666666666666666, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.011146838156484458, 0.16666666666666666, 'gini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.016291532690246517, 0.21428571428571427, 'major_other <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.01457663451232583, 0.16666666666666666, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.0180064308681672, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.016291532690246517, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01972132904608789, 0.35714285714285715, 'age <= 20.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.0180064308681672, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.021436227224008574, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.018863879957127544, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.020578778135048232, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.016291532690246517, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.0180064308681672, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01972132904608789, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.021436227224008574, 0.6904761904761905, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.032583065380493034, 0.7380952380952381, 'sql <= 0.5\ngini = 0.36\nsamples = 34\nvalue = [26, 8]'),
#  Text(0.02658092175777063, 0.6904761904761905, 'compensation <= 5000.0\ngini = 0.269\nsamples = 25\nvalue = [21, 4]'),
#  Text(0.02315112540192926, 0.6428571428571429, 'Q3_China <= 0.5\ngini = 0.095\nsamples = 20\nvalue = [19, 1]'),
#  Text(0.021436227224008574, 0.5952380952380952, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.024866023579849947, 0.5952380952380952, 'major_other <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.02315112540192926, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.02658092175777063, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.030010718113612004, 0.6428571428571429, 'age <= 23.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.02829581993569132, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.03172561629153269, 0.5952380952380952, 'Q1_Female <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.030010718113612004, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.033440514469453377, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03858520900321544, 0.6904761904761905, 'compensation <= 5000.0\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.036870310825294746, 0.6428571428571429, 'age <= 20.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.03515541264737406, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03858520900321544, 0.5952380952380952, 'age <= 23.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.036870310825294746, 0.5476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.04030010718113612, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.04030010718113612, 0.6428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.14048767416934618, 0.7857142857142857, 'major_stat <= 0.5\ngini = 0.469\nsamples = 248\nvalue = [93, 155]'),
#  Text(0.10884244372990354, 0.7380952380952381, 'education <= 17.0\ngini = 0.446\nsamples = 220\nvalue = [74, 146]'),
#  Text(0.06586280814576634, 0.6904761904761905, 'years_exp <= 1.5\ngini = 0.38\nsamples = 110\nvalue = [28, 82]'),
#  Text(0.05144694533762058, 0.6428571428571429, 'compensation <= 15000.0\ngini = 0.49\nsamples = 28\nvalue = [12, 16]'),
#  Text(0.049732047159699894, 0.5952380952380952, 'age <= 23.5\ngini = 0.444\nsamples = 24\nvalue = [8, 16]'),
#  Text(0.04372990353697749, 0.5476190476190477, 'python <= 0.5\ngini = 0.36\nsamples = 17\nvalue = [4, 13]'),
#  Text(0.04030010718113612, 0.5, 'age <= 20.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.03858520900321544, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.042015005359056806, 0.4523809523809524, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.04715969989281887, 0.5, 'Q1_Prefer not to say <= 0.5\ngini = 0.245\nsamples = 14\nvalue = [2, 12]'),
#  Text(0.045444801714898175, 0.4523809523809524, 'sql <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.04372990353697749, 0.40476190476190477, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.04715969989281887, 0.40476190476190477, 'major_eng <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.045444801714898175, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.04887459807073955, 0.35714285714285715, 'compensation <= 5000.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.04715969989281887, 0.30952380952380953, 'gini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.050589496248660236, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04887459807073955, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.055734190782422297, 0.5476190476190477, 'compensation <= 5000.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.054019292604501605, 0.5, 'major_other <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.05230439442658092, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.055734190782422297, 0.4523809523809524, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.054019292604501605, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.05744908896034298, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05744908896034298, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.05316184351554126, 0.5952380952380952, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.08027867095391211, 0.6428571428571429, 'age <= 20.0\ngini = 0.314\nsamples = 82\nvalue = [16, 66]'),
#  Text(0.07856377277599143, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0819935691318328, 0.5952380952380952, 'age <= 45.0\ngini = 0.302\nsamples = 81\nvalue = [15, 66]'),
#  Text(0.08027867095391211, 0.5476190476190477, 'years_exp <= 4.5\ngini = 0.289\nsamples = 80\nvalue = [14, 66]'),
#  Text(0.07138263665594856, 0.5, 'age <= 23.5\ngini = 0.357\nsamples = 56\nvalue = [13, 43]'),
#  Text(0.06259378349410503, 0.4523809523809524, 'compensation <= 5000.0\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.06087888531618435, 0.40476190476190477, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.06430868167202572, 0.40476190476190477, 'years_exp <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.06259378349410503, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0660235798499464, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.08017148981779207, 0.4523809523809524, 'compensation <= 45000.0\ngini = 0.402\nsamples = 43\nvalue = [12, 31]'),
#  Text(0.07845659163987138, 0.40476190476190477, 'sql <= 0.5\ngini = 0.387\nsamples = 42\nvalue = [11, 31]'),
#  Text(0.06945337620578779, 0.35714285714285715, 'age <= 32.5\ngini = 0.32\nsamples = 25\nvalue = [5, 20]'),
#  Text(0.0677384780278671, 0.30952380952380953, 'education <= 14.0\ngini = 0.351\nsamples = 22\nvalue = [5, 17]'),
#  Text(0.06430868167202572, 0.2619047619047619, 'Q1_Female <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06259378349410503, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0660235798499464, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07116827438370847, 0.2619047619047619, 'years_exp <= 2.5\ngini = 0.32\nsamples = 20\nvalue = [4, 16]'),
#  Text(0.06945337620578779, 0.21428571428571427, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.07288317256162916, 0.21428571428571427, 'Q3_India <= 0.5\ngini = 0.408\nsamples = 14\nvalue = [4, 10]'),
#  Text(0.07116827438370847, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.07459807073954984, 0.16666666666666666, 'compensation <= 5000.0\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.07031082529474812, 0.11904761904761904, 'age <= 27.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.06688102893890675, 0.07142857142857142, 'years_exp <= 3.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.06516613076098607, 0.023809523809523808, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.06859592711682744, 0.023809523809523808, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.07374062165058949, 0.07142857142857142, 'years_exp <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0720257234726688, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07545551982851018, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07888531618435156, 0.11904761904761904, 'major_eng <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.07717041800643087, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08060021436227224, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.07116827438370847, 0.30952380952380953, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.08745980707395498, 0.35714285714285715, 'python <= 0.5\ngini = 0.457\nsamples = 17\nvalue = [6, 11]'),
#  Text(0.0857449088960343, 0.30952380952380953, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.08917470525187567, 0.30952380952380953, 'compensation <= 15000.0\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.08745980707395498, 0.2619047619047619, 'compensation <= 5000.0\ngini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(0.0857449088960343, 0.21428571428571427, 'Q1_Male <= 0.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.08403001071811361, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08745980707395498, 0.16666666666666666, 'years_exp <= 3.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.0857449088960343, 0.11904761904761904, 'years_exp <= 2.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.08403001071811361, 0.07142857142857142, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.08745980707395498, 0.07142857142857142, 'major_eng <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.0857449088960343, 0.023809523809523808, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08917470525187567, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08917470525187567, 0.11904761904761904, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.08917470525187567, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.09088960342979635, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08188638799571275, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08917470525187567, 0.5, 'compensation <= 25000.0\ngini = 0.08\nsamples = 24\nvalue = [1, 23]'),
#  Text(0.08745980707395498, 0.4523809523809524, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.09088960342979635, 0.4523809523809524, 'Q3_India <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.08917470525187567, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.09260450160771704, 0.40476190476190477, 'python <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.09088960342979635, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09431939978563773, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08370846730975348, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15182207931404074, 0.6904761904761905, 'education <= 19.5\ngini = 0.487\nsamples = 110\nvalue = [46, 64]'),
#  Text(0.1435155412647374, 0.6428571428571429, 'education <= 18.5\ngini = 0.477\nsamples = 102\nvalue = [40, 62]'),
#  Text(0.1354769560557342, 0.5952380952380952, 'sql <= 0.5\ngini = 0.487\nsamples = 93\nvalue = [39, 54]'),
#  Text(0.12454448017148982, 0.5476190476190477, 'compensation <= 15000.0\ngini = 0.461\nsamples = 61\nvalue = [22, 39]'),
#  Text(0.1202572347266881, 0.5, 'years_exp <= 7.5\ngini = 0.495\nsamples = 40\nvalue = [18, 22]'),
#  Text(0.11854233654876742, 0.4523809523809524, 'age <= 32.5\ngini = 0.497\nsamples = 39\nvalue = [18, 21]'),
#  Text(0.11682743837084673, 0.40476190476190477, 'years_exp <= 3.5\ngini = 0.491\nsamples = 37\nvalue = [16, 21]'),
#  Text(0.11103965702036442, 0.35714285714285715, 'age <= 27.5\ngini = 0.477\nsamples = 28\nvalue = [11, 17]'),
#  Text(0.10932475884244373, 0.30952380952380953, 'age <= 23.5\ngini = 0.453\nsamples = 26\nvalue = [9, 17]'),
#  Text(0.09946409431939979, 0.2619047619047619, 'years_exp <= 2.5\ngini = 0.496\nsamples = 11\nvalue = [5, 6]'),
#  Text(0.0977491961414791, 0.21428571428571427, 'major_eng <= 0.5\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.09431939978563773, 0.16666666666666666, 'python <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.09260450160771704, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09603429796355842, 0.11904761904761904, 'years_exp <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.09431939978563773, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0977491961414791, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10117899249732047, 0.16666666666666666, 'python <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.09946409431939979, 0.11904761904761904, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.10289389067524116, 0.11904761904761904, 'Q3_China <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.10117899249732047, 0.07142857142857142, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.10460878885316184, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10117899249732047, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11918542336548768, 0.2619047619047619, 'Q1_Female <= 0.5\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.11489817792068596, 0.21428571428571427, 'python <= 0.5\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.11318327974276528, 0.16666666666666666, 'years_exp <= 2.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.11146838156484459, 0.11904761904761904, 'Q3_China <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.10803858520900321, 0.07142857142857142, 'years_exp <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.10632368703108253, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1097534833869239, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11489817792068596, 0.07142857142857142, 'years_exp <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.11318327974276528, 0.023809523809523808, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11661307609860665, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11489817792068596, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11661307609860665, 0.16666666666666666, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.12347266881028938, 0.21428571428571427, 'Q3_China <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.1217577706323687, 0.16666666666666666, 'python <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.12004287245444802, 0.11904761904761904, 'major_eng <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11832797427652733, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1217577706323687, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12347266881028938, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12518756698821007, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1127545551982851, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.12261521972132905, 0.35714285714285715, 'age <= 27.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.12090032154340837, 0.30952380952380953, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.12433011789924973, 0.30952380952380953, 'major_eng <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.12261521972132905, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.12604501607717042, 0.2619047619047619, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1202572347266881, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.12197213290460879, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12883172561629153, 0.5, 'years_exp <= 7.5\ngini = 0.308\nsamples = 21\nvalue = [4, 17]'),
#  Text(0.12540192926045016, 0.4523809523809524, 'compensation <= 75000.0\ngini = 0.124\nsamples = 15\nvalue = [1, 14]'),
#  Text(0.12368703108252947, 0.40476190476190477, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.12711682743837086, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1322615219721329, 0.4523809523809524, 'years_exp <= 12.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.13054662379421222, 0.40476190476190477, 'age <= 32.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.12883172561629153, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1322615219721329, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.1339764201500536, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.14640943193997857, 0.5476190476190477, 'years_exp <= 3.5\ngini = 0.498\nsamples = 32\nvalue = [17, 15]'),
#  Text(0.14083601286173633, 0.5, 'compensation <= 107500.0\ngini = 0.415\nsamples = 17\nvalue = [12, 5]'),
#  Text(0.13912111468381566, 0.4523809523809524, 'compensation <= 5000.0\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.13740621650589496, 0.40476190476190477, 'age <= 27.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.13569131832797426, 0.35714285714285715, 'major_eng <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.1339764201500536, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.13740621650589496, 0.30952380952380953, 'age <= 23.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.13569131832797426, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.13912111468381566, 0.2619047619047619, 'Q3_China <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.13740621650589496, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14083601286173633, 0.21428571428571427, 'years_exp <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.13912111468381566, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14255091103965703, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13912111468381566, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.14083601286173633, 0.40476190476190477, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.14255091103965703, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1519828510182208, 0.5, 'compensation <= 35000.0\ngini = 0.444\nsamples = 15\nvalue = [5, 10]'),
#  Text(0.14769560557341907, 0.4523809523809524, 'years_exp <= 7.5\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.1442658092175777, 0.40476190476190477, 'major_eng <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.14255091103965703, 0.35714285714285715, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.1459807073954984, 0.35714285714285715, 'age <= 27.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.1442658092175777, 0.30952380952380953, 'compensation <= 5000.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.14255091103965703, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1459807073954984, 0.2619047619047619, 'years_exp <= 4.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1442658092175777, 0.21428571428571427, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.14769560557341907, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14769560557341907, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15112540192926044, 0.40476190476190477, 'compensation <= 25000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.14941050375133977, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15284030010718114, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1562700964630225, 0.4523809523809524, 'compensation <= 90000.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.15455519828510184, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.1579849946409432, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1515541264737406, 0.5952380952380952, 'age <= 32.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.14983922829581994, 0.5476190476190477, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.1532690246516613, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16012861736334405, 0.6428571428571429, 'python <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.15841371918542335, 0.5952380952380952, 'Q3_India <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.15669882100750268, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.16012861736334405, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16184351554126475, 0.5952380952380952, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.17213290460878886, 0.7380952380952381, 'sql <= 0.5\ngini = 0.436\nsamples = 28\nvalue = [19, 9]'),
#  Text(0.1687031082529475, 0.6904761904761905, 'years_exp <= 7.5\ngini = 0.32\nsamples = 20\nvalue = [16, 4]'),
#  Text(0.1669882100750268, 0.6428571428571429, 'python <= 0.5\ngini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.16527331189710612, 0.5952380952380952, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.1687031082529475, 0.5952380952380952, 'compensation <= 15000.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.1669882100750268, 0.5476190476190477, 'Q3_India <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.16527331189710612, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1687031082529475, 0.5, 'education <= 17.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.1669882100750268, 0.4523809523809524, 'age <= 20.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.16527331189710612, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1687031082529475, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.17041800643086816, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.17041800643086816, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.17041800643086816, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17556270096463023, 0.6904761904761905, 'Q1_Male <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.17384780278670953, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.17727759914255092, 0.6428571428571429, 'compensation <= 15000.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.17556270096463023, 0.5952380952380952, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.1789924973204716, 0.5952380952380952, 'Q3_India <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.17727759914255092, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1807073954983923, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3145766345123258, 0.8333333333333334, 'years_exp <= 4.5\ngini = 0.434\nsamples = 396\nvalue = [270, 126]'),
#  Text(0.27384780278670956, 0.7857142857142857, 'major_eng <= 0.5\ngini = 0.363\nsamples = 294\nvalue = [224, 70]'),
#  Text(0.23783494105037514, 0.7380952380952381, 'education <= 19.5\ngini = 0.303\nsamples = 204\nvalue = [166, 38]'),
#  Text(0.21436227224008575, 0.6904761904761905, 'years_exp <= 1.5\ngini = 0.348\nsamples = 147\nvalue = [114, 33]'),
#  Text(0.1984994640943194, 0.6428571428571429, 'education <= 18.5\ngini = 0.263\nsamples = 77\nvalue = [65, 12]'),
#  Text(0.1967845659163987, 0.5952380952380952, 'Q1_Prefer to self-describe <= 0.5\ngini = 0.248\nsamples = 76\nvalue = [65, 11]'),
#  Text(0.19506966773847803, 0.5476190476190477, 'age <= 37.5\ngini = 0.231\nsamples = 75\nvalue = [65, 10]'),
#  Text(0.18713826366559486, 0.5, 'education <= 17.0\ngini = 0.205\nsamples = 69\nvalue = [61, 8]'),
#  Text(0.17813504823151124, 0.4523809523809524, 'major_other <= 0.5\ngini = 0.278\nsamples = 30\nvalue = [25, 5]'),
#  Text(0.17213290460878886, 0.40476190476190477, 'Q1_Female <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.17041800643086816, 0.35714285714285715, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.17384780278670953, 0.35714285714285715, 'compensation <= 85000.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.17213290460878886, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.17556270096463023, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18413719185423366, 0.40476190476190477, 'compensation <= 75000.0\ngini = 0.36\nsamples = 17\nvalue = [13, 4]'),
#  Text(0.18242229367631296, 0.35714285714285715, 'age <= 23.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.1789924973204716, 0.30952380952380953, 'compensation <= 60000.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.17727759914255092, 0.2619047619047619, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.1807073954983923, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18585209003215433, 0.30952380952380953, 'compensation <= 65000.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.18413719185423366, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.18756698821007503, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.18585209003215433, 0.35714285714285715, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.19614147909967847, 0.4523809523809524, 'major_stat <= 0.5\ngini = 0.142\nsamples = 39\nvalue = [36, 3]'),
#  Text(0.1927116827438371, 0.40476190476190477, 'compensation <= 112500.0\ngini = 0.074\nsamples = 26\nvalue = [25, 1]'),
#  Text(0.1909967845659164, 0.35714285714285715, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.19442658092175777, 0.35714285714285715, 'sql <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.1927116827438371, 0.30952380952380953, 'Q1_Male <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1909967845659164, 0.2619047619047619, 'age <= 23.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1892818863879957, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1927116827438371, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19442658092175777, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.19614147909967847, 0.30952380952380953, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.19957127545551984, 0.40476190476190477, 'sql <= 0.5\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.19785637727759914, 0.35714285714285715, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.2012861736334405, 0.35714285714285715, 'compensation <= 35000.0\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.19957127545551984, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2030010718113612, 0.30952380952380953, 'compensation <= 112500.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.2012861736334405, 0.2619047619047619, 'years_exp <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.19957127545551984, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2030010718113612, 0.21428571428571427, 'Q1_Female <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.2012861736334405, 0.16666666666666666, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.20471596998928188, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.20471596998928188, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2030010718113612, 0.5, 'compensation <= 30000.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.2012861736334405, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.20471596998928188, 0.4523809523809524, 'age <= 45.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2030010718113612, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.20643086816720257, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1984994640943194, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2002143622722401, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2302250803858521, 0.6428571428571429, 'compensation <= 75000.0\ngini = 0.42\nsamples = 70\nvalue = [49, 21]'),
#  Text(0.2210075026795284, 0.5952380952380952, 'compensation <= 10000.0\ngini = 0.499\nsamples = 25\nvalue = [13, 12]'),
#  Text(0.21672025723472668, 0.5476190476190477, 'age <= 27.5\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.2132904608788853, 0.5, 'education <= 17.0\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.21157556270096464, 0.4523809523809524, 'sql <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.20986066452304394, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2132904608788853, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.215005359056806, 0.4523809523809524, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.22015005359056805, 0.5, 'Q1_Female <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.21843515541264738, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.22186495176848875, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.22529474812433012, 0.5476190476190477, 'years_exp <= 3.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.22357984994640942, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.22700964630225082, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.23944265809217577, 0.5952380952380952, 'sql <= 0.5\ngini = 0.32\nsamples = 45\nvalue = [36, 9]'),
#  Text(0.2347266881028939, 0.5476190476190477, 'compensation <= 112500.0\ngini = 0.413\nsamples = 24\nvalue = [17, 7]'),
#  Text(0.2304394426580922, 0.5, 'education <= 17.0\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.22700964630225082, 0.4523809523809524, 'education <= 12.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.22529474812433012, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2287245444801715, 0.40476190476190477, 'years_exp <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.22700964630225082, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.2304394426580922, 0.35714285714285715, 'years_exp <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2287245444801715, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.23215434083601286, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23386923901393356, 0.4523809523809524, 'python <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.23215434083601286, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.23558413719185423, 0.40476190476190477, 'compensation <= 95000.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.23386923901393356, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23729903536977492, 0.35714285714285715, 'Q1_Male <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.23558413719185423, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2390139335476956, 0.30952380952380953, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.23729903536977492, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2407288317256163, 0.2619047619047619, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2390139335476956, 0.5, 'Q1_Prefer not to say <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.23729903536977492, 0.4523809523809524, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.2407288317256163, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.24415862808145766, 0.5476190476190477, 'compensation <= 137500.0\ngini = 0.172\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.24244372990353696, 0.5, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.24587352625937836, 0.5, 'major_other <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.24415862808145766, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.24758842443729903, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.26130760986066454, 0.6904761904761905, 'compensation <= 137500.0\ngini = 0.16\nsamples = 57\nvalue = [52, 5]'),
#  Text(0.2544480171489818, 0.6428571428571429, 'age <= 27.5\ngini = 0.083\nsamples = 46\nvalue = [44, 2]'),
#  Text(0.24930332261521973, 0.5952380952380952, 'compensation <= 90000.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.24758842443729903, 0.5476190476190477, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.2510182207931404, 0.5476190476190477, 'Q1_Male <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.24930332261521973, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2527331189710611, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.25959271168274384, 0.5952380952380952, 'age <= 32.5\ngini = 0.05\nsamples = 39\nvalue = [38, 1]'),
#  Text(0.25787781350482314, 0.5476190476190477, 'sql <= 0.5\ngini = 0.095\nsamples = 20\nvalue = [19, 1]'),
#  Text(0.25616291532690244, 0.5, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.25959271168274384, 0.5, 'years_exp <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.25787781350482314, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.26130760986066454, 0.4523809523809524, 'years_exp <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.25959271168274384, 0.40476190476190477, 'Q1_Male <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.25787781350482314, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.26130760986066454, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.26302250803858523, 0.40476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.26130760986066454, 0.5476190476190477, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.2681672025723473, 0.6428571428571429, 'Q1_Male <= 0.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.2664523043944266, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.269882100750268, 0.5952380952380952, 'sql <= 0.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.2681672025723473, 0.5476190476190477, 'major_stat <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.2664523043944266, 0.5, 'years_exp <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2647374062165059, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2681672025723473, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.269882100750268, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2715969989281886, 0.5476190476190477, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.30986066452304395, 0.7380952380952381, 'compensation <= 112500.0\ngini = 0.458\nsamples = 90\nvalue = [58, 32]'),
#  Text(0.3018220793140407, 0.6904761904761905, 'years_exp <= 3.5\ngini = 0.489\nsamples = 66\nvalue = [38, 28]'),
#  Text(0.30010718113612006, 0.6428571428571429, 'age <= 37.5\ngini = 0.475\nsamples = 62\nvalue = [38, 24]'),
#  Text(0.29088960342979636, 0.5952380952380952, 'years_exp <= 0.5\ngini = 0.456\nsamples = 57\nvalue = [37, 20]'),
#  Text(0.27759914255091106, 0.5476190476190477, 'age <= 32.5\ngini = 0.491\nsamples = 23\nvalue = [13, 10]'),
#  Text(0.27588424437299036, 0.5, 'Q1_Male <= 0.5\ngini = 0.483\nsamples = 22\nvalue = [13, 9]'),
#  Text(0.2715969989281886, 0.4523809523809524, 'sql <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.269882100750268, 0.40476190476190477, 'compensation <= 45000.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.2681672025723473, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2715969989281886, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2733118971061093, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.28017148981779205, 0.4523809523809524, 'age <= 23.5\ngini = 0.457\nsamples = 17\nvalue = [11, 6]'),
#  Text(0.2767416934619507, 0.40476190476190477, 'sql <= 0.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.27502679528403, 0.35714285714285715, 'compensation <= 75000.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.2733118971061093, 0.30952380952380953, 'education <= 19.0\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.2715969989281886, 0.2619047619047619, 'education <= 17.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.269882100750268, 0.21428571428571427, 'compensation <= 35000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2681672025723473, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2715969989281886, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2733118971061093, 0.21428571428571427, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.27502679528403, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2767416934619507, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2784565916398714, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.28360128617363345, 0.40476190476190477, 'compensation <= 60000.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.28188638799571275, 0.35714285714285715, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.28531618435155415, 0.35714285714285715, 'compensation <= 85000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.28360128617363345, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2870310825294748, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2793140407288317, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.30418006430868166, 0.5476190476190477, 'age <= 32.5\ngini = 0.415\nsamples = 34\nvalue = [24, 10]'),
#  Text(0.30246516613076097, 0.5, 'compensation <= 95000.0\ngini = 0.444\nsamples = 30\nvalue = [20, 10]'),
#  Text(0.2990353697749196, 0.4523809523809524, 'Q1_Prefer not to say <= 0.5\ngini = 0.469\nsamples = 24\nvalue = [15, 9]'),
#  Text(0.2973204715969989, 0.40476190476190477, 'sql <= 0.5\ngini = 0.476\nsamples = 23\nvalue = [14, 9]'),
#  Text(0.2921757770632369, 0.35714285714285715, 'age <= 27.5\ngini = 0.444\nsamples = 15\nvalue = [10, 5]'),
#  Text(0.2904608788853162, 0.30952380952380953, 'years_exp <= 2.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.2870310825294748, 0.2619047619047619, 'compensation <= 75000.0\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.28531618435155415, 0.21428571428571427, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.2887459807073955, 0.21428571428571427, 'python <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2870310825294748, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2904608788853162, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2938906752411576, 0.2619047619047619, 'education <= 17.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2921757770632369, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2956055734190782, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2938906752411576, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.30246516613076097, 0.35714285714285715, 'age <= 27.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.2990353697749196, 0.30952380952380953, 'compensation <= 35000.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.2973204715969989, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3007502679528403, 0.2619047619047619, 'python <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2990353697749196, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.30246516613076097, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.30589496248660236, 0.30952380952380953, 'education <= 19.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.30418006430868166, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.30760986066452306, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3007502679528403, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.30589496248660236, 0.4523809523809524, 'years_exp <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.30418006430868166, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.30760986066452306, 0.40476190476190477, 'years_exp <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.30589496248660236, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3093247588424437, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.30589496248660236, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3093247588424437, 0.5952380952380952, 'education <= 19.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.30760986066452306, 0.5476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3110396570203644, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3035369774919614, 0.6428571428571429, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.31789924973204714, 0.6904761904761905, 'education <= 17.0\ngini = 0.278\nsamples = 24\nvalue = [20, 4]'),
#  Text(0.3144694533762058, 0.6428571428571429, 'age <= 23.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3127545551982851, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3161843515541265, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.32132904608788854, 0.6428571428571429, 'age <= 27.5\ngini = 0.172\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.31961414790996784, 0.5952380952380952, 'years_exp <= 3.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.31789924973204714, 0.5476190476190477, 'sql <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.3161843515541265, 0.5, 'compensation <= 137500.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.3144694533762058, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.31789924973204714, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.31961414790996784, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.32132904608788854, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.32304394426580924, 0.5952380952380952, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.3553054662379421, 0.7857142857142857, 'education <= 18.5\ngini = 0.495\nsamples = 102\nvalue = [46, 56]'),
#  Text(0.33954983922829585, 0.7380952380952381, 'education <= 17.0\ngini = 0.438\nsamples = 74\nvalue = [24, 50]'),
#  Text(0.329903536977492, 0.6904761904761905, 'major_other <= 0.5\ngini = 0.165\nsamples = 22\nvalue = [2, 20]'),
#  Text(0.3281886387995713, 0.6428571428571429, 'age <= 40.0\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.3264737406216506, 0.5952380952380952, 'compensation <= 65000.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.3247588424437299, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3281886387995713, 0.5476190476190477, 'compensation <= 137500.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.3264737406216506, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.329903536977492, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.329903536977492, 0.5952380952380952, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.33161843515541267, 0.6428571428571429, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.34919614147909966, 0.6904761904761905, 'compensation <= 112500.0\ngini = 0.488\nsamples = 52\nvalue = [22, 30]'),
#  Text(0.3410503751339764, 0.6428571428571429, 'age <= 32.5\ngini = 0.415\nsamples = 34\nvalue = [10, 24]'),
# ...
#  Text(0.6132904608788853, 0.4523809523809524, 'years_exp <= 1.5\ngini = 0.415\nsamples = 17\nvalue = [12, 5]'),
#  Text(0.6115755627009646, 0.40476190476190477, 'compensation <= 112500.0\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.6081457663451233, 0.35714285714285715, 'age <= 27.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.6064308681672026, 0.30952380952380953, 'compensation <= 75000.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.6047159699892819, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6081457663451233, 0.2619047619047619, 'years_exp <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.6064308681672026, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.609860664523044, 0.21428571428571427, 'compensation <= 90000.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.6081457663451233, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6115755627009646, 0.16666666666666666, 'sql <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.609860664523044, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6132904608788853, 0.11904761904761904, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.609860664523044, 0.30952380952380953, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.615005359056806, 0.35714285714285715, 'years_exp <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6132904608788853, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6167202572347267, 0.30952380952380953, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.615005359056806, 0.40476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6270096463022508, 0.4523809523809524, 'sql <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.6252947481243302, 0.40476190476190477, 'years_exp <= 1.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.6218649517684888, 0.35714285714285715, 'compensation <= 35000.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6201500535905681, 0.30952380952380953, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6235798499464095, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6287245444801715, 0.35714285714285715, 'education <= 19.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6270096463022508, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6304394426580922, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6287245444801715, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6321543408360129, 0.5, 'sql <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6304394426580922, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6338692390139335, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6295819935691318, 0.5476190476190477, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6312968917470525, 0.5952380952380952, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.6330117899249732, 0.6428571428571429, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.7067825562700965, 0.8333333333333334, 'education <= 17.0\ngini = 0.334\nsamples = 293\nvalue = [62, 231]'),
#  Text(0.6632636655948553, 0.7857142857142857, 'Q3_China <= 0.5\ngini = 0.233\nsamples = 134\nvalue = [18, 116]'),
#  Text(0.6568595927116827, 0.7380952380952381, 'years_exp <= 12.5\ngini = 0.203\nsamples = 122\nvalue = [14, 108]'),
#  Text(0.655144694533762, 0.6904761904761905, 'age <= 42.5\ngini = 0.226\nsamples = 108\nvalue = [14, 94]'),
#  Text(0.6491961414790997, 0.6428571428571429, 'years_exp <= 3.5\ngini = 0.215\nsamples = 106\nvalue = [13, 93]'),
#  Text(0.6424437299035369, 0.5952380952380952, 'compensation <= 90000.0\ngini = 0.32\nsamples = 20\nvalue = [4, 16]'),
#  Text(0.6407288317256163, 0.5476190476190477, 'age <= 32.5\ngini = 0.198\nsamples = 18\nvalue = [2, 16]'),
#  Text(0.6390139335476956, 0.5, 'python <= 0.5\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(0.637299035369775, 0.4523809523809524, 'compensation <= 5000.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6355841371918542, 0.40476190476190477, 'age <= 21.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6338692390139335, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.637299035369775, 0.35714285714285715, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6390139335476956, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6407288317256163, 0.4523809523809524, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.6424437299035369, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6441586280814576, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6559485530546624, 0.5952380952380952, 'Q3_India <= 0.5\ngini = 0.187\nsamples = 86\nvalue = [9, 77]'),
#  Text(0.6542336548767417, 0.5476190476190477, 'gini = 0.0\nsamples = 30\nvalue = [0, 30]'),
#  Text(0.6576634512325831, 0.5476190476190477, 'compensation <= 85000.0\ngini = 0.27\nsamples = 56\nvalue = [9, 47]'),
#  Text(0.6514469453376206, 0.5, 'compensation <= 5000.0\ngini = 0.252\nsamples = 54\nvalue = [8, 46]'),
#  Text(0.6441586280814576, 0.4523809523809524, 'Q1_Female <= 0.5\ngini = 0.33\nsamples = 24\nvalue = [5, 19]'),
#  Text(0.6424437299035369, 0.40476190476190477, 'age <= 32.5\ngini = 0.363\nsamples = 21\nvalue = [5, 16]'),
#  Text(0.6407288317256163, 0.35714285714285715, 'python <= 0.5\ngini = 0.401\nsamples = 18\nvalue = [5, 13]'),
#  Text(0.6347266881028939, 0.30952380952380953, 'years_exp <= 4.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.6330117899249732, 0.2619047619047619, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6364415862808146, 0.2619047619047619, 'years_exp <= 7.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6347266881028939, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6381564844587353, 0.21428571428571427, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6467309753483387, 0.30952380952380953, 'years_exp <= 7.5\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.6433011789924973, 0.2619047619047619, 'sql <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.6415862808145766, 0.21428571428571427, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.645016077170418, 0.21428571428571427, 'years_exp <= 4.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6433011789924973, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6467309753483387, 0.16666666666666666, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.645016077170418, 0.11904761904761904, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6484458735262594, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6501607717041801, 0.2619047619047619, 'age <= 24.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6484458735262594, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6518756698821008, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6441586280814576, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6458735262593783, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6587352625937835, 0.4523809523809524, 'python <= 0.5\ngini = 0.18\nsamples = 30\nvalue = [3, 27]'),
#  Text(0.6570203644158628, 0.40476190476190477, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.6604501607717042, 0.40476190476190477, 'compensation <= 15000.0\ngini = 0.255\nsamples = 20\nvalue = [3, 17]'),
#  Text(0.6587352625937835, 0.35714285714285715, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.6621650589496249, 0.35714285714285715, 'years_exp <= 7.5\ngini = 0.32\nsamples = 15\nvalue = [3, 12]'),
#  Text(0.6604501607717042, 0.30952380952380953, 'compensation <= 35000.0\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(0.6587352625937835, 0.2619047619047619, 'age <= 32.5\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.6570203644158628, 0.21428571428571427, 'sql <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.6535905680600215, 0.16666666666666666, 'years_exp <= 4.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.6518756698821008, 0.11904761904761904, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6553054662379422, 0.11904761904761904, 'Q1_Female <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.6535905680600215, 0.07142857142857142, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6518756698821008, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6553054662379422, 0.023809523809523808, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6570203644158628, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6604501607717042, 0.16666666666666666, 'years_exp <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6587352625937835, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6621650589496249, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6604501607717042, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6621650589496249, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6638799571275456, 0.30952380952380953, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6638799571275456, 0.5, 'years_exp <= 7.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6621650589496249, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6655948553054662, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6610932475884245, 0.6428571428571429, 'sql <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6593783494105038, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6628081457663452, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6585744908896034, 0.6904761904761905, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.6696677384780279, 0.7380952380952381, 'sql <= 0.5\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.6662379421221865, 0.6904761904761905, 'age <= 32.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.6645230439442658, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6679528403001072, 0.6428571428571429, 'years_exp <= 4.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6662379421221865, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6696677384780279, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6730975348338692, 0.6904761904761905, 'compensation <= 55000.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.6713826366559486, 0.6428571428571429, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.67481243301179, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7503014469453376, 0.7857142857142857, 'age <= 20.0\ngini = 0.4\nsamples = 159\nvalue = [44, 115]'),
#  Text(0.7485865487674169, 0.7380952380952381, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7520163451232583, 0.7380952380952381, 'age <= 47.5\ngini = 0.392\nsamples = 157\nvalue = [42, 115]'),
#  Text(0.7406886387995713, 0.6904761904761905, 'years_exp <= 7.5\ngini = 0.375\nsamples = 148\nvalue = [37, 111]'),
#  Text(0.7283226152197213, 0.6428571428571429, 'education <= 19.5\ngini = 0.422\nsamples = 109\nvalue = [33, 76]'),
#  Text(0.7173097534833869, 0.5952380952380952, 'age <= 37.5\ngini = 0.397\nsamples = 99\nvalue = [27, 72]'),
#  Text(0.7038585209003215, 0.5476190476190477, 'age <= 27.5\ngini = 0.372\nsamples = 93\nvalue = [23, 70]'),
#  Text(0.6853161843515542, 0.5, 'education <= 18.5\ngini = 0.427\nsamples = 42\nvalue = [13, 29]'),
#  Text(0.6836012861736335, 0.4523809523809524, 'compensation <= 5000.0\ngini = 0.414\nsamples = 41\nvalue = [12, 29]'),
#  Text(0.6733118971061093, 0.40476190476190477, 'years_exp <= 4.5\ngini = 0.298\nsamples = 22\nvalue = [4, 18]'),
#  Text(0.6715969989281887, 0.35714285714285715, 'python <= 0.5\ngini = 0.332\nsamples = 19\nvalue = [4, 15]'),
#  Text(0.667309753483387, 0.30952380952380953, 'years_exp <= 3.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.6655948553054662, 0.2619047619047619, 'age <= 23.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6638799571275456, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.667309753483387, 0.21428571428571427, 'Q3_China <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6655948553054662, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6690246516613076, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6690246516613076, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6758842443729903, 0.30952380952380953, 'years_exp <= 3.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.6724544480171489, 0.2619047619047619, 'Q3_United States of America <= 0.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.6707395498392283, 0.21428571428571427, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.6741693461950696, 0.21428571428571427, 'Q1_Female <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6724544480171489, 0.16666666666666666, 'sql <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6707395498392283, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6741693461950696, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6758842443729903, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6793140407288317, 0.2619047619047619, 'Q1_Female <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.677599142550911, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6810289389067524, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.67502679528403, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6938906752411576, 0.40476190476190477, 'compensation <= 125000.0\ngini = 0.488\nsamples = 19\nvalue = [8, 11]'),
#  Text(0.6921757770632369, 0.35714285714285715, 'years_exp <= 4.5\ngini = 0.5\nsamples = 16\nvalue = [8, 8]'),
#  Text(0.6904608788853162, 0.30952380952380953, 'python <= 0.5\ngini = 0.498\nsamples = 15\nvalue = [7, 8]'),
#  Text(0.6861736334405145, 0.2619047619047619, 'Q3_United States of America <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6844587352625938, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6878885316184351, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6947481243301179, 0.2619047619047619, 'compensation <= 45000.0\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.6913183279742765, 0.21428571428571427, 'years_exp <= 3.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.6896034297963558, 0.16666666666666666, 'Q3_United States of America <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6878885316184351, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6913183279742765, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6930332261521972, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6981779206859593, 0.21428571428571427, 'Q3_United States of America <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.6964630225080386, 0.16666666666666666, 'compensation <= 55000.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6947481243301179, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6981779206859593, 0.11904761904761904, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.69989281886388, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6938906752411576, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6956055734190782, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  ...]

# %%
fig, ax = plt.subplots(figsize=(8, 4))
features = list(c for c in X_train.columns)
tree.plot_tree(hi_variance, feature_names=features, filled=True, class_names=hi_variance.classes_,
              max_depth=2, fontsize=6)
# Out:
# [Text(0.5, 0.875, 'r <= 0.5\ngini = 0.496\nsamples = 2110\nvalue = [1153, 957]\nclass = Data Scientist'),
#  Text(0.25, 0.625, 'major_cs <= 0.5\ngini = 0.493\nsamples = 1484\nvalue = [653, 831]\nclass = Software Engineer'),
#  Text(0.125, 0.375, 'Q3_United States of America <= 0.5\ngini = 0.49\nsamples = 718\nvalue = [410, 308]\nclass = Data Scientist'),
#  Text(0.0625, 0.125, '\n  (...)  \n'),
#  Text(0.1875, 0.125, '\n  (...)  \n'),
#  Text(0.375, 0.375, 'years_exp <= 2.5\ngini = 0.433\nsamples = 766\nvalue = [243, 523]\nclass = Software Engineer'),
#  Text(0.3125, 0.125, '\n  (...)  \n'),
#  Text(0.4375, 0.125, '\n  (...)  \n'),
#  Text(0.75, 0.625, 'major_cs <= 0.5\ngini = 0.322\nsamples = 626\nvalue = [500, 126]\nclass = Data Scientist'),
#  Text(0.625, 0.375, 'years_exp <= 22.5\ngini = 0.211\nsamples = 443\nvalue = [390, 53]\nclass = Data Scientist'),
#  Text(0.5625, 0.125, '\n  (...)  \n'),
#  Text(0.6875, 0.125, '\n  (...)  \n'),
#  Text(0.875, 0.375, 'years_exp <= 7.5\ngini = 0.48\nsamples = 183\nvalue = [110, 73]\nclass = Data Scientist'),
#  Text(0.8125, 0.125, '\n  (...)  \n'),
#  Text(0.9375, 0.125, '\n  (...)  \n')]

# %% [markdown]
# ## Tree Hyperparameters

# %%
stump.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 1,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %% [markdown]
# #### Tracking changes with Validation Curves

# %%
accuracies = []
for depth in range(1, 15):
    between = tree.DecisionTreeClassifier(max_depth=depth)
    between.fit(X_train, kag_y_train)
    accuracies.append(between.score(X_test, kag_y_test))

# %%
fig, ax = plt.subplots(figsize=(10, 4))
(pd.Series(accuracies, name='Accuracy', index=range(1, len(accuracies)+1))
 .plot(ax=ax, title='Accuracy at a given Tree Depth'))
ax.set_ylabel('Accuracy')
ax.set_xlabel('max_depth')

plt.grid(True)
plt.show()

# %%
between = tree.DecisionTreeClassifier(max_depth=7)
between.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier(max_depth=7)

# %%
between.score(X_test, kag_y_test)
# Out:
# 0.7348066298342542

# %% [markdown]
# #### Leveraging Yellowbrick

# %%
from yellowbrick.model_selection import validation_curve

# %%
fig, ax = plt.subplots(figsize=(10, 4))
viz = validation_curve(tree.DecisionTreeClassifier(),
                       X=pd.concat([X_train, X_test]),
                       y=pd.concat([kag_y_train, kag_y_test]),
                       param_name='max_depth', param_range=range(1, 14),
                       scoring='accuracy', cv=5, ax=ax, n_jobs=6)

plt.show()

# %% [markdown]
# #### Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'max_depth': [3, 5, 7, 8],
    'min_samples_leaf': [1, 3, 4, 5, 6],
    'min_samples_split': [2, 3, 4, 5, 6],
}

# %%
grid_search = GridSearchCV(estimator=tree.DecisionTreeClassifier(),
                           param_grid=params, cv=4, n_jobs=-1,
                           verbose=1, scoring="accuracy")

# %%
grid_search.fit(pd.concat([X_train, X_test]),
                pd.concat([kag_y_train, kag_y_test]))
# Out:
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /Users/isisromero/opt/anaconda3/envs/Data-science-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [3, 5, 7, 8],
#                          'min_samples_leaf': [1, 3, 4, 5, 6],
#                          'min_samples_split': [2, 3, 4, 5, 6]},
#              scoring='accuracy', verbose=1)

# %%
grid_search.best_params_
# Out:
# {'max_depth': 7, 'min_samples_leaf': 5, 'min_samples_split': 4}

# %%
between2 = tree.DecisionTreeClassifier(**grid_search.best_params_)

# %%
between2.fit(X_train, kag_y_train)
# Out:
# DecisionTreeClassifier(max_depth=7, min_samples_leaf=5, min_samples_split=4)

# %%
between2.score(X_test, kag_y_test)
# Out:
# 0.7259668508287292

# %%
(pd.DataFrame(grid_search.cv_results_)
 .sort_values(by='rank_test_score')
 .style
 .background_gradient(axis='rows')
)
# Out:
# <style type="text/css">
# #T_9ca6a_row0_col0, #T_9ca6a_row29_col3, #T_9ca6a_row44_col3, #T_9ca6a_row60_col10, #T_9ca6a_row61_col10, #T_9ca6a_row62_col10, #T_9ca6a_row63_col10, #T_9ca6a_row64_col10, #T_9ca6a_row69_col10, #T_9ca6a_row80_col1, #T_9ca6a_row86_col1, #T_9ca6a_row88_col3 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_9ca6a_row0_col1, #T_9ca6a_row0_col14, #T_9ca6a_row8_col3, #T_9ca6a_row51_col8, #T_9ca6a_row54_col8, #T_9ca6a_row58_col0, #T_9ca6a_row58_col2, #T_9ca6a_row60_col1, #T_9ca6a_row70_col10, #T_9ca6a_row71_col1, #T_9ca6a_row71_col10, #T_9ca6a_row73_col10, #T_9ca6a_row75_col9, #T_9ca6a_row75_col11, #T_9ca6a_row76_col9, #T_9ca6a_row76_col11, #T_9ca6a_row77_col9, #T_9ca6a_row77_col11, #T_9ca6a_row78_col9, #T_9ca6a_row78_col11, #T_9ca6a_row79_col9, #T_9ca6a_row79_col11, #T_9ca6a_row80_col9, #T_9ca6a_row80_col11, #T_9ca6a_row81_col9, #T_9ca6a_row81_col11, #T_9ca6a_row82_col9, #T_9ca6a_row82_col11, #T_9ca6a_row83_col9, #T_9ca6a_row83_col11, #T_9ca6a_row84_col9, #T_9ca6a_row84_col11, #T_9ca6a_row85_col9, #T_9ca6a_row85_col11, #T_9ca6a_row86_col9, #T_9ca6a_row86_col11, #T_9ca6a_row87_col9, #T_9ca6a_row87_col11, #T_9ca6a_row88_col9, #T_9ca6a_row88_col11, #T_9ca6a_row89_col9, #T_9ca6a_row89_col11, #T_9ca6a_row90_col9, #T_9ca6a_row90_col11, #T_9ca6a_row90_col12, #T_9ca6a_row90_col13, #T_9ca6a_row91_col9, #T_9ca6a_row91_col11, #T_9ca6a_row91_col12, #T_9ca6a_row91_col13, #T_9ca6a_row92_col9, #T_9ca6a_row92_col11, #T_9ca6a_row92_col12, #T_9ca6a_row92_col13, #T_9ca6a_row93_col9, #T_9ca6a_row93_col11, #T_9ca6a_row93_col12, #T_9ca6a_row93_col13, #T_9ca6a_row94_col9, #T_9ca6a_row94_col11, #T_9ca6a_row94_col12, #T_9ca6a_row94_col13, #T_9ca6a_row95_col9, #T_9ca6a_row95_col11, #T_9ca6a_row95_col12, #T_9ca6a_row95_col13, #T_9ca6a_row96_col9, #T_9ca6a_row96_col11, #T_9ca6a_row96_col12, #T_9ca6a_row96_col13, #T_9ca6a_row97_col9, #T_9ca6a_row97_col11, #T_9ca6a_row97_col12, #T_9ca6a_row97_col13, #T_9ca6a_row98_col9, #T_9ca6a_row98_col11, #T_9ca6a_row98_col12, #T_9ca6a_row98_col13, #T_9ca6a_row99_col9, #T_9ca6a_row99_col11, #T_9ca6a_row99_col12, #T_9ca6a_row99_col13 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_9ca6a_row0_col2, #T_9ca6a_row1_col0, #T_9ca6a_row17_col14, #T_9ca6a_row27_col0 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_9ca6a_row0_col3, #T_9ca6a_row55_col3, #T_9ca6a_row56_col3, #T_9ca6a_row69_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_9ca6a_row0_col8, #T_9ca6a_row5_col8, #T_9ca6a_row6_col8, #T_9ca6a_row13_col10, #T_9ca6a_row19_col10, #T_9ca6a_row22_col10, #T_9ca6a_row23_col10, #T_9ca6a_row67_col8, #T_9ca6a_row69_col8, #T_9ca6a_row86_col2 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_9ca6a_row0_col9, #T_9ca6a_row0_col10, #T_9ca6a_row0_col12, #T_9ca6a_row2_col10, #T_9ca6a_row17_col11, #T_9ca6a_row18_col8, #T_9ca6a_row24_col11, #T_9ca6a_row29_col11, #T_9ca6a_row54_col13, #T_9ca6a_row90_col14, #T_9ca6a_row91_col14, #T_9ca6a_row92_col0, #T_9ca6a_row92_col1, #T_9ca6a_row92_col14, #T_9ca6a_row93_col14, #T_9ca6a_row94_col14, #T_9ca6a_row95_col14, #T_9ca6a_row96_col2, #T_9ca6a_row96_col3, #T_9ca6a_row96_col14, #T_9ca6a_row97_col14, #T_9ca6a_row98_col14, #T_9ca6a_row99_col14 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9ca6a_row0_col11, #T_9ca6a_row1_col11, #T_9ca6a_row2_col11, #T_9ca6a_row18_col11, #T_9ca6a_row26_col11, #T_9ca6a_row27_col11, #T_9ca6a_row32_col11, #T_9ca6a_row33_col11, #T_9ca6a_row34_col11, #T_9ca6a_row35_col11, #T_9ca6a_row36_col11, #T_9ca6a_row37_col11, #T_9ca6a_row38_col11 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_9ca6a_row0_col13, #T_9ca6a_row43_col14, #T_9ca6a_row44_col14, #T_9ca6a_row45_col14, #T_9ca6a_row78_col2 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_9ca6a_row1_col1, #T_9ca6a_row57_col1, #T_9ca6a_row66_col1 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_9ca6a_row1_col2, #T_9ca6a_row52_col2, #T_9ca6a_row54_col2, #T_9ca6a_row64_col9, #T_9ca6a_row66_col0, #T_9ca6a_row68_col0 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_9ca6a_row1_col3, #T_9ca6a_row12_col1, #T_9ca6a_row44_col1, #T_9ca6a_row47_col3, #T_9ca6a_row59_col1, #T_9ca6a_row65_col1, #T_9ca6a_row91_col3 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_9ca6a_row1_col8, #T_9ca6a_row1_col10, #T_9ca6a_row3_col10, #T_9ca6a_row4_col10, #T_9ca6a_row7_col10, #T_9ca6a_row11_col10, #T_9ca6a_row65_col8, #T_9ca6a_row70_col8, #T_9ca6a_row99_col2 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_9ca6a_row1_col9, #T_9ca6a_row2_col9, #T_9ca6a_row3_col9, #T_9ca6a_row4_col9, #T_9ca6a_row12_col9, #T_9ca6a_row14_col9, #T_9ca6a_row21_col9, #T_9ca6a_row54_col9 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_9ca6a_row1_col12, #T_9ca6a_row2_col12 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_9ca6a_row1_col13 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_9ca6a_row1_col14, #T_9ca6a_row2_col14, #T_9ca6a_row8_col1, #T_9ca6a_row10_col1, #T_9ca6a_row69_col3, #T_9ca6a_row70_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_9ca6a_row2_col0, #T_9ca6a_row22_col13, #T_9ca6a_row50_col10, #T_9ca6a_row60_col9, #T_9ca6a_row60_col12, #T_9ca6a_row66_col9, #T_9ca6a_row77_col2 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_9ca6a_row2_col1, #T_9ca6a_row4_col2 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_9ca6a_row2_col2, #T_9ca6a_row17_col0, #T_9ca6a_row29_col2, #T_9ca6a_row44_col2, #T_9ca6a_row72_col13, #T_9ca6a_row85_col0 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_9ca6a_row2_col3, #T_9ca6a_row14_col14, #T_9ca6a_row18_col0, #T_9ca6a_row50_col8, #T_9ca6a_row52_col10, #T_9ca6a_row53_col8, #T_9ca6a_row66_col10, #T_9ca6a_row67_col10, #T_9ca6a_row75_col8, #T_9ca6a_row76_col8, #T_9ca6a_row77_col8, #T_9ca6a_row78_col8, #T_9ca6a_row79_col8, #T_9ca6a_row80_col8, #T_9ca6a_row81_col8, #T_9ca6a_row82_col8, #T_9ca6a_row83_col0, #T_9ca6a_row83_col8, #T_9ca6a_row84_col8, #T_9ca6a_row85_col8, #T_9ca6a_row86_col8, #T_9ca6a_row87_col8, #T_9ca6a_row88_col8, #T_9ca6a_row89_col8 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_9ca6a_row2_col8, #T_9ca6a_row3_col8, #T_9ca6a_row4_col8, #T_9ca6a_row12_col10, #T_9ca6a_row13_col8, #T_9ca6a_row16_col8, #T_9ca6a_row69_col14 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_9ca6a_row2_col13, #T_9ca6a_row6_col0, #T_9ca6a_row13_col13, #T_9ca6a_row47_col2, #T_9ca6a_row51_col0 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_9ca6a_row3_col0, #T_9ca6a_row15_col14, #T_9ca6a_row35_col0, #T_9ca6a_row38_col1, #T_9ca6a_row71_col0, #T_9ca6a_row77_col3, #T_9ca6a_row89_col1 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_9ca6a_row3_col1, #T_9ca6a_row4_col1, #T_9ca6a_row9_col1, #T_9ca6a_row43_col1, #T_9ca6a_row68_col3, #T_9ca6a_row75_col1, #T_9ca6a_row91_col1 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_9ca6a_row3_col2, #T_9ca6a_row9_col2, #T_9ca6a_row16_col3, #T_9ca6a_row25_col0, #T_9ca6a_row32_col2, #T_9ca6a_row33_col1, #T_9ca6a_row69_col12, #T_9ca6a_row74_col3 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_9ca6a_row3_col3, #T_9ca6a_row7_col14, #T_9ca6a_row20_col3, #T_9ca6a_row25_col1, #T_9ca6a_row27_col3, #T_9ca6a_row40_col3, #T_9ca6a_row50_col3, #T_9ca6a_row65_col10, #T_9ca6a_row68_col10, #T_9ca6a_row72_col10, #T_9ca6a_row74_col10, #T_9ca6a_row85_col3, #T_9ca6a_row90_col8, #T_9ca6a_row91_col8, #T_9ca6a_row92_col8, #T_9ca6a_row93_col8, #T_9ca6a_row94_col8, #T_9ca6a_row95_col1, #T_9ca6a_row95_col8, #T_9ca6a_row96_col8, #T_9ca6a_row97_col8, #T_9ca6a_row98_col8, #T_9ca6a_row99_col8 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_9ca6a_row3_col11, #T_9ca6a_row4_col11, #T_9ca6a_row5_col11, #T_9ca6a_row8_col11, #T_9ca6a_row9_col11, #T_9ca6a_row10_col11, #T_9ca6a_row15_col11, #T_9ca6a_row22_col9, #T_9ca6a_row25_col11, #T_9ca6a_row29_col9, #T_9ca6a_row31_col9, #T_9ca6a_row39_col9, #T_9ca6a_row40_col9, #T_9ca6a_row41_col9, #T_9ca6a_row41_col11, #T_9ca6a_row42_col9, #T_9ca6a_row46_col11, #T_9ca6a_row47_col9, #T_9ca6a_row47_col11, #T_9ca6a_row48_col11, #T_9ca6a_row49_col11, #T_9ca6a_row50_col11 {
#   background-color: #056

# %%
results = model_selection.cross_val_score(
    tree.DecisionTreeClassifier(max_depth=7),
    X=pd.concat([X_train, X_test], axis='index'),
    y=pd.concat([kag_y_train, kag_y_test], axis='index'),
    cv=4
)

# %%
results
# Out:
# array([0.69761273, 0.73740053, 0.70424403, 0.71713147])

# %%
results.mean()
# Out:
# 0.7140971921333235

# %%
results = model_selection.cross_val_score(
    tree.DecisionTreeClassifier(max_depth=7, min_samples_leaf=5,
                               min_samples_split=2),
    X=pd.concat([X_train, X_test], axis='index'),
    y=pd.concat([kag_y_train, kag_y_test], axis='index'),
    cv=4
)

# %%
results
# Out:
# array([0.70689655, 0.74005305, 0.70954907, 0.71580345])

# %%
results.mean()
# Out:
# 0.7180755316488248

# %% [markdown]
# ## Random Forest
